# %%
import pexpect
import time
import sys
import re
import datetime

# %%
child = pexpect.spawn('ssh -L 7898:localhost:8007 -J root@ip.numbers root@127.0.0.1 -p 8007', timeout=30, encoding='utf-8', logfile=sys.stdout)

child.maxread = 300000 

child.expect("root@ip.number's password: ")
child.sendline('') #Enters Password
child.expect("root@127.0.0.1's password: ")
child.sendline('') #Enters Password

time.sleep(3)

# Shell command to take after the dates in modification dates
# child.sendline('find /var/opt/common5/mdt/ -type f -newermt 2023-04-28 -exec ls -l {} \;')

# Shell command to take only the folder
# child.sendline('find /var/opt/common5/mdt/20230205 -type f -exec ls -l {} \;')

# Shell command to take certain range dates in modification dates
child.sendline('find /var/opt/common5/mdt -type f -newermt 2023-08-01 ! -newermt 2023-08-20 -exec ls -l {} \;')

try:
    child.expect(pexpect.EOF, timeout=150)

except pexpect.TIMEOUT:
    child.close()
    raw = str(child.before)
# Out:
# root@150.236.203.198's password: PMT@2022
#
# root@127.0.0.1's password: xl@cibi123
# find /var/opt/common5/mdt -type f -newermt 2023-08-01 ! -newermt 2023-08-20 -exec ls -l {} \;
#
# Last login: Tue Aug 22 16:30:19 2023 from 192.168.21.6
#  -newermt 2023-08-20 -exec ls -l {} \;xcol002p ~]# find /var/opt/common5/mdt -type f -newermt 2023-08-01 !
# -rw-r--r--. 1 root root 38492353 Aug 12 12:06 /var/opt/common5/mdt/20230812/08/ue_meas.zip
# -rw-r--r--. 1 root root 786371 Aug 12 12:20 /var/opt/common5/mdt/20230812/08/ho_counter_20230812_08.zip
# -rw-r--r--. 1 root root 26574350 Aug 12 12:08 /var/opt/common5/mdt/20230812/08/mdt_result.zip
# -rw-r--r--. 1 root root 19132528 Aug 12 12:05 /var/opt/common5/mdt/20230812/08/ue_traffic.zip
# -rw-r--r--. 1 root root 949260 Aug 12 12:04 /var/opt/common5/mdt/20230812/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 2445926 Aug 12 12:09 /var/opt/common5/mdt/20230812/08/ta_histogram.zip
# -rw-r--r--. 1 root root 40552935 Aug 13 00:09 /var/opt/common5/mdt/20230812/20/ue_meas.zip
# -rw-r--r--. 1 root root 27843039 Aug 13 00:11 /var/opt/common5/mdt/20230812/20/mdt_result.zip
# -rw-r--r--. 1 root root 817207 Aug 13 00:24 /var/opt/common5/mdt/20230812/20/ho_counter_20230812_20.zip
# -rw-r--r--. 1 root root 19886269 Aug 13 00:07 /var/opt/common5/mdt/20230812/20/ue_traffic.zip
# -rw-r--r--. 1 root root 919838 Aug 13 00:06 /var/opt/common5/mdt/20230812/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 2711237 Aug 13 00:12 /var/opt/common5/mdt/20230812/20/ta_histogram.zip
# -rw-r--r--. 1 root root 43476234 Aug 12 20:11 /var/opt/common5/mdt/20230812/16/ue_meas.zip
# -rw-r--r--. 1 root root 30843380 Aug 12 20:13 /var/opt/common5/mdt/20230812/16/mdt_result.zip
# -rw-r--r--. 1 root root 21316793 Aug 12 20:09 /var/opt/common5/mdt/20230812/16/ue_traffic.zip
# -rw-r--r--. 1 root root 827955 Aug 12 20:24 /var/opt/common5/mdt/20230812/16/ho_counter_20230812_16.zip
# -rw-r--r--. 1 root root 934935 Aug 12 20:09 /var/opt/common5/mdt/20230812/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 2571076 Aug 12 20:14 /var/opt/common5/mdt/20230812/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1213531 Aug 13 06:15 /var/opt/common5/mdt/20230812/ctr0_ho_counter_20230812.zip
# -rw-r--r--. 1 root root 57568304 Aug 13 06:35 /var/opt/common5/mdt/20230812/grid_mdt_meas_cell_20230812.zip
# -rw-r--r--. 1 root root 43931752 Aug 12 21:12 /var/opt/common5/mdt/20230812/17/ue_meas.zip
# -rw-r--r--. 1 root root 31040882 Aug 12 21:14 /var/opt/common5/mdt/20230812/17/mdt_result.zip
# -rw-r--r--. 1 root root 21520046 Aug 12 21:10 /var/opt/common5/mdt/20230812/17/ue_traffic.zip
# -rw-r--r--. 1 root root 827689 Aug 12 21:27 /var/opt/common5/mdt/20230812/17/ho_counter_20230812_17.zip
# -rw-r--r--. 1 root root 927831 Aug 12 21:09 /var/opt/common5/mdt/20230812/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 2623345 Aug 12 21:15 /var/opt/common5/mdt/20230812/17/ta_histogram.zip
# -rw-r--r--. 1 root root 42186184 Aug 12 15:11 /var/opt/common5/mdt/20230812/11/ue_meas.zip
# -rw-r--r--. 1 root root 821471 Aug 12 15:27 /var/opt/common5/mdt/20230812/11/ho_counter_20230812_11.zip
# -rw-r--r--. 1 root root 30334412 Aug 12 15:13 /var/opt/common5/mdt/20230812/11/mdt_result.zip
# -rw-r--r--. 1 root root 20706476 Aug 12 15:09 /var/opt/common5/mdt/20230812/11/ue_traffic.zip
# -rw-r--r--. 1 root root 952093 Aug 12 15:08 /var/opt/common5/mdt/20230812/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 2613931 Aug 12 15:14 /var/opt/common5/mdt/20230812/11/ta_histogram.zip
# -rw-r--r--. 1 root root 16171573 Aug 12 08:59 /var/opt/common5/mdt/20230812/05/ue_meas.zip
# -rw-r--r--. 1 root root 10949112 Aug 12 09:00 /var/opt/common5/mdt/20230812/05/mdt_result.zip
# -rw-r--r--. 1 root root 647489 Aug 12 09:07 /var/opt/common5/mdt/20230812/05/ho_counter_20230812_05.zip
# -rw-r--r--. 1 root root 8452295 Aug 12 08:58 /var/opt/common5/mdt/20230812/05/ue_traffic.zip
# -rw-r--r--. 1 root root 936596 Aug 12 08:58 /var/opt/common5/mdt/20230812/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 1933874 Aug 12 09:00 /var/opt/common5/mdt/20230812/05/ta_histogram.zip
# -rw-r--r--. 1 root root 13286782 Aug 12 05:57 /var/opt/common5/mdt/20230812/02/ue_meas.zip
# -rw-r--r--. 1 root root 8921929 Aug 12 05:58 /var/opt/common5/mdt/20230812/02/mdt_result.zip
# -rw-r--r--. 1 root root 622093 Aug 12 06:05 /var/opt/common5/mdt/20230812/02/ho_counter_20230812_02.zip
# -rw-r--r--. 1 root root 6940942 Aug 12 05:57 /var/opt/common5/mdt/20230812/02/ue_traffic.zip
# -rw-r--r--. 1 root root 927020 Aug 12 05:56 /var/opt/common5/mdt/20230812/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 1934413 Aug 12 05:58 /var/opt/common5/mdt/20230812/02/ta_histogram.zip
# -rw-r--r--. 1 root root 20316830 Aug 12 03:58 /var/opt/common5/mdt/20230812/00/ue_meas.zip
# -rw-r--r--. 1 root root 13906965 Aug 12 03:58 /var/opt/common5/mdt/20230812/00/mdt_result.zip
# -rw-r--r--. 1 root root 10373286 Aug 12 03:58 /var/opt/common5/mdt/20230812/00/ue_traffic.zip
# -rw-r--r--. 1 root root 697979 Aug 12 04:04 /var/opt/common5/mdt/20230812/00/ho_counter_20230812_00.zip
# -rw-r--r--. 1 root root 940447 Aug 12 03:57 /var/opt/common5/mdt/20230812/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 2230412 Aug 12 03:59 /var/opt/common5/mdt/20230812/00/ta_histogram.zip
# -rw-r--r--. 1 root root 32977972 Aug 12 11:03 /var/opt/common5/mdt/20230812/07/ue_meas.zip
# -rw-r--r--. 1 root root 22738849 Aug 12 11:04 /var/opt/common5/mdt/20230812/07/mdt_result.zip
# -rw-r--r--. 1 root root 762458 Aug 12 11:16 /var/opt/common5/mdt/20230812/07/ho_counter_20230812_07.zip
# -rw-r--r--. 1 root root 16575337 Aug 12 11:02 /var/opt/common5/mdt/20230812/07/ue_traffic.zip
# -rw-r--r--. 1 root root 951173 Aug 12 11:02 /var/opt/common5/mdt/20230812/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 2286782 Aug 12 11:05 /var/opt/common5/mdt/20230812/07/ta_histogram.zip
# -rw-r--r--. 1 root root 3305286 Aug 13 06:16 /var/opt/common5/mdt/20230812/ue_capability_20230812.zip
# -rw-r--r--. 1 root root 42512479 Aug 12 19:10 /var/opt/common5/mdt/20230812/15/ue_meas.zip
# -rw-r--r--. 1 root root 30098831 Aug 12 19:12 /var/opt/common5/mdt/20230812/15/mdt_result.zip
# -rw-r--r--. 1 root root 823097 Aug 12 19:22 /var/opt/common5/mdt/20230812/15/ho_counter_20230812_15.zip
# -rw-r--r--. 1 root root 20871633 Aug 12 19:08 /var/opt/common5/mdt/20230812/15/ue_traffic.zip
# -rw-r--r--. 1 root root 936830 Aug 12 19:08 /var/opt/common5/mdt/20230812/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 2568931 Aug 12 19:12 /var/opt/common5/mdt/20230812/15/ta_histogram.zip
# -rw-r--r--. 1 root root 41569976 Aug 12 14:10 /var/opt/common5/mdt/20230812/10/ue_meas.zip
# -rw-r--r--. 1 root root 29441845 Aug 12 14:12 /var/opt/common5/mdt/20230812/10/mdt_result.zip
# -rw-r--r--. 1 root root 20456921 Aug 12 14:08 /var/opt/common5/mdt/20230812/10/ue_traffic.zip
# -rw-r--r--. 1 root root 817817 Aug 12 14:26 /var/opt/common5/mdt/20230812/10/ho_counter_20230812_10.zip
# -rw-r--r--. 1 root root 929944 Aug 12 14:07 /var/opt/common5/mdt/20230812/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 2610180 Aug 12 14:13 /var/opt/common5/mdt/20230812/10/ta_histogram.zip
# -rw-r--r--. 1 root root 12140035 Aug 12 06:58 /var/opt/common5/mdt/20230812/03/ue_meas.zip
# -rw-r--r--. 1 root root 597803 Aug 12 07:07 /var/opt/common5/mdt/20230812/03/ho_counter_20230812_03.zip
# -rw-r--r--. 1 root root 8027347 Aug 12 06:59 /var/opt/common5/mdt/20230812/03/mdt_result.zip
# -rw-r--r--. 1 root root 6410391 Aug 12 06:57 /var/opt/common5/mdt/20230812/03/ue_traffic.zip
# -rw-r--r--. 1 root root 925859 Aug 12 06:57 /var/opt/common5/mdt/20230812/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 1849671 Aug 12 06:59 /var/opt/common5/mdt/20230812/03/ta_histogram.zip
# -rw-r--r--. 1 root root 37887126 Aug 13 06:30 /var/opt/common5/mdt/20230812/grid_mdt_traffic_cell_20230812.zip
# -rw-r--r--. 1 root root 42176446 Aug 12 17:10 /var/opt/common5/mdt/20230812/13/ue_meas.zip
# -rw-r--r--. 1 root root 30314384 Aug 12 17:12 /var/opt/common5/mdt/20230812/13/mdt_result.zip
# -rw-r--r--. 1 root root 20701927 Aug 12 17:09 /var/opt/common5/mdt/20230812/13/ue_traffic.zip
# -rw-r--r--. 1 root root 935231 Aug 12 17:08 /var/opt/common5/mdt/20230812/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 823071 Aug 12 17:24 /var/opt/common5/mdt/20230812/13/ho_counter_20230812_13.zip
# -rw-r--r--. 1 root root 2605102 Aug 12 17:13 /var/opt/common5/mdt/20230812/13/ta_histogram.zip
# -rw-r--r--. 1 root root 37750557 Aug 13 01:05 /var/opt/common5/mdt/20230812/21/ue_meas.zip
# -rw-r--r--. 1 root root 799461 Aug 13 01:20 /var/opt/common5/mdt/20230812/21/ho_counter_20230812_21.zip
# -rw-r--r--. 1 root root 25654592 Aug 13 01:06 /var/opt/common5/mdt/20230812/21/mdt_result.zip
# -rw-r--r--. 1 root root 18589885 Aug 13 01:04 /var/opt/common5/mdt/20230812/21/ue_traffic.zip
# -rw-r--r--. 1 root root 929370 Aug 13 01:04 /var/opt/common5/mdt/20230812/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 2665098 Aug 13 01:07 /var/opt/common5/mdt/20230812/21/ta_histogram.zip
# -rw-r--r--. 1 root root 22002007 Aug 13 06:25 /var/opt/common5/mdt/20230812/grid_mdt_cell_20230812.zip
# -rw-r--r--. 1 root root 27458293 Aug 13 03:01 /var/opt/common5/mdt/20230812/23/ue_meas.zip
# -rw-r--r--. 1 root root 18567698 Aug 13 03:02 /var/opt/common5/mdt/20230812/23/mdt_result.zip
# -rw-r--r--. 1 root root 742717 Aug 13 03:10 /var/opt/common5/mdt/20230812/23/ho_counter_20230812_23.zip
# -rw-r--r--. 1 root root 13775040 Aug 13 03:00 /var/opt/common5/mdt/20230812/23/ue_traffic.zip
# -rw-r--r--. 1 root root 936234 Aug 13 03:00 /var/opt/common5/mdt/20230812/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 2428991 Aug 13 03:02 /var/opt/common5/mdt/20230812/23/ta_histogram.zip
# -rw-r--r--. 1 root root 15393030 Aug 12 04:56 /var/opt/common5/mdt/20230812/01/ue_meas.zip
# -rw-r--r--. 1 root root 10491768 Aug 12 04:57 /var/opt/common5/mdt/20230812/01/mdt_result.zip
# -rw-r--r--. 1 root root 651780 Aug 12 05:02 /var/opt/common5/mdt/20230812/01/ho_counter_20230812_01.zip
# -rw-r--r--. 1 root root 7975578 Aug 12 04:56 /var/opt/common5/mdt/20230812/01/ue_traffic.zip
# -rw-r--r--. 1 root root 933207 Aug 12 04:56 /var/opt/common5/mdt/20230812/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 2037565 Aug 12 04:57 /var/opt/common5/mdt/20230812/01/ta_histogram.zip
# -rw-r--r--. 1 root root 42441543 Aug 12 23:10 /var/opt/common5/mdt/20230812/19/ue_meas.zip
# -rw-r--r--. 1 root root 29824451 Aug 12 23:12 /var/opt/common5/mdt/20230812/19/mdt_result.zip
# -rw-r--r--. 1 root root 20811872 Aug 12 23:09 /var/opt/common5/mdt/20230812/19/ue_traffic.zip
# -rw-r--r--. 1 root root 818586 Aug 12 23:23 /var/opt/common5/mdt/20230812/19/ho_counter_20230812_19.zip
# -rw-r--r--. 1 root root 930452 Aug 12 23:08 /var/opt/common5/mdt/20230812/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 2590925 Aug 12 23:13 /var/opt/common5/mdt/20230812/19/ta_histogram.zip
# -rw-r--r--. 1 root root 34244353 Aug 13 02:03 /var/opt/common5/mdt/20230812/22/ue_meas.zip
# -rw-r--r--. 1 root root 778512 Aug 13 02:15 /var/opt/common5/mdt/20230812/22/ho_counter_20230812_22.zip
# -rw-r--r--. 1 root root 23172895 Aug 13 02:04 /var/opt/common5/mdt/20230812/22/mdt_result.zip
# -rw-r--r--. 1 root root 16979858 Aug 13 02:03 /var/opt/common5/mdt/20230812/22/ue_traffic.zip
# -rw-r--r--. 1 root root 943723 Aug 13 02:02 /var/opt/common5/mdt/20230812/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 2568234 Aug 13 02:05 /var/opt/common5/mdt/20230812/22/ta_histogram.zip
# -rw-r--r--. 1 root root 41807525 Aug 12 16:10 /var/opt/common5/mdt/20230812/12/ue_meas.zip
# -rw-r--r--. 1 root root 29824551 Aug 12 16:12 /var/opt/common5/mdt/20230812/12/mdt_result.zip
# -rw-r--r--. 1 root root 823044 Aug 12 16:26 /var/opt/common5/mdt/20230812/12/ho_counter_20230812_12.zip
# -rw-r--r--. 1 root root 20503445 Aug 12 16:09 /var/opt/common5/mdt/20230812/12/ue_traffic.zip
# -rw-r--r--. 1 root root 929389 Aug 12 16:08 /var/opt/common5/mdt/20230812/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 2645097 Aug 12 16:13 /var/opt/common5/mdt/20230812/12/ta_histogram.zip
# -rw-r--r--. 1 root root 12805523 Aug 12 07:57 /var/opt/common5/mdt/20230812/04/ue_meas.zip
# -rw-r--r--. 1 root root 8397227 Aug 12 07:58 /var/opt/common5/mdt/20230812/04/mdt_result.zip
# -rw-r--r--. 1 root root 600663 Aug 12 08:03 /var/opt/common5/mdt/20230812/04/ho_counter_20230812_04.zip
# -rw-r--r--. 1 root root 6780993 Aug 12 07:57 /var/opt/common5/mdt/20230812/04/ue_traffic.zip
# -rw-r--r--. 1 root root 929878 Aug 12 07:57 /var/opt/common5/mdt/20230812/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 1830641 Aug 12 07:58 /var/opt/common5/mdt/20230812/04/ta_histogram.zip
# -rw-r--r--. 1 root root 823593 Aug 12 18:26 /var/opt/common5/mdt/20230812/14/ho_counter_20230812_14.zip
# -rw-r--r--. 1 root root 41397573 Aug 12 18:11 /var/opt/common5/mdt/20230812/14/ue_meas.zip
# -rw-r--r--. 1 root root 29754330 Aug 12 18:13 /var/opt/common5/mdt/20230812/14/mdt_result.zip
# -rw-r--r--. 1 root root 20318556 Aug 12 18:09 /var/opt/common5/mdt/20230812/14/ue_traffic.zip
# -rw-r--r--. 1 root root 930809 Aug 12 18:08 /var/opt/common5/mdt/20230812/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 2593837 Aug 12 18:14 /var/opt/common5/mdt/20230812/14/ta_histogram.zip
# -rw-r--r--. 1 root root 24117295 Aug 12 10:00 /var/opt/common5/mdt/20230812/06/ue_meas.zip
# -rw-r--r--. 1 root root 715735 Aug 12 10:10 /var/opt/common5/mdt/20230812/06/ho_counter_20230812_06.zip
# -rw-r--r--. 1 root root 16593747 Aug 12 10:01 /var/opt/common5/mdt/20230812/06/mdt_result.zip
# -rw-r--r--. 1 root root 12339407 Aug 12 10:00 /var/opt/common5/mdt/20230812/06/ue_traffic.zip
# -rw-r--r--. 1 root root 946924 Aug 12 10:00 /var/opt/common5/mdt/20230812/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 2154642 Aug 12 10:01 /var/opt/common5/mdt/20230812/06/ta_histogram.zip
# -rw-r--r--. 1 root root 43671603 Aug 12 22:10 /var/opt/common5/mdt/20230812/18/ue_meas.zip
# -rw-r--r--. 1 root root 30736467 Aug 12 22:12 /var/opt/common5/mdt/20230812/18/mdt_result.zip
# -rw-r--r--. 1 root root 818904 Aug 12 22:24 /var/opt/common5/mdt/20230812/18/ho_counter_20230812_18.zip
# -rw-r--r--. 1 root root 21446375 Aug 12 22:08 /var/opt/common5/mdt/20230812/18/ue_traffic.zip
# -rw-r--r--. 1 root root 933088 Aug 12 22:07 /var/opt/common5/mdt/20230812/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 2594706 Aug 12 22:13 /var/opt/common5/mdt/20230812/18/ta_histogram.zip
# -rw-r--r--. 1 root root 41809920 Aug 12 13:08 /var/opt/common5/mdt/20230812/09/ue_meas.zip
# -rw-r--r--. 1 root root 29294973 Aug 12 13:10 /var/opt/common5/mdt/20230812/09/mdt_result.zip
# -rw-r--r--. 1 root root 806046 Aug 12 13:22 /var/opt/common5/mdt/20230812/09/ho_counter_20230812_09.zip
# -rw-r--r--. 1 root root 20665589 Aug 12 13:07 /var/opt/common5/mdt/20230812/09/ue_traffic.zip
# -rw-r--r--. 1 root root 951146 Aug 12 13:06 /var/opt/common5/mdt/20230812/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 2520217 Aug 12 13:11 /var/opt/common5/mdt/20230812/09/ta_histogram.zip
# -rw-r--r--. 1 root root 42344610 Aug  7 12:12 /var/opt/common5/mdt/20230807/08/ue_meas.zip
# -rw-r--r--. 1 root root 30303840 Aug  7 12:14 /var/opt/common5/mdt/20230807/08/mdt_result.zip
# -rw-r--r--. 1 root root 820579 Aug  7 12:27 /var/opt/common5/mdt/20230807/08/ho_counter_20230807_08.zip
# -rw-r--r--. 1 root root 21098155 Aug  7 12:11 /var/opt/common5/mdt/20230807/08/ue_traffic.zip
# -rw-r--r--. 1 root root 960630 Aug  7 12:10 /var/opt/common5/mdt/20230807/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 2601065 Aug  7 12:15 /var/opt/common5/mdt/20230807/08/ta_histogram.zip
# -rw-r--r--. 1 root root 40588603 Aug  8 00:08 /var/opt/common5/mdt/20230807/20/ue_meas.zip
# -rw-r--r--. 1 root root 28912121 Aug  8 00:10 /var/opt/common5/mdt/20230807/20/mdt_result.zip
# -rw-r--r--. 1 root root 810141 Aug  8 00:25 /var/opt/common5/mdt/20230807/20/ho_counter_20230807_20.zip
# -rw-r--r--. 1 root root 20074235 Aug  8 00:07 /var/opt/common5/mdt/20230807/20/ue_traffic.zip
# -rw-r--r--. 1 root root 944077 Aug  8 00:06 /var/opt/common5/mdt/20230807/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 2815285 Aug  8 00:11 /var/opt/common5/mdt/20230807/20/ta_histogram.zip
# -rw-r--r--. 1 root root 835109 Aug  7 20:34 /var/opt/common5/mdt/20230807/16/ho_counter_20230807_16.zip
# -rw-r--r--. 1 root root 44021217 Aug  7 20:16 /var/opt/common5/mdt/20230807/16/ue_meas.zip
# -rw-r--r--. 1 root root 32091488 Aug  7 20:18 /var/opt/common5/mdt/20230807/16/mdt_result.zip
# -rw-r--r--. 1 root root 21711067 Aug  7 20:14 /var/opt/common5/mdt/20230807/16/ue_traffic.zip
# -rw-r--r--. 1 root root 950099 Aug  7 20:13 /var/opt/common5/mdt/20230807/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 2773073 Aug  7 20:19 /var/opt/common5/mdt/20230807/16/ta_histogram.zip
# -rw-r--r--. 1 root root 50640147 Aug 16 20:55 /var/opt/common5/mdt/20230807/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 46415417 Aug  7 21:14 /var/opt/common5/mdt/20230807/17/ue_meas.zip
# -rw-r--r--. 1 root root 842994 Aug  7 21:29 /var/opt/common5/mdt/20230807/17/ho_counter_20230807_17.zip
# -rw-r--r--. 1 root root 33619812 Aug  7 21:16 /var/opt/common5/mdt/20230807/17/mdt_result.zip
# -rw-r--r--. 1 root root 22873247 Aug  7 21:12 /var/opt/common5/mdt/20230807/17/ue_traffic.zip
# -rw-r--r--. 1 root root 945809 Aug  7 21:11 /var/opt/common5/mdt/20230807/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 2731170 Aug  7 21:17 /var/opt/common5/mdt/20230807/17/ta_histogram.zip
# -rw-r--r--. 1 root root 41374698 Aug  7 15:14 /var/opt/common5/mdt/20230807/11/ue_meas.zip
# -rw-r--r--. 1 root root 30013398 Aug  7 15:16 /var/opt/common5/mdt/20230807/11/mdt_result.zip
# -rw-r--r--. 1 root root 20467164 Aug  7 15:12 /var/opt/common5/mdt/20230807/11/ue_traffic.zip
# -rw-r--r--. 1 root root 832107 Aug  7 15:30 /var/opt/common5/mdt/20230807/11/ho_counter_20230807_11.zip
# -rw-r--r--. 1 root root 951970 Aug  7 15:11 /var/opt/common5/mdt/20230807/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 2730194 Aug  7 15:17 /var/opt/common5/mdt/20230807/11/ta_histogram.zip
# -rw-r--r--. 1 root root 17817386 Aug  7 08:59 /var/opt/common5/mdt/20230807/05/ue_meas.zip
# -rw-r--r--. 1 root root 12198709 Aug  7 08:59 /var/opt/common5/mdt/20230807/05/mdt_result.zip
# -rw-r--r--. 1 root root 662528 Aug  7 09:06 /var/opt/common5/mdt/20230807/05/ho_counter_20230807_05.zip
# -rw-r--r--. 1 root root 9362090 Aug  7 08:59 /var/opt/common5/mdt/20230807/05/ue_traffic.zip
# -rw-r--r--. 1 root root 926691 Aug  7 08:58 /var/opt/common5/mdt/20230807/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 1951386 Aug  7 09:00 /var/opt/common5/mdt/20230807/05/ta_histogram.zip
# -rw-r--r--. 1 root root 22401448 Aug  8 06:28 /var/opt/common5/mdt/20230807/grid_mdt_cell_20230807.zip
# -rw-r--r--. 1 root root 53739032 Aug 16 20:54 /var/opt/common5/mdt/20230807/filter_mdt_result.zip
# -rw-r--r--. 1 root root 11915717 Aug  7 05:56 /var/opt/common5/mdt/20230807/02/ue_meas.zip
# -rw-r--r--. 1 root root 592548 Aug  7 06:01 /var/opt/common5/mdt/20230807/02/ho_counter_20230807_02.zip
# -rw-r--r--. 1 root root 8013291 Aug  7 05:56 /var/opt/common5/mdt/20230807/02/mdt_result.zip
# -rw-r--r--. 1 root root 6318791 Aug  7 05:55 /var/opt/common5/mdt/20230807/02/ue_traffic.zip
# -rw-r--r--. 1 root root 910045 Aug  7 05:55 /var/opt/common5/mdt/20230807/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 1859570 Aug  7 05:56 /var/opt/common5/mdt/20230807/02/ta_histogram.zip
# -rw-r--r--. 1 root root 18143268 Aug  7 03:58 /var/opt/common5/mdt/20230807/00/ue_meas.zip
# -rw-r--r--. 1 root root 12493882 Aug  7 03:58 /var/opt/common5/mdt/20230807/00/mdt_result.zip
# -rw-r--r--. 1 root root 666843 Aug  7 04:04 /var/opt/common5/mdt/20230807/00/ho_counter_20230807_00.zip
# -rw-r--r--. 1 root root 9393555 Aug  7 03:58 /var/opt/common5/mdt/20230807/00/ue_traffic.zip
# -rw-r--r--. 1 root root 934139 Aug  7 03:57 /var/opt/common5/mdt/20230807/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 2163090 Aug  7 03:59 /var/opt/common5/mdt/20230807/00/ta_histogram.zip
# -rw-r--r--. 1 root root 800431 Aug  7 11:27 /var/opt/common5/mdt/20230807/07/ho_counter_20230807_07.zip
# -rw-r--r--. 1 root root 39961756 Aug  7 11:11 /var/opt/common5/mdt/20230807/07/ue_meas.zip
# -rw-r--r--. 1 root root 28482288 Aug  7 11:13 /var/opt/common5/mdt/20230807/07/mdt_result.zip
# -rw-r--r--. 1 root root 20093923 Aug  7 11:09 /var/opt/common5/mdt/20230807/07/ue_traffic.zip
# -rw-r--r--. 1 root root 971534 Aug  7 11:08 /var/opt/common5/mdt/20230807/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 2427938 Aug  7 11:14 /var/opt/common5/mdt/20230807/07/ta_histogram.zip
# -rw-r--r--. 1 root root 43446307 Aug  7 19:15 /var/opt/common5/mdt/20230807/15/ue_meas.zip
# -rw-r--r--. 1 root root 31415791 Aug  7 19:17 /var/opt/common5/mdt/20230807/15/mdt_result.zip
# -rw-r--r--. 1 root root 835829 Aug  7 19:30 /var/opt/common5/mdt/20230807/15/ho_counter_20230807_15.zip
# -rw-r--r--. 1 root root 21441579 Aug  7 19:13 /var/opt/common5/mdt/20230807/15/ue_traffic.zip
# -rw-r--r--. 1 root root 966890 Aug  7 19:12 /var/opt/common5/mdt/20230807/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 2797009 Aug  7 19:18 /var/opt/common5/mdt/20230807/15/ta_histogram.zip
# -rw-r--r--. 1 root root 41615988 Aug  7 14:13 /var/opt/common5/mdt/20230807/10/ue_meas.zip
# -rw-r--r--. 1 root root 30121349 Aug  7 14:15 /var/opt/common5/mdt/20230807/10/mdt_result.zip
# -rw-r--r--. 1 root root 832189 Aug  7 14:29 /var/opt/common5/mdt/20230807/10/ho_counter_20230807_10.zip
# -rw-r--r--. 1 root root 20598778 Aug  7 14:11 /var/opt/common5/mdt/20230807/10/ue_traffic.zip
# -rw-r--r--. 1 root root 957224 Aug  7 14:10 /var/opt/common5/mdt/20230807/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 2734739 Aug  7 14:16 /var/opt/common5/mdt/20230807/10/ta_histogram.zip
# -rw-r--r--. 1 root root 11427955 Aug  7 06:57 /var/opt/common5/mdt/20230807/03/ue_meas.zip
# -rw-r--r--. 1 root root 7558232 Aug  7 06:57 /var/opt/common5/mdt/20230807/03/mdt_result.zip
# -rw-r--r--. 1 root root 579843 Aug  7 07:02 /var/opt/common5/mdt/20230807/03/ho_counter_20230807_03.zip
# -rw-r--r--. 1 root root 6110454 Aug  7 06:56 /var/opt/common5/mdt/20230807/03/ue_traffic.zip
# -rw-r--r--. 1 root root 908953 Aug  7 06:56 /var/opt/common5/mdt/20230807/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 1801524 Aug  7 06:57 /var/opt/common5/mdt/20230807/03/ta_histogram.zip
# -rw-r--r--. 1 root root 3320431 Aug  8 06:16 /var/opt/common5/mdt/20230807/ue_capability_20230807.zip
# -rw-r--r--. 1 root root 58240733 Aug  8 06:39 /var/opt/common5/mdt/20230807/grid_mdt_meas_cell_20230807.zip
# -rw-r--r--. 1 root root 40896612 Aug  7 17:13 /var/opt/common5/mdt/20230807/13/ue_meas.zip
# -rw-r--r--. 1 root root 835762 Aug  7 17:29 /var/opt/common5/mdt/20230807/13/ho_counter_20230807_13.zip
# -rw-r--r--. 1 root root 29687597 Aug  7 17:15 /var/opt/common5/mdt/20230807/13/mdt_result.zip
# -rw-r--r--. 1 root root 20249751 Aug  7 17:12 /var/opt/common5/mdt/20230807/13/ue_traffic.zip
# -rw-r--r--. 1 root root 956448 Aug  7 17:11 /var/opt/common5/mdt/20230807/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 2816218 Aug  7 17:16 /var/opt/common5/mdt/20230807/13/ta_histogram.zip
# -rw-r--r--. 1 root root 35499244 Aug  8 01:05 /var/opt/common5/mdt/20230807/21/ue_meas.zip
# -rw-r--r--. 1 root root 786221 Aug  8 01:22 /var/opt/common5/mdt/20230807/21/ho_counter_20230807_21.zip
# -rw-r--r--. 1 root root 24935783 Aug  8 01:07 /var/opt/common5/mdt/20230807/21/mdt_result.zip
# -rw-r--r--. 1 root root 17695191 Aug  8 01:05 /var/opt/common5/mdt/20230807/21/ue_traffic.zip
# -rw-r--r--. 1 root root 941083 Aug  8 01:04 /var/opt/common5/mdt/20230807/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 2760461 Aug  8 01:08 /var/opt/common5/mdt/20230807/21/ta_histogram.zip
# -rw-r--r--. 1 root root 23118432 Aug  8 03:00 /var/opt/common5/mdt/20230807/23/ue_meas.zip
# -rw-r--r--. 1 root root 16112817 Aug  8 03:01 /var/opt/common5/mdt/20230807/23/mdt_result.zip
# -rw-r--r--. 1 root root 11800215 Aug  8 03:00 /var/opt/common5/mdt/20230807/23/ue_traffic.zip
# -rw-r--r--. 1 root root 936115 Aug  8 02:59 /var/opt/common5/mdt/20230807/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 711236 Aug  8 03:09 /var/opt/common5/mdt/20230807/23/ho_counter_20230807_23.zip
# -rw-r--r--. 1 root root 2414090 Aug  8 03:01 /var/opt/common5/mdt/20230807/23/ta_histogram.zip
# -rw-r--r--. 1 root root 1218960 Aug  8 06:15 /var/opt/common5/mdt/20230807/ctr0_ho_counter_20230807.zip
# -rw-r--r--. 1 root root 13970330 Aug  7 04:57 /var/opt/common5/mdt/20230807/01/ue_meas.zip
# -rw-r--r--. 1 root root 9487089 Aug  7 04:58 /var/opt/common5/mdt/20230807/01/mdt_result.zip
# -rw-r--r--. 1 root root 619436 Aug  7 05:03 /var/opt/common5/mdt/20230807/01/ho_counter_20230807_01.zip
# -rw-r--r--. 1 root root 7329485 Aug  7 04:57 /var/opt/common5/mdt/20230807/01/ue_traffic.zip
# -rw-r--r--. 1 root root 920202 Aug  7 04:56 /var/opt/common5/mdt/20230807/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 1965861 Aug  7 04:58 /var/opt/common5/mdt/20230807/01/ta_histogram.zip
# -rw-r--r--. 1 root root 41209276 Aug  7 23:11 /var/opt/common5/mdt/20230807/19/ue_meas.zip
# -rw-r--r--. 1 root root 29876052 Aug  7 23:13 /var/opt/common5/mdt/20230807/19/mdt_result.zip
# -rw-r--r--. 1 root root 799917 Aug  7 23:27 /var/opt/common5/mdt/20230807/19/ho_counter_20230807_19.zip
# -rw-r--r--. 1 root root 20382745 Aug  7 23:09 /var/opt/common5/mdt/20230807/19/ue_traffic.zip
# -rw-r--r--. 1 root root 931944 Aug  7 23:08 /var/opt/common5/mdt/20230807/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 2665243 Aug  7 23:14 /var/opt/common5/mdt/20230807/19/ta_histogram.zip
# -rw-r--r--. 1 root root 29877328 Aug  8 02:03 /var/opt/common5/mdt/20230807/22/ue_meas.zip
# -rw-r--r--. 1 root root 20765762 Aug  8 02:04 /var/opt/common5/mdt/20230807/22/mdt_result.zip
# -rw-r--r--. 1 root root 752074 Aug  8 02:15 /var/opt/common5/mdt/20230807/22/ho_counter_20230807_22.zip
# -rw-r--r--. 1 root root 15042714 Aug  8 02:02 /var/opt/common5/mdt/20230807/22/ue_traffic.zip
# -rw-r--r--. 1 root root 944510 Aug  8 02:02 /var/opt/common5/mdt/20230807/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 2650211 Aug  8 02:04 /var/opt/common5/mdt/20230807/22/ta_histogram.zip
# -rw-r--r--. 1 root root 42006667 Aug  7 16:15 /var/opt/common5/mdt/20230807/12/ue_meas.zip
# -rw-r--r--. 1 root root 839026 Aug  7 16:32 /var/opt/common5/mdt/20230807/12/ho_counter_20230807_12.zip
# -rw-r--r--. 1 root root 30148929 Aug  7 16:17 /var/opt/common5/mdt/20230807/12/mdt_result.zip
# -rw-r--r--. 1 root root 20747298 Aug  7 16:13 /var/opt/common5/mdt/20230807/12/ue_traffic.zip
# -rw-r--r--. 1 root root 948689 Aug  7 16:12 /var/opt/common5/mdt/20230807/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 2812020 Aug  7 16:18 /var/opt/common5/mdt/20230807/12/ta_histogram.zip
# -rw-r--r--. 1 root root 12446194 Aug  7 07:58 /var/opt/common5/mdt/20230807/04/ue_meas.zip
# -rw-r--r--. 1 root root 8182201 Aug  7 07:58 /var/opt/common5/mdt/20230807/04/mdt_result.zip
# -rw-r--r--. 1 root root 593784 Aug  7 08:04 /var/opt/common5/mdt/20230807/04/ho_counter_20230807_04.zip
# -rw-r--r--. 1 root root 6659957 Aug  7 07:58 /var/opt/common5/mdt/20230807/04/ue_traffic.zip
# -rw-r--r--. 1 root root 914980 Aug  7 07:57 /var/opt/common5/mdt/20230807/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 1801251 Aug  7 07:58 /var/opt/common5/mdt/20230807/04/ta_histogram.zip
# -rw-r--r--. 1 root root 38569162 Aug  8 06:34 /var/opt/common5/mdt/20230807/grid_mdt_traffic_cell_20230807.zip
# -rw-r--r--. 1 root root 101472015 Aug 16 20:57 /var/opt/common5/mdt/20230807/filter_ue_meas.zip
# -rw-r--r--. 1 root root 40915303 Aug  7 18:14 /var/opt/common5/mdt/20230807/14/ue_meas.zip
# -rw-r--r--. 1 root root 29787173 Aug  7 18:16 /var/opt/common5/mdt/20230807/14/mdt_result.zip
# -rw-r--r--. 1 root root 833911 Aug  7 18:29 /var/opt/common5/mdt/20230807/14/ho_counter_20230807_14.zip
# -rw-r--r--. 1 root root 20222850 Aug  7 18:12 /var/opt/common5/mdt/20230807/14/ue_traffic.zip
# -rw-r--r--. 1 root root 956649 Aug  7 18:11 /var/opt/common5/mdt/20230807/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 2785529 Aug  7 18:17 /var/opt/common5/mdt/20230807/14/ta_histogram.zip
# -rw-r--r--. 1 root root 30369705 Aug  7 10:06 /var/opt/common5/mdt/20230807/06/ue_meas.zip
# -rw-r--r--. 1 root root 21720486 Aug  7 10:08 /var/opt/common5/mdt/20230807/06/mdt_result.zip
# -rw-r--r--. 1 root root 15482213 Aug  7 10:05 /var/opt/common5/mdt/20230807/06/ue_traffic.zip
# -rw-r--r--. 1 root root 936811 Aug  7 10:04 /var/opt/common5/mdt/20230807/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 2165285 Aug  7 10:09 /var/opt/common5/mdt/20230807/06/ta_histogram.zip
# -rw-r--r--. 1 root root 742146 Aug  7 10:20 /var/opt/common5/mdt/20230807/06/ho_counter_20230807_06.zip
# -rw-r--r--. 1 root root 45149791 Aug  7 22:12 /var/opt/common5/mdt/20230807/18/ue_meas.zip
# -rw-r--r--. 1 root root 832523 Aug  7 22:30 /var/opt/common5/mdt/20230807/18/ho_counter_20230807_18.zip
# -rw-r--r--. 1 root root 32725819 Aug  7 22:14 /var/opt/common5/mdt/20230807/18/mdt_result.zip
# -rw-r--r--. 1 root root 22299735 Aug  7 22:10 /var/opt/common5/mdt/20230807/18/ue_traffic.zip
# -rw-r--r--. 1 root root 939880 Aug  7 22:09 /var/opt/common5/mdt/20230807/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 2763225 Aug  7 22:15 /var/opt/common5/mdt/20230807/18/ta_histogram.zip
# -rw-r--r--. 1 root root 42778441 Aug  7 13:13 /var/opt/common5/mdt/20230807/09/ue_meas.zip
# -rw-r--r--. 1 root root 30540394 Aug  7 13:15 /var/opt/common5/mdt/20230807/09/mdt_result.zip
# -rw-r--r--. 1 root root 21211714 Aug  7 13:11 /var/opt/common5/mdt/20230807/09/ue_traffic.zip
# -rw-r--r--. 1 root root 826141 Aug  7 13:29 /var/opt/common5/mdt/20230807/09/ho_counter_20230807_09.zip
# -rw-r--r--. 1 root root 955976 Aug  7 13:10 /var/opt/common5/mdt/20230807/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 2686324 Aug  7 13:16 /var/opt/common5/mdt/20230807/09/ta_histogram.zip
# -rw-r--r--. 1 root root 37919117 Aug 17 12:07 /var/opt/common5/mdt/20230817/08/ue_meas.zip
# -rw-r--r--. 1 root root 25784350 Aug 17 12:09 /var/opt/common5/mdt/20230817/08/mdt_result.zip
# -rw-r--r--. 1 root root 791866 Aug 17 12:21 /var/opt/common5/mdt/20230817/08/ho_counter_20230817_08.zip
# -rw-r--r--. 1 root root 18785341 Aug 17 12:05 /var/opt/common5/mdt/20230817/08/ue_traffic.zip
# -rw-r--r--. 1 root root 944147 Aug 17 12:05 /var/opt/common5/mdt/20230817/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 2410767 Aug 17 12:09 /var/opt/common5/mdt/20230817/08/ta_histogram.zip
# -rw-r--r--. 1 root root 37409047 Aug 18 00:04 /var/opt/common5/mdt/20230817/20/ue_meas.zip
# -rw-r--r--. 1 root root 25558374 Aug 18 00:05 /var/opt/common5/mdt/20230817/20/mdt_result.zip
# -rw-r--r--. 1 root root 18413746 Aug 18 00:04 /var/opt/common5/mdt/20230817/20/ue_traffic.zip
# -rw-r--r--. 1 root root 802189 Aug 18 00:17 /var/opt/common5/mdt/20230817/20/ho_counter_20230817_20.zip
# -rw-r--r--. 1 root root 942628 Aug 18 00:03 /var/opt/common5/mdt/20230817/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 2686023 Aug 18 00:05 /var/opt/common5/mdt/20230817/20/ta_histogram.zip
# -rw-r--r--. 1 root root 37553051 Aug 17 20:08 /var/opt/common5/mdt/20230817/16/ue_meas.zip
# -rw-r--r--. 1 root root 25789000 Aug 17 20:10 /var/opt/common5/mdt/20230817/16/mdt_result.zip
# -rw-r--r--. 1 root root 18533686 Aug 17 20:06 /var/opt/common5/mdt/20230817/16/ue_traffic.zip
# -rw-r--r--. 1 root root 806578 Aug 17 20:23 /var/opt/common5/mdt/20230817/16/ho_counter_20230817_16.zip
# -rw-r--r--. 1 root root 916268 Aug 17 20:05 /var/opt/common5/mdt/20230817/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 2570889 Aug 17 20:11 /var/opt/common5/mdt/20230817/16/ta_histogram.zip
# -rw-r--r--. 1 root root 20872070 Aug 18 06:23 /var/opt/common5/mdt/20230817/grid_mdt_cell_20230817.zip
# -rw-r--r--. 1 root root 39436208 Aug 17 21:08 /var/opt/common5/mdt/20230817/17/ue_meas.zip
# -rw-r--r--. 1 root root 811268 Aug 17 21:25 /var/opt/common5/mdt/20230817/17/ho_counter_20230817_17.zip
# -rw-r--r--. 1 root root 27020507 Aug 17 21:10 /var/opt/common5/mdt/20230817/17/mdt_result.zip
# -rw-r--r--. 1 root root 19464836 Aug 17 21:06 /var/opt/common5/mdt/20230817/17/ue_traffic.zip
# -rw-r--r--. 1 root root 931721 Aug 17 21:05 /var/opt/common5/mdt/20230817/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 2556105 Aug 17 21:11 /var/opt/common5/mdt/20230817/17/ta_histogram.zip
# -rw-r--r--. 1 root root 37276624 Aug 17 15:09 /var/opt/common5/mdt/20230817/11/ue_meas.zip
# -rw-r--r--. 1 root root 25540925 Aug 17 15:11 /var/opt/common5/mdt/20230817/11/mdt_result.zip
# -rw-r--r--. 1 root root 810262 Aug 17 15:25 /var/opt/common5/mdt/20230817/11/ho_counter_20230817_11.zip
# -rw-r--r--. 1 root root 18388770 Aug 17 15:07 /var/opt/common5/mdt/20230817/11/ue_traffic.zip
# -rw-r--r--. 1 root root 928190 Aug 17 15:06 /var/opt/common5/mdt/20230817/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 2575482 Aug 17 15:12 /var/opt/common5/mdt/20230817/11/ta_histogram.zip
# -rw-r--r--. 1 root root 17537586 Aug 17 09:01 /var/opt/common5/mdt/20230817/05/ue_meas.zip
# -rw-r--r--. 1 root root 11759403 Aug 17 09:02 /var/opt/common5/mdt/20230817/05/mdt_result.zip
# -rw-r--r--. 1 root root 9110619 Aug 17 09:00 /var/opt/common5/mdt/20230817/05/ue_traffic.zip
# -rw-r--r--. 1 root root 664790 Aug 17 09:14 /var/opt/common5/mdt/20230817/05/ho_counter_20230817_05.zip
# -rw-r--r--. 1 root root 939577 Aug 17 08:59 /var/opt/common5/mdt/20230817/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 1946077 Aug 17 09:03 /var/opt/common5/mdt/20230817/05/ta_histogram.zip
# -rw-r--r--. 1 root root 13507160 Aug 17 05:58 /var/opt/common5/mdt/20230817/02/ue_meas.zip
# -rw-r--r--. 1 root root 612664 Aug 17 06:07 /var/opt/common5/mdt/20230817/02/ho_counter_20230817_02.zip
# -rw-r--r--. 1 root root 8963658 Aug 17 05:58 /var/opt/common5/mdt/20230817/02/mdt_result.zip
# -rw-r--r--. 1 root root 7025781 Aug 17 05:57 /var/opt/common5/mdt/20230817/02/ue_traffic.zip
# -rw-r--r--. 1 root root 909658 Aug 17 05:57 /var/opt/common5/mdt/20230817/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 1900391 Aug 17 05:59 /var/opt/common5/mdt/20230817/02/ta_histogram.zip
# -rw-r--r--. 1 root root 20732927 Aug 17 03:58 /var/opt/common5/mdt/20230817/00/ue_meas.zip
# -rw-r--r--. 1 root root 14018022 Aug 17 03:59 /var/opt/common5/mdt/20230817/00/mdt_result.zip
# -rw-r--r--. 1 root root 697003 Aug 17 04:05 /var/opt/common5/mdt/20230817/00/ho_counter_20230817_00.zip
# -rw-r--r--. 1 root root 10526641 Aug 17 03:58 /var/opt/common5/mdt/20230817/00/ue_traffic.zip
# -rw-r--r--. 1 root root 921929 Aug 17 03:58 /var/opt/common5/mdt/20230817/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 2214072 Aug 17 03:59 /var/opt/common5/mdt/20230817/00/ta_histogram.zip
# -rw-r--r--. 1 root root 758435 Aug 17 11:14 /var/opt/common5/mdt/20230817/07/ho_counter_20230817_07.zip
# -rw-r--r--. 1 root root 32056719 Aug 17 11:03 /var/opt/common5/mdt/20230817/07/ue_meas.zip
# -rw-r--r--. 1 root root 22040343 Aug 17 11:04 /var/opt/common5/mdt/20230817/07/mdt_result.zip
# -rw-r--r--. 1 root root 16064330 Aug 17 11:03 /var/opt/common5/mdt/20230817/07/ue_traffic.zip
# -rw-r--r--. 1 root root 955174 Aug 17 11:03 /var/opt/common5/mdt/20230817/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 2285088 Aug 17 11:05 /var/opt/common5/mdt/20230817/07/ta_histogram.zip
# -rw-r--r--. 1 root root 36714389 Aug 17 19:08 /var/opt/common5/mdt/20230817/15/ue_meas.zip
# -rw-r--r--. 1 root root 804044 Aug 17 19:23 /var/opt/common5/mdt/20230817/15/ho_counter_20230817_15.zip
# -rw-r--r--. 1 root root 25272362 Aug 17 19:11 /var/opt/common5/mdt/20230817/15/mdt_result.zip
# -rw-r--r--. 1 root root 18125848 Aug 17 19:07 /var/opt/common5/mdt/20230817/15/ue_traffic.zip
# -rw-r--r--. 1 root root 933469 Aug 17 19:06 /var/opt/common5/mdt/20230817/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 2556523 Aug 17 19:12 /var/opt/common5/mdt/20230817/15/ta_histogram.zip
# -rw-r--r--. 1 root root 39947312 Aug 17 14:09 /var/opt/common5/mdt/20230817/10/ue_meas.zip
# -rw-r--r--. 1 root root 27205142 Aug 17 14:11 /var/opt/common5/mdt/20230817/10/mdt_result.zip
# -rw-r--r--. 1 root root 808341 Aug 17 14:25 /var/opt/common5/mdt/20230817/10/ho_counter_20230817_10.zip
# -rw-r--r--. 1 root root 19684936 Aug 17 14:07 /var/opt/common5/mdt/20230817/10/ue_traffic.zip
# -rw-r--r--. 1 root root 938860 Aug 17 14:06 /var/opt/common5/mdt/20230817/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 2585247 Aug 17 14:12 /var/opt/common5/mdt/20230817/10/ta_histogram.zip
# -rw-r--r--. 1 root root 54936750 Aug 18 06:32 /var/opt/common5/mdt/20230817/grid_mdt_meas_cell_20230817.zip
# -rw-r--r--. 1 root root 3290917 Aug 18 06:16 /var/opt/common5/mdt/20230817/ue_capability_20230817.zip
# -rw-r--r--. 1 root root 12129188 Aug 17 06:56 /var/opt/common5/mdt/20230817/03/ue_meas.zip
# -rw-r--r--. 1 root root 593653 Aug 17 07:01 /var/opt/common5/mdt/20230817/03/ho_counter_20230817_03.zip
# -rw-r--r--. 1 root root 7951705 Aug 17 06:56 /var/opt/common5/mdt/20230817/03/mdt_result.zip
# -rw-r--r--. 1 root root 6373978 Aug 17 06:55 /var/opt/common5/mdt/20230817/03/ue_traffic.zip
# -rw-r--r--. 1 root root 905639 Aug 17 06:55 /var/opt/common5/mdt/20230817/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 1821401 Aug 17 06:56 /var/opt/common5/mdt/20230817/03/ta_histogram.zip
# -rw-r--r--. 1 root root 36851187 Aug 17 17:08 /var/opt/common5/mdt/20230817/13/ue_meas.zip
# -rw-r--r--. 1 root root 25543034 Aug 17 17:09 /var/opt/common5/mdt/20230817/13/mdt_result.zip
# -rw-r--r--. 1 root root 805709 Aug 17 17:23 /var/opt/common5/mdt/20230817/13/ho_counter_20230817_13.zip
# -rw-r--r--. 1 root root 18151777 Aug 17 17:06 /var/opt/common5/mdt/20230817/13/ue_traffic.zip
# -rw-r--r--. 1 root root 929001 Aug 17 17:05 /var/opt/common5/mdt/20230817/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 2525255 Aug 17 17:11 /var/opt/common5/mdt/20230817/13/ta_histogram.zip
# -rw-r--r--. 1 root root 32555076 Aug 18 01:03 /var/opt/common5/mdt/20230817/21/ue_meas.zip
# -rw-r--r--. 1 root root 22019442 Aug 18 01:04 /var/opt/common5/mdt/20230817/21/mdt_result.zip
# -rw-r--r--. 1 root root 784870 Aug 18 01:14 /var/opt/common5/mdt/20230817/21/ho_counter_20230817_21.zip
# -rw-r--r--. 1 root root 16125652 Aug 18 01:02 /var/opt/common5/mdt/20230817/21/ue_traffic.zip
# -rw-r--r--. 1 root root 931734 Aug 18 01:02 /var/opt/common5/mdt/20230817/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 2661445 Aug 18 01:04 /var/opt/common5/mdt/20230817/21/ta_histogram.zip
# -rw-r--r--. 1 root root 21897418 Aug 18 02:59 /var/opt/common5/mdt/20230817/23/ue_meas.zip
# -rw-r--r--. 1 root root 14910006 Aug 18 02:59 /var/opt/common5/mdt/20230817/23/mdt_result.zip
# -rw-r--r--. 1 root root 709829 Aug 18 03:05 /var/opt/common5/mdt/20230817/23/ho_counter_20230817_23.zip
# -rw-r--r--. 1 root root 11092423 Aug 18 02:58 /var/opt/common5/mdt/20230817/23/ue_traffic.zip
# -rw-r--r--. 1 root root 940137 Aug 18 02:58 /var/opt/common5/mdt/20230817/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 2297230 Aug 18 02:59 /var/opt/common5/mdt/20230817/23/ta_histogram.zip
# -rw-r--r--. 1 root root 16027158 Aug 17 04:57 /var/opt/common5/mdt/20230817/01/ue_meas.zip
# -rw-r--r--. 1 root root 10831243 Aug 17 04:57 /var/opt/common5/mdt/20230817/01/mdt_result.zip
# -rw-r--r--. 1 root root 648601 Aug 17 05:03 /var/opt/common5/mdt/20230817/01/ho_counter_20230817_01.zip
# -rw-r--r--. 1 root root 8250909 Aug 17 04:56 /var/opt/common5/mdt/20230817/01/ue_traffic.zip
# -rw-r--r--. 1 root root 927704 Aug 17 04:56 /var/opt/common5/mdt/20230817/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 2022200 Aug 17 04:57 /var/opt/common5/mdt/20230817/01/ta_histogram.zip
# -rw-r--r--. 1 root root 37548838 Aug 17 23:08 /var/opt/common5/mdt/20230817/19/ue_meas.zip
# -rw-r--r--. 1 root root 25947541 Aug 17 23:10 /var/opt/common5/mdt/20230817/19/mdt_result.zip
# -rw-r--r--. 1 root root 807092 Aug 17 23:22 /var/opt/common5/mdt/20230817/19/ho_counter_20230817_19.zip
# -rw-r--r--. 1 root root 18487603 Aug 17 23:06 /var/opt/common5/mdt/20230817/19/ue_traffic.zip
# -rw-r--r--. 1 root root 933612 Aug 17 23:05 /var/opt/common5/mdt/20230817/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 2647105 Aug 17 23:11 /var/opt/common5/mdt/20230817/19/ta_histogram.zip
# -rw-r--r--. 1 root root 27984024 Aug 18 02:01 /var/opt/common5/mdt/20230817/22/ue_meas.zip
# -rw-r--r--. 1 root root 18906073 Aug 18 02:01 /var/opt/common5/mdt/20230817/22/mdt_result.zip
# -rw-r--r--. 1 root root 13982420 Aug 18 02:00 /var/opt/common5/mdt/20230817/22/ue_traffic.zip
# -rw-r--r--. 1 root root 751892 Aug 18 02:09 /var/opt/common5/mdt/20230817/22/ho_counter_20230817_22.zip
# -rw-r--r--. 1 root root 937044 Aug 18 02:00 /var/opt/common5/mdt/20230817/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 2496304 Aug 18 02:02 /var/opt/common5/mdt/20230817/22/ta_histogram.zip
# -rw-r--r--. 1 root root 37007772 Aug 17 16:06 /var/opt/common5/mdt/20230817/12/ue_meas.zip
# -rw-r--r--. 1 root root 25581629 Aug 17 16:08 /var/opt/common5/mdt/20230817/12/mdt_result.zip
# -rw-r--r--. 1 root root 18266083 Aug 17 16:05 /var/opt/common5/mdt/20230817/12/ue_traffic.zip
# -rw-r--r--. 1 root root 805222 Aug 17 16:21 /var/opt/common5/mdt/20230817/12/ho_counter_20230817_12.zip
# -rw-r--r--. 1 root root 932186 Aug 17 16:05 /var/opt/common5/mdt/20230817/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 2599794 Aug 17 16:09 /var/opt/common5/mdt/20230817/12/ta_histogram.zip
# -rw-r--r--. 1 root root 13004848 Aug 17 07:57 /var/opt/common5/mdt/20230817/04/ue_meas.zip
# -rw-r--r--. 1 root root 8496775 Aug 17 07:57 /var/opt/common5/mdt/20230817/04/mdt_result.zip
# -rw-r--r--. 1 root root 608444 Aug 17 08:03 /var/opt/common5/mdt/20230817/04/ho_counter_20230817_04.zip
# -rw-r--r--. 1 root root 6856313 Aug 17 07:56 /var/opt/common5/mdt/20230817/04/ue_traffic.zip
# -rw-r--r--. 1 root root 926037 Aug 17 07:56 /var/opt/common5/mdt/20230817/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 1815991 Aug 17 07:57 /var/opt/common5/mdt/20230817/04/ta_histogram.zip
# -rw-r--r--. 1 root root 35993845 Aug 18 06:27 /var/opt/common5/mdt/20230817/grid_mdt_traffic_cell_20230817.zip
# -rw-r--r--. 1 root root 36370346 Aug 17 18:07 /var/opt/common5/mdt/20230817/14/ue_meas.zip
# -rw-r--r--. 1 root root 25197306 Aug 17 18:09 /var/opt/common5/mdt/20230817/14/mdt_result.zip
# -rw-r--r--. 1 root root 802353 Aug 17 18:23 /var/opt/common5/mdt/20230817/14/ho_counter_20230817_14.zip
# -rw-r--r--. 1 root root 17932389 Aug 17 18:06 /var/opt/common5/mdt/20230817/14/ue_traffic.zip
# -rw-r--r--. 1 root root 927631 Aug 17 18:05 /var/opt/common5/mdt/20230817/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 2557503 Aug 17 18:10 /var/opt/common5/mdt/20230817/14/ta_histogram.zip
# -rw-r--r--. 1 root root 28628456 Aug 17 10:01 /var/opt/common5/mdt/20230817/06/ue_meas.zip
# -rw-r--r--. 1 root root 742770 Aug 17 10:09 /var/opt/common5/mdt/20230817/06/ho_counter_20230817_06.zip
# -rw-r--r--. 1 root root 19585091 Aug 17 10:02 /var/opt/common5/mdt/20230817/06/mdt_result.zip
# -rw-r--r--. 1 root root 14476203 Aug 17 10:00 /var/opt/common5/mdt/20230817/06/ue_traffic.zip
# -rw-r--r--. 1 root root 939699 Aug 17 10:00 /var/opt/common5/mdt/20230817/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 2197352 Aug 17 10:02 /var/opt/common5/mdt/20230817/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1193278 Aug 18 06:15 /var/opt/common5/mdt/20230817/ctr0_ho_counter_20230817.zip
# -rw-r--r--. 1 root root 38275402 Aug 17 22:08 /var/opt/common5/mdt/20230817/18/ue_meas.zip
# -rw-r--r--. 1 root root 804659 Aug 17 22:25 /var/opt/common5/mdt/20230817/18/ho_counter_20230817_18.zip
# -rw-r--r--. 1 root root 26489947 Aug 17 22:11 /var/opt/common5/mdt/20230817/18/mdt_result.zip
# -rw-r--r--. 1 root root 18923962 Aug 17 22:07 /var/opt/common5/mdt/20230817/18/ue_traffic.zip
# -rw-r--r--. 1 root root 941336 Aug 17 22:06 /var/opt/common5/mdt/20230817/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 2609634 Aug 17 22:12 /var/opt/common5/mdt/20230817/18/ta_histogram.zip
# -rw-r--r--. 1 root root 39512808 Aug 17 13:06 /var/opt/common5/mdt/20230817/09/ue_meas.zip
# -rw-r--r--. 1 root root 26638953 Aug 17 13:08 /var/opt/common5/mdt/20230817/09/mdt_result.zip
# -rw-r--r--. 1 root root 801537 Aug 17 13:23 /var/opt/common5/mdt/20230817/09/ho_counter_20230817_09.zip
# -rw-r--r--. 1 root root 19503270 Aug 17 13:05 /var/opt/common5/mdt/20230817/09/ue_traffic.zip
# -rw-r--r--. 1 root root 924648 Aug 17 13:04 /var/opt/common5/mdt/20230817/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 2492540 Aug 17 13:09 /var/opt/common5/mdt/20230817/09/ta_histogram.zip
# -rw-r--r--. 1 root root 37887176 Aug  5 12:07 /var/opt/common5/mdt/20230805/08/ue_meas.zip
# -rw-r--r--. 1 root root 787810 Aug  5 12:20 /var/opt/common5/mdt/20230805/08/ho_counter_20230805_08.zip
# -rw-r--r--. 1 root root 26555540 Aug  5 12:08 /var/opt/common5/mdt/20230805/08/mdt_result.zip
# -rw-r--r--. 1 root root 19034475 Aug  5 12:06 /var/opt/common5/mdt/20230805/08/ue_traffic.zip
# -rw-r--r--. 1 root root 946681 Aug  5 12:05 /var/opt/common5/mdt/20230805/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 2467985 Aug  5 12:09 /var/opt/common5/mdt/20230805/08/ta_histogram.zip
# -rw-r--r--. 1 root root 40741143 Aug  6 00:10 /var/opt/common5/mdt/20230805/20/ue_meas.zip
# -rw-r--r--. 1 root root 28496945 Aug  6 00:13 /var/opt/common5/mdt/20230805/20/mdt_result.zip
# -rw-r--r--. 1 root root 815815 Aug  6 00:27 /var/opt/common5/mdt/20230805/20/ho_counter_20230805_20.zip
# -rw-r--r--. 1 root root 20153314 Aug  6 00:09 /var/opt/common5/mdt/20230805/20/ue_traffic.zip
# -rw-r--r--. 1 root root 926940 Aug  6 00:08 /var/opt/common5/mdt/20230805/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 2704628 Aug  6 00:14 /var/opt/common5/mdt/20230805/20/ta_histogram.zip
# -rw-r--r--. 1 root root 43672985 Aug  5 20:13 /var/opt/common5/mdt/20230805/16/ue_meas.zip
# -rw-r--r--. 1 root root 31329479 Aug  5 20:15 /var/opt/common5/mdt/20230805/16/mdt_result.zip
# -rw-r--r--. 1 root root 825725 Aug  5 20:28 /var/opt/common5/mdt/20230805/16/ho_counter_20230805_16.zip
# -rw-r--r--. 1 root root 21605911 Aug  5 20:11 /var/opt/common5/mdt/20230805/16/ue_traffic.zip
# -rw-r--r--. 1 root root 931131 Aug  5 20:10 /var/opt/common5/mdt/20230805/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 2601216 Aug  5 20:16 /var/opt/common5/mdt/20230805/16/ta_histogram.zip
# -rw-r--r--. 1 root root 44383671 Aug  5 21:12 /var/opt/common5/mdt/20230805/17/ue_meas.zip
# -rw-r--r--. 1 root root 31653619 Aug  5 21:15 /var/opt/common5/mdt/20230805/17/mdt_result.zip
# -rw-r--r--. 1 root root 826634 Aug  5 21:29 /var/opt/common5/mdt/20230805/17/ho_counter_20230805_17.zip
# -rw-r--r--. 1 root root 21954882 Aug  5 21:11 /var/opt/common5/mdt/20230805/17/ue_traffic.zip
# -rw-r--r--. 1 root root 928355 Aug  5 21:10 /var/opt/common5/mdt/20230805/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 2638607 Aug  5 21:16 /var/opt/common5/mdt/20230805/17/ta_histogram.zip
# -rw-r--r--. 1 root root 42136648 Aug  5 15:10 /var/opt/common5/mdt/20230805/11/ue_meas.zip
# -rw-r--r--. 1 root root 30594641 Aug  5 15:12 /var/opt/common5/mdt/20230805/11/mdt_result.zip
# -rw-r--r--. 1 root root 823652 Aug  5 15:24 /var/opt/common5/mdt/20230805/11/ho_counter_20230805_11.zip
# -rw-r--r--. 1 root root 20856362 Aug  5 15:09 /var/opt/common5/mdt/20230805/11/ue_traffic.zip
# -rw-r--r--. 1 root root 943722 Aug  5 15:08 /var/opt/common5/mdt/20230805/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 2683189 Aug  5 15:13 /var/opt/common5/mdt/20230805/11/ta_histogram.zip
# -rw-r--r--. 1 root root 16072646 Aug  5 09:00 /var/opt/common5/mdt/20230805/05/ue_meas.zip
# -rw-r--r--. 1 root root 10913325 Aug  5 09:01 /var/opt/common5/mdt/20230805/05/mdt_result.zip
# -rw-r--r--. 1 root root 642952 Aug  5 09:11 /var/opt/common5/mdt/20230805/05/ho_counter_20230805_05.zip
# -rw-r--r--. 1 root root 8479070 Aug  5 08:59 /var/opt/common5/mdt/20230805/05/ue_traffic.zip
# -rw-r--r--. 1 root root 939626 Aug  5 08:58 /var/opt/common5/mdt/20230805/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 1944359 Aug  5 09:01 /var/opt/common5/mdt/20230805/05/ta_histogram.zip
# -rw-r--r--. 1 root root 13344542 Aug  5 05:56 /var/opt/common5/mdt/20230805/02/ue_meas.zip
# -rw-r--r--. 1 root root 615504 Aug  5 06:02 /var/opt/common5/mdt/20230805/02/ho_counter_20230805_02.zip
# -rw-r--r--. 1 root root 9022551 Aug  5 05:57 /var/opt/common5/mdt/20230805/02/mdt_result.zip
# -rw-r--r--. 1 root root 7028439 Aug  5 05:56 /var/opt/common5/mdt/20230805/02/ue_traffic.zip
# -rw-r--r--. 1 root root 928497 Aug  5 05:56 /var/opt/common5/mdt/20230805/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 1918514 Aug  5 05:57 /var/opt/common5/mdt/20230805/02/ta_histogram.zip
# -rw-r--r--. 1 root root 20318055 Aug  5 03:59 /var/opt/common5/mdt/20230805/00/ue_meas.zip
# -rw-r--r--. 1 root root 14055688 Aug  5 03:59 /var/opt/common5/mdt/20230805/00/mdt_result.zip
# -rw-r--r--. 1 root root 691343 Aug  5 04:05 /var/opt/common5/mdt/20230805/00/ho_counter_20230805_00.zip
# -rw-r--r--. 1 root root 10443154 Aug  5 03:58 /var/opt/common5/mdt/20230805/00/ue_traffic.zip
# -rw-r--r--. 1 root root 926896 Aug  5 03:58 /var/opt/common5/mdt/20230805/00/result_ue_cap.zip
# ...
# -rw-r--r--. 1 root root 22689359 Aug 14 10:08 /var/opt/common5/mdt/20230814/06/mdt_result.zip
# -rw-r--r--. 1 root root 768901 Aug 14 10:21 /var/opt/common5/mdt/20230814/06/ho_counter_20230814_06.zip
# -rw-r--r--. 1 root root 16112965 Aug 14 10:05 /var/opt/common5/mdt/20230814/06/ue_traffic.zip
# -rw-r--r--. 1 root root 957712 Aug 14 10:04 /var/opt/common5/mdt/20230814/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 2221256 Aug 14 10:09 /var/opt/common5/mdt/20230814/06/ta_histogram.zip
# -rw-r--r--. 1 root root 46067068 Aug 14 22:13 /var/opt/common5/mdt/20230814/18/ue_meas.zip
# -rw-r--r--. 1 root root 835261 Aug 14 22:30 /var/opt/common5/mdt/20230814/18/ho_counter_20230814_18.zip
# -rw-r--r--. 1 root root 32903490 Aug 14 22:16 /var/opt/common5/mdt/20230814/18/mdt_result.zip
# -rw-r--r--. 1 root root 22520230 Aug 14 22:12 /var/opt/common5/mdt/20230814/18/ue_traffic.zip
# -rw-r--r--. 1 root root 950491 Aug 14 22:11 /var/opt/common5/mdt/20230814/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 2649382 Aug 14 22:17 /var/opt/common5/mdt/20230814/18/ta_histogram.zip
# -rw-r--r--. 1 root root 43363749 Aug 14 13:12 /var/opt/common5/mdt/20230814/09/ue_meas.zip
# -rw-r--r--. 1 root root 30664823 Aug 14 13:14 /var/opt/common5/mdt/20230814/09/mdt_result.zip
# -rw-r--r--. 1 root root 21268191 Aug 14 13:10 /var/opt/common5/mdt/20230814/09/ue_traffic.zip
# -rw-r--r--. 1 root root 835351 Aug 14 13:26 /var/opt/common5/mdt/20230814/09/ho_counter_20230814_09.zip
# -rw-r--r--. 1 root root 947616 Aug 14 13:09 /var/opt/common5/mdt/20230814/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 2659891 Aug 14 13:15 /var/opt/common5/mdt/20230814/09/ta_histogram.zip
# -rw-r--r--. 1 root root 43724389 Aug 10 12:13 /var/opt/common5/mdt/20230810/08/ue_meas.zip
# -rw-r--r--. 1 root root 30589735 Aug 10 12:16 /var/opt/common5/mdt/20230810/08/mdt_result.zip
# -rw-r--r--. 1 root root 832633 Aug 10 12:30 /var/opt/common5/mdt/20230810/08/ho_counter_20230810_08.zip
# -rw-r--r--. 1 root root 21516812 Aug 10 12:11 /var/opt/common5/mdt/20230810/08/ue_traffic.zip
# -rw-r--r--. 1 root root 963606 Aug 10 12:10 /var/opt/common5/mdt/20230810/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 2607118 Aug 10 12:17 /var/opt/common5/mdt/20230810/08/ta_histogram.zip
# -rw-r--r--. 1 root root 41980027 Aug 11 00:10 /var/opt/common5/mdt/20230810/20/ue_meas.zip
# -rw-r--r--. 1 root root 29198603 Aug 11 00:12 /var/opt/common5/mdt/20230810/20/mdt_result.zip
# -rw-r--r--. 1 root root 822093 Aug 11 00:28 /var/opt/common5/mdt/20230810/20/ho_counter_20230810_20.zip
# -rw-r--r--. 1 root root 20564273 Aug 11 00:08 /var/opt/common5/mdt/20230810/20/ue_traffic.zip
# -rw-r--r--. 1 root root 948241 Aug 11 00:07 /var/opt/common5/mdt/20230810/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 2753189 Aug 11 00:13 /var/opt/common5/mdt/20230810/20/ta_histogram.zip
# -rw-r--r--. 1 root root 45905226 Aug 10 20:16 /var/opt/common5/mdt/20230810/16/ue_meas.zip
# -rw-r--r--. 1 root root 32778728 Aug 10 20:19 /var/opt/common5/mdt/20230810/16/mdt_result.zip
# -rw-r--r--. 1 root root 855095 Aug 10 20:33 /var/opt/common5/mdt/20230810/16/ho_counter_20230810_16.zip
# -rw-r--r--. 1 root root 22422268 Aug 10 20:15 /var/opt/common5/mdt/20230810/16/ue_traffic.zip
# -rw-r--r--. 1 root root 965580 Aug 10 20:13 /var/opt/common5/mdt/20230810/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 2756386 Aug 10 20:20 /var/opt/common5/mdt/20230810/16/ta_histogram.zip
# -rw-r--r--. 1 root root 48084279 Aug 10 21:17 /var/opt/common5/mdt/20230810/17/ue_meas.zip
# -rw-r--r--. 1 root root 857343 Aug 10 21:34 /var/opt/common5/mdt/20230810/17/ho_counter_20230810_17.zip
# -rw-r--r--. 1 root root 34162565 Aug 10 21:19 /var/opt/common5/mdt/20230810/17/mdt_result.zip
# -rw-r--r--. 1 root root 23440475 Aug 10 21:15 /var/opt/common5/mdt/20230810/17/ue_traffic.zip
# -rw-r--r--. 1 root root 958599 Aug 10 21:14 /var/opt/common5/mdt/20230810/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 2751994 Aug 10 21:20 /var/opt/common5/mdt/20230810/17/ta_histogram.zip
# -rw-r--r--. 1 root root 43192461 Aug 10 15:15 /var/opt/common5/mdt/20230810/11/ue_meas.zip
# -rw-r--r--. 1 root root 31090085 Aug 10 15:17 /var/opt/common5/mdt/20230810/11/mdt_result.zip
# -rw-r--r--. 1 root root 846528 Aug 10 15:30 /var/opt/common5/mdt/20230810/11/ho_counter_20230810_11.zip
# -rw-r--r--. 1 root root 21140278 Aug 10 15:13 /var/opt/common5/mdt/20230810/11/ue_traffic.zip
# -rw-r--r--. 1 root root 968723 Aug 10 15:12 /var/opt/common5/mdt/20230810/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 2729011 Aug 10 15:18 /var/opt/common5/mdt/20230810/11/ta_histogram.zip
# -rw-r--r--. 1 root root 18301296 Aug 10 09:01 /var/opt/common5/mdt/20230810/05/ue_meas.zip
# -rw-r--r--. 1 root root 672938 Aug 10 09:15 /var/opt/common5/mdt/20230810/05/ho_counter_20230810_05.zip
# -rw-r--r--. 1 root root 12443149 Aug 10 09:03 /var/opt/common5/mdt/20230810/05/mdt_result.zip
# -rw-r--r--. 1 root root 9528439 Aug 10 09:00 /var/opt/common5/mdt/20230810/05/ue_traffic.zip
# -rw-r--r--. 1 root root 953463 Aug 10 08:59 /var/opt/common5/mdt/20230810/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 1996343 Aug 10 09:03 /var/opt/common5/mdt/20230810/05/ta_histogram.zip
# -rw-r--r--. 1 root root 12303793 Aug 10 05:58 /var/opt/common5/mdt/20230810/02/ue_meas.zip
# -rw-r--r--. 1 root root 8126142 Aug 10 05:59 /var/opt/common5/mdt/20230810/02/mdt_result.zip
# -rw-r--r--. 1 root root 609412 Aug 10 06:09 /var/opt/common5/mdt/20230810/02/ho_counter_20230810_02.zip
# -rw-r--r--. 1 root root 6451804 Aug 10 05:57 /var/opt/common5/mdt/20230810/02/ue_traffic.zip
# -rw-r--r--. 1 root root 927770 Aug 10 05:57 /var/opt/common5/mdt/20230810/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 1896514 Aug 10 06:00 /var/opt/common5/mdt/20230810/02/ta_histogram.zip
# -rw-r--r--. 1 root root 58851692 Aug 11 06:38 /var/opt/common5/mdt/20230810/grid_mdt_meas_cell_20230810.zip
# -rw-r--r--. 1 root root 16724379 Aug 10 03:58 /var/opt/common5/mdt/20230810/00/ue_meas.zip
# -rw-r--r--. 1 root root 11357705 Aug 10 03:58 /var/opt/common5/mdt/20230810/00/mdt_result.zip
# -rw-r--r--. 1 root root 630975 Aug 10 04:03 /var/opt/common5/mdt/20230810/00/ho_counter_20230810_00.zip
# -rw-r--r--. 1 root root 8559257 Aug 10 03:57 /var/opt/common5/mdt/20230810/00/ue_traffic.zip
# -rw-r--r--. 1 root root 877387 Aug 10 03:57 /var/opt/common5/mdt/20230810/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 2008124 Aug 10 03:58 /var/opt/common5/mdt/20230810/00/ta_histogram.zip
# -rw-r--r--. 1 root root 803569 Aug 10 11:25 /var/opt/common5/mdt/20230810/07/ho_counter_20230810_07.zip
# -rw-r--r--. 1 root root 39024862 Aug 10 11:11 /var/opt/common5/mdt/20230810/07/ue_meas.zip
# -rw-r--r--. 1 root root 27470533 Aug 10 11:13 /var/opt/common5/mdt/20230810/07/mdt_result.zip
# -rw-r--r--. 1 root root 19404047 Aug 10 11:09 /var/opt/common5/mdt/20230810/07/ue_traffic.zip
# -rw-r--r--. 1 root root 957776 Aug 10 11:08 /var/opt/common5/mdt/20230810/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 2381166 Aug 10 11:14 /var/opt/common5/mdt/20230810/07/ta_histogram.zip
# -rw-r--r--. 1 root root 43053635 Aug 10 19:15 /var/opt/common5/mdt/20230810/15/ue_meas.zip
# -rw-r--r--. 1 root root 30816475 Aug 10 19:17 /var/opt/common5/mdt/20230810/15/mdt_result.zip
# -rw-r--r--. 1 root root 21079249 Aug 10 19:13 /var/opt/common5/mdt/20230810/15/ue_traffic.zip
# -rw-r--r--. 1 root root 852420 Aug 10 19:31 /var/opt/common5/mdt/20230810/15/ho_counter_20230810_15.zip
# -rw-r--r--. 1 root root 964017 Aug 10 19:12 /var/opt/common5/mdt/20230810/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 2742067 Aug 10 19:18 /var/opt/common5/mdt/20230810/15/ta_histogram.zip
# -rw-r--r--. 1 root root 43683923 Aug 10 14:14 /var/opt/common5/mdt/20230810/10/ue_meas.zip
# -rw-r--r--. 1 root root 846842 Aug 10 14:31 /var/opt/common5/mdt/20230810/10/ho_counter_20230810_10.zip
# -rw-r--r--. 1 root root 31260879 Aug 10 14:16 /var/opt/common5/mdt/20230810/10/mdt_result.zip
# -rw-r--r--. 1 root root 21398634 Aug 10 14:12 /var/opt/common5/mdt/20230810/10/ue_traffic.zip
# -rw-r--r--. 1 root root 969751 Aug 10 14:11 /var/opt/common5/mdt/20230810/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 2718728 Aug 10 14:17 /var/opt/common5/mdt/20230810/10/ta_histogram.zip
# -rw-r--r--. 1 root root 11956832 Aug 10 06:57 /var/opt/common5/mdt/20230810/03/ue_meas.zip
# -rw-r--r--. 1 root root 7847755 Aug 10 06:58 /var/opt/common5/mdt/20230810/03/mdt_result.zip
# -rw-r--r--. 1 root root 6331215 Aug 10 06:57 /var/opt/common5/mdt/20230810/03/ue_traffic.zip
# -rw-r--r--. 1 root root 604975 Aug 10 07:03 /var/opt/common5/mdt/20230810/03/ho_counter_20230810_03.zip
# -rw-r--r--. 1 root root 940472 Aug 10 06:57 /var/opt/common5/mdt/20230810/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 1852725 Aug 10 06:58 /var/opt/common5/mdt/20230810/03/ta_histogram.zip
# -rw-r--r--. 1 root root 3347436 Aug 11 06:16 /var/opt/common5/mdt/20230810/ue_capability_20230810.zip
# -rw-r--r--. 1 root root 41745829 Aug 10 17:14 /var/opt/common5/mdt/20230810/13/ue_meas.zip
# -rw-r--r--. 1 root root 29806165 Aug 10 17:16 /var/opt/common5/mdt/20230810/13/mdt_result.zip
# -rw-r--r--. 1 root root 854263 Aug 10 17:32 /var/opt/common5/mdt/20230810/13/ho_counter_20230810_13.zip
# -rw-r--r--. 1 root root 20484751 Aug 10 17:12 /var/opt/common5/mdt/20230810/13/ue_traffic.zip
# -rw-r--r--. 1 root root 963422 Aug 10 17:11 /var/opt/common5/mdt/20230810/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 2799034 Aug 10 17:18 /var/opt/common5/mdt/20230810/13/ta_histogram.zip
# -rw-r--r--. 1 root root 36219023 Aug 11 01:05 /var/opt/common5/mdt/20230810/21/ue_meas.zip
# -rw-r--r--. 1 root root 24867874 Aug 11 01:06 /var/opt/common5/mdt/20230810/21/mdt_result.zip
# -rw-r--r--. 1 root root 17876876 Aug 11 01:04 /var/opt/common5/mdt/20230810/21/ue_traffic.zip
# -rw-r--r--. 1 root root 950554 Aug 11 01:04 /var/opt/common5/mdt/20230810/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 800842 Aug 11 01:19 /var/opt/common5/mdt/20230810/21/ho_counter_20230810_21.zip
# -rw-r--r--. 1 root root 2722474 Aug 11 01:07 /var/opt/common5/mdt/20230810/21/ta_histogram.zip
# -rw-r--r--. 1 root root 23972318 Aug 11 02:59 /var/opt/common5/mdt/20230810/23/ue_meas.zip
# -rw-r--r--. 1 root root 16342700 Aug 11 03:00 /var/opt/common5/mdt/20230810/23/mdt_result.zip
# -rw-r--r--. 1 root root 725529 Aug 11 03:06 /var/opt/common5/mdt/20230810/23/ho_counter_20230810_23.zip
# -rw-r--r--. 1 root root 12092623 Aug 11 02:59 /var/opt/common5/mdt/20230810/23/ue_traffic.zip
# -rw-r--r--. 1 root root 956394 Aug 11 02:59 /var/opt/common5/mdt/20230810/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 2370245 Aug 11 03:00 /var/opt/common5/mdt/20230810/23/ta_histogram.zip
# -rw-r--r--. 1 root root 14464536 Aug 10 04:57 /var/opt/common5/mdt/20230810/01/ue_meas.zip
# -rw-r--r--. 1 root root 9770894 Aug 10 04:58 /var/opt/common5/mdt/20230810/01/mdt_result.zip
# -rw-r--r--. 1 root root 7501108 Aug 10 04:57 /var/opt/common5/mdt/20230810/01/ue_traffic.zip
# -rw-r--r--. 1 root root 638697 Aug 10 05:03 /var/opt/common5/mdt/20230810/01/ho_counter_20230810_01.zip
# -rw-r--r--. 1 root root 936921 Aug 10 04:57 /var/opt/common5/mdt/20230810/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 2043013 Aug 10 04:58 /var/opt/common5/mdt/20230810/01/ta_histogram.zip
# -rw-r--r--. 1 root root 44360612 Aug 10 23:13 /var/opt/common5/mdt/20230810/19/ue_meas.zip
# -rw-r--r--. 1 root root 834230 Aug 10 23:30 /var/opt/common5/mdt/20230810/19/ho_counter_20230810_19.zip
# -rw-r--r--. 1 root root 31491302 Aug 10 23:15 /var/opt/common5/mdt/20230810/19/mdt_result.zip
# -rw-r--r--. 1 root root 21695700 Aug 10 23:11 /var/opt/common5/mdt/20230810/19/ue_traffic.zip
# -rw-r--r--. 1 root root 949514 Aug 10 23:10 /var/opt/common5/mdt/20230810/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 2724000 Aug 10 23:16 /var/opt/common5/mdt/20230810/19/ta_histogram.zip
# -rw-r--r--. 1 root root 31119436 Aug 11 02:03 /var/opt/common5/mdt/20230810/22/ue_meas.zip
# -rw-r--r--. 1 root root 21295279 Aug 11 02:04 /var/opt/common5/mdt/20230810/22/mdt_result.zip
# -rw-r--r--. 1 root root 767761 Aug 11 02:18 /var/opt/common5/mdt/20230810/22/ho_counter_20230810_22.zip
# -rw-r--r--. 1 root root 15489149 Aug 11 02:03 /var/opt/common5/mdt/20230810/22/ue_traffic.zip
# -rw-r--r--. 1 root root 949491 Aug 11 02:02 /var/opt/common5/mdt/20230810/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 2598258 Aug 11 02:05 /var/opt/common5/mdt/20230810/22/ta_histogram.zip
# -rw-r--r--. 1 root root 851339 Aug 10 16:32 /var/opt/common5/mdt/20230810/12/ho_counter_20230810_12.zip
# -rw-r--r--. 1 root root 42436504 Aug 10 16:15 /var/opt/common5/mdt/20230810/12/ue_meas.zip
# -rw-r--r--. 1 root root 30049614 Aug 10 16:17 /var/opt/common5/mdt/20230810/12/mdt_result.zip
# -rw-r--r--. 1 root root 20787308 Aug 10 16:13 /var/opt/common5/mdt/20230810/12/ue_traffic.zip
# -rw-r--r--. 1 root root 964426 Aug 10 16:12 /var/opt/common5/mdt/20230810/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 2808351 Aug 10 16:18 /var/opt/common5/mdt/20230810/12/ta_histogram.zip
# -rw-r--r--. 1 root root 12761622 Aug 10 07:57 /var/opt/common5/mdt/20230810/04/ue_meas.zip
# -rw-r--r--. 1 root root 8383828 Aug 10 07:58 /var/opt/common5/mdt/20230810/04/mdt_result.zip
# -rw-r--r--. 1 root root 606061 Aug 10 08:03 /var/opt/common5/mdt/20230810/04/ho_counter_20230810_04.zip
# -rw-r--r--. 1 root root 6766451 Aug 10 07:57 /var/opt/common5/mdt/20230810/04/ue_traffic.zip
# -rw-r--r--. 1 root root 933861 Aug 10 07:57 /var/opt/common5/mdt/20230810/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 1829964 Aug 10 07:58 /var/opt/common5/mdt/20230810/04/ta_histogram.zip
# -rw-r--r--. 1 root root 38844543 Aug 11 06:32 /var/opt/common5/mdt/20230810/grid_mdt_traffic_cell_20230810.zip
# -rw-r--r--. 1 root root 1237847 Aug 11 06:15 /var/opt/common5/mdt/20230810/ctr0_ho_counter_20230810.zip
# -rw-r--r--. 1 root root 43687562 Aug 10 18:15 /var/opt/common5/mdt/20230810/14/ue_meas.zip
# -rw-r--r--. 1 root root 31264102 Aug 10 18:17 /var/opt/common5/mdt/20230810/14/mdt_result.zip
# -rw-r--r--. 1 root root 852850 Aug 10 18:32 /var/opt/common5/mdt/20230810/14/ho_counter_20230810_14.zip
# -rw-r--r--. 1 root root 21341289 Aug 10 18:13 /var/opt/common5/mdt/20230810/14/ue_traffic.zip
# -rw-r--r--. 1 root root 980921 Aug 10 18:12 /var/opt/common5/mdt/20230810/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 2764485 Aug 10 18:18 /var/opt/common5/mdt/20230810/14/ta_histogram.zip
# -rw-r--r--. 1 root root 30926228 Aug 10 10:06 /var/opt/common5/mdt/20230810/06/ue_meas.zip
# -rw-r--r--. 1 root root 21769881 Aug 10 10:08 /var/opt/common5/mdt/20230810/06/mdt_result.zip
# -rw-r--r--. 1 root root 759548 Aug 10 10:20 /var/opt/common5/mdt/20230810/06/ho_counter_20230810_06.zip
# -rw-r--r--. 1 root root 15600750 Aug 10 10:05 /var/opt/common5/mdt/20230810/06/ue_traffic.zip
# -rw-r--r--. 1 root root 948004 Aug 10 10:04 /var/opt/common5/mdt/20230810/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 2210748 Aug 10 10:09 /var/opt/common5/mdt/20230810/06/ta_histogram.zip
# -rw-r--r--. 1 root root 47319979 Aug 10 22:16 /var/opt/common5/mdt/20230810/18/ue_meas.zip
# -rw-r--r--. 1 root root 33659186 Aug 10 22:18 /var/opt/common5/mdt/20230810/18/mdt_result.zip
# -rw-r--r--. 1 root root 23136806 Aug 10 22:14 /var/opt/common5/mdt/20230810/18/ue_traffic.zip
# -rw-r--r--. 1 root root 842041 Aug 10 22:32 /var/opt/common5/mdt/20230810/18/ho_counter_20230810_18.zip
# -rw-r--r--. 1 root root 961000 Aug 10 22:13 /var/opt/common5/mdt/20230810/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 2693498 Aug 10 22:19 /var/opt/common5/mdt/20230810/18/ta_histogram.zip
# -rw-r--r--. 1 root root 44337074 Aug 10 13:14 /var/opt/common5/mdt/20230810/09/ue_meas.zip
# -rw-r--r--. 1 root root 31115352 Aug 10 13:16 /var/opt/common5/mdt/20230810/09/mdt_result.zip
# -rw-r--r--. 1 root root 841805 Aug 10 13:31 /var/opt/common5/mdt/20230810/09/ho_counter_20230810_09.zip
# -rw-r--r--. 1 root root 21749637 Aug 10 13:12 /var/opt/common5/mdt/20230810/09/ue_traffic.zip
# -rw-r--r--. 1 root root 966002 Aug 10 13:11 /var/opt/common5/mdt/20230810/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 2669297 Aug 10 13:17 /var/opt/common5/mdt/20230810/09/ta_histogram.zip
# -rw-r--r--. 1 root root 22557183 Aug 11 06:27 /var/opt/common5/mdt/20230810/grid_mdt_cell_20230810.zip
# [root@e011clxcol002p ~]#

# %%
test1 = re.split(r'\s+|\n', raw)

# %%
# Create list comprehension to filter only mdt_result.zip only 
# Option are ue_traffic or mdt_result

pattern = r'.*/(?!filter_)[^/]+/mdt_result\.zip$'
result = [path for path in test1 if re.match(pattern, path)]

# %%
# Create list comprehension to generate weekend dates in June

# weekend_dates = [date.strftime("%Y%m%d") for date in (datetime.date(2023, 6, day) for day in range(1, 31)) 
                #  if date.weekday() >= 5]

# Create list comprehension to generate continous dates in June (from 25 June until 30 June)
# continous_dates = re.compile(r'/var/opt/common5/mdt/202306(0[5-9]|30)/\d{2}/mdt_result\.zip')
# continous_dates = re.compile(r'/var/opt/common5/mdt/202306(0[1-8])/\d{2}/mdt_result\.zip')

# %%
# Create list comprehension to filter June Month only
result = [path for path in result if '20230812' in path]

# Create list comprehension to filter Out Some Date
# result = [path for path in result if '20230601' not in path and '20230602' not in path] 

# Create list comprehension to filter out continous dates
# result = [path for path in result if not continous_dates.search(path)]

# Create list comprehension to filter Out Weekend Date
# result = [path for path in result if path.split('/')[5] not in weekend_dates]

# Create list comprehension to filter Busy Hour only
result = [path for path in result if '/18/' in path or '/19/' in path or '/20/' in path or '/21/' in path or '/22/' in path or '/23/' in path]

# Create list comprehension to filter Busy Hour only
# result = [path for path in result if '/11/' in path or '/12/' in path or '/13/' in path]

result.sort()

# %%
with open(r'/home/nivag/location_to_dl_8009-mdt-polygon.txt', 'w') as fp:
    fp.write('\n'.join(result))
