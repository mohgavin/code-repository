# %%
import pexpect
import time
import sys
import re
import datetime
import os

# %%
#ENM3 -> 10.23.202.28 PW : "Enm#2021"
#ENM5 -> 10.167.30.28 PW : "Enm#2021"

child = pexpect.spawn('ssh -L 7899:localhost:8009 -J root@150.236.203.198 root@127.0.0.1 -p 8009', timeout=30, encoding='utf-8', logfile=sys.stdout)

child.maxread = 300000 

child.expect("root@150.236.203.198's password: ")
child.sendline('PMT@2022')
child.expect("root@127.0.0.1's password: ")
child.sendline('xl@cibi123')

time.sleep(10)

# Shell command to take after the dates in modification dates
# child.sendline('find /var/opt/common5/mdt/ -type f -newermt 2023-04-16 -exec ls -l {} \;')

# Shell command to take only the folder
# child.sendline('find /var/opt/common5/mdt/20230205 -type f -exec ls -l {} \;')

# Shell command to take certain range dates in modification dates
child.sendline('find /var/opt/common5/mdt -type f -newermt 2023-06-30 ! -newermt 2023-08-01 -exec ls -l {} \;')

try:
    child.expect(pexpect.EOF, timeout=150)

except pexpect.TIMEOUT:
    child.close()
    raw = str(child.before)
# Out:
# root@150.236.203.198's password: PMT@2022
#
# root@127.0.0.1's password: xl@cibi123
# find /var/opt/common5/mdt -type f -newermt 2023-06-30 ! -newermt 2023-08-01 -exec ls -l {} \;
#
# Last login: Sat Aug  5 20:50:29 2023 from 192.168.21.6
#  -newermt 2023-08-01 -exec ls -l {} \;xcol002p ~]# find /var/opt/common5/mdt -type f -newermt 2023-06-30 !
# -rw-r--r--. 1 root root 41818778 Jul 26 12:11 /var/opt/common5/mdt/20230726/08/ue_meas.zip
# -rw-r--r--. 1 root root 821975 Jul 26 12:23 /var/opt/common5/mdt/20230726/08/ho_counter_20230726_08.zip
# -rw-r--r--. 1 root root 29900271 Jul 26 12:13 /var/opt/common5/mdt/20230726/08/mdt_result.zip
# -rw-r--r--. 1 root root 20778843 Jul 26 12:09 /var/opt/common5/mdt/20230726/08/ue_traffic.zip
# -rw-r--r--. 1 root root 955039 Jul 26 12:09 /var/opt/common5/mdt/20230726/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 2551521 Jul 26 12:13 /var/opt/common5/mdt/20230726/08/ta_histogram.zip
# -rw-r--r--. 1 root root 813949 Jul 27 00:22 /var/opt/common5/mdt/20230726/20/ho_counter_20230726_20.zip
# -rw-r--r--. 1 root root 41318854 Jul 27 00:09 /var/opt/common5/mdt/20230726/20/ue_meas.zip
# -rw-r--r--. 1 root root 29547120 Jul 27 00:11 /var/opt/common5/mdt/20230726/20/mdt_result.zip
# -rw-r--r--. 1 root root 20403620 Jul 27 00:08 /var/opt/common5/mdt/20230726/20/ue_traffic.zip
# -rw-r--r--. 1 root root 941056 Jul 27 00:07 /var/opt/common5/mdt/20230726/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 2711243 Jul 27 00:11 /var/opt/common5/mdt/20230726/20/ta_histogram.zip
# -rw-r--r--. 1 root root 44659989 Jul 26 20:14 /var/opt/common5/mdt/20230726/16/ue_meas.zip
# -rw-r--r--. 1 root root 840437 Jul 26 20:27 /var/opt/common5/mdt/20230726/16/ho_counter_20230726_16.zip
# -rw-r--r--. 1 root root 32513463 Jul 26 20:17 /var/opt/common5/mdt/20230726/16/mdt_result.zip
# -rw-r--r--. 1 root root 21977648 Jul 26 20:13 /var/opt/common5/mdt/20230726/16/ue_traffic.zip
# -rw-r--r--. 1 root root 960510 Jul 26 20:12 /var/opt/common5/mdt/20230726/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 2704553 Jul 26 20:17 /var/opt/common5/mdt/20230726/16/ta_histogram.zip
# -rw-r--r--. 1 root root 45368608 Jul 26 21:15 /var/opt/common5/mdt/20230726/17/ue_meas.zip
# -rw-r--r--. 1 root root 841405 Jul 26 21:30 /var/opt/common5/mdt/20230726/17/ho_counter_20230726_17.zip
# -rw-r--r--. 1 root root 32988199 Jul 26 21:18 /var/opt/common5/mdt/20230726/17/mdt_result.zip
# -rw-r--r--. 1 root root 22332622 Jul 26 21:14 /var/opt/common5/mdt/20230726/17/ue_traffic.zip
# -rw-r--r--. 1 root root 936787 Jul 26 21:13 /var/opt/common5/mdt/20230726/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 2691941 Jul 26 21:19 /var/opt/common5/mdt/20230726/17/ta_histogram.zip
# -rw-r--r--. 1 root root 42304620 Jul 26 15:14 /var/opt/common5/mdt/20230726/11/ue_meas.zip
# -rw-r--r--. 1 root root 836263 Jul 26 15:28 /var/opt/common5/mdt/20230726/11/ho_counter_20230726_11.zip
# -rw-r--r--. 1 root root 30839680 Jul 26 15:16 /var/opt/common5/mdt/20230726/11/mdt_result.zip
# -rw-r--r--. 1 root root 20872161 Jul 26 15:12 /var/opt/common5/mdt/20230726/11/ue_traffic.zip
# -rw-r--r--. 1 root root 960884 Jul 26 15:11 /var/opt/common5/mdt/20230726/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 2752791 Jul 26 15:17 /var/opt/common5/mdt/20230726/11/ta_histogram.zip
# -rw-r--r--. 1 root root 17626903 Jul 26 08:59 /var/opt/common5/mdt/20230726/05/ue_meas.zip
# -rw-r--r--. 1 root root 662181 Jul 26 09:06 /var/opt/common5/mdt/20230726/05/ho_counter_20230726_05.zip
# -rw-r--r--. 1 root root 12121570 Jul 26 08:59 /var/opt/common5/mdt/20230726/05/mdt_result.zip
# -rw-r--r--. 1 root root 9226016 Jul 26 08:58 /var/opt/common5/mdt/20230726/05/ue_traffic.zip
# -rw-r--r--. 1 root root 945732 Jul 26 08:58 /var/opt/common5/mdt/20230726/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 1962120 Jul 26 08:59 /var/opt/common5/mdt/20230726/05/ta_histogram.zip
# -rw-r--r--. 1 root root 12106699 Jul 26 05:56 /var/opt/common5/mdt/20230726/02/ue_meas.zip
# -rw-r--r--. 1 root root 8134074 Jul 26 05:57 /var/opt/common5/mdt/20230726/02/mdt_result.zip
# -rw-r--r--. 1 root root 610414 Jul 26 06:02 /var/opt/common5/mdt/20230726/02/ho_counter_20230726_02.zip
# -rw-r--r--. 1 root root 6390492 Jul 26 05:56 /var/opt/common5/mdt/20230726/02/ue_traffic.zip
# -rw-r--r--. 1 root root 929055 Jul 26 05:56 /var/opt/common5/mdt/20230726/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 1915165 Jul 26 05:57 /var/opt/common5/mdt/20230726/02/ta_histogram.zip
# -rw-r--r--. 1 root root 18511514 Jul 26 03:58 /var/opt/common5/mdt/20230726/00/ue_meas.zip
# -rw-r--r--. 1 root root 677989 Jul 26 04:04 /var/opt/common5/mdt/20230726/00/ho_counter_20230726_00.zip
# -rw-r--r--. 1 root root 12755724 Jul 26 03:58 /var/opt/common5/mdt/20230726/00/mdt_result.zip
# -rw-r--r--. 1 root root 9534632 Jul 26 03:58 /var/opt/common5/mdt/20230726/00/ue_traffic.zip
# -rw-r--r--. 1 root root 944371 Jul 26 03:57 /var/opt/common5/mdt/20230726/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 2210747 Jul 26 03:59 /var/opt/common5/mdt/20230726/00/ta_histogram.zip
# -rw-r--r--. 1 root root 39378704 Jul 26 11:11 /var/opt/common5/mdt/20230726/07/ue_meas.zip
# -rw-r--r--. 1 root root 28034826 Jul 26 11:13 /var/opt/common5/mdt/20230726/07/mdt_result.zip
# -rw-r--r--. 1 root root 805081 Jul 26 11:24 /var/opt/common5/mdt/20230726/07/ho_counter_20230726_07.zip
# -rw-r--r--. 1 root root 19721455 Jul 26 11:10 /var/opt/common5/mdt/20230726/07/ue_traffic.zip
# -rw-r--r--. 1 root root 964537 Jul 26 11:09 /var/opt/common5/mdt/20230726/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 2424485 Jul 26 11:14 /var/opt/common5/mdt/20230726/07/ta_histogram.zip
# -rw-r--r--. 1 root root 38935463 Jul 27 06:30 /var/opt/common5/mdt/20230726/grid_mdt_traffic_cell_20230726.zip
# -rw-r--r--. 1 root root 42006319 Jul 26 19:14 /var/opt/common5/mdt/20230726/15/ue_meas.zip
# -rw-r--r--. 1 root root 30504742 Jul 26 19:17 /var/opt/common5/mdt/20230726/15/mdt_result.zip
# -rw-r--r--. 1 root root 836755 Jul 26 19:27 /var/opt/common5/mdt/20230726/15/ho_counter_20230726_15.zip
# -rw-r--r--. 1 root root 20725234 Jul 26 19:13 /var/opt/common5/mdt/20230726/15/ue_traffic.zip
# -rw-r--r--. 1 root root 942941 Jul 26 19:12 /var/opt/common5/mdt/20230726/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 2682071 Jul 26 19:17 /var/opt/common5/mdt/20230726/15/ta_histogram.zip
# -rw-r--r--. 1 root root 42667867 Jul 26 14:13 /var/opt/common5/mdt/20230726/10/ue_meas.zip
# -rw-r--r--. 1 root root 30971454 Jul 26 14:15 /var/opt/common5/mdt/20230726/10/mdt_result.zip
# -rw-r--r--. 1 root root 21057843 Jul 26 14:12 /var/opt/common5/mdt/20230726/10/ue_traffic.zip
# -rw-r--r--. 1 root root 831920 Jul 26 14:28 /var/opt/common5/mdt/20230726/10/ho_counter_20230726_10.zip
# -rw-r--r--. 1 root root 957269 Jul 26 14:11 /var/opt/common5/mdt/20230726/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 2699513 Jul 26 14:16 /var/opt/common5/mdt/20230726/10/ta_histogram.zip
# -rw-r--r--. 1 root root 11832992 Jul 26 06:56 /var/opt/common5/mdt/20230726/03/ue_meas.zip
# -rw-r--r--. 1 root root 7807248 Jul 26 06:56 /var/opt/common5/mdt/20230726/03/mdt_result.zip
# -rw-r--r--. 1 root root 598154 Jul 26 07:01 /var/opt/common5/mdt/20230726/03/ho_counter_20230726_03.zip
# -rw-r--r--. 1 root root 6279976 Jul 26 06:55 /var/opt/common5/mdt/20230726/03/ue_traffic.zip
# -rw-r--r--. 1 root root 920673 Jul 26 06:55 /var/opt/common5/mdt/20230726/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 1813081 Jul 26 06:56 /var/opt/common5/mdt/20230726/03/ta_histogram.zip
# -rw-r--r--. 1 root root 364 Jul 27 06:36 /var/opt/common5/mdt/20230726/mdt_bm_20230726.zip
# -rw-r--r--. 1 root root 22636655 Jul 27 06:24 /var/opt/common5/mdt/20230726/grid_mdt_cell_20230726.zip
# -rw-r--r--. 1 root root 837130 Jul 26 17:29 /var/opt/common5/mdt/20230726/13/ho_counter_20230726_13.zip
# -rw-r--r--. 1 root root 41483404 Jul 26 17:14 /var/opt/common5/mdt/20230726/13/ue_meas.zip
# -rw-r--r--. 1 root root 30175020 Jul 26 17:16 /var/opt/common5/mdt/20230726/13/mdt_result.zip
# -rw-r--r--. 1 root root 20481181 Jul 26 17:12 /var/opt/common5/mdt/20230726/13/ue_traffic.zip
# -rw-r--r--. 1 root root 954490 Jul 26 17:11 /var/opt/common5/mdt/20230726/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 2733883 Jul 26 17:16 /var/opt/common5/mdt/20230726/13/ta_histogram.zip
# -rw-r--r--. 1 root root 1231670 Jul 27 06:15 /var/opt/common5/mdt/20230726/ctr0_ho_counter_20230726.zip
# -rw-r--r--. 1 root root 36373646 Jul 27 01:04 /var/opt/common5/mdt/20230726/21/ue_meas.zip
# -rw-r--r--. 1 root root 791000 Jul 27 01:15 /var/opt/common5/mdt/20230726/21/ho_counter_20230726_21.zip
# -rw-r--r--. 1 root root 25420829 Jul 27 01:05 /var/opt/common5/mdt/20230726/21/mdt_result.zip
# -rw-r--r--. 1 root root 18081891 Jul 27 01:04 /var/opt/common5/mdt/20230726/21/ue_traffic.zip
# -rw-r--r--. 1 root root 948549 Jul 27 01:03 /var/opt/common5/mdt/20230726/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 2701702 Jul 27 01:06 /var/opt/common5/mdt/20230726/21/ta_histogram.zip
# -rw-r--r--. 1 root root 23481372 Jul 27 03:00 /var/opt/common5/mdt/20230726/23/ue_meas.zip
# -rw-r--r--. 1 root root 717196 Jul 27 03:06 /var/opt/common5/mdt/20230726/23/ho_counter_20230726_23.zip
# -rw-r--r--. 1 root root 16345509 Jul 27 03:00 /var/opt/common5/mdt/20230726/23/mdt_result.zip
# -rw-r--r--. 1 root root 11946294 Jul 27 02:59 /var/opt/common5/mdt/20230726/23/ue_traffic.zip
# -rw-r--r--. 1 root root 949341 Jul 27 02:59 /var/opt/common5/mdt/20230726/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 2364759 Jul 27 03:00 /var/opt/common5/mdt/20230726/23/ta_histogram.zip
# -rw-r--r--. 1 root root 14573967 Jul 26 04:56 /var/opt/common5/mdt/20230726/01/ue_meas.zip
# -rw-r--r--. 1 root root 9913804 Jul 26 04:57 /var/opt/common5/mdt/20230726/01/mdt_result.zip
# -rw-r--r--. 1 root root 628067 Jul 26 05:02 /var/opt/common5/mdt/20230726/01/ho_counter_20230726_01.zip
# -rw-r--r--. 1 root root 7592984 Jul 26 04:56 /var/opt/common5/mdt/20230726/01/ue_traffic.zip
# -rw-r--r--. 1 root root 929046 Jul 26 04:56 /var/opt/common5/mdt/20230726/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 1986902 Jul 26 04:57 /var/opt/common5/mdt/20230726/01/ta_histogram.zip
# -rw-r--r--. 1 root root 44236451 Jul 26 23:11 /var/opt/common5/mdt/20230726/19/ue_meas.zip
# -rw-r--r--. 1 root root 32175172 Jul 26 23:14 /var/opt/common5/mdt/20230726/19/mdt_result.zip
# -rw-r--r--. 1 root root 823594 Jul 26 23:26 /var/opt/common5/mdt/20230726/19/ho_counter_20230726_19.zip
# -rw-r--r--. 1 root root 21798025 Jul 26 23:10 /var/opt/common5/mdt/20230726/19/ue_traffic.zip
# -rw-r--r--. 1 root root 955096 Jul 26 23:09 /var/opt/common5/mdt/20230726/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 2670610 Jul 26 23:15 /var/opt/common5/mdt/20230726/19/ta_histogram.zip
# -rw-r--r--. 1 root root 30582902 Jul 27 02:03 /var/opt/common5/mdt/20230726/22/ue_meas.zip
# -rw-r--r--. 1 root root 754915 Jul 27 02:15 /var/opt/common5/mdt/20230726/22/ho_counter_20230726_22.zip
# -rw-r--r--. 1 root root 21275917 Jul 27 02:04 /var/opt/common5/mdt/20230726/22/mdt_result.zip
# -rw-r--r--. 1 root root 15315878 Jul 27 02:03 /var/opt/common5/mdt/20230726/22/ue_traffic.zip
# -rw-r--r--. 1 root root 951110 Jul 27 02:02 /var/opt/common5/mdt/20230726/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 2561806 Jul 27 02:05 /var/opt/common5/mdt/20230726/22/ta_histogram.zip
# -rw-r--r--. 1 root root 41722473 Jul 26 16:15 /var/opt/common5/mdt/20230726/12/ue_meas.zip
# -rw-r--r--. 1 root root 30228723 Jul 26 16:18 /var/opt/common5/mdt/20230726/12/mdt_result.zip
# -rw-r--r--. 1 root root 838228 Jul 26 16:30 /var/opt/common5/mdt/20230726/12/ho_counter_20230726_12.zip
# -rw-r--r--. 1 root root 20865687 Jul 26 16:14 /var/opt/common5/mdt/20230726/12/ue_traffic.zip
# -rw-r--r--. 1 root root 946294 Jul 26 16:13 /var/opt/common5/mdt/20230726/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 2752709 Jul 26 16:19 /var/opt/common5/mdt/20230726/12/ta_histogram.zip
# -rw-r--r--. 1 root root 12077329 Jul 26 07:58 /var/opt/common5/mdt/20230726/04/ue_meas.zip
# -rw-r--r--. 1 root root 7914145 Jul 26 07:59 /var/opt/common5/mdt/20230726/04/mdt_result.zip
# -rw-r--r--. 1 root root 602124 Jul 26 08:04 /var/opt/common5/mdt/20230726/04/ho_counter_20230726_04.zip
# -rw-r--r--. 1 root root 6437840 Jul 26 07:58 /var/opt/common5/mdt/20230726/04/ue_traffic.zip
# -rw-r--r--. 1 root root 911476 Jul 26 07:58 /var/opt/common5/mdt/20230726/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 1811991 Jul 26 07:59 /var/opt/common5/mdt/20230726/04/ta_histogram.zip
# -rw-r--r--. 1 root root 3338089 Jul 27 06:16 /var/opt/common5/mdt/20230726/ue_capability_20230726.zip
# -rw-r--r--. 1 root root 58794678 Jul 27 06:35 /var/opt/common5/mdt/20230726/grid_mdt_meas_cell_20230726.zip
# -rw-r--r--. 1 root root 42215753 Jul 26 18:15 /var/opt/common5/mdt/20230726/14/ue_meas.zip
# -rw-r--r--. 1 root root 837788 Jul 26 18:32 /var/opt/common5/mdt/20230726/14/ho_counter_20230726_14.zip
# -rw-r--r--. 1 root root 30885857 Jul 26 18:17 /var/opt/common5/mdt/20230726/14/mdt_result.zip
# -rw-r--r--. 1 root root 20960726 Jul 26 18:13 /var/opt/common5/mdt/20230726/14/ue_traffic.zip
# -rw-r--r--. 1 root root 957342 Jul 26 18:12 /var/opt/common5/mdt/20230726/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 2725654 Jul 26 18:18 /var/opt/common5/mdt/20230726/14/ta_histogram.zip
# -rw-r--r--. 1 root root 31391522 Jul 26 10:07 /var/opt/common5/mdt/20230726/06/ue_meas.zip
# -rw-r--r--. 1 root root 22408477 Jul 26 10:09 /var/opt/common5/mdt/20230726/06/mdt_result.zip
# -rw-r--r--. 1 root root 765684 Jul 26 10:22 /var/opt/common5/mdt/20230726/06/ho_counter_20230726_06.zip
# -rw-r--r--. 1 root root 15921994 Jul 26 10:05 /var/opt/common5/mdt/20230726/06/ue_traffic.zip
# -rw-r--r--. 1 root root 974179 Jul 26 10:04 /var/opt/common5/mdt/20230726/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 2269581 Jul 26 10:10 /var/opt/common5/mdt/20230726/06/ta_histogram.zip
# -rw-r--r--. 1 root root 45034769 Jul 26 22:12 /var/opt/common5/mdt/20230726/18/ue_meas.zip
# -rw-r--r--. 1 root root 32670786 Jul 26 22:15 /var/opt/common5/mdt/20230726/18/mdt_result.zip
# -rw-r--r--. 1 root root 830584 Jul 26 22:26 /var/opt/common5/mdt/20230726/18/ho_counter_20230726_18.zip
# -rw-r--r--. 1 root root 22196854 Jul 26 22:11 /var/opt/common5/mdt/20230726/18/ue_traffic.zip
# -rw-r--r--. 1 root root 946186 Jul 26 22:10 /var/opt/common5/mdt/20230726/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 2690820 Jul 26 22:15 /var/opt/common5/mdt/20230726/18/ta_histogram.zip
# -rw-r--r--. 1 root root 43314346 Jul 26 13:12 /var/opt/common5/mdt/20230726/09/ue_meas.zip
# -rw-r--r--. 1 root root 831236 Jul 26 13:27 /var/opt/common5/mdt/20230726/09/ho_counter_20230726_09.zip
# -rw-r--r--. 1 root root 31115959 Jul 26 13:15 /var/opt/common5/mdt/20230726/09/mdt_result.zip
# -rw-r--r--. 1 root root 21419372 Jul 26 13:11 /var/opt/common5/mdt/20230726/09/ue_traffic.zip
# -rw-r--r--. 1 root root 964936 Jul 26 13:10 /var/opt/common5/mdt/20230726/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 2646345 Jul 26 13:16 /var/opt/common5/mdt/20230726/09/ta_histogram.zip
# -rw-r--r--. 1 root root 22217026 Jul  9 13:01 /var/opt/common5/mdt/20230709/08/ue_meas.zip
# -rw-r--r--. 1 root root 15190651 Jul  9 13:03 /var/opt/common5/mdt/20230709/08/mdt_result.zip
# -rw-r--r--. 1 root root 11054942 Jul  9 13:00 /var/opt/common5/mdt/20230709/08/ue_traffic.zip
# -rw-r--r--. 1 root root 337407 Jul  9 13:00 /var/opt/common5/mdt/20230709/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 133532169 Jul  9 13:13 /var/opt/common5/mdt/20230709/08/ta_histogram.zip
# -rw-r--r--. 1 root root 17642333 Jul 10 00:59 /var/opt/common5/mdt/20230709/20/ue_meas.zip
# -rw-r--r--. 1 root root 12168472 Jul 10 01:07 /var/opt/common5/mdt/20230709/20/mdt_result.zip
# -rw-r--r--. 1 root root 8653613 Jul 10 00:51 /var/opt/common5/mdt/20230709/20/ue_traffic.zip
# -rw-r--r--. 1 root root 251835 Jul 10 00:49 /var/opt/common5/mdt/20230709/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 111685468 Jul 10 01:20 /var/opt/common5/mdt/20230709/20/ta_histogram.zip
# -rw-r--r--. 1 root root 38851274 Jul  9 20:32 /var/opt/common5/mdt/20230709/16/ue_meas.zip
# -rw-r--r--. 1 root root 27393840 Jul  9 20:35 /var/opt/common5/mdt/20230709/16/mdt_result.zip
# -rw-r--r--. 1 root root 19018807 Jul  9 20:31 /var/opt/common5/mdt/20230709/16/ue_traffic.zip
# -rw-r--r--. 1 root root 497499 Jul  9 20:30 /var/opt/common5/mdt/20230709/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 232077116 Jul  9 20:51 /var/opt/common5/mdt/20230709/16/ta_histogram.zip
# -rw-r--r--. 1 root root 11964679 Jul 10 10:55 /var/opt/common5/mdt/20230709/ctr1_filter_ue_traffic.zip
# -rw-r--r--. 1 root root 60710287 Jul 10 10:32 /var/opt/common5/mdt/20230709/grid_mdt_meas_cell_20230709.zip
# -rw-r--r--. 1 root root 22566366 Jul 21 08:44 /var/opt/common5/mdt/20230709/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 91496430 Jul 10 10:55 /var/opt/common5/mdt/20230709/ctr1_grid_mdt_meas_cell_20230709.zip
# -rw-r--r--. 1 root root 85370263 Jul  9 21:39 /var/opt/common5/mdt/20230709/17/ue_meas.zip
# -rw-r--r--. 1 root root 60379968 Jul  9 21:44 /var/opt/common5/mdt/20230709/17/mdt_result.zip
# -rw-r--r--. 1 root root 41795115 Jul  9 21:36 /var/opt/common5/mdt/20230709/17/ue_traffic.zip
# -rw-r--r--. 1 root root 1081713 Jul  9 21:33 /var/opt/common5/mdt/20230709/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 510938650 Jul  9 22:42 /var/opt/common5/mdt/20230709/17/ta_histogram.zip
# -rw-r--r--. 1 root root 78006420 Jul  9 15:24 /var/opt/common5/mdt/20230709/11/ue_meas.zip
# -rw-r--r--. 1 root root 55391130 Jul  9 15:29 /var/opt/common5/mdt/20230709/11/mdt_result.zip
# -rw-r--r--. 1 root root 38090881 Jul  9 15:21 /var/opt/common5/mdt/20230709/11/ue_traffic.zip
# -rw-r--r--. 1 root root 1003362 Jul  9 15:19 /var/opt/common5/mdt/20230709/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 474957775 Jul  9 16:12 /var/opt/common5/mdt/20230709/11/ta_histogram.zip
# -rw-r--r--. 1 root root 3785114 Jul 10 09:12 /var/opt/common5/mdt/20230709/ue_capability_20230709.zip
# -rw-r--r--. 1 root root 23339499 Jul 10 09:49 /var/opt/common5/mdt/20230709/grid_mdt_cell_20230709.zip
# -rw-r--r--. 1 root root 20852518 Jul 21 08:39 /var/opt/common5/mdt/20230709/filter_mdt_result.zip
# -rw-r--r--. 1 root root 33444568 Jul  9 06:44 /var/opt/common5/mdt/20230709/02/ue_meas.zip
# -rw-r--r--. 1 root root 22209754 Jul  9 06:47 /var/opt/common5/mdt/20230709/02/mdt_result.zip
# -rw-r--r--. 1 root root 17343659 Jul  9 06:43 /var/opt/common5/mdt/20230709/02/ue_traffic.zip
# -rw-r--r--. 1 root root 1218792 Jul  9 06:41 /var/opt/common5/mdt/20230709/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 321612482 Jul  9 09:32 /var/opt/common5/mdt/20230709/02/ta_histogram.zip
# -rw-r--r--. 1 root root 53619809 Jul  9 04:26 /var/opt/common5/mdt/20230709/00/ue_meas.zip
# -rw-r--r--. 1 root root 36333043 Jul  9 04:28 /var/opt/common5/mdt/20230709/00/mdt_result.zip
# -rw-r--r--. 1 root root 27034165 Jul  9 04:23 /var/opt/common5/mdt/20230709/00/ue_traffic.zip
# -rw-r--r--. 1 root root 1237753 Jul  9 04:21 /var/opt/common5/mdt/20230709/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 413657286 Jul  9 04:45 /var/opt/common5/mdt/20230709/00/ta_histogram.zip
# -rw-r--r--. 1 root root 70463226 Jul  9 11:42 /var/opt/common5/mdt/20230709/07/ue_meas.zip
# -rw-r--r--. 1 root root 48431837 Jul  9 11:45 /var/opt/common5/mdt/20230709/07/mdt_result.zip
# -rw-r--r--. 1 root root 35460974 Jul  9 11:39 /var/opt/common5/mdt/20230709/07/ue_traffic.zip
# -rw-r--r--. 1 root root 1258743 Jul  9 11:38 /var/opt/common5/mdt/20230709/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 455726010 Jul  9 13:47 /var/opt/common5/mdt/20230709/07/ta_histogram.zip
# -rw-r--r--. 1 root root 3356944 Jul 10 10:55 /var/opt/common5/mdt/20230709/ctr1_ue_capability_20230709.zip
# -rw-r--r--. 1 root root 41464688 Jul  9 19:24 /var/opt/common5/mdt/20230709/15/ue_meas.zip
# -rw-r--r--. 1 root root 29269552 Jul  9 19:27 /var/opt/common5/mdt/20230709/15/mdt_result.zip
# -rw-r--r--. 1 root root 20287645 Jul  9 19:22 /var/opt/common5/mdt/20230709/15/ue_traffic.zip
# -rw-r--r--. 1 root root 532217 Jul  9 19:20 /var/opt/common5/mdt/20230709/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 62769128 Jul  9 14:23 /var/opt/common5/mdt/20230709/10/ue_meas.zip
# -rw-r--r--. 1 root root 44027992 Jul  9 14:27 /var/opt/common5/mdt/20230709/10/mdt_result.zip
# -rw-r--r--. 1 root root 30771837 Jul  9 14:21 /var/opt/common5/mdt/20230709/10/ue_traffic.zip
# -rw-r--r--. 1 root root 825854 Jul  9 14:19 /var/opt/common5/mdt/20230709/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 375473596 Jul  9 14:57 /var/opt/common5/mdt/20230709/10/ta_histogram.zip
# -rw-r--r--. 1 root root 13531696 Jul  9 07:58 /var/opt/common5/mdt/20230709/03/ue_meas.zip
# -rw-r--r--. 1 root root 8833293 Jul  9 08:00 /var/opt/common5/mdt/20230709/03/mdt_result.zip
# -rw-r--r--. 1 root root 7096321 Jul  9 07:55 /var/opt/common5/mdt/20230709/03/ue_traffic.zip
# -rw-r--r--. 1 root root 539020 Jul  9 07:53 /var/opt/common5/mdt/20230709/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 132240864 Jul  9 08:39 /var/opt/common5/mdt/20230709/03/ta_histogram.zip
# -rw-r--r--. 1 root root 24237136 Jul 10 10:55 /var/opt/common5/mdt/20230709/ctr1_filter_ue_meas.zip
# -rw-r--r--. 1 root root 77815107 Jul  9 17:25 /var/opt/common5/mdt/20230709/13/ue_meas.zip
# -rw-r--r--. 1 root root 55304668 Jul  9 17:30 /var/opt/common5/mdt/20230709/13/mdt_result.zip
# -rw-r--r--. 1 root root 38042507 Jul  9 17:22 /var/opt/common5/mdt/20230709/13/ue_traffic.zip
# -rw-r--r--. 1 root root 997693 Jul  9 17:20 /var/opt/common5/mdt/20230709/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 477538926 Jul  9 18:11 /var/opt/common5/mdt/20230709/13/ta_histogram.zip
# -rw-r--r--. 1 root root 55225920 Jul 10 01:59 /var/opt/common5/mdt/20230709/21/ue_meas.zip
# -rw-r--r--. 1 root root 38020954 Jul 10 02:03 /var/opt/common5/mdt/20230709/21/mdt_result.zip
# -rw-r--r--. 1 root root 27302089 Jul 10 01:57 /var/opt/common5/mdt/20230709/21/ue_traffic.zip
# -rw-r--r--. 1 root root 1008061 Jul 10 01:55 /var/opt/common5/mdt/20230709/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 361255946 Jul 10 03:46 /var/opt/common5/mdt/20230709/21/ta_histogram.zip
# -rw-r--r--. 1 root root 19363392 Jul 10 03:16 /var/opt/common5/mdt/20230709/23/ue_meas.zip
# -rw-r--r--. 1 root root 13127029 Jul 10 03:18 /var/opt/common5/mdt/20230709/23/mdt_result.zip
# -rw-r--r--. 1 root root 9718543 Jul 10 03:14 /var/opt/common5/mdt/20230709/23/ue_traffic.zip
# -rw-r--r--. 1 root root 407428 Jul 10 03:13 /var/opt/common5/mdt/20230709/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 144798052 Jul 10 04:03 /var/opt/common5/mdt/20230709/23/ta_histogram.zip
# -rw-r--r--. 1 root root 61252109 Jul 10 10:55 /var/opt/common5/mdt/20230709/ctr1_grid_mdt_traffic_cell_20230709.zip
# -rw-r--r--. 1 root root 51028757 Jul 10 00:03 /var/opt/common5/mdt/20230709/19/ue_meas.zip
# -rw-r--r--. 1 root root 35963044 Jul 10 00:32 /var/opt/common5/mdt/20230709/19/mdt_result.zip
# -rw-r--r--. 1 root root 24896848 Jul  9 23:43 /var/opt/common5/mdt/20230709/19/ue_traffic.zip
# -rw-r--r--. 1 root root 661716 Jul  9 23:41 /var/opt/common5/mdt/20230709/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 319883580 Jul 10 01:17 /var/opt/common5/mdt/20230709/19/ta_histogram.zip
# -rw-r--r--. 1 root root 40835002 Jul 10 10:08 /var/opt/common5/mdt/20230709/grid_mdt_traffic_cell_20230709.zip
# -rw-r--r--. 1 root root 52975772 Jul 10 03:15 /var/opt/common5/mdt/20230709/22/ue_meas.zip
# -rw-r--r--. 1 root root 35870683 Jul 10 03:32 /var/opt/common5/mdt/20230709/22/mdt_result.zip
# -rw-r--r--. 1 root root 26251617 Jul 10 03:11 /var/opt/common5/mdt/20230709/22/ue_traffic.zip
# -rw-r--r--. 1 root root 932780 Jul 10 02:59 /var/opt/common5/mdt/20230709/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 360235761 Jul 10 05:05 /var/opt/common5/mdt/20230709/22/ta_histogram.zip
# -rw-r--r--. 1 root root 68568516 Jul  9 16:20 /var/opt/common5/mdt/20230709/12/ue_meas.zip
# -rw-r--r--. 1 root root 48485812 Jul  9 16:24 /var/opt/common5/mdt/20230709/12/mdt_result.zip
# -rw-r--r--. 1 root root 33474805 Jul  9 16:17 /var/opt/common5/mdt/20230709/12/ue_traffic.zip
# -rw-r--r--. 1 root root 878791 Jul  9 16:14 /var/opt/common5/mdt/20230709/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 421037971 Jul  9 16:59 /var/opt/common5/mdt/20230709/12/ta_histogram.zip
# -rw-r--r--. 1 root root 12143313 Jul 10 10:55 /var/opt/common5/mdt/20230709/ctr1_filter_mdt_result.zip
# -rw-r--r--. 1 root root 50167597 Jul 21 08:56 /var/opt/common5/mdt/20230709/filter_ue_meas.zip
# -rw-r--r--. 1 root root 71348100 Jul  9 18:18 /var/opt/common5/mdt/20230709/14/ue_meas.zip
# -rw-r--r--. 1 root root 50721863 Jul  9 18:22 /var/opt/common5/mdt/20230709/14/mdt_result.zip
# -rw-r--r--. 1 root root 34896273 Jul  9 18:15 /var/opt/common5/mdt/20230709/14/ue_traffic.zip
# -rw-r--r--. 1 root root 925075 Jul  9 18:13 /var/opt/common5/mdt/20230709/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 438123646 Jul  9 20:12 /var/opt/common5/mdt/20230709/14/ta_histogram.zip
# -rw-r--r--. 1 root root 46206885 Jul  9 10:03 /var/opt/common5/mdt/20230709/06/ue_meas.zip
# -rw-r--r--. 1 root root 8890129 Jul  9 10:04 /var/opt/common5/mdt/20230709/06/mdt_result.zip
# -rw-r--r--. 1 root root 21532846 Jul  9 10:01 /var/opt/common5/mdt/20230709/06/ue_traffic.zip
# -rw-r--r--. 1 root root 1145060 Jul  9 10:01 /var/opt/common5/mdt/20230709/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 97995818 Jul  9 10:08 /var/opt/common5/mdt/20230709/06/ta_histogram.zip
# -rw-r--r--. 1 root root 4767790 Jul 10 10:55 /var/opt/common5/mdt/20230709/ctr2_ue_capability_20230709.zip
# -rw-r--r--. 1 root root 72613381 Jul  9 22:44 /var/opt/common5/mdt/20230709/18/ue_meas.zip
# -rw-r--r--. 1 root root 7029273496 Jul 10 01:00 /var/opt/common5/mdt/20230709/18/ta_histogram.csv
# -rw-r--r--. 1 root root 51144777 Jul  9 22:50 /var/opt/common5/mdt/20230709/18/mdt_result.zip
# -rw-r--r--. 1 root root 35509461 Jul  9 22:21 /var/opt/common5/mdt/20230709/18/ue_traffic.zip
# -rw-r--r--. 1 root root 892978 Jul  9 22:19 /var/opt/common5/mdt/20230709/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 8685947 Jul 10 01:02 /var/opt/common5/mdt/20230709/18/ta_histogram.zip
# -rw-r--r--. 1 root root 35655633 Jul 10 10:55 /var/opt/common5/mdt/20230709/ctr1_grid_mdt_cell_20230709.zip
# -rw-r--r--. 1 root root 74466203 Jul  7 12:18 /var/opt/common5/mdt/20230707/08/ue_meas.zip
# -rw-r--r--. 1 root root 52068512 Jul  7 12:22 /var/opt/common5/mdt/20230707/08/mdt_result.zip
# -rw-r--r--. 1 root root 36546871 Jul  7 12:16 /var/opt/common5/mdt/20230707/08/ue_traffic.zip
# -rw-r--r--. 1 root root 895066 Jul  7 12:14 /var/opt/common5/mdt/20230707/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 410867764 Jul  7 13:00 /var/opt/common5/mdt/20230707/08/ta_histogram.zip
# -rw-r--r--. 1 root root 75179753 Jul  8 00:36 /var/opt/common5/mdt/20230707/20/ue_meas.zip
# -rw-r--r--. 1 root root 53294398 Jul  8 00:40 /var/opt/common5/mdt/20230707/20/mdt_result.zip
# -rw-r--r--. 1 root root 36610135 Jul  8 00:34 /var/opt/common5/mdt/20230707/20/ue_traffic.zip
# -rw-r--r--. 1 root root 948466 Jul  8 00:33 /var/opt/common5/mdt/20230707/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 448032082 Jul  8 00:58 /var/opt/common5/mdt/20230707/20/ta_histogram.zip
# -rw-r--r--. 1 root root 87870936 Jul  7 20:37 /var/opt/common5/mdt/20230707/16/ue_meas.zip
# -rw-r--r--. 1 root root 62926266 Jul  7 20:42 /var/opt/common5/mdt/20230707/16/mdt_result.zip
# -rw-r--r--. 1 root root 42783646 Jul  7 20:33 /var/opt/common5/mdt/20230707/16/ue_traffic.zip
# -rw-r--r--. 1 root root 1092311 Jul  7 20:31 /var/opt/common5/mdt/20230707/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 529449277 Jul  7 21:31 /var/opt/common5/mdt/20230707/16/ta_histogram.zip
# -rw-r--r--. 1 root root 12508948 Jul  8 10:59 /var/opt/common5/mdt/20230707/ctr1_filter_ue_traffic.zip
# -rw-r--r--. 1 root root 70713610 Jul  7 21:34 /var/opt/common5/mdt/20230707/17/ue_meas.zip
# -rw-r--r--. 1 root root 51258682 Jul  7 21:38 /var/opt/common5/mdt/20230707/17/mdt_result.zip
# -rw-r--r--. 1 root root 34385465 Jul  7 21:30 /var/opt/common5/mdt/20230707/17/ue_traffic.zip
# -rw-r--r--. 1 root root 802996 Jul  7 21:28 /var/opt/common5/mdt/20230707/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 410447224 Jul  7 22:11 /var/opt/common5/mdt/20230707/17/ta_histogram.zip
# -rw-r--r--. 1 root root 78801974 Jul  7 15:35 /var/opt/common5/mdt/20230707/11/ue_meas.zip
# -rw-r--r--. 1 root root 56160788 Jul  7 15:40 /var/opt/common5/mdt/20230707/11/mdt_result.zip
# -rw-r--r--. 1 root root 38406245 Jul  7 15:32 /var/opt/common5/mdt/20230707/11/ue_traffic.zip
# -rw-r--r--. 1 root root 1001632 Jul  7 15:30 /var/opt/common5/mdt/20230707/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 486977688 Jul  7 16:25 /var/opt/common5/mdt/20230707/11/ta_histogram.zip
# -rw-r--r--. 1 root root 4880299 Jul  8 10:56 /var/opt/common5/mdt/20230707/ctr2_ue_capability_20230707.zip
# -rw-r--r--. 1 root root 39630096 Jul  7 09:29 /var/opt/common5/mdt/20230707/05/ue_meas.zip
# -rw-r--r--. 1 root root 26778429 Jul  7 09:34 /var/opt/common5/mdt/20230707/05/mdt_result.zip
# -rw-r--r--. 1 root root 20603832 Jul  7 09:26 /var/opt/common5/mdt/20230707/05/ue_traffic.zip
# -rw-r--r--. 1 root root 1231370 Jul  7 09:24 /var/opt/common5/mdt/20230707/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 335478497 Jul  7 10:00 /var/opt/common5/mdt/20230707/05/ta_histogram.zip
# -rw-r--r--. 1 root root 49643277 Jul  7 04:33 /var/opt/common5/mdt/20230707/00/ue_meas.zip
# -rw-r--r--. 1 root root 34124994 Jul  7 04:35 /var/opt/common5/mdt/20230707/00/mdt_result.zip
# -rw-r--r--. 1 root root 25131098 Jul  7 04:31 /var/opt/common5/mdt/20230707/00/ue_traffic.zip
# -rw-r--r--. 1 root root 1253071 Jul  7 04:30 /var/opt/common5/mdt/20230707/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 399095872 Jul  7 05:59 /var/opt/common5/mdt/20230707/00/ta_histogram.zip
# -rw-r--r--. 1 root root 73729831 Jul  7 11:13 /var/opt/common5/mdt/20230707/07/ue_meas.zip
# -rw-r--r--. 1 root root 51232764 Jul  7 11:18 /var/opt/common5/mdt/20230707/07/mdt_result.zip
# -rw-r--r--. 1 root root 36615090 Jul  7 11:09 /var/opt/common5/mdt/20230707/07/ue_traffic.zip
# -rw-r--r--. 1 root root 1011859 Jul  7 11:08 /var/opt/common5/mdt/20230707/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 424654598 Jul  7 11:59 /var/opt/common5/mdt/20230707/07/ta_histogram.zip
# -rw-r--r--. 1 root root 92926978 Jul  8 10:59 /var/opt/common5/mdt/20230707/ctr1_grid_mdt_meas_cell_20230707.zip
# -rw-r--r--. 1 root root 56406851 Jul  7 19:31 /var/opt/common5/mdt/20230707/15/ue_meas.zip
# -rw-r--r--. 1 root root 40122461 Jul  7 19:34 /var/opt/common5/mdt/20230707/15/mdt_result.zip
# -rw-r--r--. 1 root root 27501150 Jul  7 19:29 /var/opt/common5/mdt/20230707/15/ue_traffic.zip
# -rw-r--r--. 1 root root 733399 Jul  7 19:28 /var/opt/common5/mdt/20230707/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 351539658 Jul  7 20:03 /var/opt/common5/mdt/20230707/15/ta_histogram.zip
# -rw-r--r--. 1 root root 65817816 Jul  7 14:22 /var/opt/common5/mdt/20230707/10/ue_meas.zip
# -rw-r--r--. 1 root root 47036162 Jul  7 14:27 /var/opt/common5/mdt/20230707/10/mdt_result.zip
# -rw-r--r--. 1 root root 32059752 Jul  7 14:20 /var/opt/common5/mdt/20230707/10/ue_traffic.zip
# -rw-r--r--. 1 root root 804035 Jul  7 14:19 /var/opt/common5/mdt/20230707/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 391152704 Jul  7 15:02 /var/opt/common5/mdt/20230707/10/ta_histogram.zip
# -rw-r--r--. 1 root root 23715892 Jul  7 07:48 /var/opt/common5/mdt/20230707/03/ue_meas.zip
# -rw-r--r--. 1 root root 15391913 Jul  7 07:51 /var/opt/common5/mdt/20230707/03/mdt_result.zip
# -rw-r--r--. 1 root root 12486570 Jul  7 07:45 /var/opt/common5/mdt/20230707/03/ue_traffic.zip
# -rw-r--r--. 1 root root 996705 Jul  7 07:42 /var/opt/common5/mdt/20230707/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 237359400 Jul  7 08:09 /var/opt/common5/mdt/20230707/03/ta_histogram.zip
# -rw-r--r--. 1 root root 25372300 Jul  8 10:59 /var/opt/common5/mdt/20230707/ctr1_filter_ue_meas.zip
# -rw-r--r--. 1 root root 75760880 Jul  7 17:37 /var/opt/common5/mdt/20230707/13/ue_meas.zip
# -rw-r--r--. 1 root root 54364312 Jul  7 17:41 /var/opt/common5/mdt/20230707/13/mdt_result.zip
# -rw-r--r--. 1 root root 36867550 Jul  7 17:34 /var/opt/common5/mdt/20230707/13/ue_traffic.zip
# -rw-r--r--. 1 root root 939895 Jul  7 17:32 /var/opt/common5/mdt/20230707/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 464947250 Jul  7 18:23 /var/opt/common5/mdt/20230707/13/ta_histogram.zip
# -rw-r--r--. 1 root root 63519407 Jul  8 03:54 /var/opt/common5/mdt/20230707/23/ue_meas.zip
# -rw-r--r--. 1 root root 43791508 Jul  8 03:57 /var/opt/common5/mdt/20230707/23/mdt_result.zip
# -rw-r--r--. 1 root root 31705518 Jul  8 03:52 /var/opt/common5/mdt/20230707/23/ue_traffic.zip
# -rw-r--r--. 1 root root 1223914 Jul  8 03:51 /var/opt/common5/mdt/20230707/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 453941716 Jul  8 04:32 /var/opt/common5/mdt/20230707/23/ta_histogram.zip
# -rw-r--r--. 1 root root 14671297 Jul  7 05:45 /var/opt/common5/mdt/20230707/01/ue_meas.zip
# -rw-r--r--. 1 root root 9933968 Jul  7 05:46 /var/opt/common5/mdt/20230707/01/mdt_result.zip
# -rw-r--r--. 1 root root 7554817 Jul  7 05:43 /var/opt/common5/mdt/20230707/01/ue_traffic.zip
# -rw-r--r--. 1 root root 484754 Jul  7 05:42 /var/opt/common5/mdt/20230707/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 132106794 Jul  7 05:53 /var/opt/common5/mdt/20230707/01/ta_histogram.zip
# -rw-r--r--. 1 root root 54277530 Jul  7 23:55 /var/opt/common5/mdt/20230707/19/ue_meas.zip
# -rw-r--r--. 1 root root 39139622 Jul  7 23:59 /var/opt/common5/mdt/20230707/19/mdt_result.zip
# -rw-r--r--. 1 root root 26369727 Jul  7 23:37 /var/opt/common5/mdt/20230707/19/ue_traffic.zip
# -rw-r--r--. 1 root root 649488 Jul  7 23:29 /var/opt/common5/mdt/20230707/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 324261216 Jul  8 00:21 /var/opt/common5/mdt/20230707/19/ta_histogram.zip
# -rw-r--r--. 1 root root 82017937 Jul  8 02:48 /var/opt/common5/mdt/20230707/22/ue_meas.zip
# -rw-r--r--. 1 root root 56574233 Jul  8 02:51 /var/opt/common5/mdt/20230707/22/mdt_result.zip
# -rw-r--r--. 1 root root 40449671 Jul  8 02:46 /var/opt/common5/mdt/20230707/22/ue_traffic.zip
# -rw-r--r--. 1 root root 1265783 Jul  8 02:45 /var/opt/common5/mdt/20230707/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 535341558 Jul  8 03:35 /var/opt/common5/mdt/20230707/22/ta_histogram.zip
# -rw-r--r--. 1 root root 62531590 Jul  8 10:58 /var/opt/common5/mdt/20230707/ctr1_grid_mdt_traffic_cell_20230707.zip
# -rw-r--r--. 1 root root 59910225 Jul  7 16:31 /var/opt/common5/mdt/20230707/12/ue_meas.zip
# -rw-r--r--. 1 root root 42369024 Jul  7 16:35 /var/opt/common5/mdt/20230707/12/mdt_result.zip
# -rw-r--r--. 1 root root 29301033 Jul  7 16:29 /var/opt/common5/mdt/20230707/12/ue_traffic.zip
# -rw-r--r--. 1 root root 802712 Jul  7 16:27 /var/opt/common5/mdt/20230707/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 385591308 Jul  7 17:11 /var/opt/common5/mdt/20230707/12/ta_histogram.zip
# -rw-r--r--. 1 root root 30040748 Jul  7 08:33 /var/opt/common5/mdt/20230707/04/ue_meas.zip
# -rw-r--r--. 1 root root 19512115 Jul  7 08:37 /var/opt/common5/mdt/20230707/04/mdt_result.zip
# -rw-r--r--. 1 root root 15868926 Jul  7 08:31 /var/opt/common5/mdt/20230707/04/ue_traffic.zip
# -rw-r--r--. 1 root root 1220705 Jul  7 08:29 /var/opt/common5/mdt/20230707/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 291815310 Jul  7 08:57 /var/opt/common5/mdt/20230707/04/ta_histogram.zip
# -rw-r--r--. 1 root root 3405810 Jul  8 10:56 /var/opt/common5/mdt/20230707/ctr1_ue_capability_20230707.zip
# -rw-r--r--. 1 root root 12993372 Jul  8 10:59 /var/opt/common5/mdt/20230707/ctr1_filter_mdt_result.zip
# -rw-r--r--. 1 root root 70896884 Jul  7 18:32 /var/opt/common5/mdt/20230707/14/ue_meas.zip
# -rw-r--r--. 1 root root 50877086 Jul  7 18:37 /var/opt/common5/mdt/20230707/14/mdt_result.zip
# -rw-r--r--. 1 root root 34523595 Jul  7 18:29 /var/opt/common5/mdt/20230707/14/ue_traffic.zip
# -rw-r--r--. 1 root root 931703 Jul  7 18:27 /var/opt/common5/mdt/20230707/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 448815682 Jul  7 19:25 /var/opt/common5/mdt/20230707/14/ta_histogram.zip
# -rw-r--r--. 1 root root 59631765 Jul  7 10:25 /var/opt/common5/mdt/20230707/06/ue_meas.zip
# -rw-r--r--. 1 root root 41158448 Jul  7 10:29 /var/opt/common5/mdt/20230707/06/mdt_result.zip
# -rw-r--r--. 1 root root 30257256 Jul  7 10:21 /var/opt/common5/mdt/20230707/06/ue_traffic.zip
# -rw-r--r--. 1 root root 1158242 Jul  7 10:18 /var/opt/common5/mdt/20230707/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 401476225 Jul  7 11:04 /var/opt/common5/mdt/20230707/06/ta_histogram.zip
# -rw-r--r--. 1 root root 36561314 Jul  8 10:57 /var/opt/common5/mdt/20230707/ctr1_grid_mdt_cell_20230707.zip
# -rw-r--r--. 1 root root 87975821 Jul  7 22:41 /var/opt/common5/mdt/20230707/18/ue_meas.zip
# -rw-r--r--. 1 root root 63609644 Jul  7 22:46 /var/opt/common5/mdt/20230707/18/mdt_result.zip
# -rw-r--r--. 1 root root 42799458 Jul  7 22:38 /var/opt/common5/mdt/20230707/18/ue_traffic.zip
# -rw-r--r--. 1 root root 1008446 Jul  7 22:36 /var/opt/common5/mdt/20230707/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 504237042 Jul  7 23:54 /var/opt/common5/mdt/20230707/18/ta_histogram.zip
# -rw-r--r--. 1 root root 83455499 Jul  7 13:25 /var/opt/common5/mdt/20230707/09/ue_meas.zip
# -rw-r--r--. 1 root root 59112279 Jul  7 13:30 /var/opt/common5/mdt/20230707/09/mdt_result.zip
# -rw-r--r--. 1 root root 40736254 Jul  7 13:22 /var/opt/common5/mdt/20230707/09/ue_traffic.zip
# -rw-r--r--. 1 root root 990345 Jul  7 13:19 /var/opt/common5/mdt/20230707/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 473582802 Jul  7 14:17 /var/opt/common5/mdt/20230707/09/ta_histogram.zip
# -rw-r--r--. 1 root root 3107484 Jul  8 13:31 /var/opt/common5/mdt/20230708/08/ue_meas.zip
# -rw-r--r--. 1 root root 2161000 Jul  8 13:31 /var/opt/common5/mdt/20230708/08/mdt_result.zip
# -rw-r--r--. 1 root root 1536379 Jul  8 13:31 /var/opt/common5/mdt/20230708/08/ue_traffic.zip
# -rw-r--r--. 1 root root 45103 Jul  8 13:31 /var/opt/common5/mdt/20230708/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 17540291 Jul  8 13:31 /var/opt/common5/mdt/20230708/08/ta_histogram.zip
# -rw-r--r--. 1 root root 12378417 Jul  9 10:57 /var/opt/common5/mdt/20230708/ctr1_filter_ue_traffic.zip
# -rw-r--r--. 1 root root 9302736 Jul 21 08:34 /var/opt/common5/mdt/20230708/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 17224608 Jul  8 10:07 /var/opt/common5/mdt/20230708/05/ue_meas.zip
# -rw-r--r--. 1 root root 11378648 Jul  8 10:12 /var/opt/common5/mdt/20230708/05/mdt_result.zip
# -rw-r--r--. 1 root root 8964833 Jul  8 10:03 /var/opt/common5/mdt/20230708/05/ue_traffic.zip
# -rw-r--r--. 1 root root 549981 Jul  8 09:58 /var/opt/common5/mdt/20230708/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 148971999 Jul  8 13:40 /var/opt/common5/mdt/20230708/05/ta_histogram.zip
# -rw-r--r--. 1 root root 36628396 Jul  9 10:57 /var/opt/common5/mdt/20230708/ctr1_grid_mdt_cell_20230708.zip
# -rw-r--r--. 1 root root 7166553 Jul 21 08:33 /var/opt/common5/mdt/20230708/filter_mdt_result.zip
# -rw-r--r--. 1 root root 26241140 Jul  8 06:37 /var/opt/common5/mdt/20230708/02/ue_meas.zip
# -rw-r--r--. 1 root root 17316342 Jul  8 06:39 /var/opt/common5/mdt/20230708/02/mdt_result.zip
# -rw-r--r--. 1 root root 13658699 Jul  8 06:36 /var/opt/common5/mdt/20230708/02/ue_traffic.zip
# -rw-r--r--. 1 root root 1019120 Jul  8 06:35 /var/opt/common5/mdt/20230708/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 256934807 Jul  8 08:10 /var/opt/common5/mdt/20230708/02/ta_histogram.zip
# -rw-r--r--. 1 root root 51357031 Jul  8 04:41 /var/opt/common5/mdt/20230708/00/ue_meas.zip
# -rw-r--r--. 1 root root 34863273 Jul  8 04:44 /var/opt/common5/mdt/20230708/00/mdt_result.zip
# -rw-r--r--. 1 root root 26020318 Jul  8 04:40 /var/opt/common5/mdt/20230708/00/ue_traffic.zip
# -rw-r--r--. 1 root root 1246898 Jul  8 04:39 /var/opt/common5/mdt/20230708/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 406445184 Jul  8 05:14 /var/opt/common5/mdt/20230708/00/ta_histogram.zip
# -rw-r--r--. 1 root root 47252287 Jul  9 10:56 /var/opt/common5/mdt/20230708/ctr2_grid_mdt_traffic_cell_20230708.zip
# -rw-r--r--. 1 root root 32657308 Jul  8 21:11 /var/opt/common5/mdt/20230708/15/ue_meas.zip
# -rw-r--r--. 1 root root 23473079 Jul  8 21:14 /var/opt/common5/mdt/20230708/15/mdt_result.zip
# -rw-r--r--. 1 root root 15957432 Jul  8 21:09 /var/opt/common5/mdt/20230708/15/ue_traffic.zip
# -rw-r--r--. 1 root root 413793 Jul  8 21:08 /var/opt/common5/mdt/20230708/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 187238509 Jul  8 21:25 /var/opt/common5/mdt/20230708/15/ta_histogram.zip
# -rw-r--r--. 1 root root 4588450 Jul  9 10:55 /var/opt/common5/mdt/20230708/ctr2_ue_capability_20230708.zip
# -rw-r--r--. 1 root root 93673260 Jul  9 10:57 /var/opt/common5/mdt/20230708/ctr1_grid_mdt_meas_cell_20230708.zip
# -rw-r--r--. 1 root root 25073573 Jul  9 10:57 /var/opt/common5/mdt/20230708/ctr1_filter_ue_meas.zip
# -rw-r--r--. 1 root root 75036511 Jul  9 10:57 /var/opt/common5/mdt/20230708/ctr2_grid_mdt_meas_cell_20230708.zip
# -rw-r--r--. 1 root root 60173111 Jul  9 01:46 /var/opt/common5/mdt/20230708/21/ue_meas.zip
# -rw-r--r--. 1 root root 21351950 Jul  9 01:51 /var/opt/common5/mdt/20230708/21/mdt_result.zip
# -rw-r--r--. 1 root root 29723595 Jul  9 01:42 /var/opt/common5/mdt/20230708/21/ue_traffic.zip
# -rw-r--r--. 1 root root 1108529 Jul  9 01:39 /var/opt/common5/mdt/20230708/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 195363084 Jul  9 02:23 /var/opt/common5/mdt/20230708/21/ta_histogram.zip
# -rw-r--r--. 1 root root 63812169 Jul  9 03:00 /var/opt/common5/mdt/20230708/23/ue_meas.zip
# -rw-r--r--. 1 root root 4877222 Jul  9 03:00 /var/opt/common5/mdt/20230708/23/mdt_result.zip
# -rw-r--r--. 1 root root 29401323 Jul  9 02:59 /var/opt/common5/mdt/20230708/23/ue_traffic.zip
# -rw-r--r--. 1 root root 1264513 Jul  9 02:58 /var/opt/common5/mdt/20230708/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 51775852 Jul  9 03:02 /var/opt/common5/mdt/20230708/23/ta_histogram.zip
# -rw-r--r--. 1 root root 62896449 Jul  9 10:57 /var/opt/common5/mdt/20230708/ctr1_grid_mdt_traffic_cell_20230708.zip
# -rw-r--r--. 1 root root 41347270 Jul  9 00:31 /var/opt/common5/mdt/20230708/19/ue_meas.zip
# -rw-r--r--. 1 root root 27047776 Jul  9 00:46 /var/opt/common5/mdt/20230708/19/mdt_result.zip
# -rw-r--r--. 1 root root 20287295 Jul  9 00:18 /var/opt/common5/mdt/20230708/19/ue_traffic.zip
# -rw-r--r--. 1 root root 538226 Jul  9 00:14 /var/opt/common5/mdt/20230708/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 228864384 Jul  9 01:41 /var/opt/common5/mdt/20230708/19/ta_histogram.zip
# -rw-r--r--. 1 root root 39092013 Jul  8 16:34 /var/opt/common5/mdt/20230708/12/ue_meas.zip
# -rw-r--r--. 1 root root 27968392 Jul  8 16:39 /var/opt/common5/mdt/20230708/12/mdt_result.zip
# -rw-r--r--. 1 root root 19015065 Jul  8 16:33 /var/opt/common5/mdt/20230708/12/ue_traffic.zip
# -rw-r--r--. 1 root root 460160 Jul  8 16:32 /var/opt/common5/mdt/20230708/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 228308227 Jul  8 16:53 /var/opt/common5/mdt/20230708/12/ta_histogram.zip
# -rw-r--r--. 1 root root 21396315 Jul  8 08:17 /var/opt/common5/mdt/20230708/04/ue_meas.zip
# -rw-r--r--. 1 root root 13779239 Jul  8 08:22 /var/opt/common5/mdt/20230708/04/mdt_result.zip
# -rw-r--r--. 1 root root 11285821 Jul  8 08:13 /var/opt/common5/mdt/20230708/04/ue_traffic.zip
# -rw-r--r--. 1 root root 841779 Jul  8 08:10 /var/opt/common5/mdt/20230708/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 208224453 Jul  8 09:04 /var/opt/common5/mdt/20230708/04/ta_histogram.zip
# -rw-r--r--. 1 root root 12719267 Jul  9 10:57 /var/opt/common5/mdt/20230708/ctr1_filter_mdt_result.zip
# -rw-r--r--. 1 root root 20126948 Jul 21 08:36 /var/opt/common5/mdt/20230708/filter_ue_meas.zip
# -rw-r--r--. 1 root root 29105754 Jul  9 10:55 /var/opt/common5/mdt/20230708/ctr2_grid_mdt_cell_20230708.zip
# -rw-r--r--. 1 root root 38323011 Jul  8 18:53 /var/opt/common5/mdt/20230708/14/ue_meas.zip
# -rw-r--r--. 1 root root 27822720 Jul  8 18:57 /var/opt/common5/mdt/20230708/14/mdt_result.zip
# -rw-r--r--. 1 root root 18694372 Jul  8 18:51 /var/opt/common5/mdt/20230708/14/ue_traffic.zip
# -rw-r--r--. 1 root root 494375 Jul  8 18:48 /var/opt/common5/mdt/20230708/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 223786896 Jul  8 22:51 /var/opt/common5/mdt/20230708/14/ta_histogram.zip
# -rw-r--r--. 1 root root 28643672 Jul  8 11:21 /var/opt/common5/mdt/20230708/06/ue_meas.zip
# -rw-r--r--. 1 root root 19498967 Jul  8 11:25 /var/opt/common5/mdt/20230708/06/mdt_result.zip
# -rw-r--r--. 1 root root 14613464 Jul  8 11:18 /var/opt/common5/mdt/20230708/06/ue_traffic.zip
# -rw-r--r--. 1 root root 667609 Jul  8 11:15 /var/opt/common5/mdt/20230708/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 203716265 Jul  8 13:47 /var/opt/common5/mdt/20230708/06/ta_histogram.zip
# -rw-r--r--. 1 root root 3376037 Jul  9 10:57 /var/opt/common5/mdt/20230708/ctr1_ue_capability_20230708.zip
# -rw-r--r--. 1 root root 3449307 Jul  9 09:03 /var/opt/common5/mdt/20230708/ue_capability_20230708.zip
# -rw-r--r--. 1 root root 2206848 Jul 13 15:13 /var/opt/common5/mdt/20230607/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 2000056 Jul 13 15:11 /var/opt/common5/mdt/20230607/filter_mdt_result.zip
# -rw-r--r--. 1 root root 4891418 Jul 13 15:18 /var/opt/common5/mdt/20230607/filter_ue_meas.zip
# -rw-r--r--. 1 root root 78215231 Jul 22 12:29 /var/opt/common5/mdt/20230722/08/ue_meas.zip
# -rw-r--r--. 1 root root 53796795 Jul 22 12:34 /var/opt/common5/mdt/20230722/08/mdt_result.zip
# -rw-r--r--. 1 root root 38260283 Jul 22 12:25 /var/opt/common5/mdt/20230722/08/ue_traffic.zip
# -rw-r--r--. 1 root root 1037289 Jul 22 12:23 /var/opt/common5/mdt/20230722/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 482317680 Jul 22 13:17 /var/opt/common5/mdt/20230722/08/ta_histogram.zip
# -rw-r--r--. 1 root root 51644868 Jul 23 00:41 /var/opt/common5/mdt/20230722/20/ue_meas.zip
# -rw-r--r--. 1 root root 35377739 Jul 23 00:45 /var/opt/common5/mdt/20230722/20/mdt_result.zip
# -rw-r--r--. 1 root root 24970412 Jul 23 00:39 /var/opt/common5/mdt/20230722/20/ue_traffic.zip
# -rw-r--r--. 1 root root 638770 Jul 23 00:35 /var/opt/common5/mdt/20230722/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 343289073 Jul 23 01:10 /var/opt/common5/mdt/20230722/20/ta_histogram.zip
# -rw-r--r--. 1 root root 3393666 Jul 23 10:55 /var/opt/common5/mdt/20230722/ctr1_ue_capability_20230722.zip
# -rw-r--r--. 1 root root 74780442 Jul 23 10:55 /var/opt/common5/mdt/20230722/ctr2_grid_mdt_meas_cell_20230722.zip
# -rw-r--r--. 1 root root 12801903 Jul 23 10:56 /var/opt/common5/mdt/20230722/ctr1_filter_ue_traffic.zip
# -rw-r--r--. 1 root root 1927586 Jul 27 14:45 /var/opt/common5/mdt/20230722/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 589 Jul 23 08:10 /var/opt/common5/mdt/20230722/mdt_bm_20230722.zip
# -rw-r--r--. 1 root root 90820140 Jul 22 21:19 /var/opt/common5/mdt/20230722/17/ue_meas.zip
# -rw-r--r--. 1 root root 63541012 Jul 22 21:24 /var/opt/common5/mdt/20230722/17/mdt_result.zip
# -rw-r--r--. 1 root root 43909014 Jul 22 21:16 /var/opt/common5/mdt/20230722/17/ue_traffic.zip
# -rw-r--r--. 1 root root 1020516 Jul 22 21:13 /var/opt/common5/mdt/20230722/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 73645191 Jul 22 15:30 /var/opt/common5/mdt/20230722/11/ue_meas.zip
# -rw-r--r--. 1 root root 52266188 Jul 22 15:34 /var/opt/common5/mdt/20230722/11/mdt_result.zip
# -rw-r--r--. 1 root root 35616109 Jul 22 15:27 /var/opt/common5/mdt/20230722/11/ue_traffic.zip
# -rw-r--r--. 1 root root 890462 Jul 22 15:25 /var/opt/common5/mdt/20230722/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 462715103 Jul 22 16:24 /var/opt/common5/mdt/20230722/11/ta_histogram.zip
# -rw-r--r--. 1 root root 40620137 Jul 22 08:58 /var/opt/common5/mdt/20230722/05/ue_meas.zip
# -rw-r--r--. 1 root root 26707991 Jul 22 09:01 /var/opt/common5/mdt/20230722/05/mdt_result.zip
# -rw-r--r--. 1 root root 20828696 Jul 22 08:57 /var/opt/common5/mdt/20230722/05/ue_traffic.zip
# -rw-r--r--. 1 root root 1238060 Jul 22 08:56 /var/opt/common5/mdt/20230722/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 377284948 Jul 22 09:31 /var/opt/common5/mdt/20230722/05/ta_histogram.zip
# -rw-r--r--. 1 root root 2228892 Jul 27 14:43 /var/opt/common5/mdt/20230722/filter_mdt_result.zip
# -rw-r--r--. 1 root root 33392170 Jul 22 06:58 /var/opt/common5/mdt/20230722/02/ue_meas.zip
# -rw-r--r--. 1 root root 21745941 Jul 22 07:00 /var/opt/common5/mdt/20230722/02/mdt_result.zip
# -rw-r--r--. 1 root root 17106367 Jul 22 06:56 /var/opt/common5/mdt/20230722/02/ue_traffic.zip
# -rw-r--r--. 1 root root 1192789 Jul 22 06:54 /var/opt/common5/mdt/20230722/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 339095117 Jul 22 07:44 /var/opt/common5/mdt/20230722/02/ta_histogram.zip
# -rw-r--r--. 1 root root 50716595 Jul 22 04:34 /var/opt/common5/mdt/20230722/00/ue_meas.zip
# -rw-r--r--. 1 root root 34049894 Jul 22 04:36 /var/opt/common5/mdt/20230722/00/mdt_result.zip
# ...
# -rw-r--r--. 1 root root 3421336 Jul 11 10:55 /var/opt/common5/mdt/20230710/ctr1_ue_capability_20230710.zip
# -rw-r--r--. 1 root root 40790328 Jul 11 21:04 /var/opt/common5/mdt/20230710/grid_mdt_traffic_cell_20230710.zip
# -rw-r--r--. 1 root root 64436661 Jul 10 19:53 /var/opt/common5/mdt/20230710/15/ue_meas.zip
# -rw-r--r--. 1 root root 46540316 Jul 10 20:03 /var/opt/common5/mdt/20230710/15/mdt_result.zip
# -rw-r--r--. 1 root root 31350374 Jul 10 19:38 /var/opt/common5/mdt/20230710/15/ue_traffic.zip
# -rw-r--r--. 1 root root 810891 Jul 10 19:35 /var/opt/common5/mdt/20230710/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 407992852 Jul 10 21:14 /var/opt/common5/mdt/20230710/15/ta_histogram.zip
# -rw-r--r--. 1 root root 76138839 Jul 10 14:53 /var/opt/common5/mdt/20230710/10/ue_meas.zip
# -rw-r--r--. 1 root root 54667466 Jul 10 14:59 /var/opt/common5/mdt/20230710/10/mdt_result.zip
# -rw-r--r--. 1 root root 37004437 Jul 10 14:49 /var/opt/common5/mdt/20230710/10/ue_traffic.zip
# -rw-r--r--. 1 root root 926633 Jul 10 14:45 /var/opt/common5/mdt/20230710/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 472116119 Jul 10 16:04 /var/opt/common5/mdt/20230710/10/ta_histogram.zip
# -rw-r--r--. 1 root root 25024931 Jul 11 10:55 /var/opt/common5/mdt/20230710/ctr1_filter_ue_meas.zip
# -rw-r--r--. 1 root root 4653555 Jul 11 10:55 /var/opt/common5/mdt/20230710/ctr2_ue_capability_20230710.zip
# -rw-r--r--. 1 root root 73247594 Jul 10 17:53 /var/opt/common5/mdt/20230710/13/ue_meas.zip
# -rw-r--r--. 1 root root 53016354 Jul 10 17:58 /var/opt/common5/mdt/20230710/13/mdt_result.zip
# -rw-r--r--. 1 root root 35697751 Jul 10 17:49 /var/opt/common5/mdt/20230710/13/ue_traffic.zip
# -rw-r--r--. 1 root root 1018072 Jul 10 17:47 /var/opt/common5/mdt/20230710/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 470136090 Jul 10 18:56 /var/opt/common5/mdt/20230710/13/ta_histogram.zip
# -rw-r--r--. 1 root root 37460529 Jul 11 03:08 /var/opt/common5/mdt/20230710/23/ue_meas.zip
# -rw-r--r--. 1 root root 11119418 Jul 11 03:09 /var/opt/common5/mdt/20230710/23/mdt_result.zip
# -rw-r--r--. 1 root root 18838551 Jul 11 03:06 /var/opt/common5/mdt/20230710/23/ue_traffic.zip
# -rw-r--r--. 1 root root 997450 Jul 11 03:05 /var/opt/common5/mdt/20230710/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 130949384 Jul 11 03:16 /var/opt/common5/mdt/20230710/23/ta_histogram.zip
# -rw-r--r--. 1 root root 34683587 Jul 10 05:46 /var/opt/common5/mdt/20230710/01/ue_meas.zip
# -rw-r--r--. 1 root root 23268419 Jul 10 05:48 /var/opt/common5/mdt/20230710/01/mdt_result.zip
# -rw-r--r--. 1 root root 17921374 Jul 10 05:44 /var/opt/common5/mdt/20230710/01/ue_traffic.zip
# -rw-r--r--. 1 root root 1215354 Jul 10 05:43 /var/opt/common5/mdt/20230710/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 67124940 Jul 11 00:49 /var/opt/common5/mdt/20230710/19/ue_meas.zip
# -rw-r--r--. 1 root root 48536899 Jul 11 01:14 /var/opt/common5/mdt/20230710/19/mdt_result.zip
# -rw-r--r--. 1 root root 32671247 Jul 11 00:29 /var/opt/common5/mdt/20230710/19/ue_traffic.zip
# -rw-r--r--. 1 root root 843327 Jul 11 00:17 /var/opt/common5/mdt/20230710/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 418611681 Jul 11 02:05 /var/opt/common5/mdt/20230710/19/ta_histogram.zip
# -rw-r--r--. 1 root root 36550377 Jul 11 02:29 /var/opt/common5/mdt/20230710/22/ue_meas.zip
# -rw-r--r--. 1 root root 16606665 Jul 11 02:33 /var/opt/common5/mdt/20230710/22/mdt_result.zip
# -rw-r--r--. 1 root root 18382434 Jul 11 02:27 /var/opt/common5/mdt/20230710/22/ue_traffic.zip
# -rw-r--r--. 1 root root 1053854 Jul 11 02:25 /var/opt/common5/mdt/20230710/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 171948484 Jul 11 02:44 /var/opt/common5/mdt/20230710/22/ta_histogram.zip
# -rw-r--r--. 1 root root 13019087 Jul 10 08:57 /var/opt/common5/mdt/20230710/04/ue_meas.zip
# -rw-r--r--. 1 root root 8609653 Jul 10 09:02 /var/opt/common5/mdt/20230710/04/mdt_result.zip
# -rw-r--r--. 1 root root 6989656 Jul 10 08:52 /var/opt/common5/mdt/20230710/04/ue_traffic.zip
# -rw-r--r--. 1 root root 797620 Jul 10 08:49 /var/opt/common5/mdt/20230710/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 126266956 Jul 10 09:16 /var/opt/common5/mdt/20230710/04/ta_histogram.zip
# -rw-r--r--. 1 root root 62554851 Jul 11 10:55 /var/opt/common5/mdt/20230710/ctr1_grid_mdt_traffic_cell_20230710.zip
# -rw-r--r--. 1 root root 12755679 Jul 11 10:55 /var/opt/common5/mdt/20230710/ctr1_filter_mdt_result.zip
# -rw-r--r--. 1 root root 23105878 Jul 11 20:45 /var/opt/common5/mdt/20230710/grid_mdt_cell_20230710.zip
# -rw-r--r--. 1 root root 71497342 Jul 10 19:00 /var/opt/common5/mdt/20230710/14/ue_meas.zip
# -rw-r--r--. 1 root root 51636484 Jul 10 19:08 /var/opt/common5/mdt/20230710/14/mdt_result.zip
# -rw-r--r--. 1 root root 34728824 Jul 10 18:47 /var/opt/common5/mdt/20230710/14/ue_traffic.zip
# -rw-r--r--. 1 root root 890376 Jul 10 18:31 /var/opt/common5/mdt/20230710/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 459856973 Jul 10 19:58 /var/opt/common5/mdt/20230710/14/ta_histogram.zip
# -rw-r--r--. 1 root root 33701432 Jul 10 10:39 /var/opt/common5/mdt/20230710/06/ue_meas.zip
# -rw-r--r--. 1 root root 23477839 Jul 10 10:41 /var/opt/common5/mdt/20230710/06/mdt_result.zip
# -rw-r--r--. 1 root root 17095740 Jul 10 10:34 /var/opt/common5/mdt/20230710/06/ue_traffic.zip
# -rw-r--r--. 1 root root 638476 Jul 10 10:32 /var/opt/common5/mdt/20230710/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 231783048 Jul 10 10:59 /var/opt/common5/mdt/20230710/06/ta_histogram.zip
# -rw-r--r--. 1 root root 59641276 Jul 10 23:10 /var/opt/common5/mdt/20230710/18/ue_meas.zip
# -rw-r--r--. 1 root root 43328900 Jul 10 23:18 /var/opt/common5/mdt/20230710/18/mdt_result.zip
# -rw-r--r--. 1 root root 29144000 Jul 10 23:05 /var/opt/common5/mdt/20230710/18/ue_traffic.zip
# -rw-r--r--. 1 root root 820220 Jul 10 22:55 /var/opt/common5/mdt/20230710/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 360899464 Jul 11 01:15 /var/opt/common5/mdt/20230710/18/ta_histogram.zip
# -rw-r--r--. 1 root root 74357323 Jul 10 13:54 /var/opt/common5/mdt/20230710/09/ue_meas.zip
# -rw-r--r--. 1 root root 52572101 Jul 10 13:59 /var/opt/common5/mdt/20230710/09/mdt_result.zip
# -rw-r--r--. 1 root root 36202854 Jul 10 13:49 /var/opt/common5/mdt/20230710/09/ue_traffic.zip
# -rw-r--r--. 1 root root 886152 Jul 10 13:38 /var/opt/common5/mdt/20230710/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 443614549 Jul 10 14:45 /var/opt/common5/mdt/20230710/09/ta_histogram.zip
# -rw-r--r--. 1 root root 45423211 Jul  4 14:18 /var/opt/common5/mdt/20230704/08/ue_meas.zip
# -rw-r--r--. 1 root root 31973658 Jul  4 14:24 /var/opt/common5/mdt/20230704/08/mdt_result.zip
# -rw-r--r--. 1 root root 22264974 Jul  4 13:53 /var/opt/common5/mdt/20230704/08/ue_traffic.zip
# -rw-r--r--. 1 root root 679181 Jul  4 13:31 /var/opt/common5/mdt/20230704/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 265511389 Jul  4 14:40 /var/opt/common5/mdt/20230704/08/ta_histogram.zip
# -rw-r--r--. 1 root root 32695804 Jul  5 02:06 /var/opt/common5/mdt/20230704/20/ue_meas.zip
# -rw-r--r--. 1 root root 22965470 Jul  5 02:15 /var/opt/common5/mdt/20230704/20/mdt_result.zip
# -rw-r--r--. 1 root root 15961162 Jul  5 02:01 /var/opt/common5/mdt/20230704/20/ue_traffic.zip
# -rw-r--r--. 1 root root 506019 Jul  5 01:03 /var/opt/common5/mdt/20230704/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 208063149 Jul  5 02:49 /var/opt/common5/mdt/20230704/20/ta_histogram.zip
# -rw-r--r--. 1 root root 12370397 Jul  5 10:56 /var/opt/common5/mdt/20230704/ctr1_filter_ue_traffic.zip
# -rw-r--r--. 1 root root 13687474 Jul  5 10:28 /var/opt/common5/mdt/20230704/grid_mdt_cell_20230704.zip
# -rw-r--r--. 1 root root 23200216 Jul  4 22:26 /var/opt/common5/mdt/20230704/17/ue_meas.zip
# -rw-r--r--. 1 root root 16768511 Jul  4 22:31 /var/opt/common5/mdt/20230704/17/mdt_result.zip
# -rw-r--r--. 1 root root 11379007 Jul  4 22:22 /var/opt/common5/mdt/20230704/17/ue_traffic.zip
# -rw-r--r--. 1 root root 401265 Jul  4 22:15 /var/opt/common5/mdt/20230704/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 142374705 Jul  4 22:52 /var/opt/common5/mdt/20230704/17/ta_histogram.zip
# -rw-r--r--. 1 root root 49644722 Jul  5 10:55 /var/opt/common5/mdt/20230704/ctr2_grid_mdt_traffic_cell_20230704.zip
# -rw-r--r--. 1 root root 62380974 Jul  5 10:56 /var/opt/common5/mdt/20230704/ctr1_grid_mdt_traffic_cell_20230704.zip
# -rw-r--r--. 1 root root 19273854 Jul  4 10:14 /var/opt/common5/mdt/20230704/05/ue_meas.zip
# -rw-r--r--. 1 root root 12757119 Jul  4 10:18 /var/opt/common5/mdt/20230704/05/mdt_result.zip
# -rw-r--r--. 1 root root 9936871 Jul  4 10:10 /var/opt/common5/mdt/20230704/05/ue_traffic.zip
# -rw-r--r--. 1 root root 585446 Jul  4 09:56 /var/opt/common5/mdt/20230704/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 165385015 Jul  4 10:39 /var/opt/common5/mdt/20230704/05/ta_histogram.zip
# -rw-r--r--. 1 root root 30934556 Jul  4 06:54 /var/opt/common5/mdt/20230704/02/ue_meas.zip
# -rw-r--r--. 1 root root 20140150 Jul  4 06:58 /var/opt/common5/mdt/20230704/02/mdt_result.zip
# -rw-r--r--. 1 root root 15989945 Jul  4 06:50 /var/opt/common5/mdt/20230704/02/ue_traffic.zip
# -rw-r--r--. 1 root root 1211267 Jul  4 06:49 /var/opt/common5/mdt/20230704/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 322039891 Jul  4 09:45 /var/opt/common5/mdt/20230704/02/ta_histogram.zip
# -rw-r--r--. 1 root root 47494955 Jul  4 04:26 /var/opt/common5/mdt/20230704/00/ue_meas.zip
# -rw-r--r--. 1 root root 31882393 Jul  4 04:29 /var/opt/common5/mdt/20230704/00/mdt_result.zip
# -rw-r--r--. 1 root root 23952923 Jul  4 04:24 /var/opt/common5/mdt/20230704/00/ue_traffic.zip
# -rw-r--r--. 1 root root 1236621 Jul  4 04:23 /var/opt/common5/mdt/20230704/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 405974352 Jul  4 05:19 /var/opt/common5/mdt/20230704/00/ta_histogram.zip
# -rw-r--r--. 1 root root 21274862 Jul  4 11:56 /var/opt/common5/mdt/20230704/07/ue_meas.zip
# -rw-r--r--. 1 root root 14805233 Jul  4 11:59 /var/opt/common5/mdt/20230704/07/mdt_result.zip
# -rw-r--r--. 1 root root 10521699 Jul  4 11:53 /var/opt/common5/mdt/20230704/07/ue_traffic.zip
# -rw-r--r--. 1 root root 332223 Jul  4 11:51 /var/opt/common5/mdt/20230704/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 125474256 Jul  4 12:15 /var/opt/common5/mdt/20230704/07/ta_histogram.zip
# -rw-r--r--. 1 root root 23246705 Jul  5 10:32 /var/opt/common5/mdt/20230704/grid_mdt_traffic_cell_20230704.zip
# -rw-r--r--. 1 root root 35784099 Jul  4 20:53 /var/opt/common5/mdt/20230704/15/ue_meas.zip
# -rw-r--r--. 1 root root 25338120 Jul  4 20:56 /var/opt/common5/mdt/20230704/15/mdt_result.zip
# -rw-r--r--. 1 root root 17428074 Jul  4 20:50 /var/opt/common5/mdt/20230704/15/ue_traffic.zip
# -rw-r--r--. 1 root root 518926 Jul  4 20:42 /var/opt/common5/mdt/20230704/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 233143328 Jul  4 23:15 /var/opt/common5/mdt/20230704/15/ta_histogram.zip
# -rw-r--r--. 1 root root 22720638 Jul  4 14:26 /var/opt/common5/mdt/20230704/10/ue_meas.zip
# -rw-r--r--. 1 root root 14176788 Jul  4 14:27 /var/opt/common5/mdt/20230704/10/mdt_result.zip
# -rw-r--r--. 1 root root 11133137 Jul  4 14:25 /var/opt/common5/mdt/20230704/10/ue_traffic.zip
# -rw-r--r--. 1 root root 413889 Jul  4 14:24 /var/opt/common5/mdt/20230704/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 122960333 Jul  4 14:36 /var/opt/common5/mdt/20230704/10/ta_histogram.zip
# -rw-r--r--. 1 root root 93087879 Jul  5 10:56 /var/opt/common5/mdt/20230704/ctr1_grid_mdt_meas_cell_20230704.zip
# -rw-r--r--. 1 root root 12861823 Jul  4 08:08 /var/opt/common5/mdt/20230704/03/ue_meas.zip
# -rw-r--r--. 1 root root 8223399 Jul  4 08:13 /var/opt/common5/mdt/20230704/03/mdt_result.zip
# -rw-r--r--. 1 root root 6702396 Jul  4 08:03 /var/opt/common5/mdt/20230704/03/ue_traffic.zip
# -rw-r--r--. 1 root root 523267 Jul  4 08:01 /var/opt/common5/mdt/20230704/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 130389582 Jul  4 08:27 /var/opt/common5/mdt/20230704/03/ta_histogram.zip
# -rw-r--r--. 1 root root 25128829 Jul  5 10:56 /var/opt/common5/mdt/20230704/ctr1_filter_ue_meas.zip
# -rw-r--r--. 1 root root 2804191 Jul  5 10:01 /var/opt/common5/mdt/20230704/ue_capability_20230704.zip
# -rw-r--r--. 1 root root 22420192 Jul  4 18:02 /var/opt/common5/mdt/20230704/13/ue_meas.zip
# -rw-r--r--. 1 root root 16045984 Jul  4 18:15 /var/opt/common5/mdt/20230704/13/mdt_result.zip
# -rw-r--r--. 1 root root 10903566 Jul  4 17:57 /var/opt/common5/mdt/20230704/13/ue_traffic.zip
# -rw-r--r--. 1 root root 316514 Jul  4 17:47 /var/opt/common5/mdt/20230704/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 143925640 Jul  4 18:51 /var/opt/common5/mdt/20230704/13/ta_histogram.zip
# -rw-r--r--. 1 root root 36393681 Jul  5 10:56 /var/opt/common5/mdt/20230704/ctr1_grid_mdt_cell_20230704.zip
# -rw-r--r--. 1 root root 21526363 Jul  5 04:15 /var/opt/common5/mdt/20230704/23/ue_meas.zip
# -rw-r--r--. 1 root root 11336622 Jul  5 05:06 /var/opt/common5/mdt/20230704/23/mdt_result.zip
# -rw-r--r--. 1 root root 10970892 Jul  5 04:08 /var/opt/common5/mdt/20230704/23/ue_traffic.zip
# -rw-r--r--. 1 root root 872927 Jul  5 04:03 /var/opt/common5/mdt/20230704/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 128296629 Jul  5 05:35 /var/opt/common5/mdt/20230704/23/ta_histogram.zip
# -rw-r--r--. 1 root root 31077846 Jul  5 00:07 /var/opt/common5/mdt/20230704/19/ue_meas.zip
# -rw-r--r--. 1 root root 20946879 Jul  5 00:14 /var/opt/common5/mdt/20230704/19/mdt_result.zip
# -rw-r--r--. 1 root root 15176218 Jul  5 00:01 /var/opt/common5/mdt/20230704/19/ue_traffic.zip
# -rw-r--r--. 1 root root 507071 Jul  4 23:57 /var/opt/common5/mdt/20230704/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 184701679 Jul  5 02:18 /var/opt/common5/mdt/20230704/19/ta_histogram.zip
# -rw-r--r--. 1 root root 2285486 Jul  5 02:05 /var/opt/common5/mdt/20230704/22/ue_meas.zip
# -rw-r--r--. 1 root root 1538154 Jul  5 02:05 /var/opt/common5/mdt/20230704/22/mdt_result.zip
# -rw-r--r--. 1 root root 1147355 Jul  5 02:05 /var/opt/common5/mdt/20230704/22/ue_traffic.zip
# -rw-r--r--. 1 root root 56769 Jul  5 02:05 /var/opt/common5/mdt/20230704/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 15613197 Jul  5 02:08 /var/opt/common5/mdt/20230704/22/ta_histogram.zip
# -rw-r--r--. 1 root root 37666624 Jul  4 16:39 /var/opt/common5/mdt/20230704/12/ue_meas.zip
# -rw-r--r--. 1 root root 26571946 Jul  4 16:42 /var/opt/common5/mdt/20230704/12/mdt_result.zip
# -rw-r--r--. 1 root root 18238119 Jul  4 16:37 /var/opt/common5/mdt/20230704/12/ue_traffic.zip
# -rw-r--r--. 1 root root 467227 Jul  4 16:35 /var/opt/common5/mdt/20230704/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 238595075 Jul  4 17:41 /var/opt/common5/mdt/20230704/12/ta_histogram.zip
# -rw-r--r--. 1 root root 35774765 Jul  5 10:43 /var/opt/common5/mdt/20230704/grid_mdt_meas_cell_20230704.zip
# -rw-r--r--. 1 root root 12831352 Jul  5 10:56 /var/opt/common5/mdt/20230704/ctr1_filter_mdt_result.zip
# -rw-r--r--. 1 root root 78596938 Jul  5 10:55 /var/opt/common5/mdt/20230704/ctr2_grid_mdt_meas_cell_20230704.zip
# -rw-r--r--. 1 root root 28842804 Jul  5 10:55 /var/opt/common5/mdt/20230704/ctr2_grid_mdt_cell_20230704.zip
# -rw-r--r--. 1 root root 31100679 Jul  4 19:33 /var/opt/common5/mdt/20230704/14/ue_meas.zip
# -rw-r--r--. 1 root root 22295445 Jul  4 19:37 /var/opt/common5/mdt/20230704/14/mdt_result.zip
# -rw-r--r--. 1 root root 15158909 Jul  4 19:30 /var/opt/common5/mdt/20230704/14/ue_traffic.zip
# -rw-r--r--. 1 root root 476412 Jul  4 18:58 /var/opt/common5/mdt/20230704/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 203330812 Jul  4 20:04 /var/opt/common5/mdt/20230704/14/ta_histogram.zip
# -rw-r--r--. 1 root root 12493336 Jul  4 10:16 /var/opt/common5/mdt/20230704/06/ue_meas.zip
# -rw-r--r--. 1 root root 8482394 Jul  4 10:18 /var/opt/common5/mdt/20230704/06/mdt_result.zip
# -rw-r--r--. 1 root root 6296886 Jul  4 10:15 /var/opt/common5/mdt/20230704/06/ue_traffic.zip
# -rw-r--r--. 1 root root 238482 Jul  4 10:14 /var/opt/common5/mdt/20230704/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 85152212 Jul  4 10:27 /var/opt/common5/mdt/20230704/06/ta_histogram.zip
# -rw-r--r--. 1 root root 4515139 Jul  5 10:55 /var/opt/common5/mdt/20230704/ctr2_ue_capability_20230704.zip
# -rw-r--r--. 1 root root 3395910 Jul  5 10:56 /var/opt/common5/mdt/20230704/ctr1_ue_capability_20230704.zip
# [root@e011clxcol002p ~]#

# %%
test1 = re.split(r'\s+|\n', raw)

# %%
# Create list comprehension to filter list of zip files only

# result = [file for file in test1 if file.endswith('.zip')]

# Create list comprehension to filter only mdt_result.zip only
# Option are ue_traffic or mdt_result

pattern = r'.*/(?!filter_)[^/]+/ue_traffic\.zip$'
result = [path for path in test1 if re.match(pattern, path)]

# %%
# Create list comprehension to generate weekend dates in June

weekend_dates = [date.strftime("%Y%m%d") for date in (datetime.date(2023, 7, day) for day in range(1, 32)) 
                 if date.weekday() >= 5]

# Create list comprehension to generate continous dates in June (from 25 June until 30 June)
# continous_dates = re.compile(r'/var/opt/common5/mdt/202306(2[5-9]|30)/\d{2}/ue_traffic\.zip')

# %%
# Create list comprehension to filter June Month only
result = [path for path in result if '202307' in path]

# Create list comprehension to filter Out Some Date
result = [path for path in result if '20230719' not in path] 

# Create list comprehension to filter out continous dates
# result = [path for path in result if not continous_dates.search(path)]

# Create list comprehension to filter Out Weekend Date
# result = [path for path in result if path.split('/')[5] not in weekend_dates]

# Create list comprehension to filter Busy Hour only
result = [path for path in result if '/07/' in path or '/08/' in path or '/09/' in path or '/18/' in path or '/19/' in path or '/20/' in path or '/21/' in path or '/22/' in path]

# Create list comprehension to filter Busy Hour only
# result = [path for path in result if '/11/' in path or '/12/' in path or '/13/' in path]

# result = [path for path in result if '/07/' in path or '/08/' in path or '/09/']

result.sort()

# %%
with open(r'/home/nivag/location_to_dl_8009-throughput.txt', 'w') as fp:
    fp.write('\n'.join(result))
