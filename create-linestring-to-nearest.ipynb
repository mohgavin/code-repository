# %%
import pandas as pd
import geopandas as gpd
from shapely import LineString

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 500)

# %%
point_df = pd.read_excel('sample-folder/trial-calculate-line-distance.xlsx')

# %%
point_df
# Out:
#       SiteID_Source_Alternative  Longitude_Source  Latitude_Source SiteID_Target_Alternative  Longitude_Target  Latitude_Target    distance
# 0                      SiteID-1        106.041358        -6.003581               SiteID-3698        106.043200        -6.006975  431.734531
# 1                      SiteID-2        106.042389        -6.009056               SiteID-3698        106.043200        -6.006975  249.776735
# 2                      SiteID-3        106.069482        -6.025184              SiteID-15302        106.071811        -6.026569  302.117152
# 3                      SiteID-4        106.044056        -6.015861               SiteID-4526        106.046111        -6.013611  340.277799
# 4                      SiteID-5        106.049439        -6.013789               SiteID-4526        106.046111        -6.013611  370.980627
# ...                         ...               ...              ...                       ...               ...              ...         ...
# ...

# %%
point_df['linestring'] = "LINESTRING (" + point_df['Longitude_Source'].astype(str) + " " + point_df['Latitude_Source'].astype(str) + ", " + point_df['Longitude_Target'].astype(str) + " " + point_df['Latitude_Target'].astype(str) + ")"

# %%
point_df.to_csv('result/ISD-with_linestring.csv', index=False)
