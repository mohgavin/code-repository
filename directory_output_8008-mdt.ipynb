# %%
import pexpect
import time
import sys
import re
import datetime
import os

# %%
#ENM3 -> 10.23.202.28 PW : "Enm#2021"
#ENM5 -> 10.167.30.28 PW : "Enm#2021"

child = pexpect.spawn('ssh -L 7899:localhost:8008 -J root@150.236.203.198 root@127.0.0.1 -p 8008', timeout=30, encoding='utf-8', logfile=sys.stdout)

child.maxread = 300000 

child.expect("root@150.236.203.198's password: ")
child.sendline('PMT@2022')
child.expect("root@127.0.0.1's password: ")
child.sendline('PMT@2022')

time.sleep(10)

# Shell command to take after the dates in modification dates
# child.sendline('find /var/opt/common5/mdt/ -type f -newermt 2023-04-16 -exec ls -l {} \;')

# Shell command to take only the folder
# child.sendline('find /var/opt/common5/mdt/20230205 -type f -exec ls -l {} \;')

# Shell command to take certain range dates in modification dates
child.sendline('find /var/opt/common5/mdt -type f -newermt 2023-05-01 ! -newermt 2023-06-01 -exec ls -l {} \;')

try:
    child.expect(pexpect.EOF, timeout=100)

except pexpect.TIMEOUT:
    child.close()
    raw = str(child.before)
# Out:
# root@150.236.203.198's password: PMT@2022
#
# root@127.0.0.1's password: PMT@2022
# find /var/opt/common5/mdt -type f -newermt 2023-05-01 ! -newermt 2023-06-01 -exec ls -l {} \;
#
# Last login: Thu Jun  8 10:47:36 2023 from 192.168.21.6
# ! -newermt 2023-06-01 -exec ls -l {} \;-2 ~]# find /var/opt/common5/mdt -type f -newermt 2023-05-01
# -rw-r--r--. 1 root root 4659112 May 11 11:58 /var/opt/common5/mdt/20230314/ue_capability_20230314.zip
# -rw-r--r--. 1 root root 40617518 May 11 12:21 /var/opt/common5/mdt/20230314/grid_mdt_cell_20230314.zip
# -rw-r--r--. 1 root root 67930591 May 11 12:32 /var/opt/common5/mdt/20230314/grid_mdt_traffic_cell_20230314.zip
# -rw-r--r--. 1 root root 104351461 May 11 12:56 /var/opt/common5/mdt/20230314/grid_mdt_meas_cell_20230314.zip
# -rw-r--r--. 1 root root 233874 May 11 18:58 /var/opt/common5/mdt/20230314/filter_mdt_result.zip
# -rw-r--r--. 1 root root 288666 May 11 19:00 /var/opt/common5/mdt/20230314/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 546988 May 11 19:05 /var/opt/common5/mdt/20230314/filter_ue_meas.zip
# -rw-r--r--. 1 root root 764289 May 12 08:33 /var/opt/common5/mdt/20230314/scanning_mdt_20230314.zip
# -rw-r--r--. 1 root root 748090 May 12 08:49 /var/opt/common5/mdt/20230314/scanning_traffic_20230314.zip
# -rw-r--r--. 1 root root 94141 May  8 09:58 /var/opt/common5/mdt/20230315/filter_mdt_result.zip
# -rw-r--r--. 1 root root 114233 May  8 09:59 /var/opt/common5/mdt/20230315/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 224574 May  8 10:01 /var/opt/common5/mdt/20230315/filter_ue_meas.zip
# -rw-r--r--. 1 root root 8116896 May  4 13:25 /var/opt/common5/mdt/20230316/filter_mdt_result.zip
# -rw-r--r--. 1 root root 8085253 May  4 13:26 /var/opt/common5/mdt/20230316/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 16379440 May  4 13:29 /var/opt/common5/mdt/20230316/filter_ue_meas.zip
# -rw-r--r--. 1 root root 476222 May 24 07:38 /var/opt/common5/mdt/20230317/filter_mdt_result.zip
# -rw-r--r--. 1 root root 520444 May 24 07:39 /var/opt/common5/mdt/20230317/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 1062424 May 24 07:43 /var/opt/common5/mdt/20230317/filter_ue_meas.zip
# -rw-r--r--. 1 root root 178393 May  8 20:43 /var/opt/common5/mdt/20230318/filter_mdt_result.zip
# -rw-r--r--. 1 root root 204422 May  8 20:48 /var/opt/common5/mdt/20230318/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 418379 May  8 20:50 /var/opt/common5/mdt/20230318/filter_ue_meas.zip
# -rw-r--r--. 1 root root 69164 May  8 20:52 /var/opt/common5/mdt/20230319/filter_mdt_result.zip
# -rw-r--r--. 1 root root 85152 May  8 20:52 /var/opt/common5/mdt/20230319/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 164346 May  8 20:54 /var/opt/common5/mdt/20230319/filter_ue_meas.zip
# -rw-r--r--. 1 root root 684184 May 23 17:24 /var/opt/common5/mdt/20230427/filter_mdt_result.zip
# -rw-r--r--. 1 root root 786896 May 23 17:27 /var/opt/common5/mdt/20230427/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 710939911 May  1 00:00 /var/opt/common5/mdt/20230430/17/ta_histogram.zip
# -rw-r--r--. 1 root root 51865461 May  1 00:02 /var/opt/common5/mdt/20230430/18/mdt_result.zip
# -rw-r--r--. 1 root root 696362725 May  1 01:00 /var/opt/common5/mdt/20230430/18/ta_histogram.zip
# -rw-r--r--. 1 root root 945978 May  1 00:53 /var/opt/common5/mdt/20230430/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 35820136 May  1 00:55 /var/opt/common5/mdt/20230430/19/ue_traffic.zip
# -rw-r--r--. 1 root root 74032641 May  1 00:58 /var/opt/common5/mdt/20230430/19/ue_meas.zip
# -rw-r--r--. 1 root root 47225255 May  1 01:01 /var/opt/common5/mdt/20230430/19/mdt_result.zip
# -rw-r--r--. 1 root root 670891774 May  1 01:55 /var/opt/common5/mdt/20230430/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1018785 May  1 01:51 /var/opt/common5/mdt/20230430/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 37281349 May  1 01:52 /var/opt/common5/mdt/20230430/20/ue_traffic.zip
# -rw-r--r--. 1 root root 76302850 May  1 01:55 /var/opt/common5/mdt/20230430/20/ue_meas.zip
# -rw-r--r--. 1 root root 47848308 May  1 01:58 /var/opt/common5/mdt/20230430/20/mdt_result.zip
# -rw-r--r--. 1 root root 700430553 May  1 02:52 /var/opt/common5/mdt/20230430/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1250241 May  1 02:50 /var/opt/common5/mdt/20230430/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 41849639 May  1 02:53 /var/opt/common5/mdt/20230430/21/ue_traffic.zip
# -rw-r--r--. 1 root root 85269085 May  1 02:54 /var/opt/common5/mdt/20230430/21/ue_meas.zip
# -rw-r--r--. 1 root root 53002213 May  1 02:58 /var/opt/common5/mdt/20230430/21/mdt_result.zip
# -rw-r--r--. 1 root root 792067153 May  1 03:52 /var/opt/common5/mdt/20230430/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1376690 May  1 03:51 /var/opt/common5/mdt/20230430/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 41298714 May  1 03:52 /var/opt/common5/mdt/20230430/22/ue_traffic.zip
# -rw-r--r--. 1 root root 83529489 May  1 03:54 /var/opt/common5/mdt/20230430/22/ue_meas.zip
# -rw-r--r--. 1 root root 51899738 May  1 03:58 /var/opt/common5/mdt/20230430/22/mdt_result.zip
# -rw-r--r--. 1 root root 771382100 May  1 04:51 /var/opt/common5/mdt/20230430/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1556273 May  1 04:50 /var/opt/common5/mdt/20230430/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 40375764 May  1 04:53 /var/opt/common5/mdt/20230430/23/ue_traffic.zip
# -rw-r--r--. 1 root root 81064653 May  1 04:55 /var/opt/common5/mdt/20230430/23/ue_meas.zip
# -rw-r--r--. 1 root root 50555760 May  1 04:59 /var/opt/common5/mdt/20230430/23/mdt_result.zip
# -rw-r--r--. 1 root root 760766064 May  1 05:46 /var/opt/common5/mdt/20230430/23/ta_histogram.zip
# -rw-r--r--. 1 root root 1728364 May  1 05:46 /var/opt/common5/mdt/20230501/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 38868050 May  1 05:47 /var/opt/common5/mdt/20230501/00/ue_traffic.zip
# -rw-r--r--. 1 root root 77996518 May  1 05:50 /var/opt/common5/mdt/20230501/00/ue_meas.zip
# -rw-r--r--. 1 root root 48513385 May  1 05:53 /var/opt/common5/mdt/20230501/00/mdt_result.zip
# -rw-r--r--. 1 root root 753480966 May  1 06:32 /var/opt/common5/mdt/20230501/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1723849 May  1 06:38 /var/opt/common5/mdt/20230501/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 32105361 May  1 06:41 /var/opt/common5/mdt/20230501/01/ue_traffic.zip
# -rw-r--r--. 1 root root 63815800 May  1 06:44 /var/opt/common5/mdt/20230501/01/ue_meas.zip
# -rw-r--r--. 1 root root 39440632 May  1 06:50 /var/opt/common5/mdt/20230501/01/mdt_result.zip
# -rw-r--r--. 1 root root 640234990 May  1 07:53 /var/opt/common5/mdt/20230501/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1718466 May  1 07:51 /var/opt/common5/mdt/20230501/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 28246731 May  1 07:57 /var/opt/common5/mdt/20230501/02/ue_traffic.zip
# -rw-r--r--. 1 root root 55618458 May  1 08:00 /var/opt/common5/mdt/20230501/02/ue_meas.zip
# -rw-r--r--. 1 root root 34034534 May  1 08:12 /var/opt/common5/mdt/20230501/02/mdt_result.zip
# -rw-r--r--. 1 root root 594863623 May  1 10:15 /var/opt/common5/mdt/20230501/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1390562 May  1 08:51 /var/opt/common5/mdt/20230501/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 21155099 May  1 08:53 /var/opt/common5/mdt/20230501/03/ue_traffic.zip
# -rw-r--r--. 1 root root 41241683 May  1 09:01 /var/opt/common5/mdt/20230501/03/ue_meas.zip
# -rw-r--r--. 1 root root 24972855 May  1 09:04 /var/opt/common5/mdt/20230501/03/mdt_result.zip
# -rw-r--r--. 1 root root 451943656 May  1 10:23 /var/opt/common5/mdt/20230501/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1422391 May  1 10:04 /var/opt/common5/mdt/20230501/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 21530051 May  1 10:13 /var/opt/common5/mdt/20230501/04/ue_traffic.zip
# -rw-r--r--. 1 root root 41771673 May  1 10:24 /var/opt/common5/mdt/20230501/04/ue_meas.zip
# -rw-r--r--. 1 root root 25384231 May  1 10:28 /var/opt/common5/mdt/20230501/04/mdt_result.zip
# -rw-r--r--. 1 root root 6816017680 May  1 11:22 /var/opt/common5/mdt/20230501/04/ta_histogram.csv
# -rw-r--r--. 1 root root 324534757 May  1 13:04 /var/opt/common5/mdt/20230501/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1044946 May  1 10:56 /var/opt/common5/mdt/20230501/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 18377230 May  1 11:01 /var/opt/common5/mdt/20230501/05/ue_traffic.zip
# -rw-r--r--. 1 root root 35845802 May  1 11:27 /var/opt/common5/mdt/20230501/05/ue_meas.zip
# -rw-r--r--. 1 root root 22216204 May  1 11:59 /var/opt/common5/mdt/20230501/05/mdt_result.zip
# -rw-r--r--. 1 root root 678534 May  1 12:34 /var/opt/common5/mdt/20230501/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 891772 May  1 20:11 /var/opt/common5/mdt/20230501/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 32933372 May  1 20:12 /var/opt/common5/mdt/20230501/15/ue_traffic.zip
# -rw-r--r--. 1 root root 67324136 May  1 20:13 /var/opt/common5/mdt/20230501/15/ue_meas.zip
# -rw-r--r--. 1 root root 43791621 May  1 20:14 /var/opt/common5/mdt/20230501/15/mdt_result.zip
# -rw-r--r--. 1 root root 579469444 May  1 20:32 /var/opt/common5/mdt/20230501/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1491618 May  1 21:50 /var/opt/common5/mdt/20230501/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 57317618 May  1 21:52 /var/opt/common5/mdt/20230501/16/ue_traffic.zip
# -rw-r--r--. 1 root root 118222912 May  1 21:56 /var/opt/common5/mdt/20230501/16/ue_meas.zip
# -rw-r--r--. 1 root root 76541813 May  1 22:00 /var/opt/common5/mdt/20230501/16/mdt_result.zip
# -rw-r--r--. 1 root root 1004079702 May  1 23:29 /var/opt/common5/mdt/20230501/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1099317 May  1 22:54 /var/opt/common5/mdt/20230501/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 42339946 May  1 22:58 /var/opt/common5/mdt/20230501/17/ue_traffic.zip
# -rw-r--r--. 1 root root 86495366 May  1 23:04 /var/opt/common5/mdt/20230501/17/ue_meas.zip
# -rw-r--r--. 1 root root 55566344 May  1 23:22 /var/opt/common5/mdt/20230501/17/mdt_result.zip
# -rw-r--r--. 1 root root 761049078 May  2 00:54 /var/opt/common5/mdt/20230501/17/ta_histogram.zip
# -rw-r--r--. 1 root root 856721 May  1 23:51 /var/opt/common5/mdt/20230501/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 31668136 May  1 23:52 /var/opt/common5/mdt/20230501/18/ue_traffic.zip
# -rw-r--r--. 1 root root 65237322 May  1 23:55 /var/opt/common5/mdt/20230501/18/ue_meas.zip
# -rw-r--r--. 1 root root 41855461 May  2 00:00 /var/opt/common5/mdt/20230501/18/mdt_result.zip
# -rw-r--r--. 1 root root 585663528 May  2 01:08 /var/opt/common5/mdt/20230501/18/ta_histogram.zip
# -rw-r--r--. 1 root root 903286 May  2 00:55 /var/opt/common5/mdt/20230501/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 32775553 May  2 00:57 /var/opt/common5/mdt/20230501/19/ue_traffic.zip
# -rw-r--r--. 1 root root 67129047 May  2 00:58 /var/opt/common5/mdt/20230501/19/ue_meas.zip
# -rw-r--r--. 1 root root 42529984 May  2 01:01 /var/opt/common5/mdt/20230501/19/mdt_result.zip
# -rw-r--r--. 1 root root 631386433 May  2 01:54 /var/opt/common5/mdt/20230501/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1021022 May  2 01:50 /var/opt/common5/mdt/20230501/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 35618523 May  2 01:51 /var/opt/common5/mdt/20230501/20/ue_traffic.zip
# -rw-r--r--. 1 root root 72991941 May  2 01:54 /var/opt/common5/mdt/20230501/20/ue_meas.zip
# -rw-r--r--. 1 root root 45575948 May  2 01:57 /var/opt/common5/mdt/20230501/20/mdt_result.zip
# -rw-r--r--. 1 root root 695803101 May  2 02:49 /var/opt/common5/mdt/20230501/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1248017 May  2 02:50 /var/opt/common5/mdt/20230501/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 39550366 May  2 02:51 /var/opt/common5/mdt/20230501/21/ue_traffic.zip
# -rw-r--r--. 1 root root 81356379 May  2 02:53 /var/opt/common5/mdt/20230501/21/ue_meas.zip
# -rw-r--r--. 1 root root 50326480 May  2 02:56 /var/opt/common5/mdt/20230501/21/mdt_result.zip
# -rw-r--r--. 1 root root 772122460 May  2 03:46 /var/opt/common5/mdt/20230501/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1430050 May  2 03:49 /var/opt/common5/mdt/20230501/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 39861110 May  2 03:50 /var/opt/common5/mdt/20230501/22/ue_traffic.zip
# -rw-r--r--. 1 root root 80586775 May  2 03:52 /var/opt/common5/mdt/20230501/22/ue_meas.zip
# -rw-r--r--. 1 root root 49879028 May  2 03:55 /var/opt/common5/mdt/20230501/22/mdt_result.zip
# -rw-r--r--. 1 root root 770294369 May  2 04:40 /var/opt/common5/mdt/20230501/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1703235 May  2 04:49 /var/opt/common5/mdt/20230501/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 39662512 May  2 04:51 /var/opt/common5/mdt/20230501/23/ue_traffic.zip
# -rw-r--r--. 1 root root 80129519 May  2 04:54 /var/opt/common5/mdt/20230501/23/ue_meas.zip
# -rw-r--r--. 1 root root 49890058 May  2 04:57 /var/opt/common5/mdt/20230501/23/mdt_result.zip
# -rw-r--r--. 1 root root 787671053 May  2 05:44 /var/opt/common5/mdt/20230501/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4573874 May  2 10:16 /var/opt/common5/mdt/20230501/ue_capability_20230501.zip
# -rw-r--r--. 1 root root 456679011 May  2 10:25 /var/opt/common5/mdt/20230501/mdt_20230501.zip
# -rw-r--r--. 1 root root 10276228 May  2 10:27 /var/opt/common5/mdt/20230501/grid_mdt_20230501.zip
# -rw-r--r--. 1 root root 29739378 May  2 10:27 /var/opt/common5/mdt/20230501/grid_mdt_cell_20230501.zip
# -rw-r--r--. 1 root root 70134905 May  2 10:33 /var/opt/common5/mdt/20230501/grid10_mdt_20230501.zip
# -rw-r--r--. 1 root root 98269403 May  2 10:34 /var/opt/common5/mdt/20230501/grid10_mdt_cell_20230501.zip
# -rw-r--r--. 1 root root 21512586 May  2 10:38 /var/opt/common5/mdt/20230501/grid_mdt_traffic_20230501.zip
# -rw-r--r--. 1 root root 65774735 May  2 10:39 /var/opt/common5/mdt/20230501/grid_mdt_traffic_cell_20230501.zip
# -rw-r--r--. 1 root root 110298646 May  2 10:45 /var/opt/common5/mdt/20230501/grid10_mdt_traffic_20230501.zip
# -rw-r--r--. 1 root root 174658947 May  2 10:46 /var/opt/common5/mdt/20230501/grid10_mdt_traffic_cell_20230501.zip
# -rw-r--r--. 1 root root 29734331 May  2 10:53 /var/opt/common5/mdt/20230501/grid_mdt_meas_20230501.zip
# -rw-r--r--. 1 root root 103217311 May  2 10:53 /var/opt/common5/mdt/20230501/grid_mdt_meas_cell_20230501.zip
# -rw-r--r--. 1 root root 162831741 May  2 11:01 /var/opt/common5/mdt/20230501/grid10_mdt_meas_20230501.zip
# -rw-r--r--. 1 root root 280365072 May  2 11:02 /var/opt/common5/mdt/20230501/grid10_mdt_meas_cell_20230501.zip
# -rw-r--r--. 1 root root 1732596 May  2 05:43 /var/opt/common5/mdt/20230502/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 34553639 May  2 05:45 /var/opt/common5/mdt/20230502/00/ue_traffic.zip
# -rw-r--r--. 1 root root 69079602 May  2 05:48 /var/opt/common5/mdt/20230502/00/ue_meas.zip
# -rw-r--r--. 1 root root 42697302 May  2 05:51 /var/opt/common5/mdt/20230502/00/mdt_result.zip
# -rw-r--r--. 1 root root 711731056 May  2 06:25 /var/opt/common5/mdt/20230502/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1721106 May  2 06:27 /var/opt/common5/mdt/20230502/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 28770521 May  2 06:29 /var/opt/common5/mdt/20230502/01/ue_traffic.zip
# -rw-r--r--. 1 root root 56873598 May  2 06:31 /var/opt/common5/mdt/20230502/01/ue_meas.zip
# -rw-r--r--. 1 root root 35082262 May  2 06:34 /var/opt/common5/mdt/20230502/01/mdt_result.zip
# -rw-r--r--. 1 root root 606118068 May  2 08:01 /var/opt/common5/mdt/20230502/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1340144 May  2 07:59 /var/opt/common5/mdt/20230502/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 19692159 May  2 08:02 /var/opt/common5/mdt/20230502/02/ue_traffic.zip
# -rw-r--r--. 1 root root 38712176 May  2 08:05 /var/opt/common5/mdt/20230502/02/ue_meas.zip
# -rw-r--r--. 1 root root 23971371 May  2 08:08 /var/opt/common5/mdt/20230502/02/mdt_result.zip
# -rw-r--r--. 1 root root 439808681 May  2 09:16 /var/opt/common5/mdt/20230502/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1244989 May  2 08:50 /var/opt/common5/mdt/20230502/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 17337949 May  2 08:51 /var/opt/common5/mdt/20230502/03/ue_traffic.zip
# -rw-r--r--. 1 root root 33701865 May  2 08:56 /var/opt/common5/mdt/20230502/03/ue_meas.zip
# -rw-r--r--. 1 root root 20357873 May  2 08:59 /var/opt/common5/mdt/20230502/03/mdt_result.zip
# -rw-r--r--. 1 root root 394877962 May  2 09:51 /var/opt/common5/mdt/20230502/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1542893 May  2 09:52 /var/opt/common5/mdt/20230502/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 22980659 May  2 10:02 /var/opt/common5/mdt/20230502/04/ue_traffic.zip
# -rw-r--r--. 1 root root 44491168 May  2 10:04 /var/opt/common5/mdt/20230502/04/ue_meas.zip
# -rw-r--r--. 1 root root 26873854 May  2 10:17 /var/opt/common5/mdt/20230502/04/mdt_result.zip
# -rw-r--r--. 1 root root 504033507 May  2 10:59 /var/opt/common5/mdt/20230502/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1240151 May  2 10:53 /var/opt/common5/mdt/20230502/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 23603185 May  2 10:55 /var/opt/common5/mdt/20230502/05/ue_traffic.zip
# -rw-r--r--. 1 root root 46236887 May  2 10:59 /var/opt/common5/mdt/20230502/05/ue_meas.zip
# -rw-r--r--. 1 root root 29007611 May  2 11:01 /var/opt/common5/mdt/20230502/05/mdt_result.zip
# -rw-r--r--. 1 root root 495665157 May  2 11:46 /var/opt/common5/mdt/20230502/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1348255 May  2 11:46 /var/opt/common5/mdt/20230502/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 27552635 May  2 11:48 /var/opt/common5/mdt/20230502/06/ue_traffic.zip
# -rw-r--r--. 1 root root 54994698 May  2 11:51 /var/opt/common5/mdt/20230502/06/ue_meas.zip
# -rw-r--r--. 1 root root 36200777 May  2 11:55 /var/opt/common5/mdt/20230502/06/mdt_result.zip
# -rw-r--r--. 1 root root 926543 May  2 20:10 /var/opt/common5/mdt/20230502/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 31811640 May  2 20:11 /var/opt/common5/mdt/20230502/15/ue_traffic.zip
# -rw-r--r--. 1 root root 65605855 May  2 20:12 /var/opt/common5/mdt/20230502/15/ue_meas.zip
# -rw-r--r--. 1 root root 43048134 May  2 20:14 /var/opt/common5/mdt/20230502/15/mdt_result.zip
# -rw-r--r--. 1 root root 576139626 May  2 20:36 /var/opt/common5/mdt/20230502/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1512135 May  2 21:50 /var/opt/common5/mdt/20230502/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 56047648 May  2 21:53 /var/opt/common5/mdt/20230502/16/ue_traffic.zip
# -rw-r--r--. 1 root root 115762894 May  2 21:56 /var/opt/common5/mdt/20230502/16/ue_meas.zip
# -rw-r--r--. 1 root root 75794327 May  2 22:01 /var/opt/common5/mdt/20230502/16/mdt_result.zip
# -rw-r--r--. 1 root root 1002099406 May  2 23:25 /var/opt/common5/mdt/20230502/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1097675 May  2 22:53 /var/opt/common5/mdt/20230502/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 41315943 May  2 22:57 /var/opt/common5/mdt/20230502/17/ue_traffic.zip
# -rw-r--r--. 1 root root 84580538 May  2 23:01 /var/opt/common5/mdt/20230502/17/ue_meas.zip
# -rw-r--r--. 1 root root 54836501 May  2 23:10 /var/opt/common5/mdt/20230502/17/mdt_result.zip
# -rw-r--r--. 1 root root 752139625 May  3 00:24 /var/opt/common5/mdt/20230502/17/ta_histogram.zip
# -rw-r--r--. 1 root root 903311 May  2 23:51 /var/opt/common5/mdt/20230502/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 33072436 May  2 23:52 /var/opt/common5/mdt/20230502/18/ue_traffic.zip
# -rw-r--r--. 1 root root 67602859 May  2 23:55 /var/opt/common5/mdt/20230502/18/ue_meas.zip
# -rw-r--r--. 1 root root 43615628 May  2 23:59 /var/opt/common5/mdt/20230502/18/mdt_result.zip
# -rw-r--r--. 1 root root 608477612 May  3 00:55 /var/opt/common5/mdt/20230502/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1020581 May  3 00:50 /var/opt/common5/mdt/20230502/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 36462247 May  3 00:53 /var/opt/common5/mdt/20230502/19/ue_traffic.zip
# -rw-r--r--. 1 root root 74811032 May  3 00:55 /var/opt/common5/mdt/20230502/19/ue_meas.zip
# -rw-r--r--. 1 root root 47634941 May  3 00:58 /var/opt/common5/mdt/20230502/19/mdt_result.zip
# -rw-r--r--. 1 root root 700736129 May  3 01:49 /var/opt/common5/mdt/20230502/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1166112 May  3 01:50 /var/opt/common5/mdt/20230502/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 39783390 May  3 01:52 /var/opt/common5/mdt/20230502/20/ue_traffic.zip
# -rw-r--r--. 1 root root 81442369 May  3 01:54 /var/opt/common5/mdt/20230502/20/ue_meas.zip
# -rw-r--r--. 1 root root 51044577 May  3 01:56 /var/opt/common5/mdt/20230502/20/mdt_result.zip
# -rw-r--r--. 1 root root 768013193 May  3 02:47 /var/opt/common5/mdt/20230502/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1261236 May  3 02:49 /var/opt/common5/mdt/20230502/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 39338246 May  3 02:50 /var/opt/common5/mdt/20230502/21/ue_traffic.zip
# -rw-r--r--. 1 root root 80162905 May  3 02:52 /var/opt/common5/mdt/20230502/21/ue_meas.zip
# -rw-r--r--. 1 root root 49813534 May  3 02:55 /var/opt/common5/mdt/20230502/21/mdt_result.zip
# -rw-r--r--. 1 root root 765080410 May  3 03:46 /var/opt/common5/mdt/20230502/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1504440 May  3 03:49 /var/opt/common5/mdt/20230502/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 41280548 May  3 03:51 /var/opt/common5/mdt/20230502/22/ue_traffic.zip
# -rw-r--r--. 1 root root 83505398 May  3 03:53 /var/opt/common5/mdt/20230502/22/ue_meas.zip
# -rw-r--r--. 1 root root 51808135 May  3 03:56 /var/opt/common5/mdt/20230502/22/mdt_result.zip
# -rw-r--r--. 1 root root 807838748 May  3 04:48 /var/opt/common5/mdt/20230502/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1683063 May  3 04:49 /var/opt/common5/mdt/20230502/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 38476486 May  3 04:51 /var/opt/common5/mdt/20230502/23/ue_traffic.zip
# -rw-r--r--. 1 root root 77756280 May  3 04:54 /var/opt/common5/mdt/20230502/23/ue_meas.zip
# -rw-r--r--. 1 root root 48488331 May  3 04:57 /var/opt/common5/mdt/20230502/23/mdt_result.zip
# -rw-r--r--. 1 root root 777649718 May  3 05:41 /var/opt/common5/mdt/20230502/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4630411 May  5 19:22 /var/opt/common5/mdt/20230502/ue_capability_20230502.zip
# -rw-r--r--. 1 root root 36178969 May  5 19:37 /var/opt/common5/mdt/20230502/grid_mdt_cell_20230502.zip
# -rw-r--r--. 1 root root 60018297 May  5 19:54 /var/opt/common5/mdt/20230502/grid_mdt_traffic_cell_20230502.zip
# -rw-r--r--. 1 root root 93804605 May  5 20:08 /var/opt/common5/mdt/20230502/grid_mdt_meas_cell_20230502.zip
# -rw-r--r--. 1 root root 1734375 May  3 05:41 /var/opt/common5/mdt/20230503/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 34408691 May  3 05:42 /var/opt/common5/mdt/20230503/00/ue_traffic.zip
# -rw-r--r--. 1 root root 68853970 May  3 05:45 /var/opt/common5/mdt/20230503/00/ue_meas.zip
# -rw-r--r--. 1 root root 42592915 May  3 05:48 /var/opt/common5/mdt/20230503/00/mdt_result.zip
# -rw-r--r--. 1 root root 713365104 May  3 06:22 /var/opt/common5/mdt/20230503/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1725269 May  3 06:23 /var/opt/common5/mdt/20230503/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 28697164 May  3 06:24 /var/opt/common5/mdt/20230503/01/ue_traffic.zip
# -rw-r--r--. 1 root root 56823939 May  3 06:26 /var/opt/common5/mdt/20230503/01/ue_meas.zip
# -rw-r--r--. 1 root root 34948591 May  3 06:28 /var/opt/common5/mdt/20230503/01/mdt_result.zip
# -rw-r--r--. 1 root root 607995635 May  3 07:37 /var/opt/common5/mdt/20230503/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1726603 May  3 07:38 /var/opt/common5/mdt/20230503/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 25184573 May  3 07:44 /var/opt/common5/mdt/20230503/02/ue_traffic.zip
# -rw-r--r--. 1 root root 49319111 May  3 07:47 /var/opt/common5/mdt/20230503/02/ue_meas.zip
# -rw-r--r--. 1 root root 29839476 May  3 07:52 /var/opt/common5/mdt/20230503/02/mdt_result.zip
# -rw-r--r--. 1 root root 569127762 May  3 09:05 /var/opt/common5/mdt/20230503/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1713909 May  3 08:51 /var/opt/common5/mdt/20230503/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 23693649 May  3 08:54 /var/opt/common5/mdt/20230503/03/ue_traffic.zip
# -rw-r--r--. 1 root root 45971225 May  3 08:56 /var/opt/common5/mdt/20230503/03/ue_meas.zip
# -rw-r--r--. 1 root root 27542588 May  3 08:59 /var/opt/common5/mdt/20230503/03/mdt_result.zip
# -rw-r--r--. 1 root root 533276353 May  3 09:26 /var/opt/common5/mdt/20230503/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1500923 May  3 09:26 /var/opt/common5/mdt/20230503/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 21087826 May  3 09:27 /var/opt/common5/mdt/20230503/04/ue_traffic.zip
# -rw-r--r--. 1 root root 40536360 May  3 09:29 /var/opt/common5/mdt/20230503/04/ue_meas.zip
# -rw-r--r--. 1 root root 24472119 May  3 09:31 /var/opt/common5/mdt/20230503/04/mdt_result.zip
# -rw-r--r--. 1 root root 455628133 May  3 09:59 /var/opt/common5/mdt/20230503/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1599318 May  3 10:24 /var/opt/common5/mdt/20230503/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 27917237 May  3 10:25 /var/opt/common5/mdt/20230503/05/ue_traffic.zip
# -rw-r--r--. 1 root root 54866177 May  3 10:27 /var/opt/common5/mdt/20230503/05/ue_meas.zip
# -rw-r--r--. 1 root root 34618213 May  3 10:28 /var/opt/common5/mdt/20230503/05/mdt_result.zip
# -rw-r--r--. 1 root root 576838077 May  3 11:01 /var/opt/common5/mdt/20230503/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1621538 May  3 11:33 /var/opt/common5/mdt/20230503/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 38461505 May  3 11:36 /var/opt/common5/mdt/20230503/06/ue_traffic.zip
# -rw-r--r--. 1 root root 77175582 May  3 11:39 /var/opt/common5/mdt/20230503/06/ue_meas.zip
# -rw-r--r--. 1 root root 50394413 May  3 11:44 /var/opt/common5/mdt/20230503/06/mdt_result.zip
# -rw-r--r--. 1 root root 712645173 May  3 12:29 /var/opt/common5/mdt/20230503/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1517019 May  3 12:50 /var/opt/common5/mdt/20230503/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 50971087 May  3 12:53 /var/opt/common5/mdt/20230503/07/ue_traffic.zip
# -rw-r--r--. 1 root root 103067892 May  3 12:57 /var/opt/common5/mdt/20230503/07/ue_meas.zip
# -rw-r--r--. 1 root root 68376408 May  3 13:02 /var/opt/common5/mdt/20230503/07/mdt_result.zip
# -rw-r--r--. 1 root root 12470479060 May  3 13:41 /var/opt/common5/mdt/20230503/07/ta_histogram.csv
# -rw-r--r--. 1 root root 398438400 May  3 14:18 /var/opt/common5/mdt/20230503/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1121867 May  3 13:59 /var/opt/common5/mdt/20230503/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 2800 May  3 18:30 /var/opt/common5/mdt/20230503/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 36955 May  3 18:30 /var/opt/common5/mdt/20230503/14/ue_traffic.zip
# -rw-r--r--. 1 root root 73942 May  3 18:30 /var/opt/common5/mdt/20230503/14/ue_meas.zip
# -rw-r--r--. 1 root root 49892 May  3 18:30 /var/opt/common5/mdt/20230503/14/mdt_result.zip
# -rw-r--r--. 1 root root 722033 May  3 18:30 /var/opt/common5/mdt/20230503/14/ta_histogram.zip
# -rw-r--r--. 1 root root 929309 May  3 20:12 /var/opt/common5/mdt/20230503/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 32033366 May  3 20:12 /var/opt/common5/mdt/20230503/15/ue_traffic.zip
# -rw-r--r--. 1 root root 65601733 May  3 20:14 /var/opt/common5/mdt/20230503/15/ue_meas.zip
# -rw-r--r--. 1 root root 43327265 May  3 20:15 /var/opt/common5/mdt/20230503/15/mdt_result.zip
# -rw-r--r--. 1 root root 585192718 May  3 20:40 /var/opt/common5/mdt/20230503/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1503482 May  3 21:49 /var/opt/common5/mdt/20230503/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 54950912 May  3 21:51 /var/opt/common5/mdt/20230503/16/ue_traffic.zip
# -rw-r--r--. 1 root root 112619094 May  3 21:54 /var/opt/common5/mdt/20230503/16/ue_meas.zip
# -rw-r--r--. 1 root root 73682742 May  3 21:59 /var/opt/common5/mdt/20230503/16/mdt_result.zip
# -rw-r--r--. 1 root root 987470231 May  3 23:22 /var/opt/common5/mdt/20230503/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1140440 May  3 22:54 /var/opt/common5/mdt/20230503/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 41936157 May  3 22:57 /var/opt/common5/mdt/20230503/17/ue_traffic.zip
# -rw-r--r--. 1 root root 86529500 May  3 23:00 /var/opt/common5/mdt/20230503/17/ue_meas.zip
# -rw-r--r--. 1 root root 56062989 May  3 23:13 /var/opt/common5/mdt/20230503/17/mdt_result.zip
# -rw-r--r--. 1 root root 775810037 May  4 00:28 /var/opt/common5/mdt/20230503/17/ta_histogram.zip
# -rw-r--r--. 1 root root 995676 May  3 23:53 /var/opt/common5/mdt/20230503/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 35908818 May  3 23:55 /var/opt/common5/mdt/20230503/18/ue_traffic.zip
# -rw-r--r--. 1 root root 73436991 May  3 23:57 /var/opt/common5/mdt/20230503/18/ue_meas.zip
# -rw-r--r--. 1 root root 47434968 May  4 00:02 /var/opt/common5/mdt/20230503/18/mdt_result.zip
# -rw-r--r--. 1 root root 661165666 May  4 00:59 /var/opt/common5/mdt/20230503/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1002847 May  4 00:52 /var/opt/common5/mdt/20230503/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 34252950 May  4 00:54 /var/opt/common5/mdt/20230503/19/ue_traffic.zip
# -rw-r--r--. 1 root root 70227998 May  4 00:57 /var/opt/common5/mdt/20230503/19/ue_meas.zip
# -rw-r--r--. 1 root root 44592228 May  4 01:00 /var/opt/common5/mdt/20230503/19/mdt_result.zip
# -rw-r--r--. 1 root root 667318813 May  4 01:53 /var/opt/common5/mdt/20230503/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1167271 May  4 01:50 /var/opt/common5/mdt/20230503/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 37149118 May  4 01:52 /var/opt/common5/mdt/20230503/20/ue_traffic.zip
# -rw-r--r--. 1 root root 75898525 May  4 01:54 /var/opt/common5/mdt/20230503/20/ue_meas.zip
# -rw-r--r--. 1 root root 47735390 May  4 01:58 /var/opt/common5/mdt/20230503/20/mdt_result.zip
# -rw-r--r--. 1 root root 729926909 May  4 02:51 /var/opt/common5/mdt/20230503/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1332384 May  4 02:50 /var/opt/common5/mdt/20230503/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 39253675 May  4 02:52 /var/opt/common5/mdt/20230503/21/ue_traffic.zip
# -rw-r--r--. 1 root root 79784188 May  4 02:55 /var/opt/common5/mdt/20230503/21/ue_meas.zip
# -rw-r--r--. 1 root root 49756680 May  4 02:58 /var/opt/common5/mdt/20230503/21/mdt_result.zip
# -rw-r--r--. 1 root root 765188633 May  4 03:53 /var/opt/common5/mdt/20230503/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1503720 May  4 03:51 /var/opt/common5/mdt/20230503/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 38511527 May  4 03:52 /var/opt/common5/mdt/20230503/22/ue_traffic.zip
# -rw-r--r--. 1 root root 78493383 May  4 03:55 /var/opt/common5/mdt/20230503/22/ue_meas.zip
# -rw-r--r--. 1 root root 48892855 May  4 03:58 /var/opt/common5/mdt/20230503/22/mdt_result.zip
# -rw-r--r--. 1 root root 768760656 May  4 04:49 /var/opt/common5/mdt/20230503/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1717559 May  4 04:50 /var/opt/common5/mdt/20230503/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 37402453 May  4 04:52 /var/opt/common5/mdt/20230503/23/ue_traffic.zip
# -rw-r--r--. 1 root root 75416744 May  4 04:55 /var/opt/common5/mdt/20230503/23/ue_meas.zip
# -rw-r--r--. 1 root root 47222992 May  4 04:58 /var/opt/common5/mdt/20230503/23/mdt_result.zip
# -rw-r--r--. 1 root root 763246740 May  4 05:42 /var/opt/common5/mdt/20230503/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4800468 May  5 20:10 /var/opt/common5/mdt/20230503/ue_capability_20230503.zip
# -rw-r--r--. 1 root root 39471231 May  5 20:30 /var/opt/common5/mdt/20230503/grid_mdt_cell_20230503.zip
# -rw-r--r--. 1 root root 65596782 May  5 20:47 /var/opt/common5/mdt/20230503/grid_mdt_traffic_cell_20230503.zip
# -rw-r--r--. 1 root root 102143915 May  5 21:01 /var/opt/common5/mdt/20230503/grid_mdt_meas_cell_20230503.zip
# -rw-r--r--. 1 root root 1730994 May  4 05:41 /var/opt/common5/mdt/20230504/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 33105475 May  4 05:43 /var/opt/common5/mdt/20230504/00/ue_traffic.zip
# -rw-r--r--. 1 root root 65998627 May  4 05:45 /var/opt/common5/mdt/20230504/00/ue_meas.zip
# -rw-r--r--. 1 root root 40748309 May  4 05:48 /var/opt/common5/mdt/20230504/00/mdt_result.zip
# -rw-r--r--. 1 root root 691779846 May  4 06:23 /var/opt/common5/mdt/20230504/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1718070 May  4 06:29 /var/opt/common5/mdt/20230504/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 27175159 May  4 06:31 /var/opt/common5/mdt/20230504/01/ue_traffic.zip
# -rw-r--r--. 1 root root 53591945 May  4 06:34 /var/opt/common5/mdt/20230504/01/ue_meas.zip
# -rw-r--r--. 1 root root 32915611 May  4 06:39 /var/opt/common5/mdt/20230504/01/mdt_result.zip
# -rw-r--r--. 1 root root 592713194 May  4 07:52 /var/opt/common5/mdt/20230504/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1715418 May  4 07:48 /var/opt/common5/mdt/20230504/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 24459707 May  4 07:50 /var/opt/common5/mdt/20230504/02/ue_traffic.zip
# -rw-r--r--. 1 root root 47494786 May  4 07:53 /var/opt/common5/mdt/20230504/02/ue_meas.zip
# -rw-r--r--. 1 root root 28724582 May  4 07:56 /var/opt/common5/mdt/20230504/02/mdt_result.zip
# -rw-r--r--. 1 root root 558134019 May  4 08:50 /var/opt/common5/mdt/20230504/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1711770 May  4 08:52 /var/opt/common5/mdt/20230504/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 23321057 May  4 08:55 /var/opt/common5/mdt/20230504/03/ue_traffic.zip
# -rw-r--r--. 1 root root 45152551 May  4 09:00 /var/opt/common5/mdt/20230504/03/ue_meas.zip
# -rw-r--r--. 1 root root 27082380 May  4 09:04 /var/opt/common5/mdt/20230504/03/mdt_result.zip
# -rw-r--r--. 1 root root 535250677 May  4 10:08 /var/opt/common5/mdt/20230504/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1371901 May  4 09:51 /var/opt/common5/mdt/20230504/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 19702459 May  4 10:00 /var/opt/common5/mdt/20230504/04/ue_traffic.zip
# -rw-r--r--. 1 root root 38024481 May  4 10:08 /var/opt/common5/mdt/20230504/04/ue_meas.zip
# -rw-r--r--. 1 root root 22964879 May  4 10:25 /var/opt/common5/mdt/20230504/04/mdt_result.zip
# -rw-r--r--. 1 root root 437002403 May  4 11:15 /var/opt/common5/mdt/20230504/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1224562 May  4 10:49 /var/opt/common5/mdt/20230504/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 21809354 May  4 10:50 /var/opt/common5/mdt/20230504/05/ue_traffic.zip
# -rw-r--r--. 1 root root 42895713 May  4 10:51 /var/opt/common5/mdt/20230504/05/ue_meas.zip
# -rw-r--r--. 1 root root 26719608 May  4 10:59 /var/opt/common5/mdt/20230504/05/mdt_result.zip
# -rw-r--r--. 1 root root 473607682 May  4 11:21 /var/opt/common5/mdt/20230504/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1389981 May  4 12:51 /var/opt/common5/mdt/20230504/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 45353526 May  4 12:53 /var/opt/common5/mdt/20230504/07/ue_traffic.zip
# -rw-r--r--. 1 root root 92307237 May  4 12:56 /var/opt/common5/mdt/20230504/07/ue_meas.zip
# -rw-r--r--. 1 root root 60872880 May  4 13:01 /var/opt/common5/mdt/20230504/07/mdt_result.zip
# -rw-r--r--. 1 root root 11410324616 May  4 14:10 /var/opt/common5/mdt/20230504/07/ta_histogram.csv
# -rw-r--r--. 1 root root 22745351 May  4 14:42 /var/opt/common5/mdt/20230504/07/ta_histogram.zip
# -rw-r--r--. 1 root root 942525 May  4 14:30 /var/opt/common5/mdt/20230504/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 873325 May  4 20:15 /var/opt/common5/mdt/20230504/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 30290532 May  4 20:16 /var/opt/common5/mdt/20230504/15/ue_traffic.zip
# -rw-r--r--. 1 root root 61966398 May  4 20:17 /var/opt/common5/mdt/20230504/15/ue_meas.zip
# -rw-r--r--. 1 root root 40750938 May  4 20:19 /var/opt/common5/mdt/20230504/15/mdt_result.zip
# -rw-r--r--. 1 root root 552594417 May  4 20:46 /var/opt/common5/mdt/20230504/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1246767 May  4 21:49 /var/opt/common5/mdt/20230504/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 44297280 May  4 21:51 /var/opt/common5/mdt/20230504/16/ue_traffic.zip
# -rw-r--r--. 1 root root 91411297 May  4 21:54 /var/opt/common5/mdt/20230504/16/ue_meas.zip
# -rw-r--r--. 1 root root 59781295 May  4 21:57 /var/opt/common5/mdt/20230504/16/mdt_result.zip
# -rw-r--r--. 1 root root 817397813 May  4 23:25 /var/opt/common5/mdt/20230504/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1003555 May  4 22:52 /var/opt/common5/mdt/20230504/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 36747685 May  4 22:56 /var/opt/common5/mdt/20230504/17/ue_traffic.zip
# -rw-r--r--. 1 root root 75173124 May  4 23:04 /var/opt/common5/mdt/20230504/17/ue_meas.zip
# -rw-r--r--. 1 root root 48459218 May  4 23:26 /var/opt/common5/mdt/20230504/17/mdt_result.zip
# -rw-r--r--. 1 root root 683342421 May  5 01:05 /var/opt/common5/mdt/20230504/17/ta_histogram.zip
# -rw-r--r--. 1 root root 702112 May  4 23:49 /var/opt/common5/mdt/20230504/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 24895187 May  4 23:50 /var/opt/common5/mdt/20230504/18/ue_traffic.zip
# -rw-r--r--. 1 root root 50839835 May  4 23:52 /var/opt/common5/mdt/20230504/18/ue_meas.zip
# -rw-r--r--. 1 root root 32632260 May  4 23:56 /var/opt/common5/mdt/20230504/18/mdt_result.zip
# -rw-r--r--. 1 root root 466947063 May  5 01:11 /var/opt/common5/mdt/20230504/18/ta_histogram.zip
# -rw-r--r--. 1 root root 723907 May  5 01:05 /var/opt/common5/mdt/20230504/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 25135122 May  5 01:06 /var/opt/common5/mdt/20230504/19/ue_traffic.zip
# -rw-r--r--. 1 root root 51518084 May  5 01:09 /var/opt/common5/mdt/20230504/19/ue_meas.zip
# -rw-r--r--. 1 root root 32596073 May  5 01:12 /var/opt/common5/mdt/20230504/19/mdt_result.zip
# -rw-r--r--. 1 root root 498314939 May  5 01:52 /var/opt/common5/mdt/20230504/19/ta_histogram.zip
# -rw-r--r--. 1 root root 886964 May  5 01:51 /var/opt/common5/mdt/20230504/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 29562888 May  5 01:53 /var/opt/common5/mdt/20230504/20/ue_traffic.zip
# -rw-r--r--. 1 root root 60547048 May  5 01:54 /var/opt/common5/mdt/20230504/20/ue_meas.zip
# -rw-r--r--. 1 root root 37793709 May  5 01:56 /var/opt/common5/mdt/20230504/20/mdt_result.zip
# -rw-r--r--. 1 root root 592851543 May  5 02:27 /var/opt/common5/mdt/20230504/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1319116 May  5 02:49 /var/opt/common5/mdt/20230504/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 40152963 May  5 02:51 /var/opt/common5/mdt/20230504/21/ue_traffic.zip
# -rw-r--r--. 1 root root 82546085 May  5 02:53 /var/opt/common5/mdt/20230504/21/ue_meas.zip
# -rw-r--r--. 1 root root 51474533 May  5 02:56 /var/opt/common5/mdt/20230504/21/mdt_result.zip
# -rw-r--r--. 1 root root 803433399 May  5 03:50 /var/opt/common5/mdt/20230504/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1454353 May  5 03:50 /var/opt/common5/mdt/20230504/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 38910724 May  5 03:52 /var/opt/common5/mdt/20230504/22/ue_traffic.zip
# -rw-r--r--. 1 root root 79410280 May  5 03:54 /var/opt/common5/mdt/20230504/22/ue_meas.zip
# -rw-r--r--. 1 root root 49322305 May  5 03:58 /var/opt/common5/mdt/20230504/22/mdt_result.zip
# -rw-r--r--. 1 root root 781065835 May  5 04:50 /var/opt/common5/mdt/20230504/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1685073 May  5 04:49 /var/opt/common5/mdt/20230504/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 38871223 May  5 04:51 /var/opt/common5/mdt/20230504/23/ue_traffic.zip
# -rw-r--r--. 1 root root 78603558 May  5 04:53 /var/opt/common5/mdt/20230504/23/ue_meas.zip
# -rw-r--r--. 1 root root 49085738 May  5 04:57 /var/opt/common5/mdt/20230504/23/mdt_result.zip
# -rw-r--r--. 1 root root 785618254 May  5 05:46 /var/opt/common5/mdt/20230504/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4633263 May  5 21:01 /var/opt/common5/mdt/20230504/ue_capability_20230504.zip
# -rw-r--r--. 1 root root 35005163 May  5 21:20 /var/opt/common5/mdt/20230504/grid_mdt_cell_20230504.zip
# -rw-r--r--. 1 root root 57816243 May  5 21:29 /var/opt/common5/mdt/20230504/grid_mdt_traffic_cell_20230504.zip
# -rw-r--r--. 1 root root 90526896 May  5 21:53 /var/opt/common5/mdt/20230504/grid_mdt_meas_cell_20230504.zip
# -rw-r--r--. 1 root root 1737727 May  5 05:42 /var/opt/common5/mdt/20230505/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 34623973 May  5 05:44 /var/opt/common5/mdt/20230505/00/ue_traffic.zip
# -rw-r--r--. 1 root root 69288501 May  5 05:47 /var/opt/common5/mdt/20230505/00/ue_meas.zip
# -rw-r--r--. 1 root root 43304519 May  5 05:50 /var/opt/common5/mdt/20230505/00/mdt_result.zip
# -rw-r--r--. 1 root root 722340480 May  5 06:54 /var/opt/common5/mdt/20230505/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1436903 May  5 06:55 /var/opt/common5/mdt/20230505/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 23410877 May  5 06:56 /var/opt/common5/mdt/20230505/01/ue_traffic.zip
# -rw-r--r--. 1 root root 46316873 May  5 06:59 /var/opt/common5/mdt/20230505/01/ue_meas.zip
# -rw-r--r--. 1 root root 28552147 May  5 07:01 /var/opt/common5/mdt/20230505/01/mdt_result.zip
# -rw-r--r--. 1 root root 510867407 May  5 07:56 /var/opt/common5/mdt/20230505/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1451702 May  5 07:52 /var/opt/common5/mdt/20230505/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 21152233 May  5 07:54 /var/opt/common5/mdt/20230505/02/ue_traffic.zip
# -rw-r--r--. 1 root root 41407319 May  5 07:57 /var/opt/common5/mdt/20230505/02/ue_meas.zip
# -rw-r--r--. 1 root root 25187795 May  5 08:00 /var/opt/common5/mdt/20230505/02/mdt_result.zip
# -rw-r--r--. 1 root root 486419817 May  5 09:09 /var/opt/common5/mdt/20230505/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1514335 May  5 08:56 /var/opt/common5/mdt/20230505/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 21007418 May  5 09:02 /var/opt/common5/mdt/20230505/03/ue_traffic.zip
# -rw-r--r--. 1 root root 40756614 May  5 09:06 /var/opt/common5/mdt/20230505/03/ue_meas.zip
# -rw-r--r--. 1 root root 24470106 May  5 09:12 /var/opt/common5/mdt/20230505/03/mdt_result.zip
# -rw-r--r--. 1 root root 7236470434 May  5 10:12 /var/opt/common5/mdt/20230505/03/ta_histogram.csv
# -rw-r--r--. 1 root root 11387231 May  5 10:28 /var/opt/common5/mdt/20230505/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1436425 May  5 09:51 /var/opt/common5/mdt/20230505/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 20227406 May  5 09:53 /var/opt/common5/mdt/20230505/04/ue_traffic.zip
# -rw-r--r--. 1 root root 39085564 May  5 09:55 /var/opt/common5/mdt/20230505/04/ue_meas.zip
# -rw-r--r--. 1 root root 23831582 May  5 10:01 /var/opt/common5/mdt/20230505/04/mdt_result.zip
# -rw-r--r--. 1 root root 1570003 May  5 16:50 /var/opt/common5/mdt/20230505/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 52707014 May  5 16:52 /var/opt/common5/mdt/20230505/11/ue_traffic.zip
# -rw-r--r--. 1 root root 108751108 May  5 16:56 /var/opt/common5/mdt/20230505/11/ue_meas.zip
# -rw-r--r--. 1 root root 70587908 May  5 17:01 /var/opt/common5/mdt/20230505/11/mdt_result.zip
# -rw-r--r--. 1 root root 1040024663 May  5 18:22 /var/opt/common5/mdt/20230505/11/ta_histogram.zip
# -rw-r--r--. 1 root root 1117942 May  5 17:52 /var/opt/common5/mdt/20230505/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 35738337 May  5 17:55 /var/opt/common5/mdt/20230505/12/ue_traffic.zip
# -rw-r--r--. 1 root root 73092638 May  5 17:57 /var/opt/common5/mdt/20230505/12/ue_meas.zip
# -rw-r--r--. 1 root root 46579109 May  5 18:04 /var/opt/common5/mdt/20230505/12/mdt_result.zip
# -rw-r--r--. 1 root root 721505841 May  5 19:13 /var/opt/common5/mdt/20230505/12/ta_histogram.zip
# -rw-r--r--. 1 root root 907712 May  5 18:51 /var/opt/common5/mdt/20230505/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 29990130 May  5 18:53 /var/opt/common5/mdt/20230505/13/ue_traffic.zip
# -rw-r--r--. 1 root root 61964595 May  5 18:56 /var/opt/common5/mdt/20230505/13/ue_meas.zip
# -rw-r--r--. 1 root root 40083767 May  5 19:08 /var/opt/common5/mdt/20230505/13/mdt_result.zip
# -rw-r--r--. 1 root root 604790875 May  5 20:09 /var/opt/common5/mdt/20230505/13/ta_histogram.zip
# -rw-r--r--. 1 root root 905492 May  5 19:53 /var/opt/common5/mdt/20230505/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 30148852 May  5 19:56 /var/opt/common5/mdt/20230505/14/ue_traffic.zip
# -rw-r--r--. 1 root root 61757553 May  5 19:58 /var/opt/common5/mdt/20230505/14/ue_meas.zip
# -rw-r--r--. 1 root root 39965602 May  5 20:09 /var/opt/common5/mdt/20230505/14/mdt_result.zip
# -rw-r--r--. 1 root root 586978230 May  5 21:09 /var/opt/common5/mdt/20230505/14/ta_histogram.zip
# -rw-r--r--. 1 root root 841465 May  5 20:52 /var/opt/common5/mdt/20230505/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 28631838 May  5 20:57 /var/opt/common5/mdt/20230505/15/ue_traffic.zip
# -rw-r--r--. 1 root root 58580015 May  5 21:01 /var/opt/common5/mdt/20230505/15/ue_meas.zip
# -rw-r--r--. 1 root root 37853773 May  5 21:06 /var/opt/common5/mdt/20230505/15/mdt_result.zip
# -rw-r--r--. 1 root root 7730232074 May  5 21:35 /var/opt/common5/mdt/20230505/15/ta_histogram.csv
# -rw-r--r--. 1 root root 535244800 May  5 22:29 /var/opt/common5/mdt/20230505/15/ta_histogram.zip
# -rw-r--r--. 1 root root 827416 May  5 21:55 /var/opt/common5/mdt/20230505/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 29674020 May  5 21:56 /var/opt/common5/mdt/20230505/16/ue_traffic.zip
# -rw-r--r--. 1 root root 60722391 May  5 21:59 /var/opt/common5/mdt/20230505/16/ue_meas.zip
# -rw-r--r--. 1 root root 446700 May  6 19:49 /var/opt/common5/mdt/20230506/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 15990951 May  6 19:50 /var/opt/common5/mdt/20230506/15/ue_traffic.zip
# -rw-r--r--. 1 root root 32665741 May  6 19:50 /var/opt/common5/mdt/20230506/15/ue_meas.zip
# -rw-r--r--. 1 root root 21578863 May  6 19:51 /var/opt/common5/mdt/20230506/15/mdt_result.zip
# -rw-r--r--. 1 root root 289692233 May  6 19:59 /var/opt/common5/mdt/20230506/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1439055 May  6 21:51 /var/opt/common5/mdt/20230506/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 53959091 May  6 21:53 /var/opt/common5/mdt/20230506/16/ue_traffic.zip
# -rw-r--r--. 1 root root 110219953 May  6 21:56 /var/opt/common5/mdt/20230506/16/ue_meas.zip
# -rw-r--r--. 1 root root 71890285 May  6 22:01 /var/opt/common5/mdt/20230506/16/mdt_result.zip
# -rw-r--r--. 1 root root 963623387 May  6 23:31 /var/opt/common5/mdt/20230506/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1037854 May  6 22:54 /var/opt/common5/mdt/20230506/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 39189720 May  6 22:58 /var/opt/common5/mdt/20230506/17/ue_traffic.zip
# -rw-r--r--. 1 root root 80694468 May  6 23:04 /var/opt/common5/mdt/20230506/17/ue_meas.zip
# -rw-r--r--. 1 root root 52280668 May  6 23:19 /var/opt/common5/mdt/20230506/17/mdt_result.zip
# -rw-r--r--. 1 root root 723466579 May  7 00:54 /var/opt/common5/mdt/20230506/17/ta_histogram.zip
# -rw-r--r--. 1 root root 841695 May  6 23:49 /var/opt/common5/mdt/20230506/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 31076656 May  6 23:51 /var/opt/common5/mdt/20230506/18/ue_traffic.zip
# -rw-r--r--. 1 root root 63960395 May  6 23:53 /var/opt/common5/mdt/20230506/18/ue_meas.zip
# -rw-r--r--. 1 root root 41259559 May  6 23:57 /var/opt/common5/mdt/20230506/18/mdt_result.zip
# -rw-r--r--. 1 root root 580413586 May  7 01:20 /var/opt/common5/mdt/20230506/18/ta_histogram.zip
# -rw-r--r--. 1 root root 858587 May  7 00:55 /var/opt/common5/mdt/20230506/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 31666046 May  7 00:57 /var/opt/common5/mdt/20230506/19/ue_traffic.zip
# -rw-r--r--. 1 root root 64856391 May  7 00:59 /var/opt/common5/mdt/20230506/19/ue_meas.zip
# -rw-r--r--. 1 root root 41465016 May  7 01:03 /var/opt/common5/mdt/20230506/19/mdt_result.zip
# -rw-r--r--. 1 root root 615057970 May  7 01:55 /var/opt/common5/mdt/20230506/19/ta_histogram.zip
# -rw-r--r--. 1 root root 921230 May  7 01:51 /var/opt/common5/mdt/20230506/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 32492207 May  7 01:53 /var/opt/common5/mdt/20230506/20/ue_traffic.zip
# -rw-r--r--. 1 root root 67139615 May  7 01:55 /var/opt/common5/mdt/20230506/20/ue_meas.zip
# -rw-r--r--. 1 root root 42165759 May  7 01:58 /var/opt/common5/mdt/20230506/20/mdt_result.zip
# -rw-r--r--. 1 root root 650394715 May  7 03:04 /var/opt/common5/mdt/20230506/20/ta_histogram.zip
# -rw-r--r--. 1 root root 910428 May  7 02:53 /var/opt/common5/mdt/20230506/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 30244260 May  7 02:56 /var/opt/common5/mdt/20230506/21/ue_traffic.zip
# -rw-r--r--. 1 root root 61690078 May  7 02:59 /var/opt/common5/mdt/20230506/21/ue_meas.zip
# -rw-r--r--. 1 root root 38270986 May  7 03:05 /var/opt/common5/mdt/20230506/21/mdt_result.zip
# -rw-r--r--. 1 root root 601433804 May  7 03:50 /var/opt/common5/mdt/20230506/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1125029 May  7 03:48 /var/opt/common5/mdt/20230506/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 33318139 May  7 03:50 /var/opt/common5/mdt/20230506/22/ue_traffic.zip
# -rw-r--r--. 1 root root 67574361 May  7 03:52 /var/opt/common5/mdt/20230506/22/ue_meas.zip
# ...
# -rw-r--r--. 1 root root 4782817 May 30 10:22 /var/opt/common5/mdt/20230529/ue_capability_20230529.zip
# -rw-r--r--. 1 root root 40122559 May 30 10:41 /var/opt/common5/mdt/20230529/grid_mdt_cell_20230529.zip
# -rw-r--r--. 1 root root 67355159 May 30 10:56 /var/opt/common5/mdt/20230529/grid_mdt_traffic_cell_20230529.zip
# -rw-r--r--. 1 root root 104212301 May 30 11:12 /var/opt/common5/mdt/20230529/grid_mdt_meas_cell_20230529.zip
# -rw-r--r--. 1 root root 1769415 May 30 05:43 /var/opt/common5/mdt/20230530/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 34757473 May 30 05:45 /var/opt/common5/mdt/20230530/00/ue_traffic.zip
# -rw-r--r--. 1 root root 69504534 May 30 05:47 /var/opt/common5/mdt/20230530/00/ue_meas.zip
# -rw-r--r--. 1 root root 42376977 May 30 05:50 /var/opt/common5/mdt/20230530/00/mdt_result.zip
# -rw-r--r--. 1 root root 731726437 May 30 06:27 /var/opt/common5/mdt/20230530/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1763955 May 30 06:30 /var/opt/common5/mdt/20230530/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 28281575 May 30 06:32 /var/opt/common5/mdt/20230530/01/ue_traffic.zip
# -rw-r--r--. 1 root root 56023072 May 30 06:35 /var/opt/common5/mdt/20230530/01/ue_meas.zip
# -rw-r--r--. 1 root root 33738180 May 30 06:38 /var/opt/common5/mdt/20230530/01/mdt_result.zip
# -rw-r--r--. 1 root root 623760088 May 30 07:43 /var/opt/common5/mdt/20230530/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1761306 May 30 07:49 /var/opt/common5/mdt/20230530/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 25069887 May 30 07:52 /var/opt/common5/mdt/20230530/02/ue_traffic.zip
# -rw-r--r--. 1 root root 49156154 May 30 07:54 /var/opt/common5/mdt/20230530/02/ue_meas.zip
# -rw-r--r--. 1 root root 29162861 May 30 08:09 /var/opt/common5/mdt/20230530/02/mdt_result.zip
# -rw-r--r--. 1 root root 585422812 May 30 09:03 /var/opt/common5/mdt/20230530/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1535405 May 30 08:51 /var/opt/common5/mdt/20230530/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 20807305 May 30 08:58 /var/opt/common5/mdt/20230530/03/ue_traffic.zip
# -rw-r--r--. 1 root root 40406956 May 30 09:01 /var/opt/common5/mdt/20230530/03/ue_meas.zip
# -rw-r--r--. 1 root root 23884922 May 30 09:04 /var/opt/common5/mdt/20230530/03/mdt_result.zip
# -rw-r--r--. 1 root root 485670934 May 30 10:09 /var/opt/common5/mdt/20230530/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1323973 May 30 09:54 /var/opt/common5/mdt/20230530/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 19279283 May 30 09:58 /var/opt/common5/mdt/20230530/04/ue_traffic.zip
# -rw-r--r--. 1 root root 37352094 May 30 10:04 /var/opt/common5/mdt/20230530/04/ue_meas.zip
# -rw-r--r--. 1 root root 22167930 May 30 10:09 /var/opt/common5/mdt/20230530/04/mdt_result.zip
# -rw-r--r--. 1 root root 432050512 May 30 10:52 /var/opt/common5/mdt/20230530/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1380326 May 30 10:51 /var/opt/common5/mdt/20230530/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 25738798 May 30 10:53 /var/opt/common5/mdt/20230530/05/ue_traffic.zip
# -rw-r--r--. 1 root root 50845910 May 30 10:56 /var/opt/common5/mdt/20230530/05/ue_meas.zip
# -rw-r--r--. 1 root root 31308704 May 30 10:59 /var/opt/common5/mdt/20230530/05/mdt_result.zip
# -rw-r--r--. 1 root root 550712582 May 30 11:53 /var/opt/common5/mdt/20230530/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1204006 May 30 11:53 /var/opt/common5/mdt/20230530/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 31907594 May 30 11:55 /var/opt/common5/mdt/20230530/06/ue_traffic.zip
# -rw-r--r--. 1 root root 64388619 May 30 11:57 /var/opt/common5/mdt/20230530/06/ue_meas.zip
# -rw-r--r--. 1 root root 40702195 May 30 12:00 /var/opt/common5/mdt/20230530/06/mdt_result.zip
# -rw-r--r--. 1 root root 617519538 May 30 12:53 /var/opt/common5/mdt/20230530/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1213116 May 30 12:50 /var/opt/common5/mdt/20230530/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 37652142 May 30 12:53 /var/opt/common5/mdt/20230530/07/ue_traffic.zip
# -rw-r--r--. 1 root root 76676132 May 30 12:56 /var/opt/common5/mdt/20230530/07/ue_meas.zip
# -rw-r--r--. 1 root root 49870010 May 30 13:00 /var/opt/common5/mdt/20230530/07/mdt_result.zip
# -rw-r--r--. 1 root root 652060716 May 30 13:59 /var/opt/common5/mdt/20230530/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1107086 May 30 13:53 /var/opt/common5/mdt/20230530/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 37900634 May 30 13:55 /var/opt/common5/mdt/20230530/08/ue_traffic.zip
# -rw-r--r--. 1 root root 77207817 May 30 13:59 /var/opt/common5/mdt/20230530/08/ue_meas.zip
# -rw-r--r--. 1 root root 49474611 May 30 14:03 /var/opt/common5/mdt/20230530/08/mdt_result.zip
# -rw-r--r--. 1 root root 674149566 May 30 14:58 /var/opt/common5/mdt/20230530/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1019315 May 30 14:53 /var/opt/common5/mdt/20230530/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 35805434 May 30 14:54 /var/opt/common5/mdt/20230530/09/ue_traffic.zip
# -rw-r--r--. 1 root root 73188927 May 30 14:58 /var/opt/common5/mdt/20230530/09/ue_meas.zip
# -rw-r--r--. 1 root root 46625719 May 30 15:01 /var/opt/common5/mdt/20230530/09/mdt_result.zip
# -rw-r--r--. 1 root root 649780801 May 30 15:56 /var/opt/common5/mdt/20230530/09/ta_histogram.zip
# -rw-r--r--. 1 root root 1028437 May 30 15:51 /var/opt/common5/mdt/20230530/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 35260060 May 30 15:53 /var/opt/common5/mdt/20230530/10/ue_traffic.zip
# -rw-r--r--. 1 root root 72245622 May 30 15:56 /var/opt/common5/mdt/20230530/10/ue_meas.zip
# -rw-r--r--. 1 root root 45883182 May 30 15:59 /var/opt/common5/mdt/20230530/10/mdt_result.zip
# -rw-r--r--. 1 root root 674806199 May 30 17:00 /var/opt/common5/mdt/20230530/10/ta_histogram.zip
# -rw-r--r--. 1 root root 989195 May 30 16:52 /var/opt/common5/mdt/20230530/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 33878783 May 30 16:55 /var/opt/common5/mdt/20230530/11/ue_traffic.zip
# -rw-r--r--. 1 root root 70098089 May 30 16:57 /var/opt/common5/mdt/20230530/11/ue_meas.zip
# -rw-r--r--. 1 root root 44241060 May 30 17:01 /var/opt/common5/mdt/20230530/11/mdt_result.zip
# -rw-r--r--. 1 root root 668722478 May 30 18:07 /var/opt/common5/mdt/20230530/11/ta_histogram.zip
# -rw-r--r--. 1 root root 914059 May 30 17:52 /var/opt/common5/mdt/20230530/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 31417845 May 30 17:56 /var/opt/common5/mdt/20230530/12/ue_traffic.zip
# -rw-r--r--. 1 root root 65049759 May 30 17:58 /var/opt/common5/mdt/20230530/12/ue_meas.zip
# -rw-r--r--. 1 root root 40774203 May 30 18:08 /var/opt/common5/mdt/20230530/12/mdt_result.zip
# -rw-r--r--. 1 root root 8989641439 May 30 18:43 /var/opt/common5/mdt/20230530/12/ta_histogram.csv
# -rw-r--r--. 1 root root 463765725 May 30 19:42 /var/opt/common5/mdt/20230530/12/ta_histogram.zip
# -rw-r--r--. 1 root root 827063 May 30 18:52 /var/opt/common5/mdt/20230530/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 27756294 May 30 18:56 /var/opt/common5/mdt/20230530/13/ue_traffic.zip
# -rw-r--r--. 1 root root 57383970 May 30 18:58 /var/opt/common5/mdt/20230530/13/ue_meas.zip
# -rw-r--r--. 1 root root 883688 May 31 01:06 /var/opt/common5/mdt/20230530/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 30471125 May 31 01:06 /var/opt/common5/mdt/20230530/20/ue_traffic.zip
# -rw-r--r--. 1 root root 63041614 May 31 01:07 /var/opt/common5/mdt/20230530/20/ue_meas.zip
# -rw-r--r--. 1 root root 39100559 May 31 01:08 /var/opt/common5/mdt/20230530/20/mdt_result.zip
# -rw-r--r--. 1 root root 577495544 May 31 01:24 /var/opt/common5/mdt/20230530/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1718972 May 31 02:43 /var/opt/common5/mdt/20230530/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 55509356 May 31 02:45 /var/opt/common5/mdt/20230530/21/ue_traffic.zip
# -rw-r--r--. 1 root root 114352450 May 31 02:48 /var/opt/common5/mdt/20230530/21/ue_meas.zip
# -rw-r--r--. 1 root root 70022812 May 31 02:51 /var/opt/common5/mdt/20230530/21/mdt_result.zip
# -rw-r--r--. 1 root root 1062104151 May 31 03:56 /var/opt/common5/mdt/20230530/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1481214 May 31 03:50 /var/opt/common5/mdt/20230530/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 40442342 May 31 03:51 /var/opt/common5/mdt/20230530/22/ue_traffic.zip
# -rw-r--r--. 1 root root 82636005 May 31 03:54 /var/opt/common5/mdt/20230530/22/ue_meas.zip
# -rw-r--r--. 1 root root 50130016 May 31 03:57 /var/opt/common5/mdt/20230530/22/mdt_result.zip
# -rw-r--r--. 1 root root 801942067 May 31 04:48 /var/opt/common5/mdt/20230530/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1635704 May 31 04:49 /var/opt/common5/mdt/20230530/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 36602937 May 31 04:50 /var/opt/common5/mdt/20230530/23/ue_traffic.zip
# -rw-r--r--. 1 root root 74007599 May 31 04:53 /var/opt/common5/mdt/20230530/23/ue_meas.zip
# -rw-r--r--. 1 root root 45328744 May 31 04:56 /var/opt/common5/mdt/20230530/23/mdt_result.zip
# -rw-r--r--. 1 root root 754087830 May 31 05:39 /var/opt/common5/mdt/20230530/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4778642 May 31 10:32 /var/opt/common5/mdt/20230530/ue_capability_20230530.zip
# -rw-r--r--. 1 root root 36908974 May 31 10:54 /var/opt/common5/mdt/20230530/grid_mdt_cell_20230530.zip
# -rw-r--r--. 1 root root 63144814 May 31 11:04 /var/opt/common5/mdt/20230530/grid_mdt_traffic_cell_20230530.zip
# -rw-r--r--. 1 root root 98216964 May 31 11:17 /var/opt/common5/mdt/20230530/grid_mdt_meas_cell_20230530.zip
# -rw-r--r--. 1 root root 1756460 May 31 05:41 /var/opt/common5/mdt/20230531/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 34569762 May 31 05:43 /var/opt/common5/mdt/20230531/00/ue_traffic.zip
# -rw-r--r--. 1 root root 69120931 May 31 05:45 /var/opt/common5/mdt/20230531/00/ue_meas.zip
# -rw-r--r--. 1 root root 42082044 May 31 05:47 /var/opt/common5/mdt/20230531/00/mdt_result.zip
# -rw-r--r--. 1 root root 724823916 May 31 06:24 /var/opt/common5/mdt/20230531/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1752691 May 31 06:27 /var/opt/common5/mdt/20230531/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 27499561 May 31 06:28 /var/opt/common5/mdt/20230531/01/ue_traffic.zip
# -rw-r--r--. 1 root root 54459148 May 31 06:30 /var/opt/common5/mdt/20230531/01/ue_meas.zip
# -rw-r--r--. 1 root root 32874023 May 31 06:34 /var/opt/common5/mdt/20230531/01/mdt_result.zip
# -rw-r--r--. 1 root root 619388123 May 31 07:47 /var/opt/common5/mdt/20230531/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1756731 May 31 07:32 /var/opt/common5/mdt/20230531/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 24109313 May 31 07:36 /var/opt/common5/mdt/20230531/02/ue_traffic.zip
# -rw-r--r--. 1 root root 47223010 May 31 07:39 /var/opt/common5/mdt/20230531/02/ue_meas.zip
# -rw-r--r--. 1 root root 28123654 May 31 07:47 /var/opt/common5/mdt/20230531/02/mdt_result.zip
# -rw-r--r--. 1 root root 578289427 May 31 09:01 /var/opt/common5/mdt/20230531/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1750415 May 31 08:51 /var/opt/common5/mdt/20230531/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 23232029 May 31 09:00 /var/opt/common5/mdt/20230531/03/ue_traffic.zip
# -rw-r--r--. 1 root root 45124680 May 31 09:03 /var/opt/common5/mdt/20230531/03/ue_meas.zip
# -rw-r--r--. 1 root root 26721500 May 31 09:08 /var/opt/common5/mdt/20230531/03/mdt_result.zip
# -rw-r--r--. 1 root root 548426741 May 31 10:56 /var/opt/common5/mdt/20230531/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1691495 May 31 09:53 /var/opt/common5/mdt/20230531/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 22549469 May 31 09:55 /var/opt/common5/mdt/20230531/04/ue_traffic.zip
# -rw-r--r--. 1 root root 43651869 May 31 10:03 /var/opt/common5/mdt/20230531/04/ue_meas.zip
# -rw-r--r--. 1 root root 26144783 May 31 10:12 /var/opt/common5/mdt/20230531/04/mdt_result.zip
# -rw-r--r--. 1 root root 506860693 May 31 11:05 /var/opt/common5/mdt/20230531/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1293332 May 31 10:58 /var/opt/common5/mdt/20230531/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 24012553 May 31 11:00 /var/opt/common5/mdt/20230531/05/ue_traffic.zip
# -rw-r--r--. 1 root root 47471605 May 31 11:02 /var/opt/common5/mdt/20230531/05/ue_meas.zip
# -rw-r--r--. 1 root root 29354785 May 31 11:06 /var/opt/common5/mdt/20230531/05/mdt_result.zip
# -rw-r--r--. 1 root root 512023942 May 31 11:52 /var/opt/common5/mdt/20230531/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1195579 May 31 11:50 /var/opt/common5/mdt/20230531/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 31341287 May 31 11:53 /var/opt/common5/mdt/20230531/06/ue_traffic.zip
# -rw-r--r--. 1 root root 63219781 May 31 11:56 /var/opt/common5/mdt/20230531/06/ue_meas.zip
# -rw-r--r--. 1 root root 40395077 May 31 11:59 /var/opt/common5/mdt/20230531/06/mdt_result.zip
# -rw-r--r--. 1 root root 607727360 May 31 12:56 /var/opt/common5/mdt/20230531/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1158325 May 31 12:52 /var/opt/common5/mdt/20230531/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 38625341 May 31 12:55 /var/opt/common5/mdt/20230531/07/ue_traffic.zip
# -rw-r--r--. 1 root root 78324867 May 31 12:57 /var/opt/common5/mdt/20230531/07/ue_meas.zip
# -rw-r--r--. 1 root root 50627977 May 31 13:01 /var/opt/common5/mdt/20230531/07/mdt_result.zip
# -rw-r--r--. 1 root root 680218290 May 31 13:58 /var/opt/common5/mdt/20230531/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1104103 May 31 13:51 /var/opt/common5/mdt/20230531/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 37277356 May 31 13:54 /var/opt/common5/mdt/20230531/08/ue_traffic.zip
# -rw-r--r--. 1 root root 76039065 May 31 13:57 /var/opt/common5/mdt/20230531/08/ue_meas.zip
# -rw-r--r--. 1 root root 48904755 May 31 14:01 /var/opt/common5/mdt/20230531/08/mdt_result.zip
# -rw-r--r--. 1 root root 675964465 May 31 14:57 /var/opt/common5/mdt/20230531/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1059629 May 31 14:52 /var/opt/common5/mdt/20230531/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 37330336 May 31 14:54 /var/opt/common5/mdt/20230531/09/ue_traffic.zip
# -rw-r--r--. 1 root root 76334884 May 31 14:57 /var/opt/common5/mdt/20230531/09/ue_meas.zip
# -rw-r--r--. 1 root root 48880594 May 31 15:00 /var/opt/common5/mdt/20230531/09/mdt_result.zip
# -rw-r--r--. 1 root root 676415855 May 31 15:56 /var/opt/common5/mdt/20230531/09/ta_histogram.zip
# -rw-r--r--. 1 root root 990757 May 31 15:52 /var/opt/common5/mdt/20230531/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 34738494 May 31 15:54 /var/opt/common5/mdt/20230531/10/ue_traffic.zip
# -rw-r--r--. 1 root root 71255154 May 31 15:56 /var/opt/common5/mdt/20230531/10/ue_meas.zip
# -rw-r--r--. 1 root root 45188133 May 31 16:00 /var/opt/common5/mdt/20230531/10/mdt_result.zip
# -rw-r--r--. 1 root root 657644192 May 31 16:58 /var/opt/common5/mdt/20230531/10/ta_histogram.zip
# -rw-r--r--. 1 root root 981927 May 31 16:51 /var/opt/common5/mdt/20230531/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 33849781 May 31 16:54 /var/opt/common5/mdt/20230531/11/ue_traffic.zip
# -rw-r--r--. 1 root root 69447463 May 31 16:56 /var/opt/common5/mdt/20230531/11/ue_meas.zip
# -rw-r--r--. 1 root root 43960026 May 31 17:00 /var/opt/common5/mdt/20230531/11/mdt_result.zip
# -rw-r--r--. 1 root root 670645030 May 31 17:57 /var/opt/common5/mdt/20230531/11/ta_histogram.zip
# -rw-r--r--. 1 root root 981270 May 31 17:51 /var/opt/common5/mdt/20230531/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 34376576 May 31 17:54 /var/opt/common5/mdt/20230531/12/ue_traffic.zip
# -rw-r--r--. 1 root root 70154001 May 31 17:58 /var/opt/common5/mdt/20230531/12/ue_meas.zip
# -rw-r--r--. 1 root root 44034722 May 31 18:01 /var/opt/common5/mdt/20230531/12/mdt_result.zip
# -rw-r--r--. 1 root root 684539715 May 31 19:06 /var/opt/common5/mdt/20230531/12/ta_histogram.zip
# -rw-r--r--. 1 root root 983166 May 31 18:53 /var/opt/common5/mdt/20230531/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 34156627 May 31 18:56 /var/opt/common5/mdt/20230531/13/ue_traffic.zip
# -rw-r--r--. 1 root root 70107753 May 31 19:00 /var/opt/common5/mdt/20230531/13/ue_meas.zip
# -rw-r--r--. 1 root root 44248173 May 31 19:08 /var/opt/common5/mdt/20230531/13/mdt_result.zip
# -rw-r--r--. 1 root root 9461256744 May 31 19:45 /var/opt/common5/mdt/20230531/13/ta_histogram.csv
# -rw-r--r--. 1 root root 45551616 May 31 20:03 /var/opt/common5/mdt/20230531/13/ta_histogram.zip

# %%
test1 = re.split(r'\s+|\n', raw)

# %%
# Create list comprehension to filter list of zip files only

# result = [file for file in test1 if file.endswith('.zip')]

# Create list comprehension to filter only mdt_result.zip only
# Option are ue_traffic or mdt_result

pattern = r'.*/(?!filter_)[^/]+/mdt_result\.zip$'
result = [path for path in test1 if re.match(pattern, path)]

# %%
# Create list comprehension to generate weekend dates in May

weekend_dates = [date.strftime("%Y%m%d") for date in (datetime.date(2023, 5, day) for day in range(1, 32)) 
                 if date.weekday() >= 5]

# %%
# Create list comprehension to filter May Month only
result = [path for path in result if '202305' in path]

# Create list comprehension to filter Out Some Date
result = [path for path in result if '20230501' not in path and '20230518' not in path]

# Create list comprehension to filter Out Some Date
# result = [path for path in result if '20230501' not in path and '20230518' not in path]

# Create list comprehension to filter Out Weekend Date
result = [path for path in result if path.split('/')[5] not in weekend_dates]

# Create list comprehension to filter Busy Hour only
result = [path for path in result if '/07/' in path or '/08/' in path or '/09/' in path or '/17/' in path or '/18/' in path or '/19/' in path]

# Create list comprehension to filter Busy Hour only
# result = [path for path in result if '/11/' in path or '/12/' in path or '/13/' in path]

# result = [path for path in result if '/07/' in path or '/08/' in path or '/09/']

# %%
with open(r'/home/nivag/location_to_dl_8008-mdt.txt', 'w') as fp:
    fp.write('\n'.join(result))
