# %%
import pexpect
import time
import sys
import re
import datetime

# %%
#ENM3 -> 10.23.202.28 PW : "Enm#2021"
#ENM5 -> 10.167.30.28 PW : "Enm#2021"

child = pexpect.spawn('ssh -L 7898:localhost:8007 -J root@150.236.203.198 root@127.0.0.1 -p 8007', timeout=30, encoding='utf-8', logfile=sys.stdout)

child.maxread = 300000 

child.expect("root@150.236.203.198's password: ")
child.sendline('PMT@2022')
child.expect("root@127.0.0.1's password: ")
child.sendline('PMT@2022')

time.sleep(3)

# Shell command to take after the dates in modification dates
# child.sendline('find /var/opt/common5/mdt/ -type f -newermt 2023-04-28 -exec ls -l {} \;')

# Shell command to take only the folder
# child.sendline('find /var/opt/common5/mdt/20230205 -type f -exec ls -l {} \;')

# Shell command to take certain range dates in modification dates
child.sendline('find /var/opt/common5/mdt -type f -newermt 2023-04-10 ! -newermt 2023-07-05 -exec ls -l {} \;')

try:
    child.expect(pexpect.EOF, timeout=150)

except pexpect.TIMEOUT:
    child.close()
    raw = str(child.before)
# Out:
# root@150.236.203.198's password: PMT@2022
#
# root@127.0.0.1's password: PMT@2022
# find /var/opt/common5/mdt -type f -newermt 2023-04-10 ! -newermt 2023-07-05 -exec ls -l {} \;
#
# Last login: Thu Jul  6 10:46:27 2023 from 192.168.21.6
# ! -newermt 202l-1:~(base) [root@pmt-xl-1 ~]# find /var/opt/common5/mdt -type f -newermt 2023-04-10  3-07-05 -exec ls -l {} \;
# -rw-r--r--. 1 root root 109709 Jun  7 11:34 /var/opt/common5/mdt/20230607/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 5216463 Jun  7 11:34 /var/opt/common5/mdt/20230607/07/ue_traffic.zip
# -rw-r--r--. 1 root root 10668634 Jun  7 11:34 /var/opt/common5/mdt/20230607/07/ue_meas.zip
# -rw-r--r--. 1 root root 7316622 Jun  7 11:34 /var/opt/common5/mdt/20230607/07/mdt_result.zip
# -rw-r--r--. 1 root root 60995639 Jun  7 11:36 /var/opt/common5/mdt/20230607/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1122948 Jun  7 12:57 /var/opt/common5/mdt/20230607/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 43830314 Jun  7 12:57 /var/opt/common5/mdt/20230607/08/ue_traffic.zip
# -rw-r--r--. 1 root root 89291218 Jun  7 12:58 /var/opt/common5/mdt/20230607/08/ue_meas.zip
# -rw-r--r--. 1 root root 62137659 Jun  7 12:59 /var/opt/common5/mdt/20230607/08/mdt_result.zip
# -rw-r--r--. 1 root root 325418448 Jun  7 13:07 /var/opt/common5/mdt/20230607/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1115888 Jun  7 13:57 /var/opt/common5/mdt/20230607/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 45483905 Jun  7 13:57 /var/opt/common5/mdt/20230607/09/ue_traffic.zip
# -rw-r--r--. 1 root root 92563022 Jun  7 13:58 /var/opt/common5/mdt/20230607/09/ue_meas.zip
# -rw-r--r--. 1 root root 64338785 Jun  7 13:59 /var/opt/common5/mdt/20230607/09/mdt_result.zip
# -rw-r--r--. 1 root root 332757374 Jun  7 14:06 /var/opt/common5/mdt/20230607/09/ta_histogram.zip
# -rw-r--r--. 1 root root 1111019 Jun  7 14:57 /var/opt/common5/mdt/20230607/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 45155022 Jun  7 14:57 /var/opt/common5/mdt/20230607/10/ue_traffic.zip
# -rw-r--r--. 1 root root 92149190 Jun  7 14:58 /var/opt/common5/mdt/20230607/10/ue_meas.zip
# -rw-r--r--. 1 root root 64508446 Jun  7 14:59 /var/opt/common5/mdt/20230607/10/mdt_result.zip
# -rw-r--r--. 1 root root 339061801 Jun  7 15:08 /var/opt/common5/mdt/20230607/10/ta_histogram.zip
# -rw-r--r--. 1 root root 1112942 Jun  7 15:57 /var/opt/common5/mdt/20230607/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 44540221 Jun  7 15:57 /var/opt/common5/mdt/20230607/11/ue_traffic.zip
# -rw-r--r--. 1 root root 91683474 Jun  7 15:58 /var/opt/common5/mdt/20230607/11/ue_meas.zip
# -rw-r--r--. 1 root root 64553795 Jun  7 15:59 /var/opt/common5/mdt/20230607/11/mdt_result.zip
# -rw-r--r--. 1 root root 343539179 Jun  7 16:06 /var/opt/common5/mdt/20230607/11/ta_histogram.zip
# -rw-r--r--. 1 root root 1115311 Jun  7 16:57 /var/opt/common5/mdt/20230607/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 44855173 Jun  7 16:58 /var/opt/common5/mdt/20230607/12/ue_traffic.zip
# -rw-r--r--. 1 root root 91647459 Jun  7 16:58 /var/opt/common5/mdt/20230607/12/ue_meas.zip
# -rw-r--r--. 1 root root 64181198 Jun  7 17:00 /var/opt/common5/mdt/20230607/12/mdt_result.zip
# -rw-r--r--. 1 root root 345100124 Jun  7 17:09 /var/opt/common5/mdt/20230607/12/ta_histogram.zip
# -rw-r--r--. 1 root root 1115925 Jun  7 17:57 /var/opt/common5/mdt/20230607/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 43591614 Jun  7 17:57 /var/opt/common5/mdt/20230607/13/ue_traffic.zip
# -rw-r--r--. 1 root root 88896083 Jun  7 17:58 /var/opt/common5/mdt/20230607/13/ue_meas.zip
# -rw-r--r--. 1 root root 62548763 Jun  7 17:59 /var/opt/common5/mdt/20230607/13/mdt_result.zip
# -rw-r--r--. 1 root root 335868074 Jun  7 18:06 /var/opt/common5/mdt/20230607/13/ta_histogram.zip
# -rw-r--r--. 1 root root 1118406 Jun  7 18:57 /var/opt/common5/mdt/20230607/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 43288664 Jun  7 18:57 /var/opt/common5/mdt/20230607/14/ue_traffic.zip
# -rw-r--r--. 1 root root 88282903 Jun  7 18:58 /var/opt/common5/mdt/20230607/14/ue_meas.zip
# -rw-r--r--. 1 root root 62159172 Jun  7 18:59 /var/opt/common5/mdt/20230607/14/mdt_result.zip
# -rw-r--r--. 1 root root 331811844 Jun  7 19:06 /var/opt/common5/mdt/20230607/14/ta_histogram.zip
# -rw-r--r--. 1 root root 1121014 Jun  7 19:57 /var/opt/common5/mdt/20230607/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 44174085 Jun  7 19:57 /var/opt/common5/mdt/20230607/15/ue_traffic.zip
# -rw-r--r--. 1 root root 90020123 Jun  7 19:58 /var/opt/common5/mdt/20230607/15/ue_meas.zip
# -rw-r--r--. 1 root root 63504437 Jun  7 19:59 /var/opt/common5/mdt/20230607/15/mdt_result.zip
# -rw-r--r--. 1 root root 333394919 Jun  7 20:07 /var/opt/common5/mdt/20230607/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1122220 Jun  7 20:57 /var/opt/common5/mdt/20230607/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 46561674 Jun  7 20:58 /var/opt/common5/mdt/20230607/16/ue_traffic.zip
# -rw-r--r--. 1 root root 94987713 Jun  7 20:58 /var/opt/common5/mdt/20230607/16/ue_meas.zip
# -rw-r--r--. 1 root root 67174644 Jun  7 21:00 /var/opt/common5/mdt/20230607/16/mdt_result.zip
# -rw-r--r--. 1 root root 341535430 Jun  7 21:07 /var/opt/common5/mdt/20230607/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1119465 Jun  7 21:58 /var/opt/common5/mdt/20230607/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 48970007 Jun  7 21:59 /var/opt/common5/mdt/20230607/17/ue_traffic.zip
# -rw-r--r--. 1 root root 99807829 Jun  7 22:00 /var/opt/common5/mdt/20230607/17/ue_meas.zip
# -rw-r--r--. 1 root root 70531452 Jun  7 22:01 /var/opt/common5/mdt/20230607/17/mdt_result.zip
# -rw-r--r--. 1 root root 354226967 Jun  7 22:09 /var/opt/common5/mdt/20230607/17/ta_histogram.zip
# -rw-r--r--. 1 root root 1122851 Jun  7 22:58 /var/opt/common5/mdt/20230607/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 49138932 Jun  7 22:58 /var/opt/common5/mdt/20230607/18/ue_traffic.zip
# -rw-r--r--. 1 root root 100179399 Jun  7 22:59 /var/opt/common5/mdt/20230607/18/ue_meas.zip
# -rw-r--r--. 1 root root 70334770 Jun  7 23:00 /var/opt/common5/mdt/20230607/18/mdt_result.zip
# -rw-r--r--. 1 root root 352526030 Jun  7 23:10 /var/opt/common5/mdt/20230607/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1117674 Jun  7 23:57 /var/opt/common5/mdt/20230607/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 47355368 Jun  7 23:57 /var/opt/common5/mdt/20230607/19/ue_traffic.zip
# -rw-r--r--. 1 root root 96688660 Jun  7 23:58 /var/opt/common5/mdt/20230607/19/ue_meas.zip
# -rw-r--r--. 1 root root 67469297 Jun  7 23:59 /var/opt/common5/mdt/20230607/19/mdt_result.zip
# -rw-r--r--. 1 root root 350182703 Jun  8 00:06 /var/opt/common5/mdt/20230607/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1123252 Jun  8 00:56 /var/opt/common5/mdt/20230607/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 44764479 Jun  8 00:57 /var/opt/common5/mdt/20230607/20/ue_traffic.zip
# -rw-r--r--. 1 root root 91974650 Jun  8 00:57 /var/opt/common5/mdt/20230607/20/ue_meas.zip
# -rw-r--r--. 1 root root 63306960 Jun  8 00:59 /var/opt/common5/mdt/20230607/20/mdt_result.zip
# -rw-r--r--. 1 root root 338769242 Jun  8 01:06 /var/opt/common5/mdt/20230607/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1126818 Jun  8 01:54 /var/opt/common5/mdt/20230607/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 41042170 Jun  8 01:55 /var/opt/common5/mdt/20230607/21/ue_traffic.zip
# -rw-r--r--. 1 root root 83902275 Jun  8 01:55 /var/opt/common5/mdt/20230607/21/ue_meas.zip
# -rw-r--r--. 1 root root 56685584 Jun  8 01:56 /var/opt/common5/mdt/20230607/21/mdt_result.zip
# -rw-r--r--. 1 root root 317821791 Jun  8 02:03 /var/opt/common5/mdt/20230607/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1129639 Jun  8 02:52 /var/opt/common5/mdt/20230607/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 35784448 Jun  8 02:53 /var/opt/common5/mdt/20230607/22/ue_traffic.zip
# -rw-r--r--. 1 root root 72564728 Jun  8 02:53 /var/opt/common5/mdt/20230607/22/ue_meas.zip
# -rw-r--r--. 1 root root 48187032 Jun  8 02:54 /var/opt/common5/mdt/20230607/22/mdt_result.zip
# -rw-r--r--. 1 root root 285179697 Jun  8 03:00 /var/opt/common5/mdt/20230607/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1185716 Jun  8 03:52 /var/opt/common5/mdt/20230607/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 29931406 Jun  8 03:52 /var/opt/common5/mdt/20230607/23/ue_traffic.zip
# -rw-r--r--. 1 root root 60130738 Jun  8 03:53 /var/opt/common5/mdt/20230607/23/ue_meas.zip
# -rw-r--r--. 1 root root 39606466 Jun  8 03:54 /var/opt/common5/mdt/20230607/23/mdt_result.zip
# -rw-r--r--. 1 root root 244070379 Jun  8 03:58 /var/opt/common5/mdt/20230607/23/ta_histogram.zip
# -rw-r--r--. 1 root root 1796989 Jun  8 05:30 /var/opt/common5/mdt/20230607/ue_capability_20230607.zip
# -rw-r--r--. 1 root root 33827610 Jun  8 05:50 /var/opt/common5/mdt/20230607/grid_mdt_cell_20230607.zip
# -rw-r--r--. 1 root root 58164732 Jun  8 05:57 /var/opt/common5/mdt/20230607/grid_mdt_traffic_cell_20230607.zip
# -rw-r--r--. 1 root root 87103381 Jun  8 06:04 /var/opt/common5/mdt/20230607/grid_mdt_meas_cell_20230607.zip
# -rw-r--r--. 1 root root 13872834 Jun  8 06:09 /var/opt/common5/mdt/20230607/filter_mdt_result.zip
# -rw-r--r--. 1 root root 13326887 Jun  8 06:09 /var/opt/common5/mdt/20230607/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 27142763 Jun  8 06:10 /var/opt/common5/mdt/20230607/filter_ue_meas.zip
# -rw-r--r--. 1 root root 1195867 Jun  8 04:51 /var/opt/common5/mdt/20230608/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 25567667 Jun  8 04:52 /var/opt/common5/mdt/20230608/00/ue_traffic.zip
# -rw-r--r--. 1 root root 50878408 Jun  8 04:52 /var/opt/common5/mdt/20230608/00/ue_meas.zip
# -rw-r--r--. 1 root root 32796059 Jun  8 04:53 /var/opt/common5/mdt/20230608/00/mdt_result.zip
# -rw-r--r--. 1 root root 210713868 Jun  8 04:57 /var/opt/common5/mdt/20230608/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1183805 Jun  8 05:51 /var/opt/common5/mdt/20230608/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 20430932 Jun  8 05:51 /var/opt/common5/mdt/20230608/01/ue_traffic.zip
# -rw-r--r--. 1 root root 40197493 Jun  8 05:52 /var/opt/common5/mdt/20230608/01/ue_meas.zip
# -rw-r--r--. 1 root root 25387036 Jun  8 05:53 /var/opt/common5/mdt/20230608/01/mdt_result.zip
# -rw-r--r--. 1 root root 182149702 Jun  8 05:57 /var/opt/common5/mdt/20230608/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1175183 Jun  8 06:50 /var/opt/common5/mdt/20230608/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 18224377 Jun  8 06:50 /var/opt/common5/mdt/20230608/02/ue_traffic.zip
# -rw-r--r--. 1 root root 35195565 Jun  8 06:50 /var/opt/common5/mdt/20230608/02/ue_meas.zip
# -rw-r--r--. 1 root root 21638579 Jun  8 06:51 /var/opt/common5/mdt/20230608/02/mdt_result.zip
# -rw-r--r--. 1 root root 173389659 Jun  8 06:54 /var/opt/common5/mdt/20230608/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1183141 Jun  8 07:49 /var/opt/common5/mdt/20230608/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 17717424 Jun  8 07:49 /var/opt/common5/mdt/20230608/03/ue_traffic.zip
# -rw-r--r--. 1 root root 33943542 Jun  8 07:49 /var/opt/common5/mdt/20230608/03/ue_meas.zip
# -rw-r--r--. 1 root root 20443401 Jun  8 07:50 /var/opt/common5/mdt/20230608/03/mdt_result.zip
# -rw-r--r--. 1 root root 165135207 Jun  8 07:54 /var/opt/common5/mdt/20230608/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1184943 Jun  8 08:50 /var/opt/common5/mdt/20230608/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 19007476 Jun  8 08:50 /var/opt/common5/mdt/20230608/04/ue_traffic.zip
# -rw-r--r--. 1 root root 36361290 Jun  8 08:50 /var/opt/common5/mdt/20230608/04/ue_meas.zip
# -rw-r--r--. 1 root root 22088301 Jun  8 08:51 /var/opt/common5/mdt/20230608/04/mdt_result.zip
# -rw-r--r--. 1 root root 171948390 Jun  8 08:54 /var/opt/common5/mdt/20230608/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1125231 Jun  8 09:51 /var/opt/common5/mdt/20230608/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 24425566 Jun  8 09:51 /var/opt/common5/mdt/20230608/05/ue_traffic.zip
# -rw-r--r--. 1 root root 47611453 Jun  8 09:52 /var/opt/common5/mdt/20230608/05/ue_meas.zip
# -rw-r--r--. 1 root root 31247212 Jun  8 09:52 /var/opt/common5/mdt/20230608/05/mdt_result.zip
# -rw-r--r--. 1 root root 210783137 Jun  8 09:57 /var/opt/common5/mdt/20230608/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1137340 Jun  8 10:54 /var/opt/common5/mdt/20230608/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 36684418 Jun  8 10:54 /var/opt/common5/mdt/20230608/06/ue_traffic.zip
# -rw-r--r--. 1 root root 72698617 Jun  8 10:55 /var/opt/common5/mdt/20230608/06/ue_meas.zip
# -rw-r--r--. 1 root root 49349058 Jun  8 10:56 /var/opt/common5/mdt/20230608/06/mdt_result.zip
# -rw-r--r--. 1 root root 273827895 Jun  8 11:01 /var/opt/common5/mdt/20230608/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1127961 Jun  8 11:57 /var/opt/common5/mdt/20230608/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 43877377 Jun  8 11:57 /var/opt/common5/mdt/20230608/07/ue_traffic.zip
# -rw-r--r--. 1 root root 88090266 Jun  8 11:58 /var/opt/common5/mdt/20230608/07/ue_meas.zip
# -rw-r--r--. 1 root root 59836912 Jun  8 11:59 /var/opt/common5/mdt/20230608/07/mdt_result.zip
# -rw-r--r--. 1 root root 308014745 Jun  8 12:05 /var/opt/common5/mdt/20230608/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1121515 Jun  8 12:57 /var/opt/common5/mdt/20230608/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 45170651 Jun  8 12:57 /var/opt/common5/mdt/20230608/08/ue_traffic.zip
# -rw-r--r--. 1 root root 90784763 Jun  8 12:58 /var/opt/common5/mdt/20230608/08/ue_meas.zip
# -rw-r--r--. 1 root root 62073665 Jun  8 12:59 /var/opt/common5/mdt/20230608/08/mdt_result.zip
# -rw-r--r--. 1 root root 320588385 Jun  8 13:07 /var/opt/common5/mdt/20230608/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1116826 Jun  8 13:57 /var/opt/common5/mdt/20230608/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 46401104 Jun  8 13:57 /var/opt/common5/mdt/20230608/09/ue_traffic.zip
# -rw-r--r--. 1 root root 94348386 Jun  8 13:58 /var/opt/common5/mdt/20230608/09/ue_meas.zip
# -rw-r--r--. 1 root root 64470199 Jun  8 13:59 /var/opt/common5/mdt/20230608/09/mdt_result.zip
# -rw-r--r--. 1 root root 328744541 Jun  8 14:07 /var/opt/common5/mdt/20230608/09/ta_histogram.zip
# -rw-r--r--. 1 root root 1116400 Jun  8 14:57 /var/opt/common5/mdt/20230608/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 45475626 Jun  8 14:57 /var/opt/common5/mdt/20230608/10/ue_traffic.zip
# -rw-r--r--. 1 root root 92703710 Jun  8 14:58 /var/opt/common5/mdt/20230608/10/ue_meas.zip
# -rw-r--r--. 1 root root 64144953 Jun  8 14:59 /var/opt/common5/mdt/20230608/10/mdt_result.zip
# -rw-r--r--. 1 root root 334807727 Jun  8 15:08 /var/opt/common5/mdt/20230608/10/ta_histogram.zip
# -rw-r--r--. 1 root root 1114458 Jun  8 15:57 /var/opt/common5/mdt/20230608/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 45187810 Jun  8 15:58 /var/opt/common5/mdt/20230608/11/ue_traffic.zip
# -rw-r--r--. 1 root root 92297034 Jun  8 15:58 /var/opt/common5/mdt/20230608/11/ue_meas.zip
# -rw-r--r--. 1 root root 64167052 Jun  8 16:00 /var/opt/common5/mdt/20230608/11/mdt_result.zip
# -rw-r--r--. 1 root root 339817211 Jun  8 16:07 /var/opt/common5/mdt/20230608/11/ta_histogram.zip
# -rw-r--r--. 1 root root 1113291 Jun  8 16:58 /var/opt/common5/mdt/20230608/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 45049255 Jun  8 16:58 /var/opt/common5/mdt/20230608/12/ue_traffic.zip
# -rw-r--r--. 1 root root 92017612 Jun  8 16:59 /var/opt/common5/mdt/20230608/12/ue_meas.zip
# -rw-r--r--. 1 root root 63780295 Jun  8 17:00 /var/opt/common5/mdt/20230608/12/mdt_result.zip
# -rw-r--r--. 1 root root 341969625 Jun  8 17:10 /var/opt/common5/mdt/20230608/12/ta_histogram.zip
# -rw-r--r--. 1 root root 1113288 Jun  8 17:56 /var/opt/common5/mdt/20230608/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 44159670 Jun  8 17:56 /var/opt/common5/mdt/20230608/13/ue_traffic.zip
# -rw-r--r--. 1 root root 90087918 Jun  8 17:57 /var/opt/common5/mdt/20230608/13/ue_meas.zip
# -rw-r--r--. 1 root root 62483432 Jun  8 17:58 /var/opt/common5/mdt/20230608/13/mdt_result.zip
# -rw-r--r--. 1 root root 333864988 Jun  8 18:06 /var/opt/common5/mdt/20230608/13/ta_histogram.zip
# -rw-r--r--. 1 root root 1116920 Jun  8 18:57 /var/opt/common5/mdt/20230608/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 43481193 Jun  8 18:57 /var/opt/common5/mdt/20230608/14/ue_traffic.zip
# -rw-r--r--. 1 root root 88639119 Jun  8 18:58 /var/opt/common5/mdt/20230608/14/ue_meas.zip
# -rw-r--r--. 1 root root 61845384 Jun  8 18:59 /var/opt/common5/mdt/20230608/14/mdt_result.zip
# -rw-r--r--. 1 root root 329152683 Jun  8 19:07 /var/opt/common5/mdt/20230608/14/ta_histogram.zip
# -rw-r--r--. 1 root root 1120745 Jun  8 19:58 /var/opt/common5/mdt/20230608/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 44879139 Jun  8 19:58 /var/opt/common5/mdt/20230608/15/ue_traffic.zip
# -rw-r--r--. 1 root root 91403271 Jun  8 19:59 /var/opt/common5/mdt/20230608/15/ue_meas.zip
# -rw-r--r--. 1 root root 63577291 Jun  8 20:00 /var/opt/common5/mdt/20230608/15/mdt_result.zip
# -rw-r--r--. 1 root root 329187276 Jun  8 20:07 /var/opt/common5/mdt/20230608/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1123558 Jun  8 20:57 /var/opt/common5/mdt/20230608/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 46862627 Jun  8 20:58 /var/opt/common5/mdt/20230608/16/ue_traffic.zip
# -rw-r--r--. 1 root root 95526002 Jun  8 20:58 /var/opt/common5/mdt/20230608/16/ue_meas.zip
# -rw-r--r--. 1 root root 66685715 Jun  8 21:00 /var/opt/common5/mdt/20230608/16/mdt_result.zip
# -rw-r--r--. 1 root root 338674498 Jun  8 21:07 /var/opt/common5/mdt/20230608/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1121539 Jun  8 21:58 /var/opt/common5/mdt/20230608/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 49877348 Jun  8 21:58 /var/opt/common5/mdt/20230608/17/ue_traffic.zip
# -rw-r--r--. 1 root root 101658459 Jun  8 21:59 /var/opt/common5/mdt/20230608/17/ue_meas.zip
# -rw-r--r--. 1 root root 71240748 Jun  8 22:01 /var/opt/common5/mdt/20230608/17/mdt_result.zip
# -rw-r--r--. 1 root root 353076308 Jun  8 22:08 /var/opt/common5/mdt/20230608/17/ta_histogram.zip
# -rw-r--r--. 1 root root 1126033 Jun  8 22:57 /var/opt/common5/mdt/20230608/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 48848334 Jun  8 22:58 /var/opt/common5/mdt/20230608/18/ue_traffic.zip
# -rw-r--r--. 1 root root 100288982 Jun  8 22:59 /var/opt/common5/mdt/20230608/18/ue_meas.zip
# -rw-r--r--. 1 root root 69615049 Jun  8 23:00 /var/opt/common5/mdt/20230608/18/mdt_result.zip
# -rw-r--r--. 1 root root 350997275 Jun  8 23:07 /var/opt/common5/mdt/20230608/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1123045 Jun  8 23:57 /var/opt/common5/mdt/20230608/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 46398279 Jun  8 23:57 /var/opt/common5/mdt/20230608/19/ue_traffic.zip
# -rw-r--r--. 1 root root 95424140 Jun  8 23:58 /var/opt/common5/mdt/20230608/19/ue_meas.zip
# -rw-r--r--. 1 root root 66234437 Jun  8 23:59 /var/opt/common5/mdt/20230608/19/mdt_result.zip
# -rw-r--r--. 1 root root 348466393 Jun  9 00:07 /var/opt/common5/mdt/20230608/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1127613 Jun  9 00:57 /var/opt/common5/mdt/20230608/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 45176476 Jun  9 00:57 /var/opt/common5/mdt/20230608/20/ue_traffic.zip
# -rw-r--r--. 1 root root 91987376 Jun  9 00:58 /var/opt/common5/mdt/20230608/20/ue_meas.zip
# -rw-r--r--. 1 root root 62594841 Jun  9 00:59 /var/opt/common5/mdt/20230608/20/mdt_result.zip
# -rw-r--r--. 1 root root 338286977 Jun  9 01:06 /var/opt/common5/mdt/20230608/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1132001 Jun  9 01:55 /var/opt/common5/mdt/20230608/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 41321732 Jun  9 01:55 /var/opt/common5/mdt/20230608/21/ue_traffic.zip
# -rw-r--r--. 1 root root 83804806 Jun  9 01:56 /var/opt/common5/mdt/20230608/21/ue_meas.zip
# -rw-r--r--. 1 root root 56131888 Jun  9 01:57 /var/opt/common5/mdt/20230608/21/mdt_result.zip
# -rw-r--r--. 1 root root 317094060 Jun  9 02:03 /var/opt/common5/mdt/20230608/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1126536 Jun  9 02:53 /var/opt/common5/mdt/20230608/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 35408437 Jun  9 02:53 /var/opt/common5/mdt/20230608/22/ue_traffic.zip
# -rw-r--r--. 1 root root 71780585 Jun  9 02:54 /var/opt/common5/mdt/20230608/22/ue_meas.zip
# -rw-r--r--. 1 root root 47464397 Jun  9 02:55 /var/opt/common5/mdt/20230608/22/mdt_result.zip
# -rw-r--r--. 1 root root 284226892 Jun  9 03:00 /var/opt/common5/mdt/20230608/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1130085 Jun  9 03:51 /var/opt/common5/mdt/20230608/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 28992001 Jun  9 03:52 /var/opt/common5/mdt/20230608/23/ue_traffic.zip
# -rw-r--r--. 1 root root 58111340 Jun  9 03:52 /var/opt/common5/mdt/20230608/23/ue_meas.zip
# -rw-r--r--. 1 root root 38162146 Jun  9 03:53 /var/opt/common5/mdt/20230608/23/mdt_result.zip
# -rw-r--r--. 1 root root 249193989 Jun  9 03:58 /var/opt/common5/mdt/20230608/23/ta_histogram.zip
# -rw-r--r--. 1 root root 3424635 Jun  9 05:44 /var/opt/common5/mdt/20230608/ue_capability_20230608.zip
# -rw-r--r--. 1 root root 38057628 Jun  9 06:03 /var/opt/common5/mdt/20230608/grid_mdt_cell_20230608.zip
# -rw-r--r--. 1 root root 65791928 Jun  9 06:11 /var/opt/common5/mdt/20230608/grid_mdt_traffic_cell_20230608.zip
# -rw-r--r--. 1 root root 97240736 Jun  9 06:22 /var/opt/common5/mdt/20230608/grid_mdt_meas_cell_20230608.zip
# -rw-r--r--. 1 root root 697176 Jun 13 14:37 /var/opt/common5/mdt/20230608/filter_mdt_result.zip
# -rw-r--r--. 1 root root 933190 Jun 13 14:39 /var/opt/common5/mdt/20230608/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 1938688 Jun 13 14:42 /var/opt/common5/mdt/20230608/filter_ue_meas.zip
# -rw-r--r--. 1 root root 1123068 Jun  9 04:50 /var/opt/common5/mdt/20230609/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 24259957 Jun  9 04:50 /var/opt/common5/mdt/20230609/00/ue_traffic.zip
# -rw-r--r--. 1 root root 48032759 Jun  9 04:51 /var/opt/common5/mdt/20230609/00/ue_meas.zip
# -rw-r--r--. 1 root root 31014688 Jun  9 04:51 /var/opt/common5/mdt/20230609/00/mdt_result.zip
# -rw-r--r--. 1 root root 220597947 Jun  9 04:57 /var/opt/common5/mdt/20230609/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1110788 Jun  9 05:49 /var/opt/common5/mdt/20230609/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 19603865 Jun  9 05:49 /var/opt/common5/mdt/20230609/01/ue_traffic.zip
# -rw-r--r--. 1 root root 38412513 Jun  9 05:50 /var/opt/common5/mdt/20230609/01/ue_meas.zip
# -rw-r--r--. 1 root root 24281986 Jun  9 05:50 /var/opt/common5/mdt/20230609/01/mdt_result.zip
# -rw-r--r--. 1 root root 188698497 Jun  9 05:55 /var/opt/common5/mdt/20230609/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1110044 Jun  9 06:49 /var/opt/common5/mdt/20230609/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 17545141 Jun  9 06:49 /var/opt/common5/mdt/20230609/02/ue_traffic.zip
# -rw-r--r--. 1 root root 33983825 Jun  9 06:49 /var/opt/common5/mdt/20230609/02/ue_meas.zip
# -rw-r--r--. 1 root root 21120270 Jun  9 06:50 /var/opt/common5/mdt/20230609/02/mdt_result.zip
# -rw-r--r--. 1 root root 178652537 Jun  9 06:54 /var/opt/common5/mdt/20230609/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1105494 Jun  9 07:48 /var/opt/common5/mdt/20230609/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 16944515 Jun  9 07:48 /var/opt/common5/mdt/20230609/03/ue_traffic.zip
# -rw-r--r--. 1 root root 32481553 Jun  9 07:49 /var/opt/common5/mdt/20230609/03/ue_meas.zip
# -rw-r--r--. 1 root root 19922615 Jun  9 07:49 /var/opt/common5/mdt/20230609/03/mdt_result.zip
# -rw-r--r--. 1 root root 169587035 Jun  9 07:53 /var/opt/common5/mdt/20230609/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1108490 Jun  9 08:49 /var/opt/common5/mdt/20230609/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 18287416 Jun  9 08:50 /var/opt/common5/mdt/20230609/04/ue_traffic.zip
# -rw-r--r--. 1 root root 34992038 Jun  9 08:50 /var/opt/common5/mdt/20230609/04/ue_meas.zip
# -rw-r--r--. 1 root root 21612521 Jun  9 08:50 /var/opt/common5/mdt/20230609/04/mdt_result.zip
# -rw-r--r--. 1 root root 177169741 Jun  9 08:54 /var/opt/common5/mdt/20230609/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1122350 Jun  9 09:52 /var/opt/common5/mdt/20230609/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 23745659 Jun  9 09:52 /var/opt/common5/mdt/20230609/05/ue_traffic.zip
# -rw-r--r--. 1 root root 46277522 Jun  9 09:53 /var/opt/common5/mdt/20230609/05/ue_meas.zip
# -rw-r--r--. 1 root root 30327444 Jun  9 09:53 /var/opt/common5/mdt/20230609/05/mdt_result.zip
# -rw-r--r--. 1 root root 213675509 Jun  9 09:58 /var/opt/common5/mdt/20230609/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1140490 Jun  9 10:56 /var/opt/common5/mdt/20230609/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 35569148 Jun  9 10:56 /var/opt/common5/mdt/20230609/06/ue_traffic.zip
# -rw-r--r--. 1 root root 70981905 Jun  9 10:57 /var/opt/common5/mdt/20230609/06/ue_meas.zip
# -rw-r--r--. 1 root root 48486414 Jun  9 10:57 /var/opt/common5/mdt/20230609/06/mdt_result.zip
# -rw-r--r--. 1 root root 279471374 Jun  9 11:03 /var/opt/common5/mdt/20230609/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1131740 Jun  9 11:57 /var/opt/common5/mdt/20230609/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 42908052 Jun  9 11:57 /var/opt/common5/mdt/20230609/07/ue_traffic.zip
# -rw-r--r--. 1 root root 86262141 Jun  9 11:58 /var/opt/common5/mdt/20230609/07/ue_meas.zip
# -rw-r--r--. 1 root root 59156388 Jun  9 11:59 /var/opt/common5/mdt/20230609/07/mdt_result.zip
# -rw-r--r--. 1 root root 312410401 Jun  9 12:06 /var/opt/common5/mdt/20230609/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1123591 Jun  9 12:57 /var/opt/common5/mdt/20230609/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 44248827 Jun  9 12:57 /var/opt/common5/mdt/20230609/08/ue_traffic.zip
# -rw-r--r--. 1 root root 89685159 Jun  9 12:58 /var/opt/common5/mdt/20230609/08/ue_meas.zip
# -rw-r--r--. 1 root root 61742222 Jun  9 12:59 /var/opt/common5/mdt/20230609/08/mdt_result.zip
# -rw-r--r--. 1 root root 324893072 Jun  9 13:07 /var/opt/common5/mdt/20230609/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1119218 Jun  9 13:57 /var/opt/common5/mdt/20230609/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 45546982 Jun  9 13:57 /var/opt/common5/mdt/20230609/09/ue_traffic.zip
# -rw-r--r--. 1 root root 92750903 Jun  9 13:58 /var/opt/common5/mdt/20230609/09/ue_meas.zip
# -rw-r--r--. 1 root root 64026285 Jun  9 13:59 /var/opt/common5/mdt/20230609/09/mdt_result.zip
# -rw-r--r--. 1 root root 333254933 Jun  9 14:07 /var/opt/common5/mdt/20230609/09/ta_histogram.zip
# -rw-r--r--. 1 root root 1118175 Jun  9 14:57 /var/opt/common5/mdt/20230609/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 44812998 Jun  9 14:58 /var/opt/common5/mdt/20230609/10/ue_traffic.zip
# -rw-r--r--. 1 root root 91449455 Jun  9 14:58 /var/opt/common5/mdt/20230609/10/ue_meas.zip
# -rw-r--r--. 1 root root 63288701 Jun  9 14:59 /var/opt/common5/mdt/20230609/10/mdt_result.zip
# -rw-r--r--. 1 root root 339684974 Jun  9 15:08 /var/opt/common5/mdt/20230609/10/ta_histogram.zip
# -rw-r--r--. 1 root root 1126224 Jun  9 15:57 /var/opt/common5/mdt/20230609/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 43752352 Jun  9 15:58 /var/opt/common5/mdt/20230609/11/ue_traffic.zip
# -rw-r--r--. 1 root root 89153306 Jun  9 15:58 /var/opt/common5/mdt/20230609/11/ue_meas.zip
# -rw-r--r--. 1 root root 61478016 Jun  9 15:59 /var/opt/common5/mdt/20230609/11/mdt_result.zip
# -rw-r--r--. 1 root root 340170752 Jun  9 16:09 /var/opt/common5/mdt/20230609/11/ta_histogram.zip
# -rw-r--r--. 1 root root 1129301 Jun  9 16:57 /var/opt/common5/mdt/20230609/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 41305015 Jun  9 16:57 /var/opt/common5/mdt/20230609/12/ue_traffic.zip
# -rw-r--r--. 1 root root 84564101 Jun  9 16:58 /var/opt/common5/mdt/20230609/12/ue_meas.zip
# -rw-r--r--. 1 root root 57839426 Jun  9 16:59 /var/opt/common5/mdt/20230609/12/mdt_result.zip
# -rw-r--r--. 1 root root 331000099 Jun  9 17:06 /var/opt/common5/mdt/20230609/12/ta_histogram.zip
# -rw-r--r--. 1 root root 1123499 Jun  9 17:57 /var/opt/common5/mdt/20230609/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 44569267 Jun  9 17:58 /var/opt/common5/mdt/20230609/13/ue_traffic.zip
# -rw-r--r--. 1 root root 90934177 Jun  9 17:58 /var/opt/common5/mdt/20230609/13/ue_meas.zip
# -rw-r--r--. 1 root root 63928617 Jun  9 17:59 /var/opt/common5/mdt/20230609/13/mdt_result.zip
# -rw-r--r--. 1 root root 338096413 Jun  9 18:07 /var/opt/common5/mdt/20230609/13/ta_histogram.zip
# -rw-r--r--. 1 root root 1121469 Jun  9 18:57 /var/opt/common5/mdt/20230609/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 44039694 Jun  9 18:57 /var/opt/common5/mdt/20230609/14/ue_traffic.zip
# -rw-r--r--. 1 root root 89847765 Jun  9 18:58 /var/opt/common5/mdt/20230609/14/ue_meas.zip
# -rw-r--r--. 1 root root 63374196 Jun  9 18:59 /var/opt/common5/mdt/20230609/14/mdt_result.zip
# -rw-r--r--. 1 root root 334238800 Jun  9 19:06 /var/opt/common5/mdt/20230609/14/ta_histogram.zip
# -rw-r--r--. 1 root root 1123637 Jun  9 19:57 /var/opt/common5/mdt/20230609/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 44933798 Jun  9 19:58 /var/opt/common5/mdt/20230609/15/ue_traffic.zip
# -rw-r--r--. 1 root root 91578627 Jun  9 19:58 /var/opt/common5/mdt/20230609/15/ue_meas.zip
# -rw-r--r--. 1 root root 64484940 Jun  9 19:59 /var/opt/common5/mdt/20230609/15/mdt_result.zip
# -rw-r--r--. 1 root root 334432173 Jun  9 20:06 /var/opt/common5/mdt/20230609/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1123026 Jun  9 20:57 /var/opt/common5/mdt/20230609/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 47056087 Jun  9 20:58 /var/opt/common5/mdt/20230609/16/ue_traffic.zip
# -rw-r--r--. 1 root root 96007442 Jun  9 20:58 /var/opt/common5/mdt/20230609/16/ue_meas.zip
# -rw-r--r--. 1 root root 68060966 Jun  9 21:00 /var/opt/common5/mdt/20230609/16/mdt_result.zip
# -rw-r--r--. 1 root root 341852274 Jun  9 21:07 /var/opt/common5/mdt/20230609/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1121962 Jun  9 21:58 /var/opt/common5/mdt/20230609/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 49114640 Jun  9 21:59 /var/opt/common5/mdt/20230609/17/ue_traffic.zip
# -rw-r--r--. 1 root root 100069916 Jun  9 21:59 /var/opt/common5/mdt/20230609/17/ue_meas.zip
# -rw-r--r--. 1 root root 70771363 Jun  9 22:01 /var/opt/common5/mdt/20230609/17/mdt_result.zip
# -rw-r--r--. 1 root root 354450991 Jun  9 22:08 /var/opt/common5/mdt/20230609/17/ta_histogram.zip
# -rw-r--r--. 1 root root 1124649 Jun  9 22:58 /var/opt/common5/mdt/20230609/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 49472796 Jun  9 22:58 /var/opt/common5/mdt/20230609/18/ue_traffic.zip
# -rw-r--r--. 1 root root 100900298 Jun  9 22:59 /var/opt/common5/mdt/20230609/18/ue_meas.zip
# -rw-r--r--. 1 root root 70796723 Jun  9 23:01 /var/opt/common5/mdt/20230609/18/mdt_result.zip
# -rw-r--r--. 1 root root 353478696 Jun  9 23:10 /var/opt/common5/mdt/20230609/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1121357 Jun  9 23:57 /var/opt/common5/mdt/20230609/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 47391543 Jun  9 23:58 /var/opt/common5/mdt/20230609/19/ue_traffic.zip
# -rw-r--r--. 1 root root 96815105 Jun  9 23:59 /var/opt/common5/mdt/20230609/19/ue_meas.zip
# -rw-r--r--. 1 root root 67722124 Jun 10 00:00 /var/opt/common5/mdt/20230609/19/mdt_result.zip
# -rw-r--r--. 1 root root 354700743 Jun 10 00:07 /var/opt/common5/mdt/20230609/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1122929 Jun 10 00:56 /var/opt/common5/mdt/20230609/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 45467483 Jun 10 00:57 /var/opt/common5/mdt/20230609/20/ue_traffic.zip
# -rw-r--r--. 1 root root 93487309 Jun 10 00:58 /var/opt/common5/mdt/20230609/20/ue_meas.zip
# -rw-r--r--. 1 root root 64051039 Jun 10 00:59 /var/opt/common5/mdt/20230609/20/mdt_result.zip
# -rw-r--r--. 1 root root 346049017 Jun 10 01:07 /var/opt/common5/mdt/20230609/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1127481 Jun 10 01:55 /var/opt/common5/mdt/20230609/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 42141778 Jun 10 01:56 /var/opt/common5/mdt/20230609/21/ue_traffic.zip
# -rw-r--r--. 1 root root 86248460 Jun 10 01:56 /var/opt/common5/mdt/20230609/21/ue_meas.zip
# -rw-r--r--. 1 root root 58093395 Jun 10 01:57 /var/opt/common5/mdt/20230609/21/mdt_result.zip
# -rw-r--r--. 1 root root 326453199 Jun 10 02:04 /var/opt/common5/mdt/20230609/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1119713 Jun 10 02:53 /var/opt/common5/mdt/20230609/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 37261842 Jun 10 02:53 /var/opt/common5/mdt/20230609/22/ue_traffic.zip
# -rw-r--r--. 1 root root 75148376 Jun 10 02:54 /var/opt/common5/mdt/20230609/22/ue_meas.zip
# -rw-r--r--. 1 root root 49829396 Jun 10 02:55 /var/opt/common5/mdt/20230609/22/mdt_result.zip
# -rw-r--r--. 1 root root 294624130 Jun 10 03:01 /var/opt/common5/mdt/20230609/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1118327 Jun 10 03:52 /var/opt/common5/mdt/20230609/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 30771044 Jun 10 03:52 /var/opt/common5/mdt/20230609/23/ue_traffic.zip
# -rw-r--r--. 1 root root 61848003 Jun 10 03:53 /var/opt/common5/mdt/20230609/23/ue_meas.zip
# -rw-r--r--. 1 root root 40733770 Jun 10 03:54 /var/opt/common5/mdt/20230609/23/mdt_result.zip
# -rw-r--r--. 1 root root 259283273 Jun 10 03:59 /var/opt/common5/mdt/20230609/23/ta_histogram.zip
# -rw-r--r--. 1 root root 3366927 Jun 10 05:45 /var/opt/common5/mdt/20230609/ue_capability_20230609.zip
# -rw-r--r--. 1 root root 37975382 Jun 10 06:03 /var/opt/common5/mdt/20230609/grid_mdt_cell_20230609.zip
# -rw-r--r--. 1 root root 65477203 Jun 10 06:11 /var/opt/common5/mdt/20230609/grid_mdt_traffic_cell_20230609.zip
# -rw-r--r--. 1 root root 96892346 Jun 10 06:21 /var/opt/common5/mdt/20230609/grid_mdt_meas_cell_20230609.zip
# -rw-r--r--. 1 root root 745562 Jun 26 13:33 /var/opt/common5/mdt/20230609/filter_mdt_result.zip
# -rw-r--r--. 1 root root 914742 Jun 26 13:34 /var/opt/common5/mdt/20230609/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 1914749 Jun 26 13:38 /var/opt/common5/mdt/20230609/filter_ue_meas.zip
# -rw-r--r--. 1 root root 917758 Jun 10 04:42 /var/opt/common5/mdt/20230610/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 14580313 Jun 10 04:42 /var/opt/common5/mdt/20230610/00/ue_traffic.zip
# -rw-r--r--. 1 root root 28623720 Jun 10 04:43 /var/opt/common5/mdt/20230610/00/ue_meas.zip
# -rw-r--r--. 1 root root 18898745 Jun 10 04:43 /var/opt/common5/mdt/20230610/00/mdt_result.zip
# -rw-r--r--. 1 root root 132999145 Jun 10 04:46 /var/opt/common5/mdt/20230610/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1104134 Jun 10 05:49 /var/opt/common5/mdt/20230610/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 20935305 Jun 10 05:50 /var/opt/common5/mdt/20230610/01/ue_traffic.zip
# -rw-r--r--. 1 root root 40873193 Jun 10 05:50 /var/opt/common5/mdt/20230610/01/ue_meas.zip
# -rw-r--r--. 1 root root 26349161 Jun 10 05:51 /var/opt/common5/mdt/20230610/01/mdt_result.zip
# -rw-r--r--. 1 root root 194738019 Jun 10 05:54 /var/opt/common5/mdt/20230610/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1109441 Jun 10 06:48 /var/opt/common5/mdt/20230610/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 18149881 Jun 10 06:49 /var/opt/common5/mdt/20230610/02/ue_traffic.zip
# -rw-r--r--. 1 root root 35208665 Jun 10 06:49 /var/opt/common5/mdt/20230610/02/ue_meas.zip
# -rw-r--r--. 1 root root 22178798 Jun 10 06:49 /var/opt/common5/mdt/20230610/02/mdt_result.zip
# -rw-r--r--. 1 root root 181636532 Jun 10 06:53 /var/opt/common5/mdt/20230610/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1104547 Jun 10 07:48 /var/opt/common5/mdt/20230610/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 16969200 Jun 10 07:49 /var/opt/common5/mdt/20230610/03/ue_traffic.zip
# -rw-r--r--. 1 root root 32601096 Jun 10 07:49 /var/opt/common5/mdt/20230610/03/ue_meas.zip
# -rw-r--r--. 1 root root 20115484 Jun 10 07:49 /var/opt/common5/mdt/20230610/03/mdt_result.zip
# -rw-r--r--. 1 root root 171412689 Jun 10 07:53 /var/opt/common5/mdt/20230610/03/ta_histogram.zip
# -rw-r--r--. 1 root root 103048 Jun 10 08:32 /var/opt/common5/mdt/20230610/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 1827805 Jun 10 08:32 /var/opt/common5/mdt/20230610/04/ue_traffic.zip
# -rw-r--r--. 1 root root 3527412 Jun 10 08:33 /var/opt/common5/mdt/20230610/04/ue_meas.zip
# -rw-r--r--. 1 root root 2172552 Jun 10 08:33 /var/opt/common5/mdt/20230610/04/mdt_result.zip
# -rw-r--r--. 1 root root 26943418 Jun 10 08:33 /var/opt/common5/mdt/20230610/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1118020 Jun 10 09:51 /var/opt/common5/mdt/20230610/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 22228014 Jun 10 09:51 /var/opt/common5/mdt/20230610/05/ue_traffic.zip
# -rw-r--r--. 1 root root 43252181 Jun 10 09:52 /var/opt/common5/mdt/20230610/05/ue_meas.zip
# -rw-r--r--. 1 root root 27850319 Jun 10 09:52 /var/opt/common5/mdt/20230610/05/mdt_result.zip
# -rw-r--r--. 1 root root 203897412 Jun 10 09:57 /var/opt/common5/mdt/20230610/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1145348 Jun 10 10:53 /var/opt/common5/mdt/20230610/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 31546614 Jun 10 10:54 /var/opt/common5/mdt/20230610/06/ue_traffic.zip
# -rw-r--r--. 1 root root 62590347 Jun 10 10:54 /var/opt/common5/mdt/20230610/06/ue_meas.zip
# -rw-r--r--. 1 root root 41408046 Jun 10 10:55 /var/opt/common5/mdt/20230610/06/mdt_result.zip
# -rw-r--r--. 1 root root 256655461 Jun 10 11:00 /var/opt/common5/mdt/20230610/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1138134 Jun 10 11:56 /var/opt/common5/mdt/20230610/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 40366872 Jun 10 11:56 /var/opt/common5/mdt/20230610/07/ue_traffic.zip
# -rw-r--r--. 1 root root 80759787 Jun 10 11:57 /var/opt/common5/mdt/20230610/07/ue_meas.zip
# -rw-r--r--. 1 root root 54204410 Jun 10 11:57 /var/opt/common5/mdt/20230610/07/mdt_result.zip
# -rw-r--r--. 1 root root 293648864 Jun 10 12:03 /var/opt/common5/mdt/20230610/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1133934 Jun 10 12:56 /var/opt/common5/mdt/20230610/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 43584761 Jun 10 12:56 /var/opt/common5/mdt/20230610/08/ue_traffic.zip
# -rw-r--r--. 1 root root 87892497 Jun 10 12:57 /var/opt/common5/mdt/20230610/08/ue_meas.zip
# -rw-r--r--. 1 root root 59862098 Jun 10 12:58 /var/opt/common5/mdt/20230610/08/mdt_result.zip
# -rw-r--r--. 1 root root 310979270 Jun 10 13:05 /var/opt/common5/mdt/20230610/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1128128 Jun 10 13:57 /var/opt/common5/mdt/20230610/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 46395535 Jun 10 13:58 /var/opt/common5/mdt/20230610/09/ue_traffic.zip
# -rw-r--r--. 1 root root 94068867 Jun 10 13:59 /var/opt/common5/mdt/20230610/09/ue_meas.zip
# -rw-r--r--. 1 root root 64431921 Jun 10 14:00 /var/opt/common5/mdt/20230610/09/mdt_result.zip
# -rw-r--r--. 1 root root 324861056 Jun 10 14:06 /var/opt/common5/mdt/20230610/09/ta_histogram.zip
# -rw-r--r--. 1 root root 1126186 Jun 10 14:58 /var/opt/common5/mdt/20230610/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 45668649 Jun 10 14:58 /var/opt/common5/mdt/20230610/10/ue_traffic.zip
# -rw-r--r--. 1 root root 92860772 Jun 10 14:59 /var/opt/common5/mdt/20230610/10/ue_meas.zip
# -rw-r--r--. 1 root root 64750692 Jun 10 15:00 /var/opt/common5/mdt/20230610/10/mdt_result.zip
# -rw-r--r--. 1 root root 333071658 Jun 10 15:07 /var/opt/common5/mdt/20230610/10/ta_histogram.zip
# -rw-r--r--. 1 root root 1124348 Jun 10 15:57 /var/opt/common5/mdt/20230610/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 45383666 Jun 10 15:57 /var/opt/common5/mdt/20230610/11/ue_traffic.zip
# -rw-r--r--. 1 root root 92380636 Jun 10 15:58 /var/opt/common5/mdt/20230610/11/ue_meas.zip
# -rw-r--r--. 1 root root 64900618 Jun 10 15:59 /var/opt/common5/mdt/20230610/11/mdt_result.zip
# -rw-r--r--. 1 root root 337518727 Jun 10 16:06 /var/opt/common5/mdt/20230610/11/ta_histogram.zip
# -rw-r--r--. 1 root root 1124297 Jun 10 16:58 /var/opt/common5/mdt/20230610/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 45807584 Jun 10 16:58 /var/opt/common5/mdt/20230610/12/ue_traffic.zip
# -rw-r--r--. 1 root root 93262071 Jun 10 16:59 /var/opt/common5/mdt/20230610/12/ue_meas.zip
# -rw-r--r--. 1 root root 65182551 Jun 10 17:00 /var/opt/common5/mdt/20230610/12/mdt_result.zip
# -rw-r--r--. 1 root root 340057963 Jun 10 17:07 /var/opt/common5/mdt/20230610/12/ta_histogram.zip
# -rw-r--r--. 1 root root 1123537 Jun 10 17:57 /var/opt/common5/mdt/20230610/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 45168590 Jun 10 17:58 /var/opt/common5/mdt/20230610/13/ue_traffic.zip
# -rw-r--r--. 1 root root 92524841 Jun 10 17:58 /var/opt/common5/mdt/20230610/13/ue_meas.zip
# -rw-r--r--. 1 root root 64689271 Jun 10 18:00 /var/opt/common5/mdt/20230610/13/mdt_result.zip
# -rw-r--r--. 1 root root 335773209 Jun 10 18:09 /var/opt/common5/mdt/20230610/13/ta_histogram.zip
# -rw-r--r--. 1 root root 1122817 Jun 10 18:57 /var/opt/common5/mdt/20230610/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 44912684 Jun 10 18:57 /var/opt/common5/mdt/20230610/14/ue_traffic.zip
# -rw-r--r--. 1 root root 91299198 Jun 10 18:58 /var/opt/common5/mdt/20230610/14/ue_meas.zip
# -rw-r--r--. 1 root root 64060890 Jun 10 18:59 /var/opt/common5/mdt/20230610/14/mdt_result.zip
# -rw-r--r--. 1 root root 332468766 Jun 10 19:06 /var/opt/common5/mdt/20230610/14/ta_histogram.zip
# -rw-r--r--. 1 root root 1124108 Jun 10 19:57 /var/opt/common5/mdt/20230610/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 45831419 Jun 10 19:58 /var/opt/common5/mdt/20230610/15/ue_traffic.zip
# -rw-r--r--. 1 root root 93822419 Jun 10 19:59 /var/opt/common5/mdt/20230610/15/ue_meas.zip
# -rw-r--r--. 1 root root 65387378 Jun 10 20:00 /var/opt/common5/mdt/20230610/15/mdt_result.zip
# -rw-r--r--. 1 root root 333194900 Jun 10 20:07 /var/opt/common5/mdt/20230610/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1120932 Jun 10 20:58 /var/opt/common5/mdt/20230610/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 47170341 Jun 10 20:58 /var/opt/common5/mdt/20230610/16/ue_traffic.zip
# -rw-r--r--. 1 root root 95970025 Jun 10 20:59 /var/opt/common5/mdt/20230610/16/ue_meas.zip
# -rw-r--r--. 1 root root 67070177 Jun 10 21:00 /var/opt/common5/mdt/20230610/16/mdt_result.zip
# -rw-r--r--. 1 root root 338746090 Jun 10 21:08 /var/opt/common5/mdt/20230610/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1117710 Jun 10 21:58 /var/opt/common5/mdt/20230610/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 47888220 Jun 10 21:58 /var/opt/common5/mdt/20230610/17/ue_traffic.zip
# -rw-r--r--. 1 root root 97384419 Jun 10 21:59 /var/opt/common5/mdt/20230610/17/ue_meas.zip
# -rw-r--r--. 1 root root 67668687 Jun 10 22:00 /var/opt/common5/mdt/20230610/17/mdt_result.zip
# -rw-r--r--. 1 root root 345413236 Jun 10 22:08 /var/opt/common5/mdt/20230610/17/ta_histogram.zip
# -rw-r--r--. 1 root root 1119634 Jun 10 22:58 /var/opt/common5/mdt/20230610/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 48277730 Jun 10 22:58 /var/opt/common5/mdt/20230610/18/ue_traffic.zip
# -rw-r--r--. 1 root root 98280100 Jun 10 22:59 /var/opt/common5/mdt/20230610/18/ue_meas.zip
# -rw-r--r--. 1 root root 67879735 Jun 10 23:00 /var/opt/common5/mdt/20230610/18/mdt_result.zip
# -rw-r--r--. 1 root root 342832073 Jun 10 23:07 /var/opt/common5/mdt/20230610/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1113516 Jun 10 23:57 /var/opt/common5/mdt/20230610/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 46550643 Jun 10 23:58 /var/opt/common5/mdt/20230610/19/ue_traffic.zip
# -rw-r--r--. 1 root root 94977774 Jun 10 23:58 /var/opt/common5/mdt/20230610/19/ue_meas.zip
# -rw-r--r--. 1 root root 65356035 Jun 10 23:59 /var/opt/common5/mdt/20230610/19/mdt_result.zip
# -rw-r--r--. 1 root root 346650275 Jun 11 00:09 /var/opt/common5/mdt/20230610/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1112428 Jun 11 00:56 /var/opt/common5/mdt/20230610/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 44588220 Jun 11 00:57 /var/opt/common5/mdt/20230610/20/ue_traffic.zip
# -rw-r--r--. 1 root root 91594506 Jun 11 00:57 /var/opt/common5/mdt/20230610/20/ue_meas.zip
# -rw-r--r--. 1 root root 62210243 Jun 11 00:59 /var/opt/common5/mdt/20230610/20/mdt_result.zip
# -rw-r--r--. 1 root root 342444104 Jun 11 01:05 /var/opt/common5/mdt/20230610/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1116432 Jun 11 01:54 /var/opt/common5/mdt/20230610/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 41860007 Jun 11 01:55 /var/opt/common5/mdt/20230610/21/ue_traffic.zip
# -rw-r--r--. 1 root root 85668766 Jun 11 01:55 /var/opt/common5/mdt/20230610/21/ue_meas.zip
# -rw-r--r--. 1 root root 57076581 Jun 11 01:56 /var/opt/common5/mdt/20230610/21/mdt_result.zip
# -rw-r--r--. 1 root root 327663493 Jun 11 02:03 /var/opt/common5/mdt/20230610/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1123366 Jun 11 02:53 /var/opt/common5/mdt/20230610/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 38288581 Jun 11 02:54 /var/opt/common5/mdt/20230610/22/ue_traffic.zip
# -rw-r--r--. 1 root root 77841954 Jun 11 02:54 /var/opt/common5/mdt/20230610/22/ue_meas.zip
# -rw-r--r--. 1 root root 51283182 Jun 11 02:55 /var/opt/common5/mdt/20230610/22/mdt_result.zip
# -rw-r--r--. 1 root root 301783054 Jun 11 03:01 /var/opt/common5/mdt/20230610/22/ta_histogram.zip
# -rw-r--r--. 1 root root 927274 Jun 11 03:43 /var/opt/common5/mdt/20230610/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 18448021 Jun 11 03:43 /var/opt/common5/mdt/20230610/23/ue_traffic.zip
# -rw-r--r--. 1 root root 36668558 Jun 11 03:44 /var/opt/common5/mdt/20230610/23/ue_meas.zip
# -rw-r--r--. 1 root root 24432132 Jun 11 03:44 /var/opt/common5/mdt/20230610/23/mdt_result.zip
# -rw-r--r--. 1 root root 155801538 Jun 11 03:47 /var/opt/common5/mdt/20230610/23/ta_histogram.zip
# -rw-r--r--. 1 root root 3306711 Jun 11 05:42 /var/opt/common5/mdt/20230610/ue_capability_20230610.zip
# -rw-r--r--. 1 root root 37005580 Jun 11 06:00 /var/opt/common5/mdt/20230610/grid_mdt_cell_20230610.zip
# -rw-r--r--. 1 root root 64024208 Jun 11 06:08 /var/opt/common5/mdt/20230610/grid_mdt_traffic_cell_20230610.zip
# -rw-r--r--. 1 root root 94971476 Jun 11 06:18 /var/opt/common5/mdt/20230610/grid_mdt_meas_cell_20230610.zip
# -rw-r--r--. 1 root root 13900592 Jun 11 06:23 /var/opt/common5/mdt/20230610/filter_mdt_result.zip
# -rw-r--r--. 1 root root 13455102 Jun 11 06:24 /var/opt/common5/mdt/20230610/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 27411744 Jun 11 06:24 /var/opt/common5/mdt/20230610/filter_ue_meas.zip
# -rw-r--r--. 1 root root 916570 Jun 11 04:42 /var/opt/common5/mdt/20230611/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 15634704 Jun 11 04:43 /var/opt/common5/mdt/20230611/00/ue_traffic.zip
# -rw-r--r--. 1 root root 30812355 Jun 11 04:43 /var/opt/common5/mdt/20230611/00/ue_meas.zip
# -rw-r--r--. 1 root root 20251983 Jun 11 04:43 /var/opt/common5/mdt/20230611/00/mdt_result.zip
# -rw-r--r--. 1 root root 138284115 Jun 11 04:47 /var/opt/common5/mdt/20230611/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1109852 Jun 11 05:50 /var/opt/common5/mdt/20230611/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 22090373 Jun 11 05:50 /var/opt/common5/mdt/20230611/01/ue_traffic.zip
# -rw-r--r--. 1 root root 43348515 Jun 11 05:50 /var/opt/common5/mdt/20230611/01/ue_meas.zip
# -rw-r--r--. 1 root root 27955279 Jun 11 05:51 /var/opt/common5/mdt/20230611/01/mdt_result.zip
# -rw-r--r--. 1 root root 200834194 Jun 11 05:55 /var/opt/common5/mdt/20230611/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1106271 Jun 11 06:48 /var/opt/common5/mdt/20230611/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 18999520 Jun 11 06:49 /var/opt/common5/mdt/20230611/02/ue_traffic.zip
# -rw-r--r--. 1 root root 37132826 Jun 11 06:49 /var/opt/common5/mdt/20230611/02/ue_meas.zip
# -rw-r--r--. 1 root root 23397783 Jun 11 06:49 /var/opt/common5/mdt/20230611/02/mdt_result.zip
# -rw-r--r--. 1 root root 186282917 Jun 11 06:54 /var/opt/common5/mdt/20230611/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1100469 Jun 11 07:48 /var/opt/common5/mdt/20230611/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 17578005 Jun 11 07:48 /var/opt/common5/mdt/20230611/03/ue_traffic.zip
# -rw-r--r--. 1 root root 34025905 Jun 11 07:49 /var/opt/common5/mdt/20230611/03/ue_meas.zip
# -rw-r--r--. 1 root root 21084638 Jun 11 07:49 /var/opt/common5/mdt/20230611/03/mdt_result.zip
# -rw-r--r--. 1 root root 174202662 Jun 11 07:53 /var/opt/common5/mdt/20230611/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1103012 Jun 11 08:48 /var/opt/common5/mdt/20230611/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 17973543 Jun 11 08:48 /var/opt/common5/mdt/20230611/04/ue_traffic.zip
# -rw-r--r--. 1 root root 34530759 Jun 11 08:49 /var/opt/common5/mdt/20230611/04/ue_meas.zip
# -rw-r--r--. 1 root root 21562345 Jun 11 08:49 /var/opt/common5/mdt/20230611/04/mdt_result.zip
# -rw-r--r--. 1 root root 175281122 Jun 11 08:53 /var/opt/common5/mdt/20230611/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1108339 Jun 11 09:50 /var/opt/common5/mdt/20230611/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 20982940 Jun 11 09:50 /var/opt/common5/mdt/20230611/05/ue_traffic.zip
# -rw-r--r--. 1 root root 40701241 Jun 11 09:50 /var/opt/common5/mdt/20230611/05/ue_meas.zip
# -rw-r--r--. 1 root root 26211112 Jun 11 09:51 /var/opt/common5/mdt/20230611/05/mdt_result.zip
# ...
# -rw-r--r--. 1 root root 114861717 Jun  4 05:46 /var/opt/common5/mdt/20230604/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1103107 Jun  4 06:48 /var/opt/common5/mdt/20230604/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 19161472 Jun  4 06:48 /var/opt/common5/mdt/20230604/02/ue_traffic.zip
# -rw-r--r--. 1 root root 37428710 Jun  4 06:49 /var/opt/common5/mdt/20230604/02/ue_meas.zip
# -rw-r--r--. 1 root root 23662090 Jun  4 06:49 /var/opt/common5/mdt/20230604/02/mdt_result.zip
# -rw-r--r--. 1 root root 183251102 Jun  4 06:53 /var/opt/common5/mdt/20230604/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1097456 Jun  4 07:48 /var/opt/common5/mdt/20230604/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 17660613 Jun  4 07:48 /var/opt/common5/mdt/20230604/03/ue_traffic.zip
# -rw-r--r--. 1 root root 34103550 Jun  4 07:48 /var/opt/common5/mdt/20230604/03/ue_meas.zip
# -rw-r--r--. 1 root root 21282534 Jun  4 07:49 /var/opt/common5/mdt/20230604/03/mdt_result.zip
# -rw-r--r--. 1 root root 171277902 Jun  4 07:52 /var/opt/common5/mdt/20230604/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1099580 Jun  4 08:48 /var/opt/common5/mdt/20230604/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 17741256 Jun  4 08:48 /var/opt/common5/mdt/20230604/04/ue_traffic.zip
# -rw-r--r--. 1 root root 34042867 Jun  4 08:48 /var/opt/common5/mdt/20230604/04/ue_meas.zip
# -rw-r--r--. 1 root root 21079671 Jun  4 08:49 /var/opt/common5/mdt/20230604/04/mdt_result.zip
# -rw-r--r--. 1 root root 171197641 Jun  4 08:53 /var/opt/common5/mdt/20230604/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1102324 Jun  4 09:50 /var/opt/common5/mdt/20230604/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 21078294 Jun  4 09:50 /var/opt/common5/mdt/20230604/05/ue_traffic.zip
# -rw-r--r--. 1 root root 40932509 Jun  4 09:50 /var/opt/common5/mdt/20230604/05/ue_meas.zip
# -rw-r--r--. 1 root root 26230730 Jun  4 09:51 /var/opt/common5/mdt/20230604/05/mdt_result.zip
# -rw-r--r--. 1 root root 192492362 Jun  4 09:55 /var/opt/common5/mdt/20230604/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1124709 Jun  4 10:52 /var/opt/common5/mdt/20230604/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 28362089 Jun  4 10:52 /var/opt/common5/mdt/20230604/06/ue_traffic.zip
# -rw-r--r--. 1 root root 55929241 Jun  4 10:53 /var/opt/common5/mdt/20230604/06/ue_meas.zip
# -rw-r--r--. 1 root root 36854345 Jun  4 10:53 /var/opt/common5/mdt/20230604/06/mdt_result.zip
# -rw-r--r--. 1 root root 233231976 Jun  4 10:58 /var/opt/common5/mdt/20230604/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1126106 Jun  4 11:55 /var/opt/common5/mdt/20230604/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 35912094 Jun  4 11:55 /var/opt/common5/mdt/20230604/07/ue_traffic.zip
# -rw-r--r--. 1 root root 71855699 Jun  4 11:56 /var/opt/common5/mdt/20230604/07/ue_meas.zip
# -rw-r--r--. 1 root root 47867060 Jun  4 11:56 /var/opt/common5/mdt/20230604/07/mdt_result.zip
# -rw-r--r--. 1 root root 267436109 Jun  4 12:02 /var/opt/common5/mdt/20230604/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1125515 Jun  4 12:55 /var/opt/common5/mdt/20230604/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 40962935 Jun  4 12:56 /var/opt/common5/mdt/20230604/08/ue_traffic.zip
# -rw-r--r--. 1 root root 82224308 Jun  4 12:56 /var/opt/common5/mdt/20230604/08/ue_meas.zip
# -rw-r--r--. 1 root root 55123397 Jun  4 12:57 /var/opt/common5/mdt/20230604/08/mdt_result.zip
# -rw-r--r--. 1 root root 291189278 Jun  4 13:03 /var/opt/common5/mdt/20230604/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1123998 Jun  4 13:57 /var/opt/common5/mdt/20230604/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 44125265 Jun  4 13:57 /var/opt/common5/mdt/20230604/09/ue_traffic.zip
# -rw-r--r--. 1 root root 89015378 Jun  4 13:58 /var/opt/common5/mdt/20230604/09/ue_meas.zip
# -rw-r--r--. 1 root root 60384629 Jun  4 13:59 /var/opt/common5/mdt/20230604/09/mdt_result.zip
# -rw-r--r--. 1 root root 308069065 Jun  4 14:07 /var/opt/common5/mdt/20230604/09/ta_histogram.zip
# -rw-r--r--. 1 root root 1121473 Jun  4 14:57 /var/opt/common5/mdt/20230604/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 44108891 Jun  4 14:57 /var/opt/common5/mdt/20230604/10/ue_traffic.zip
# -rw-r--r--. 1 root root 89982665 Jun  4 14:58 /var/opt/common5/mdt/20230604/10/ue_meas.zip
# -rw-r--r--. 1 root root 61541751 Jun  4 14:59 /var/opt/common5/mdt/20230604/10/mdt_result.zip
# -rw-r--r--. 1 root root 320981612 Jun  4 15:08 /var/opt/common5/mdt/20230604/10/ta_histogram.zip
# -rw-r--r--. 1 root root 1120650 Jun  4 15:57 /var/opt/common5/mdt/20230604/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 43647364 Jun  4 15:57 /var/opt/common5/mdt/20230604/11/ue_traffic.zip
# -rw-r--r--. 1 root root 89244811 Jun  4 15:58 /var/opt/common5/mdt/20230604/11/ue_meas.zip
# -rw-r--r--. 1 root root 61155707 Jun  4 15:59 /var/opt/common5/mdt/20230604/11/mdt_result.zip
# -rw-r--r--. 1 root root 325265514 Jun  4 16:06 /var/opt/common5/mdt/20230604/11/ta_histogram.zip
# -rw-r--r--. 1 root root 1120813 Jun  4 16:57 /var/opt/common5/mdt/20230604/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 43333669 Jun  4 16:57 /var/opt/common5/mdt/20230604/12/ue_traffic.zip
# -rw-r--r--. 1 root root 87967940 Jun  4 16:58 /var/opt/common5/mdt/20230604/12/ue_meas.zip
# -rw-r--r--. 1 root root 60308876 Jun  4 16:59 /var/opt/common5/mdt/20230604/12/mdt_result.zip
# -rw-r--r--. 1 root root 326912854 Jun  4 17:07 /var/opt/common5/mdt/20230604/12/ta_histogram.zip
# -rw-r--r--. 1 root root 1120419 Jun  4 17:57 /var/opt/common5/mdt/20230604/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 43708079 Jun  4 17:58 /var/opt/common5/mdt/20230604/13/ue_traffic.zip
# -rw-r--r--. 1 root root 88741554 Jun  4 17:58 /var/opt/common5/mdt/20230604/13/ue_meas.zip
# -rw-r--r--. 1 root root 60986819 Jun  4 17:59 /var/opt/common5/mdt/20230604/13/mdt_result.zip
# -rw-r--r--. 1 root root 326953388 Jun  4 18:06 /var/opt/common5/mdt/20230604/13/ta_histogram.zip
# -rw-r--r--. 1 root root 1118831 Jun  4 18:57 /var/opt/common5/mdt/20230604/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 43051272 Jun  4 18:57 /var/opt/common5/mdt/20230604/14/ue_traffic.zip
# -rw-r--r--. 1 root root 87409724 Jun  4 18:58 /var/opt/common5/mdt/20230604/14/ue_meas.zip
# -rw-r--r--. 1 root root 59909967 Jun  4 18:59 /var/opt/common5/mdt/20230604/14/mdt_result.zip
# -rw-r--r--. 1 root root 326092559 Jun  4 19:06 /var/opt/common5/mdt/20230604/14/ta_histogram.zip
# -rw-r--r--. 1 root root 1120587 Jun  4 19:57 /var/opt/common5/mdt/20230604/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 44044866 Jun  4 19:57 /var/opt/common5/mdt/20230604/15/ue_traffic.zip
# -rw-r--r--. 1 root root 89375582 Jun  4 19:58 /var/opt/common5/mdt/20230604/15/ue_meas.zip
# -rw-r--r--. 1 root root 60844979 Jun  4 19:59 /var/opt/common5/mdt/20230604/15/mdt_result.zip
# -rw-r--r--. 1 root root 326334527 Jun  4 20:06 /var/opt/common5/mdt/20230604/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1120046 Jun  4 20:57 /var/opt/common5/mdt/20230604/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 46217723 Jun  4 20:58 /var/opt/common5/mdt/20230604/16/ue_traffic.zip
# -rw-r--r--. 1 root root 93783838 Jun  4 20:58 /var/opt/common5/mdt/20230604/16/ue_meas.zip
# -rw-r--r--. 1 root root 64159659 Jun  4 21:00 /var/opt/common5/mdt/20230604/16/mdt_result.zip
# -rw-r--r--. 1 root root 331841582 Jun  4 21:06 /var/opt/common5/mdt/20230604/16/ta_histogram.zip
# -rw-r--r--. 1 root root 1117653 Jun  4 21:57 /var/opt/common5/mdt/20230604/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 46731464 Jun  4 21:58 /var/opt/common5/mdt/20230604/17/ue_traffic.zip
# -rw-r--r--. 1 root root 95529654 Jun  4 21:59 /var/opt/common5/mdt/20230604/17/ue_meas.zip
# -rw-r--r--. 1 root root 65323067 Jun  4 22:00 /var/opt/common5/mdt/20230604/17/mdt_result.zip
# -rw-r--r--. 1 root root 338333626 Jun  4 22:08 /var/opt/common5/mdt/20230604/17/ta_histogram.zip
# -rw-r--r--. 1 root root 1119291 Jun  4 22:58 /var/opt/common5/mdt/20230604/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 46578086 Jun  4 22:58 /var/opt/common5/mdt/20230604/18/ue_traffic.zip
# -rw-r--r--. 1 root root 95258684 Jun  4 22:59 /var/opt/common5/mdt/20230604/18/ue_meas.zip
# -rw-r--r--. 1 root root 65159524 Jun  4 23:00 /var/opt/common5/mdt/20230604/18/mdt_result.zip
# -rw-r--r--. 1 root root 334443125 Jun  4 23:08 /var/opt/common5/mdt/20230604/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1115994 Jun  4 23:56 /var/opt/common5/mdt/20230604/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 44429522 Jun  4 23:57 /var/opt/common5/mdt/20230604/19/ue_traffic.zip
# -rw-r--r--. 1 root root 91071495 Jun  4 23:58 /var/opt/common5/mdt/20230604/19/ue_meas.zip
# -rw-r--r--. 1 root root 62180180 Jun  4 23:59 /var/opt/common5/mdt/20230604/19/mdt_result.zip
# -rw-r--r--. 1 root root 336347767 Jun  5 00:06 /var/opt/common5/mdt/20230604/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1116151 Jun  5 00:56 /var/opt/common5/mdt/20230604/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 43364516 Jun  5 00:57 /var/opt/common5/mdt/20230604/20/ue_traffic.zip
# -rw-r--r--. 1 root root 88072341 Jun  5 00:57 /var/opt/common5/mdt/20230604/20/ue_meas.zip
# -rw-r--r--. 1 root root 59213293 Jun  5 00:58 /var/opt/common5/mdt/20230604/20/mdt_result.zip
# -rw-r--r--. 1 root root 328704784 Jun  5 01:05 /var/opt/common5/mdt/20230604/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1117440 Jun  5 01:54 /var/opt/common5/mdt/20230604/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 40747431 Jun  5 01:54 /var/opt/common5/mdt/20230604/21/ue_traffic.zip
# -rw-r--r--. 1 root root 82475203 Jun  5 01:55 /var/opt/common5/mdt/20230604/21/ue_meas.zip
# -rw-r--r--. 1 root root 54509774 Jun  5 01:56 /var/opt/common5/mdt/20230604/21/mdt_result.zip
# -rw-r--r--. 1 root root 308855241 Jun  5 02:02 /var/opt/common5/mdt/20230604/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1123139 Jun  5 02:52 /var/opt/common5/mdt/20230604/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 35423245 Jun  5 02:53 /var/opt/common5/mdt/20230604/22/ue_traffic.zip
# -rw-r--r--. 1 root root 71246194 Jun  5 02:53 /var/opt/common5/mdt/20230604/22/ue_meas.zip
# -rw-r--r--. 1 root root 46748624 Jun  5 02:54 /var/opt/common5/mdt/20230604/22/mdt_result.zip
# -rw-r--r--. 1 root root 276914713 Jun  5 02:59 /var/opt/common5/mdt/20230604/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1123221 Jun  5 03:51 /var/opt/common5/mdt/20230604/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 28626587 Jun  5 03:51 /var/opt/common5/mdt/20230604/23/ue_traffic.zip
# -rw-r--r--. 1 root root 57356860 Jun  5 03:52 /var/opt/common5/mdt/20230604/23/ue_meas.zip
# -rw-r--r--. 1 root root 37454539 Jun  5 03:52 /var/opt/common5/mdt/20230604/23/mdt_result.zip
# -rw-r--r--. 1 root root 241147663 Jun  5 03:58 /var/opt/common5/mdt/20230604/23/ta_histogram.zip
# -rw-r--r--. 1 root root 3319635 Jun  5 05:42 /var/opt/common5/mdt/20230604/ue_capability_20230604.zip
# -rw-r--r--. 1 root root 36107733 Jun  5 05:59 /var/opt/common5/mdt/20230604/grid_mdt_cell_20230604.zip
# -rw-r--r--. 1 root root 62440666 Jun  5 06:07 /var/opt/common5/mdt/20230604/grid_mdt_traffic_cell_20230604.zip
# -rw-r--r--. 1 root root 92410752 Jun  5 06:17 /var/opt/common5/mdt/20230604/grid_mdt_meas_cell_20230604.zip
# -rw-r--r--. 1 root root 13090797 Jun  5 06:22 /var/opt/common5/mdt/20230604/filter_mdt_result.zip
# -rw-r--r--. 1 root root 13044093 Jun  5 06:22 /var/opt/common5/mdt/20230604/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 26452803 Jun  5 06:23 /var/opt/common5/mdt/20230604/filter_ue_meas.zip
# -rw-r--r--. 1 root root 1114788 Jun  5 04:50 /var/opt/common5/mdt/20230605/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 24125906 Jun  5 04:50 /var/opt/common5/mdt/20230605/00/ue_traffic.zip
# -rw-r--r--. 1 root root 47742018 Jun  5 04:51 /var/opt/common5/mdt/20230605/00/ue_meas.zip
# -rw-r--r--. 1 root root 30842689 Jun  5 04:51 /var/opt/common5/mdt/20230605/00/mdt_result.zip
# -rw-r--r--. 1 root root 212657157 Jun  5 04:56 /var/opt/common5/mdt/20230605/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1103448 Jun  5 05:49 /var/opt/common5/mdt/20230605/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 19806131 Jun  5 05:49 /var/opt/common5/mdt/20230605/01/ue_traffic.zip
# -rw-r--r--. 1 root root 38761378 Jun  5 05:50 /var/opt/common5/mdt/20230605/01/ue_meas.zip
# -rw-r--r--. 1 root root 24701477 Jun  5 05:50 /var/opt/common5/mdt/20230605/01/mdt_result.zip
# -rw-r--r--. 1 root root 183424708 Jun  5 05:54 /var/opt/common5/mdt/20230605/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1100648 Jun  5 06:49 /var/opt/common5/mdt/20230605/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 17729272 Jun  5 06:49 /var/opt/common5/mdt/20230605/02/ue_traffic.zip
# -rw-r--r--. 1 root root 34341000 Jun  5 06:50 /var/opt/common5/mdt/20230605/02/ue_meas.zip
# -rw-r--r--. 1 root root 21373854 Jun  5 06:50 /var/opt/common5/mdt/20230605/02/mdt_result.zip
# -rw-r--r--. 1 root root 174037661 Jun  5 06:53 /var/opt/common5/mdt/20230605/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1098189 Jun  5 07:48 /var/opt/common5/mdt/20230605/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 17451169 Jun  5 07:48 /var/opt/common5/mdt/20230605/03/ue_traffic.zip
# -rw-r--r--. 1 root root 33506284 Jun  5 07:49 /var/opt/common5/mdt/20230605/03/ue_meas.zip
# -rw-r--r--. 1 root root 20676868 Jun  5 07:49 /var/opt/common5/mdt/20230605/03/mdt_result.zip
# -rw-r--r--. 1 root root 166788719 Jun  5 07:52 /var/opt/common5/mdt/20230605/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1101480 Jun  5 08:50 /var/opt/common5/mdt/20230605/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 18892519 Jun  5 08:50 /var/opt/common5/mdt/20230605/04/ue_traffic.zip
# -rw-r--r--. 1 root root 36247739 Jun  5 08:51 /var/opt/common5/mdt/20230605/04/ue_meas.zip
# -rw-r--r--. 1 root root 22557047 Jun  5 08:51 /var/opt/common5/mdt/20230605/04/mdt_result.zip
# -rw-r--r--. 1 root root 175269626 Jun  5 08:55 /var/opt/common5/mdt/20230605/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1112810 Jun  5 09:52 /var/opt/common5/mdt/20230605/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 25134495 Jun  5 09:52 /var/opt/common5/mdt/20230605/05/ue_traffic.zip
# -rw-r--r--. 1 root root 48916487 Jun  5 09:53 /var/opt/common5/mdt/20230605/05/ue_meas.zip
# -rw-r--r--. 1 root root 32094908 Jun  5 09:53 /var/opt/common5/mdt/20230605/05/mdt_result.zip
# -rw-r--r--. 1 root root 213600717 Jun  5 09:58 /var/opt/common5/mdt/20230605/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1135815 Jun  5 10:55 /var/opt/common5/mdt/20230605/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 37133786 Jun  5 10:55 /var/opt/common5/mdt/20230605/06/ue_traffic.zip
# -rw-r--r--. 1 root root 73779946 Jun  5 10:56 /var/opt/common5/mdt/20230605/06/ue_meas.zip
# -rw-r--r--. 1 root root 50781890 Jun  5 10:57 /var/opt/common5/mdt/20230605/06/mdt_result.zip
# -rw-r--r--. 1 root root 278906216 Jun  5 11:03 /var/opt/common5/mdt/20230605/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1125603 Jun  5 11:57 /var/opt/common5/mdt/20230605/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 43810093 Jun  5 11:57 /var/opt/common5/mdt/20230605/07/ue_traffic.zip
# -rw-r--r--. 1 root root 88094349 Jun  5 11:58 /var/opt/common5/mdt/20230605/07/ue_meas.zip
# -rw-r--r--. 1 root root 60923815 Jun  5 11:59 /var/opt/common5/mdt/20230605/07/mdt_result.zip
# -rw-r--r--. 1 root root 313077171 Jun  5 12:07 /var/opt/common5/mdt/20230605/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1117180 Jun  5 12:57 /var/opt/common5/mdt/20230605/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 44528823 Jun  5 12:57 /var/opt/common5/mdt/20230605/08/ue_traffic.zip
# -rw-r--r--. 1 root root 90846512 Jun  5 12:58 /var/opt/common5/mdt/20230605/08/ue_meas.zip
# -rw-r--r--. 1 root root 62851707 Jun  5 12:59 /var/opt/common5/mdt/20230605/08/mdt_result.zip
# -rw-r--r--. 1 root root 325110026 Jun  5 13:08 /var/opt/common5/mdt/20230605/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1113514 Jun  5 13:58 /var/opt/common5/mdt/20230605/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 45468444 Jun  5 13:59 /var/opt/common5/mdt/20230605/09/ue_traffic.zip
# -rw-r--r--. 1 root root 92536537 Jun  5 13:59 /var/opt/common5/mdt/20230605/09/ue_meas.zip
# -rw-r--r--. 1 root root 64115274 Jun  5 14:00 /var/opt/common5/mdt/20230605/09/mdt_result.zip
# -rw-r--r--. 1 root root 331486174 Jun  5 14:07 /var/opt/common5/mdt/20230605/09/ta_histogram.zip
# (base) [root@pmt-xl-1 ~]#

# %%
test1 = re.split(r'\s+|\n', raw)

# %%
# Create list comprehension to filter only mdt_result.zip only 
# Option are ue_traffic or mdt_result

pattern = r'.*/(?!filter_)[^/]+/mdt_result\.zip$'
result = [path for path in test1 if re.match(pattern, path)]

# %%
# Create list comprehension to generate weekend dates in June

# weekend_dates = [date.strftime("%Y%m%d") for date in (datetime.date(2023, 6, day) for day in range(1, 31)) 
                #  if date.weekday() >= 5]

# Create list comprehension to generate continous dates in June (from 25 June until 30 June)
# continous_dates = re.compile(r'/var/opt/common5/mdt/202306(0[5-9]|30)/\d{2}/mdt_result\.zip')
# continous_dates = re.compile(r'/var/opt/common5/mdt/202306(0[1-8])/\d{2}/mdt_result\.zip')

# %%
# Create list comprehension to filter June Month only
# result = [path for path in result if '202306' in path]

# Create list comprehension to filter Out Some Date
# result = [path for path in result if '20230601' not in path and '20230602' not in path] 

# Create list comprehension to filter out continous dates
# result = [path for path in result if not continous_dates.search(path)]

# Create list comprehension to filter Out Weekend Date
# result = [path for path in result if path.split('/')[5] not in weekend_dates]

# Create list comprehension to filter Busy Hour only
# result = [path for path in result if '/07/' in path or '/08/' in path or '/09/' in path or '/17/' in path or '/18/' in path or '/19/' in path]

# Create list comprehension to filter Busy Hour only
# result = [path for path in result if '/11/' in path or '/12/' in path or '/13/' in path]

# result = [path for path in result if '/07/' in path or '/08/' in path or '/09/']

result.sort()

# %%
with open(r'/home/nivag/location_to_dl_8007-mdt-polygon.txt', 'w') as fp:
    fp.write('\n'.join(result))
