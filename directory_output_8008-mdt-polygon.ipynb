# %%
import pexpect
import time
import sys
import re
import datetime
import os

# %%
#ENM3 -> 10.23.202.28 PW : "Enm#2021"
#ENM5 -> 10.167.30.28 PW : "Enm#2021"

child = pexpect.spawn('ssh -L 7899:localhost:8008 -J root@150.236.203.198 root@127.0.0.1 -p 8008', timeout=30, encoding='utf-8', logfile=sys.stdout)

child.maxread = 300000 

child.expect("root@150.236.203.198's password: ")
child.sendline('PMT@2022')
child.expect("root@127.0.0.1's password: ")
child.sendline('PMT@2022')

time.sleep(10)

# Shell command to take after the dates in modification dates
# child.sendline('find /var/opt/common5/mdt/ -type f -newermt 2023-04-16 -exec ls -l {} \;')

# Shell command to take only the folder
# child.sendline('find /var/opt/common5/mdt/20230205 -type f -exec ls -l {} \;')

# Shell command to take certain range dates in modification dates
child.sendline('find /var/opt/common5/mdt -type f -newermt 2023-04-10 ! -newermt 2023-07-05 -exec ls -l {} \;')

try:
    child.expect(pexpect.EOF, timeout=150)

except pexpect.TIMEOUT:
    child.close()
    raw = str(child.before)
# Out:
# root@150.236.203.198's password: PMT@2022
#
# root@127.0.0.1's password: PMT@2022
# find /var/opt/common5/mdt -type f -newermt 2023-04-10 ! -newermt 2023-07-05 -exec ls -l {} \;
#
# Last login: Thu Jul  6 11:02:54 2023 from 192.168.21.6
# ! -newermt 2023-07-05 -exec ls -l {} \;-2 ~]# find /var/opt/common5/mdt -type f -newermt 2023-04-10
# -rw-r--r--. 1 root root 4659112 May 11 11:58 /var/opt/common5/mdt/20230314/ue_capability_20230314.zip
# -rw-r--r--. 1 root root 40617518 May 11 12:21 /var/opt/common5/mdt/20230314/grid_mdt_cell_20230314.zip
# -rw-r--r--. 1 root root 67930591 May 11 12:32 /var/opt/common5/mdt/20230314/grid_mdt_traffic_cell_20230314.zip
# -rw-r--r--. 1 root root 104351461 May 11 12:56 /var/opt/common5/mdt/20230314/grid_mdt_meas_cell_20230314.zip
# -rw-r--r--. 1 root root 233874 May 11 18:58 /var/opt/common5/mdt/20230314/filter_mdt_result.zip
# -rw-r--r--. 1 root root 288666 May 11 19:00 /var/opt/common5/mdt/20230314/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 546988 May 11 19:05 /var/opt/common5/mdt/20230314/filter_ue_meas.zip
# -rw-r--r--. 1 root root 764289 May 12 08:33 /var/opt/common5/mdt/20230314/scanning_mdt_20230314.zip
# -rw-r--r--. 1 root root 748090 May 12 08:49 /var/opt/common5/mdt/20230314/scanning_traffic_20230314.zip
# -rw-r--r--. 1 root root 94141 May  8 09:58 /var/opt/common5/mdt/20230315/filter_mdt_result.zip
# -rw-r--r--. 1 root root 114233 May  8 09:59 /var/opt/common5/mdt/20230315/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 224574 May  8 10:01 /var/opt/common5/mdt/20230315/filter_ue_meas.zip
# -rw-r--r--. 1 root root 8116896 May  4 13:25 /var/opt/common5/mdt/20230316/filter_mdt_result.zip
# -rw-r--r--. 1 root root 8085253 May  4 13:26 /var/opt/common5/mdt/20230316/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 16379440 May  4 13:29 /var/opt/common5/mdt/20230316/filter_ue_meas.zip
# -rw-r--r--. 1 root root 476222 May 24 07:38 /var/opt/common5/mdt/20230317/filter_mdt_result.zip
# -rw-r--r--. 1 root root 520444 May 24 07:39 /var/opt/common5/mdt/20230317/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 1062424 May 24 07:43 /var/opt/common5/mdt/20230317/filter_ue_meas.zip
# -rw-r--r--. 1 root root 178393 May  8 20:43 /var/opt/common5/mdt/20230318/filter_mdt_result.zip
# -rw-r--r--. 1 root root 204422 May  8 20:48 /var/opt/common5/mdt/20230318/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 418379 May  8 20:50 /var/opt/common5/mdt/20230318/filter_ue_meas.zip
# -rw-r--r--. 1 root root 69164 May  8 20:52 /var/opt/common5/mdt/20230319/filter_mdt_result.zip
# -rw-r--r--. 1 root root 85152 May  8 20:52 /var/opt/common5/mdt/20230319/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 164346 May  8 20:54 /var/opt/common5/mdt/20230319/filter_ue_meas.zip
# -rw-r--r--. 1 root root 512785 Apr 10 03:40 /var/opt/common5/mdt/20230408/filter_mdt_result_ctr2.zip
# -rw-r--r--. 1 root root 523241 Apr 10 03:40 /var/opt/common5/mdt/20230408/filter_ue_traffic_ctr2.zip
# -rw-r--r--. 1 root root 1086092 Apr 10 03:40 /var/opt/common5/mdt/20230408/filter_ue_meas_ctr2.zip
# -rw-r--r--. 1 root root 2640035 Apr 10 11:06 /var/opt/common5/mdt/20230408/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 5434284 Apr 10 11:07 /var/opt/common5/mdt/20230408/filter_ue_meas.zip
# -rw-r--r--. 1 root root 2644430 Apr 10 11:05 /var/opt/common5/mdt/20230408/filter_mdt_result_ctr2_revA.zip
# -rw-r--r--. 1 root root 4153117 Apr 10 08:12 /var/opt/common5/mdt/20230409/ue_capability_20230409.zip
# -rw-r--r--. 1 root root 286531188 Apr 10 08:18 /var/opt/common5/mdt/20230409/mdt_20230409.zip
# -rw-r--r--. 1 root root 8923875 Apr 10 08:20 /var/opt/common5/mdt/20230409/grid_mdt_20230409.zip
# -rw-r--r--. 1 root root 23448080 Apr 10 08:20 /var/opt/common5/mdt/20230409/grid_mdt_cell_20230409.zip
# -rw-r--r--. 1 root root 53157974 Apr 10 08:24 /var/opt/common5/mdt/20230409/grid10_mdt_20230409.zip
# -rw-r--r--. 1 root root 69288745 Apr 10 08:25 /var/opt/common5/mdt/20230409/grid10_mdt_cell_20230409.zip
# -rw-r--r--. 1 root root 18347045 Apr 10 08:27 /var/opt/common5/mdt/20230409/grid_mdt_traffic_20230409.zip
# -rw-r--r--. 1 root root 50591138 Apr 10 08:28 /var/opt/common5/mdt/20230409/grid_mdt_traffic_cell_20230409.zip
# -rw-r--r--. 1 root root 80784809 Apr 10 08:32 /var/opt/common5/mdt/20230409/grid10_mdt_traffic_20230409.zip
# -rw-r--r--. 1 root root 117953000 Apr 10 08:32 /var/opt/common5/mdt/20230409/grid10_mdt_traffic_cell_20230409.zip
# -rw-r--r--. 1 root root 26016662 Apr 10 08:42 /var/opt/common5/mdt/20230409/grid_mdt_meas_20230409.zip
# -rw-r--r--. 1 root root 81431790 Apr 10 08:42 /var/opt/common5/mdt/20230409/grid_mdt_meas_cell_20230409.zip
# -rw-r--r--. 1 root root 120763177 Apr 10 08:47 /var/opt/common5/mdt/20230409/grid10_mdt_meas_20230409.zip
# -rw-r--r--. 1 root root 190059881 Apr 10 08:48 /var/opt/common5/mdt/20230409/grid10_mdt_meas_cell_20230409.zip
# -rw-r--r--. 1 root root 1706364 Apr 10 06:20 /var/opt/common5/mdt/20230410/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 32338802 Apr 10 06:21 /var/opt/common5/mdt/20230410/02/ue_traffic.zip
# -rw-r--r--. 1 root root 64969412 Apr 10 06:23 /var/opt/common5/mdt/20230410/02/ue_meas.zip
# -rw-r--r--. 1 root root 39196665 Apr 10 06:24 /var/opt/common5/mdt/20230410/02/mdt_result.zip
# -rw-r--r--. 1 root root 667535246 Apr 10 07:17 /var/opt/common5/mdt/20230410/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1471271 Apr 10 07:51 /var/opt/common5/mdt/20230410/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 31939777 Apr 10 07:53 /var/opt/common5/mdt/20230410/03/ue_traffic.zip
# -rw-r--r--. 1 root root 63983571 Apr 10 07:56 /var/opt/common5/mdt/20230410/03/ue_meas.zip
# -rw-r--r--. 1 root root 38654900 Apr 10 07:59 /var/opt/common5/mdt/20230410/03/mdt_result.zip
# -rw-r--r--. 1 root root 644725733 Apr 10 08:54 /var/opt/common5/mdt/20230410/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1485075 Apr 10 08:49 /var/opt/common5/mdt/20230410/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 32374001 Apr 10 08:51 /var/opt/common5/mdt/20230410/04/ue_traffic.zip
# -rw-r--r--. 1 root root 65528152 Apr 10 08:54 /var/opt/common5/mdt/20230410/04/ue_meas.zip
# -rw-r--r--. 1 root root 40087413 Apr 10 08:57 /var/opt/common5/mdt/20230410/04/mdt_result.zip
# -rw-r--r--. 1 root root 663166350 Apr 10 09:30 /var/opt/common5/mdt/20230410/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1687586 Apr 10 09:49 /var/opt/common5/mdt/20230410/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 37231441 Apr 10 09:51 /var/opt/common5/mdt/20230410/05/ue_traffic.zip
# -rw-r--r--. 1 root root 74855277 Apr 10 09:54 /var/opt/common5/mdt/20230410/05/ue_meas.zip
# -rw-r--r--. 1 root root 46787131 Apr 10 09:58 /var/opt/common5/mdt/20230410/05/mdt_result.zip
# -rw-r--r--. 1 root root 742298354 Apr 10 10:56 /var/opt/common5/mdt/20230410/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1610892 Apr 10 10:51 /var/opt/common5/mdt/20230410/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 41962445 Apr 10 10:54 /var/opt/common5/mdt/20230410/06/ue_traffic.zip
# -rw-r--r--. 1 root root 84777473 Apr 10 10:58 /var/opt/common5/mdt/20230410/06/ue_meas.zip
# -rw-r--r--. 1 root root 54367081 Apr 10 11:01 /var/opt/common5/mdt/20230410/06/mdt_result.zip
# -rw-r--r--. 1 root root 770830963 Apr 10 11:59 /var/opt/common5/mdt/20230410/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1331227 Apr 10 11:51 /var/opt/common5/mdt/20230410/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 41884008 Apr 10 11:53 /var/opt/common5/mdt/20230410/07/ue_traffic.zip
# -rw-r--r--. 1 root root 85561047 Apr 10 11:56 /var/opt/common5/mdt/20230410/07/ue_meas.zip
# -rw-r--r--. 1 root root 55967221 Apr 10 12:01 /var/opt/common5/mdt/20230410/07/mdt_result.zip
# -rw-r--r--. 1 root root 716935793 Apr 10 12:58 /var/opt/common5/mdt/20230410/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1236265 Apr 10 12:51 /var/opt/common5/mdt/20230410/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 39559253 Apr 10 12:53 /var/opt/common5/mdt/20230410/08/ue_traffic.zip
# -rw-r--r--. 1 root root 81211094 Apr 10 12:56 /var/opt/common5/mdt/20230410/08/ue_meas.zip
# -rw-r--r--. 1 root root 52851739 Apr 10 13:00 /var/opt/common5/mdt/20230410/08/mdt_result.zip
# -rw-r--r--. 1 root root 696008210 Apr 10 13:53 /var/opt/common5/mdt/20230410/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1236561 Apr 10 13:51 /var/opt/common5/mdt/20230410/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 41078189 Apr 10 13:54 /var/opt/common5/mdt/20230410/09/ue_traffic.zip
# -rw-r--r--. 1 root root 84123560 Apr 10 13:57 /var/opt/common5/mdt/20230410/09/ue_meas.zip
# -rw-r--r--. 1 root root 54409321 Apr 10 14:01 /var/opt/common5/mdt/20230410/09/mdt_result.zip
# -rw-r--r--. 1 root root 717775190 Apr 10 15:00 /var/opt/common5/mdt/20230410/09/ta_histogram.zip
# -rw-r--r--. 1 root root 1176774 Apr 10 14:52 /var/opt/common5/mdt/20230410/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 39546181 Apr 10 14:54 /var/opt/common5/mdt/20230410/10/ue_traffic.zip
# -rw-r--r--. 1 root root 81282838 Apr 10 14:58 /var/opt/common5/mdt/20230410/10/ue_meas.zip
# -rw-r--r--. 1 root root 52179345 Apr 10 15:02 /var/opt/common5/mdt/20230410/10/mdt_result.zip
# -rw-r--r--. 1 root root 707520054 Apr 10 15:59 /var/opt/common5/mdt/20230410/10/ta_histogram.zip
# -rw-r--r--. 1 root root 1095995 Apr 10 15:52 /var/opt/common5/mdt/20230410/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 36786525 Apr 10 15:54 /var/opt/common5/mdt/20230410/11/ue_traffic.zip
# -rw-r--r--. 1 root root 75799617 Apr 10 15:56 /var/opt/common5/mdt/20230410/11/ue_meas.zip
# -rw-r--r--. 1 root root 48768934 Apr 10 16:01 /var/opt/common5/mdt/20230410/11/mdt_result.zip
# -rw-r--r--. 1 root root 681556056 Apr 10 16:56 /var/opt/common5/mdt/20230410/11/ta_histogram.zip
# -rw-r--r--. 1 root root 1076148 Apr 10 16:51 /var/opt/common5/mdt/20230410/12/result_ue_cap.zip
# -rw-r--r--. 1 root root 37553253 Apr 10 16:53 /var/opt/common5/mdt/20230410/12/ue_traffic.zip
# -rw-r--r--. 1 root root 77461387 Apr 10 16:56 /var/opt/common5/mdt/20230410/12/ue_meas.zip
# -rw-r--r--. 1 root root 49711219 Apr 10 16:59 /var/opt/common5/mdt/20230410/12/mdt_result.zip
# -rw-r--r--. 1 root root 688853590 Apr 10 17:59 /var/opt/common5/mdt/20230410/12/ta_histogram.zip
# -rw-r--r--. 1 root root 1111176 Apr 10 17:51 /var/opt/common5/mdt/20230410/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 38493715 Apr 10 17:54 /var/opt/common5/mdt/20230410/13/ue_traffic.zip
# -rw-r--r--. 1 root root 80040348 Apr 10 17:58 /var/opt/common5/mdt/20230410/13/ue_meas.zip
# -rw-r--r--. 1 root root 51674765 Apr 10 18:02 /var/opt/common5/mdt/20230410/13/mdt_result.zip
# -rw-r--r--. 1 root root 702949930 Apr 10 18:57 /var/opt/common5/mdt/20230410/13/ta_histogram.zip
# -rw-r--r--. 1 root root 1561181 Apr 10 19:10 /var/opt/common5/mdt/20230410/14/result_ue_cap.zip
# -rw-r--r--. 1 root root 55881147 Apr 10 19:11 /var/opt/common5/mdt/20230410/14/ue_traffic.zip
# -rw-r--r--. 1 root root 114877611 Apr 10 19:13 /var/opt/common5/mdt/20230410/14/ue_meas.zip
# -rw-r--r--. 1 root root 30639126 Apr 10 19:14 /var/opt/common5/mdt/20230410/14/mdt_result.zip
# -rw-r--r--. 1 root root 377830211 Apr 10 19:24 /var/opt/common5/mdt/20230410/14/ta_histogram.zip
# -rw-r--r--. 1 root root 1497883 Apr 10 20:50 /var/opt/common5/mdt/20230410/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 54136102 Apr 10 20:52 /var/opt/common5/mdt/20230410/15/ue_traffic.zip
# -rw-r--r--. 1 root root 112509140 Apr 10 20:56 /var/opt/common5/mdt/20230410/15/ue_meas.zip
# -rw-r--r--. 1 root root 73574966 Apr 10 21:01 /var/opt/common5/mdt/20230410/15/mdt_result.zip
# -rw-r--r--. 1 root root 950020901 Apr 10 22:18 /var/opt/common5/mdt/20230410/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1120014 Apr 10 21:51 /var/opt/common5/mdt/20230410/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 43380255 Apr 10 21:53 /var/opt/common5/mdt/20230410/16/ue_traffic.zip
# -rw-r--r--. 1 root root 89542165 Apr 10 21:56 /var/opt/common5/mdt/20230410/16/ue_meas.zip
# -rw-r--r--. 1 root root 58413824 Apr 10 22:04 /var/opt/common5/mdt/20230410/16/mdt_result.zip
# -rw-r--r--. 1 root root 739400967 Apr 10 23:07 /var/opt/common5/mdt/20230410/16/ta_histogram.zip
# -rw-r--r--. 1 root root 921535 Apr 10 22:51 /var/opt/common5/mdt/20230410/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 38415525 Apr 10 22:53 /var/opt/common5/mdt/20230410/17/ue_traffic.zip
# -rw-r--r--. 1 root root 79347556 Apr 10 22:55 /var/opt/common5/mdt/20230410/17/ue_meas.zip
# -rw-r--r--. 1 root root 51196446 Apr 10 23:00 /var/opt/common5/mdt/20230410/17/mdt_result.zip
# -rw-r--r--. 1 root root 646264972 Apr 10 23:56 /var/opt/common5/mdt/20230410/17/ta_histogram.zip
# -rw-r--r--. 1 root root 1014619 Apr 10 23:50 /var/opt/common5/mdt/20230410/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 37477693 Apr 10 23:53 /var/opt/common5/mdt/20230410/18/ue_traffic.zip
# -rw-r--r--. 1 root root 77710409 Apr 10 23:55 /var/opt/common5/mdt/20230410/18/ue_meas.zip
# -rw-r--r--. 1 root root 49551668 Apr 10 23:59 /var/opt/common5/mdt/20230410/18/mdt_result.zip
# -rw-r--r--. 1 root root 672213733 Apr 11 00:52 /var/opt/common5/mdt/20230410/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1068094 Apr 11 00:51 /var/opt/common5/mdt/20230410/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 39378508 Apr 11 00:53 /var/opt/common5/mdt/20230410/19/ue_traffic.zip
# -rw-r--r--. 1 root root 81170857 Apr 11 00:56 /var/opt/common5/mdt/20230410/19/ue_meas.zip
# -rw-r--r--. 1 root root 50994508 Apr 11 00:59 /var/opt/common5/mdt/20230410/19/mdt_result.zip
# -rw-r--r--. 1 root root 709930227 Apr 11 01:54 /var/opt/common5/mdt/20230410/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1138636 Apr 11 01:51 /var/opt/common5/mdt/20230410/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 41457684 Apr 11 01:53 /var/opt/common5/mdt/20230410/20/ue_traffic.zip
# -rw-r--r--. 1 root root 86335364 Apr 11 01:55 /var/opt/common5/mdt/20230410/20/ue_meas.zip
# -rw-r--r--. 1 root root 53863609 Apr 11 01:58 /var/opt/common5/mdt/20230410/20/mdt_result.zip
# -rw-r--r--. 1 root root 754224290 Apr 11 02:50 /var/opt/common5/mdt/20230410/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1212615 Apr 11 02:49 /var/opt/common5/mdt/20230410/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 42132795 Apr 11 02:50 /var/opt/common5/mdt/20230410/21/ue_traffic.zip
# -rw-r--r--. 1 root root 87550981 Apr 11 02:52 /var/opt/common5/mdt/20230410/21/ue_meas.zip
# -rw-r--r--. 1 root root 54236855 Apr 11 02:55 /var/opt/common5/mdt/20230410/21/mdt_result.zip
# -rw-r--r--. 1 root root 771728265 Apr 11 03:48 /var/opt/common5/mdt/20230410/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1348010 Apr 11 03:49 /var/opt/common5/mdt/20230410/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 41763946 Apr 11 03:51 /var/opt/common5/mdt/20230410/22/ue_traffic.zip
# -rw-r--r--. 1 root root 86292444 Apr 11 03:53 /var/opt/common5/mdt/20230410/22/ue_meas.zip
# -rw-r--r--. 1 root root 53248390 Apr 11 03:56 /var/opt/common5/mdt/20230410/22/mdt_result.zip
# -rw-r--r--. 1 root root 769106737 Apr 11 04:48 /var/opt/common5/mdt/20230410/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1538198 Apr 11 04:50 /var/opt/common5/mdt/20230410/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 40889870 Apr 11 04:52 /var/opt/common5/mdt/20230410/23/ue_traffic.zip
# -rw-r--r--. 1 root root 83750247 Apr 11 04:54 /var/opt/common5/mdt/20230410/23/ue_meas.zip
# -rw-r--r--. 1 root root 51784854 Apr 11 04:57 /var/opt/common5/mdt/20230410/23/mdt_result.zip
# -rw-r--r--. 1 root root 770262551 Apr 11 05:50 /var/opt/common5/mdt/20230410/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4732129 Apr 11 11:09 /var/opt/common5/mdt/20230410/ue_capability_20230410.zip
# -rw-r--r--. 1 root root 776278054 Apr 11 11:29 /var/opt/common5/mdt/20230410/mdt_20230410.zip
# -rw-r--r--. 1 root root 11454402 Apr 11 11:32 /var/opt/common5/mdt/20230410/grid_mdt_20230410.zip
# -rw-r--r--. 1 root root 38040337 Apr 11 11:34 /var/opt/common5/mdt/20230410/grid_mdt_cell_20230410.zip
# -rw-r--r--. 1 root root 95435540 Apr 11 11:44 /var/opt/common5/mdt/20230410/grid10_mdt_20230410.zip
# -rw-r--r--. 1 root root 144322619 Apr 11 11:45 /var/opt/common5/mdt/20230410/grid10_mdt_cell_20230410.zip
# -rw-r--r--. 1 root root 24300569 Apr 11 11:52 /var/opt/common5/mdt/20230410/grid_mdt_traffic_20230410.zip
# -rw-r--r--. 1 root root 85359760 Apr 11 11:53 /var/opt/common5/mdt/20230410/grid_mdt_traffic_cell_20230410.zip
# -rw-r--r--. 1 root root 154115070 Apr 11 12:03 /var/opt/common5/mdt/20230410/grid10_mdt_traffic_20230410.zip
# -rw-r--r--. 1 root root 263193117 Apr 11 12:04 /var/opt/common5/mdt/20230410/grid10_mdt_traffic_cell_20230410.zip
# -rw-r--r--. 1 root root 33286726 Apr 11 12:16 /var/opt/common5/mdt/20230410/grid_mdt_meas_20230410.zip
# -rw-r--r--. 1 root root 133597516 Apr 11 12:16 /var/opt/common5/mdt/20230410/grid_mdt_meas_cell_20230410.zip
# -rw-r--r--. 1 root root 230729463 Apr 11 12:48 /var/opt/common5/mdt/20230410/grid10_mdt_meas_20230410.zip
# -rw-r--r--. 1 root root 431514600 Apr 11 12:54 /var/opt/common5/mdt/20230410/grid10_mdt_meas_cell_20230410.zip
# -rw-r--r--. 1 root root 1602467 Apr 11 05:49 /var/opt/common5/mdt/20230411/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 36920519 Apr 11 05:50 /var/opt/common5/mdt/20230411/00/ue_traffic.zip
# -rw-r--r--. 1 root root 74992017 Apr 11 05:53 /var/opt/common5/mdt/20230411/00/ue_meas.zip
# -rw-r--r--. 1 root root 46003484 Apr 11 05:56 /var/opt/common5/mdt/20230411/00/mdt_result.zip
# -rw-r--r--. 1 root root 721521296 Apr 11 06:46 /var/opt/common5/mdt/20230411/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1722517 Apr 11 06:48 /var/opt/common5/mdt/20230411/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 34006199 Apr 11 06:50 /var/opt/common5/mdt/20230411/01/ue_traffic.zip
# -rw-r--r--. 1 root root 68678048 Apr 11 06:54 /var/opt/common5/mdt/20230411/01/ue_meas.zip
# -rw-r--r--. 1 root root 41866864 Apr 11 06:57 /var/opt/common5/mdt/20230411/01/mdt_result.zip
# -rw-r--r--. 1 root root 676560825 Apr 11 08:28 /var/opt/common5/mdt/20230411/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1325309 Apr 11 07:55 /var/opt/common5/mdt/20230411/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 24748703 Apr 11 07:56 /var/opt/common5/mdt/20230411/02/ue_traffic.zip
# -rw-r--r--. 1 root root 49765228 Apr 11 08:00 /var/opt/common5/mdt/20230411/02/ue_meas.zip
# -rw-r--r--. 1 root root 29861949 Apr 11 08:07 /var/opt/common5/mdt/20230411/02/mdt_result.zip
# -rw-r--r--. 1 root root 515798000 Apr 11 09:14 /var/opt/common5/mdt/20230411/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1124978 Apr 11 08:53 /var/opt/common5/mdt/20230411/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 23959668 Apr 11 08:56 /var/opt/common5/mdt/20230411/03/ue_traffic.zip
# -rw-r--r--. 1 root root 48051030 Apr 11 08:58 /var/opt/common5/mdt/20230411/03/ue_meas.zip
# -rw-r--r--. 1 root root 28787777 Apr 11 09:05 /var/opt/common5/mdt/20230411/03/mdt_result.zip
# -rw-r--r--. 1 root root 491801114 Apr 11 10:09 /var/opt/common5/mdt/20230411/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1056407 Apr 11 09:53 /var/opt/common5/mdt/20230411/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 23420309 Apr 11 09:55 /var/opt/common5/mdt/20230411/04/ue_traffic.zip
# -rw-r--r--. 1 root root 47498007 Apr 11 09:56 /var/opt/common5/mdt/20230411/04/ue_meas.zip
# -rw-r--r--. 1 root root 28755029 Apr 11 10:03 /var/opt/common5/mdt/20230411/04/mdt_result.zip
# -rw-r--r--. 1 root root 492041575 Apr 11 11:08 /var/opt/common5/mdt/20230411/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1052651 Apr 11 10:56 /var/opt/common5/mdt/20230411/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 22062472 Apr 11 10:58 /var/opt/common5/mdt/20230411/05/ue_traffic.zip
# -rw-r--r--. 1 root root 44374520 Apr 11 11:00 /var/opt/common5/mdt/20230411/05/ue_meas.zip
# -rw-r--r--. 1 root root 27375552 Apr 11 11:10 /var/opt/common5/mdt/20230411/05/mdt_result.zip
# -rw-r--r--. 1 root root 458117769 Apr 11 11:52 /var/opt/common5/mdt/20230411/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1162905 Apr 11 11:51 /var/opt/common5/mdt/20230411/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 27661453 Apr 11 11:52 /var/opt/common5/mdt/20230411/06/ue_traffic.zip
# -rw-r--r--. 1 root root 55805447 Apr 11 11:55 /var/opt/common5/mdt/20230411/06/ue_meas.zip
# -rw-r--r--. 1 root root 35795000 Apr 11 11:58 /var/opt/common5/mdt/20230411/06/mdt_result.zip
# -rw-r--r--. 1 root root 524451466 Apr 11 12:53 /var/opt/common5/mdt/20230411/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1149732 Apr 11 12:54 /var/opt/common5/mdt/20230411/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 35405693 Apr 11 12:56 /var/opt/common5/mdt/20230411/07/ue_traffic.zip
# -rw-r--r--. 1 root root 72327753 Apr 11 12:59 /var/opt/common5/mdt/20230411/07/ue_meas.zip
# -rw-r--r--. 1 root root 47366146 Apr 11 13:02 /var/opt/common5/mdt/20230411/07/mdt_result.zip
# -rw-r--r--. 1 root root 595754686 Apr 11 13:55 /var/opt/common5/mdt/20230411/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1158021 Apr 11 13:51 /var/opt/common5/mdt/20230411/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 37699026 Apr 11 13:53 /var/opt/common5/mdt/20230411/08/ue_traffic.zip
# -rw-r--r--. 1 root root 77060908 Apr 11 13:57 /var/opt/common5/mdt/20230411/08/ue_meas.zip
# -rw-r--r--. 1 root root 49797532 Apr 11 14:00 /var/opt/common5/mdt/20230411/08/mdt_result.zip
# -rw-r--r--. 1 root root 9423102034 Apr 11 14:48 /var/opt/common5/mdt/20230411/08/ta_histogram.csv
# -rw-r--r--. 1 root root 37511754 Apr 11 15:00 /var/opt/common5/mdt/20230411/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1702535 Apr 11 20:48 /var/opt/common5/mdt/20230411/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 62848114 Apr 11 20:50 /var/opt/common5/mdt/20230411/15/ue_traffic.zip
# -rw-r--r--. 1 root root 129534179 Apr 11 20:54 /var/opt/common5/mdt/20230411/15/ue_meas.zip
# -rw-r--r--. 1 root root 85223391 Apr 11 20:59 /var/opt/common5/mdt/20230411/15/mdt_result.zip
# -rw-r--r--. 1 root root 1073690048 Apr 11 22:15 /var/opt/common5/mdt/20230411/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1119233 Apr 11 21:53 /var/opt/common5/mdt/20230411/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 43859926 Apr 11 21:58 /var/opt/common5/mdt/20230411/16/ue_traffic.zip
# -rw-r--r--. 1 root root 90517008 Apr 11 22:04 /var/opt/common5/mdt/20230411/16/ue_meas.zip
# -rw-r--r--. 1 root root 58940199 Apr 11 22:13 /var/opt/common5/mdt/20230411/16/mdt_result.zip
# -rw-r--r--. 1 root root 738558680 Apr 11 22:48 /var/opt/common5/mdt/20230411/16/ta_histogram.zip
# -rw-r--r--. 1 root root 428214 Apr 11 22:11 /var/opt/common5/mdt/20230411/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 18096034 Apr 11 22:12 /var/opt/common5/mdt/20230411/17/ue_traffic.zip
# -rw-r--r--. 1 root root 37656880 Apr 11 22:12 /var/opt/common5/mdt/20230411/17/ue_meas.zip
# -rw-r--r--. 1 root root 24688452 Apr 11 22:13 /var/opt/common5/mdt/20230411/17/mdt_result.zip
# -rw-r--r--. 1 root root 297128182 Apr 11 22:22 /var/opt/common5/mdt/20230411/17/ta_histogram.zip
# -rw-r--r--. 1 root root 387010 Apr 12 09:57 /var/opt/common5/mdt/20230411/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 803100 Apr 12 09:57 /var/opt/common5/mdt/20230411/filter_ue_meas.zip
# -rw-r--r--. 1 root root 397881 Apr 12 09:57 /var/opt/common5/mdt/20230411/filter_mdt_result_ctr2_20230411.zip
# -rw-r--r--. 1 root root 1713801 Apr 12 13:41 /var/opt/common5/mdt/20230412/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 57119611 Apr 12 13:43 /var/opt/common5/mdt/20230412/08/ue_traffic.zip
# -rw-r--r--. 1 root root 116794634 Apr 12 13:46 /var/opt/common5/mdt/20230412/08/ue_meas.zip
# -rw-r--r--. 1 root root 76330244 Apr 12 13:51 /var/opt/common5/mdt/20230412/08/mdt_result.zip
# -rw-r--r--. 1 root root 978906736 Apr 12 14:55 /var/opt/common5/mdt/20230412/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1468361 Apr 12 14:51 /var/opt/common5/mdt/20230412/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 50081477 Apr 12 14:54 /var/opt/common5/mdt/20230412/09/ue_traffic.zip
# -rw-r--r--. 1 root root 102728389 Apr 12 14:57 /var/opt/common5/mdt/20230412/09/ue_meas.zip
# -rw-r--r--. 1 root root 66603741 Apr 12 15:01 /var/opt/common5/mdt/20230412/09/mdt_result.zip
# -rw-r--r--. 1 root root 5968216064 Apr 12 15:26 /var/opt/common5/mdt/20230412/09/ta_histogram.csv
# -rw-r--r--. 1 root root 889338 Apr 12 17:58 /var/opt/common5/mdt/20230412/13/result_ue_cap.zip
# -rw-r--r--. 1 root root 19153537 Apr 12 17:59 /var/opt/common5/mdt/20230412/13/ue_traffic.zip
# -rw-r--r--. 1 root root 39242593 Apr 12 18:00 /var/opt/common5/mdt/20230412/13/ue_meas.zip
# -rw-r--r--. 1 root root 25534436 Apr 12 18:01 /var/opt/common5/mdt/20230412/13/mdt_result.zip
# -rw-r--r--. 1 root root 351623338 Apr 12 18:09 /var/opt/common5/mdt/20230412/13/ta_histogram.zip
# -rw-r--r--. 1 root root 1582416 Apr 12 20:48 /var/opt/common5/mdt/20230412/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 57454836 Apr 12 20:50 /var/opt/common5/mdt/20230412/15/ue_traffic.zip
# -rw-r--r--. 1 root root 118507716 Apr 12 20:54 /var/opt/common5/mdt/20230412/15/ue_meas.zip
# -rw-r--r--. 1 root root 77684036 Apr 12 20:58 /var/opt/common5/mdt/20230412/15/mdt_result.zip
# -rw-r--r--. 1 root root 1006531863 Apr 12 22:44 /var/opt/common5/mdt/20230412/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1141476 Apr 12 21:53 /var/opt/common5/mdt/20230412/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 44057057 Apr 12 21:55 /var/opt/common5/mdt/20230412/16/ue_traffic.zip
# -rw-r--r--. 1 root root 91032418 Apr 12 21:59 /var/opt/common5/mdt/20230412/16/ue_meas.zip
# -rw-r--r--. 1 root root 59217121 Apr 12 22:10 /var/opt/common5/mdt/20230412/16/mdt_result.zip
# -rw-r--r--. 1 root root 754231595 Apr 12 23:53 /var/opt/common5/mdt/20230412/16/ta_histogram.zip
# -rw-r--r--. 1 root root 755524 Apr 12 22:48 /var/opt/common5/mdt/20230412/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 30592210 Apr 12 22:50 /var/opt/common5/mdt/20230412/17/ue_traffic.zip
# -rw-r--r--. 1 root root 63821564 Apr 12 22:52 /var/opt/common5/mdt/20230412/17/ue_meas.zip
# -rw-r--r--. 1 root root 40978708 Apr 12 22:55 /var/opt/common5/mdt/20230412/17/mdt_result.zip
# -rw-r--r--. 1 root root 529447781 Apr 12 23:59 /var/opt/common5/mdt/20230412/17/ta_histogram.zip
# -rw-r--r--. 1 root root 828872 Apr 12 23:53 /var/opt/common5/mdt/20230412/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 30141408 Apr 12 23:55 /var/opt/common5/mdt/20230412/18/ue_traffic.zip
# -rw-r--r--. 1 root root 62677498 Apr 12 23:57 /var/opt/common5/mdt/20230412/18/ue_meas.zip
# -rw-r--r--. 1 root root 39721715 Apr 13 00:00 /var/opt/common5/mdt/20230412/18/mdt_result.zip
# -rw-r--r--. 1 root root 554830382 Apr 13 00:48 /var/opt/common5/mdt/20230412/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1028748 Apr 13 00:50 /var/opt/common5/mdt/20230412/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 37698445 Apr 13 00:52 /var/opt/common5/mdt/20230412/19/ue_traffic.zip
# -rw-r--r--. 1 root root 77909789 Apr 13 00:54 /var/opt/common5/mdt/20230412/19/ue_meas.zip
# -rw-r--r--. 1 root root 48874909 Apr 13 00:58 /var/opt/common5/mdt/20230412/19/mdt_result.zip
# -rw-r--r--. 1 root root 694919807 Apr 13 01:52 /var/opt/common5/mdt/20230412/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1179346 Apr 13 01:50 /var/opt/common5/mdt/20230412/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 42834488 Apr 13 01:52 /var/opt/common5/mdt/20230412/20/ue_traffic.zip
# -rw-r--r--. 1 root root 88466142 Apr 13 01:54 /var/opt/common5/mdt/20230412/20/ue_meas.zip
# -rw-r--r--. 1 root root 55236161 Apr 13 01:58 /var/opt/common5/mdt/20230412/20/mdt_result.zip
# -rw-r--r--. 1 root root 780927941 Apr 13 02:52 /var/opt/common5/mdt/20230412/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1228242 Apr 13 02:50 /var/opt/common5/mdt/20230412/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 42158023 Apr 13 02:52 /var/opt/common5/mdt/20230412/21/ue_traffic.zip
# -rw-r--r--. 1 root root 87713172 Apr 13 02:54 /var/opt/common5/mdt/20230412/21/ue_meas.zip
# -rw-r--r--. 1 root root 54334248 Apr 13 02:57 /var/opt/common5/mdt/20230412/21/mdt_result.zip
# -rw-r--r--. 1 root root 785420739 Apr 13 03:51 /var/opt/common5/mdt/20230412/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1392070 Apr 13 03:49 /var/opt/common5/mdt/20230412/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 43062491 Apr 13 03:51 /var/opt/common5/mdt/20230412/22/ue_traffic.zip
# -rw-r--r--. 1 root root 89097109 Apr 13 03:54 /var/opt/common5/mdt/20230412/22/ue_meas.zip
# -rw-r--r--. 1 root root 54991920 Apr 13 03:56 /var/opt/common5/mdt/20230412/22/mdt_result.zip
# -rw-r--r--. 1 root root 801008001 Apr 13 04:51 /var/opt/common5/mdt/20230412/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1506303 Apr 13 04:50 /var/opt/common5/mdt/20230412/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 39855747 Apr 13 04:52 /var/opt/common5/mdt/20230412/23/ue_traffic.zip
# -rw-r--r--. 1 root root 81807610 Apr 13 04:54 /var/opt/common5/mdt/20230412/23/ue_meas.zip
# -rw-r--r--. 1 root root 50481494 Apr 13 04:57 /var/opt/common5/mdt/20230412/23/mdt_result.zip
# -rw-r--r--. 1 root root 761759309 Apr 13 05:50 /var/opt/common5/mdt/20230412/23/ta_histogram.zip
# -rw-r--r--. 1 root root 1597896 Apr 13 05:50 /var/opt/common5/mdt/20230413/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 36753254 Apr 13 05:51 /var/opt/common5/mdt/20230413/00/ue_traffic.zip
# -rw-r--r--. 1 root root 74880930 Apr 13 05:53 /var/opt/common5/mdt/20230413/00/ue_meas.zip
# -rw-r--r--. 1 root root 46024697 Apr 13 05:56 /var/opt/common5/mdt/20230413/00/mdt_result.zip
# -rw-r--r--. 1 root root 723344112 Apr 13 06:45 /var/opt/common5/mdt/20230413/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1716655 Apr 13 06:52 /var/opt/common5/mdt/20230413/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 34243283 Apr 13 06:56 /var/opt/common5/mdt/20230413/01/ue_traffic.zip
# -rw-r--r--. 1 root root 68770579 Apr 13 06:58 /var/opt/common5/mdt/20230413/01/ue_meas.zip
# -rw-r--r--. 1 root root 41787043 Apr 13 07:02 /var/opt/common5/mdt/20230413/01/mdt_result.zip
# -rw-r--r--. 1 root root 683996673 Apr 13 08:02 /var/opt/common5/mdt/20230413/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1591113 Apr 13 07:59 /var/opt/common5/mdt/20230413/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 30257604 Apr 13 08:01 /var/opt/common5/mdt/20230413/02/ue_traffic.zip
# -rw-r--r--. 1 root root 60983202 Apr 13 08:04 /var/opt/common5/mdt/20230413/02/ue_meas.zip
# -rw-r--r--. 1 root root 36413009 Apr 13 08:14 /var/opt/common5/mdt/20230413/02/mdt_result.zip
# -rw-r--r--. 1 root root 627360593 Apr 13 10:00 /var/opt/common5/mdt/20230413/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1140953 Apr 13 08:53 /var/opt/common5/mdt/20230413/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 24200285 Apr 13 08:55 /var/opt/common5/mdt/20230413/03/ue_traffic.zip
# -rw-r--r--. 1 root root 48970911 Apr 13 08:57 /var/opt/common5/mdt/20230413/03/ue_meas.zip
# -rw-r--r--. 1 root root 29277227 Apr 13 08:59 /var/opt/common5/mdt/20230413/03/mdt_result.zip
# -rw-r--r--. 1 root root 501236489 Apr 13 10:13 /var/opt/common5/mdt/20230413/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1060976 Apr 13 09:54 /var/opt/common5/mdt/20230413/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 23742581 Apr 13 09:58 /var/opt/common5/mdt/20230413/04/ue_traffic.zip
# -rw-r--r--. 1 root root 48189838 Apr 13 10:01 /var/opt/common5/mdt/20230413/04/ue_meas.zip
# -rw-r--r--. 1 root root 29086943 Apr 13 10:12 /var/opt/common5/mdt/20230413/04/mdt_result.zip
# -rw-r--r--. 1 root root 1606536 Apr 13 20:50 /var/opt/common5/mdt/20230413/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 58400502 Apr 13 20:53 /var/opt/common5/mdt/20230413/15/ue_traffic.zip
# -rw-r--r--. 1 root root 121228689 Apr 13 20:57 /var/opt/common5/mdt/20230413/15/ue_meas.zip
# -rw-r--r--. 1 root root 79520941 Apr 13 21:02 /var/opt/common5/mdt/20230413/15/mdt_result.zip
# -rw-r--r--. 1 root root 1017283629 Apr 13 22:27 /var/opt/common5/mdt/20230413/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1108484 Apr 13 21:51 /var/opt/common5/mdt/20230413/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 43409565 Apr 13 21:56 /var/opt/common5/mdt/20230413/16/ue_traffic.zip
# -rw-r--r--. 1 root root 89644225 Apr 13 22:00 /var/opt/common5/mdt/20230413/16/ue_meas.zip
# -rw-r--r--. 1 root root 58341705 Apr 13 22:14 /var/opt/common5/mdt/20230413/16/mdt_result.zip
# -rw-r--r--. 1 root root 734399373 Apr 13 23:47 /var/opt/common5/mdt/20230413/16/ta_histogram.zip
# -rw-r--r--. 1 root root 898050 Apr 13 22:50 /var/opt/common5/mdt/20230413/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 37366482 Apr 13 22:51 /var/opt/common5/mdt/20230413/17/ue_traffic.zip
# -rw-r--r--. 1 root root 77879112 Apr 13 22:55 /var/opt/common5/mdt/20230413/17/ue_meas.zip
# -rw-r--r--. 1 root root 50372285 Apr 13 23:01 /var/opt/common5/mdt/20230413/17/mdt_result.zip
# -rw-r--r--. 1 root root 632346534 Apr 14 00:26 /var/opt/common5/mdt/20230413/17/ta_histogram.zip
# -rw-r--r--. 1 root root 991333 Apr 13 23:51 /var/opt/common5/mdt/20230413/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 37058046 Apr 13 23:53 /var/opt/common5/mdt/20230413/18/ue_traffic.zip
# -rw-r--r--. 1 root root 76989415 Apr 13 23:56 /var/opt/common5/mdt/20230413/18/ue_meas.zip
# -rw-r--r--. 1 root root 49067360 Apr 14 00:00 /var/opt/common5/mdt/20230413/18/mdt_result.zip
# -rw-r--r--. 1 root root 663150175 Apr 14 00:59 /var/opt/common5/mdt/20230413/18/ta_histogram.zip
# -rw-r--r--. 1 root root 945699 Apr 14 00:52 /var/opt/common5/mdt/20230413/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 35239440 Apr 14 00:54 /var/opt/common5/mdt/20230413/19/ue_traffic.zip
# -rw-r--r--. 1 root root 72787570 Apr 14 00:56 /var/opt/common5/mdt/20230413/19/ue_meas.zip
# -rw-r--r--. 1 root root 45848860 Apr 14 01:00 /var/opt/common5/mdt/20230413/19/mdt_result.zip
# -rw-r--r--. 1 root root 638987159 Apr 14 01:52 /var/opt/common5/mdt/20230413/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1057678 Apr 14 01:52 /var/opt/common5/mdt/20230413/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 38729257 Apr 14 01:53 /var/opt/common5/mdt/20230413/20/ue_traffic.zip
# -rw-r--r--. 1 root root 80658167 Apr 14 01:55 /var/opt/common5/mdt/20230413/20/ue_meas.zip
# -rw-r--r--. 1 root root 50591243 Apr 14 01:58 /var/opt/common5/mdt/20230413/20/mdt_result.zip
# -rw-r--r--. 1 root root 711057221 Apr 14 02:50 /var/opt/common5/mdt/20230413/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1172538 Apr 14 02:50 /var/opt/common5/mdt/20230413/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 41171920 Apr 14 02:52 /var/opt/common5/mdt/20230413/21/ue_traffic.zip
# -rw-r--r--. 1 root root 84887427 Apr 14 02:54 /var/opt/common5/mdt/20230413/21/ue_meas.zip
# -rw-r--r--. 1 root root 52600157 Apr 14 02:57 /var/opt/common5/mdt/20230413/21/mdt_result.zip
# -rw-r--r--. 1 root root 761266803 Apr 14 03:48 /var/opt/common5/mdt/20230413/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1258585 Apr 14 03:48 /var/opt/common5/mdt/20230413/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 39036536 Apr 14 03:50 /var/opt/common5/mdt/20230413/22/ue_traffic.zip
# -rw-r--r--. 1 root root 80730082 Apr 14 03:52 /var/opt/common5/mdt/20230413/22/ue_meas.zip
# -rw-r--r--. 1 root root 49738404 Apr 14 03:55 /var/opt/common5/mdt/20230413/22/mdt_result.zip
# -rw-r--r--. 1 root root 734136746 Apr 14 04:46 /var/opt/common5/mdt/20230413/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1500184 Apr 14 04:49 /var/opt/common5/mdt/20230413/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 40261554 Apr 14 04:50 /var/opt/common5/mdt/20230413/23/ue_traffic.zip
# -rw-r--r--. 1 root root 82667004 Apr 14 04:52 /var/opt/common5/mdt/20230413/23/ue_meas.zip
# -rw-r--r--. 1 root root 50969657 Apr 14 04:55 /var/opt/common5/mdt/20230413/23/mdt_result.zip
# -rw-r--r--. 1 root root 766510003 Apr 14 05:53 /var/opt/common5/mdt/20230413/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4336167 Apr 14 10:23 /var/opt/common5/mdt/20230413/ue_capability_20230413.zip
# -rw-r--r--. 1 root root 468525214 Apr 14 10:51 /var/opt/common5/mdt/20230413/mdt_20230413.zip
# -rw-r--r--. 1 root root 9724847 Apr 14 10:53 /var/opt/common5/mdt/20230413/grid_mdt_20230413.zip
# -rw-r--r--. 1 root root 28900168 Apr 14 10:54 /var/opt/common5/mdt/20230413/grid_mdt_cell_20230413.zip
# -rw-r--r--. 1 root root 69718880 Apr 14 11:00 /var/opt/common5/mdt/20230413/grid10_mdt_20230413.zip
# -rw-r--r--. 1 root root 98292484 Apr 14 11:00 /var/opt/common5/mdt/20230413/grid10_mdt_cell_20230413.zip
# -rw-r--r--. 1 root root 20387495 Apr 14 11:04 /var/opt/common5/mdt/20230413/grid_mdt_traffic_20230413.zip
# -rw-r--r--. 1 root root 63743010 Apr 14 11:04 /var/opt/common5/mdt/20230413/grid_mdt_traffic_cell_20230413.zip
# -rw-r--r--. 1 root root 108729265 Apr 14 11:10 /var/opt/common5/mdt/20230413/grid10_mdt_traffic_20230413.zip
# -rw-r--r--. 1 root root 173001169 Apr 14 11:11 /var/opt/common5/mdt/20230413/grid10_mdt_traffic_cell_20230413.zip
# -rw-r--r--. 1 root root 28360586 Apr 14 11:18 /var/opt/common5/mdt/20230413/grid_mdt_meas_20230413.zip
# -rw-r--r--. 1 root root 100599561 Apr 14 11:18 /var/opt/common5/mdt/20230413/grid_mdt_meas_cell_20230413.zip
# -rw-r--r--. 1 root root 161891213 Apr 14 11:26 /var/opt/common5/mdt/20230413/grid10_mdt_meas_20230413.zip
# -rw-r--r--. 1 root root 279884043 Apr 14 11:29 /var/opt/common5/mdt/20230413/grid10_mdt_meas_cell_20230413.zip
# -rw-r--r--. 1 root root 1358051 Apr 14 05:49 /var/opt/common5/mdt/20230414/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 31614849 Apr 14 05:51 /var/opt/common5/mdt/20230414/00/ue_traffic.zip
# -rw-r--r--. 1 root root 64374678 Apr 14 05:54 /var/opt/common5/mdt/20230414/00/ue_meas.zip
# -rw-r--r--. 1 root root 39392259 Apr 14 05:56 /var/opt/common5/mdt/20230414/00/mdt_result.zip
# -rw-r--r--. 1 root root 627580229 Apr 14 06:28 /var/opt/common5/mdt/20230414/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1719800 Apr 14 06:48 /var/opt/common5/mdt/20230414/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 35043029 Apr 14 06:52 /var/opt/common5/mdt/20230414/01/ue_traffic.zip
# -rw-r--r--. 1 root root 70914875 Apr 14 06:55 /var/opt/common5/mdt/20230414/01/ue_meas.zip
# -rw-r--r--. 1 root root 43217827 Apr 14 06:58 /var/opt/common5/mdt/20230414/01/mdt_result.zip
# -rw-r--r--. 1 root root 694262089 Apr 14 08:29 /var/opt/common5/mdt/20230414/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1412695 Apr 14 07:56 /var/opt/common5/mdt/20230414/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 27042085 Apr 14 07:59 /var/opt/common5/mdt/20230414/02/ue_traffic.zip
# -rw-r--r--. 1 root root 54425696 Apr 14 08:02 /var/opt/common5/mdt/20230414/02/ue_meas.zip
# -rw-r--r--. 1 root root 32652197 Apr 14 08:10 /var/opt/common5/mdt/20230414/02/mdt_result.zip
# -rw-r--r--. 1 root root 564370634 Apr 14 10:02 /var/opt/common5/mdt/20230414/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1177607 Apr 14 08:58 /var/opt/common5/mdt/20230414/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 25130347 Apr 14 09:20 /var/opt/common5/mdt/20230414/03/ue_traffic.zip
# -rw-r--r--. 1 root root 50798972 Apr 14 09:24 /var/opt/common5/mdt/20230414/03/ue_meas.zip
# -rw-r--r--. 1 root root 30533909 Apr 14 09:32 /var/opt/common5/mdt/20230414/03/mdt_result.zip
# -rw-r--r--. 1 root root 519243124 Apr 14 11:01 /var/opt/common5/mdt/20230414/03/ta_histogram.zip
# -rw-r--r--. 1 root root 791176 Apr 14 09:56 /var/opt/common5/mdt/20230414/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 17475788 Apr 14 09:59 /var/opt/common5/mdt/20230414/04/ue_traffic.zip
# -rw-r--r--. 1 root root 35439139 Apr 14 10:01 /var/opt/common5/mdt/20230414/04/ue_meas.zip
# -rw-r--r--. 1 root root 21353213 Apr 14 10:08 /var/opt/common5/mdt/20230414/04/mdt_result.zip
# -rw-r--r--. 1 root root 369791337 Apr 14 10:56 /var/opt/common5/mdt/20230414/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1110792 Apr 14 10:54 /var/opt/common5/mdt/20230414/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 23745780 Apr 14 10:57 /var/opt/common5/mdt/20230414/05/ue_traffic.zip
# -rw-r--r--. 1 root root 47347179 Apr 14 10:59 /var/opt/common5/mdt/20230414/05/ue_meas.zip
# -rw-r--r--. 1 root root 29250146 Apr 14 11:02 /var/opt/common5/mdt/20230414/05/mdt_result.zip
# -rw-r--r--. 1 root root 483432008 Apr 14 11:39 /var/opt/common5/mdt/20230414/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1307478 Apr 14 11:51 /var/opt/common5/mdt/20230414/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 33287306 Apr 14 11:54 /var/opt/common5/mdt/20230414/06/ue_traffic.zip
# -rw-r--r--. 1 root root 67092195 Apr 14 11:57 /var/opt/common5/mdt/20230414/06/ue_meas.zip
# -rw-r--r--. 1 root root 42659663 Apr 14 12:01 /var/opt/common5/mdt/20230414/06/mdt_result.zip
# -rw-r--r--. 1 root root 621876636 Apr 14 12:56 /var/opt/common5/mdt/20230414/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1372977 Apr 14 12:51 /var/opt/common5/mdt/20230414/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 41291739 Apr 14 12:54 /var/opt/common5/mdt/20230414/07/ue_traffic.zip
# -rw-r--r--. 1 root root 83453005 Apr 14 12:57 /var/opt/common5/mdt/20230414/07/ue_meas.zip
# -rw-r--r--. 1 root root 54382251 Apr 14 13:01 /var/opt/common5/mdt/20230414/07/mdt_result.zip
# -rw-r--r--. 1 root root 9872411417 Apr 14 13:32 /var/opt/common5/mdt/20230414/07/ta_histogram.csv
# -rw-r--r--. 1 root root 557944832 Apr 14 14:30 /var/opt/common5/mdt/20230414/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1140506 Apr 14 13:51 /var/opt/common5/mdt/20230414/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 36833764 Apr 14 13:54 /var/opt/common5/mdt/20230414/08/ue_traffic.zip
# -rw-r--r--. 1 root root 75586466 Apr 14 13:59 /var/opt/common5/mdt/20230414/08/ue_meas.zip
# -rw-r--r--. 1 root root 1605550 Apr 14 20:50 /var/opt/common5/mdt/20230414/15/result_ue_cap.zip
# -rw-r--r--. 1 root root 59901926 Apr 14 20:53 /var/opt/common5/mdt/20230414/15/ue_traffic.zip
# -rw-r--r--. 1 root root 123533598 Apr 14 20:56 /var/opt/common5/mdt/20230414/15/ue_meas.zip
# -rw-r--r--. 1 root root 80712879 Apr 14 21:01 /var/opt/common5/mdt/20230414/15/mdt_result.zip
# -rw-r--r--. 1 root root 1030574499 Apr 14 22:40 /var/opt/common5/mdt/20230414/15/ta_histogram.zip
# -rw-r--r--. 1 root root 1101389 Apr 14 21:51 /var/opt/common5/mdt/20230414/16/result_ue_cap.zip
# -rw-r--r--. 1 root root 43945525 Apr 14 21:53 /var/opt/common5/mdt/20230414/16/ue_traffic.zip
# -rw-r--r--. 1 root root 90733086 Apr 14 21:56 /var/opt/common5/mdt/20230414/16/ue_meas.zip
# -rw-r--r--. 1 root root 59413832 Apr 14 22:05 /var/opt/common5/mdt/20230414/16/mdt_result.zip
# -rw-r--r--. 1 root root 742813167 Apr 14 23:51 /var/opt/common5/mdt/20230414/16/ta_histogram.zip
# -rw-r--r--. 1 root root 819288 Apr 14 22:48 /var/opt/common5/mdt/20230414/17/result_ue_cap.zip
# -rw-r--r--. 1 root root 34230728 Apr 14 22:50 /var/opt/common5/mdt/20230414/17/ue_traffic.zip
# -rw-r--r--. 1 root root 71285317 Apr 14 22:53 /var/opt/common5/mdt/20230414/17/ue_meas.zip
# -rw-r--r--. 1 root root 45886936 Apr 14 22:57 /var/opt/common5/mdt/20230414/17/mdt_result.zip
# -rw-r--r--. 1 root root 587686103 Apr 15 00:00 /var/opt/common5/mdt/20230414/17/ta_histogram.zip
# -rw-r--r--. 1 root root 894126 Apr 14 23:53 /var/opt/common5/mdt/20230414/18/result_ue_cap.zip
# -rw-r--r--. 1 root root 33726659 Apr 14 23:55 /var/opt/common5/mdt/20230414/18/ue_traffic.zip
# -rw-r--r--. 1 root root 69343102 Apr 14 23:57 /var/opt/common5/mdt/20230414/18/ue_meas.zip
# -rw-r--r--. 1 root root 44033887 Apr 15 00:01 /var/opt/common5/mdt/20230414/18/mdt_result.zip
# -rw-r--r--. 1 root root 602181477 Apr 15 00:48 /var/opt/common5/mdt/20230414/18/ta_histogram.zip
# -rw-r--r--. 1 root root 1018905 Apr 15 00:50 /var/opt/common5/mdt/20230414/19/result_ue_cap.zip
# -rw-r--r--. 1 root root 38082843 Apr 15 00:52 /var/opt/common5/mdt/20230414/19/ue_traffic.zip
# -rw-r--r--. 1 root root 78453392 Apr 15 00:54 /var/opt/common5/mdt/20230414/19/ue_meas.zip
# -rw-r--r--. 1 root root 49435508 Apr 15 00:58 /var/opt/common5/mdt/20230414/19/mdt_result.zip
# -rw-r--r--. 1 root root 689885477 Apr 15 01:50 /var/opt/common5/mdt/20230414/19/ta_histogram.zip
# -rw-r--r--. 1 root root 1153545 Apr 15 01:50 /var/opt/common5/mdt/20230414/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 42265712 Apr 15 01:52 /var/opt/common5/mdt/20230414/20/ue_traffic.zip
# -rw-r--r--. 1 root root 87930438 Apr 15 01:55 /var/opt/common5/mdt/20230414/20/ue_meas.zip
# -rw-r--r--. 1 root root 54930789 Apr 15 01:58 /var/opt/common5/mdt/20230414/20/mdt_result.zip
# -rw-r--r--. 1 root root 775740578 Apr 15 02:52 /var/opt/common5/mdt/20230414/20/ta_histogram.zip
# -rw-r--r--. 1 root root 1220074 Apr 15 02:50 /var/opt/common5/mdt/20230414/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 42820734 Apr 15 02:52 /var/opt/common5/mdt/20230414/21/ue_traffic.zip
# -rw-r--r--. 1 root root 88911355 Apr 15 02:54 /var/opt/common5/mdt/20230414/21/ue_meas.zip
# -rw-r--r--. 1 root root 55140154 Apr 15 02:57 /var/opt/common5/mdt/20230414/21/mdt_result.zip
# -rw-r--r--. 1 root root 794738216 Apr 15 03:50 /var/opt/common5/mdt/20230414/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1404397 Apr 15 03:50 /var/opt/common5/mdt/20230414/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 45034440 Apr 15 03:51 /var/opt/common5/mdt/20230414/22/ue_traffic.zip
# -rw-r--r--. 1 root root 92148138 Apr 15 03:54 /var/opt/common5/mdt/20230414/22/ue_meas.zip
# -rw-r--r--. 1 root root 56700715 Apr 15 03:57 /var/opt/common5/mdt/20230414/22/mdt_result.zip
# -rw-r--r--. 1 root root 828333359 Apr 15 05:20 /var/opt/common5/mdt/20230414/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1243085 Apr 15 04:56 /var/opt/common5/mdt/20230414/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 33637601 Apr 15 04:59 /var/opt/common5/mdt/20230414/23/ue_traffic.zip
# -rw-r--r--. 1 root root 68328762 Apr 15 05:08 /var/opt/common5/mdt/20230414/23/ue_meas.zip
# -rw-r--r--. 1 root root 41950507 Apr 15 05:22 /var/opt/common5/mdt/20230414/23/mdt_result.zip
# -rw-r--r--. 1 root root 639312710 Apr 15 06:21 /var/opt/common5/mdt/20230414/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4488537 Apr 15 10:12 /var/opt/common5/mdt/20230414/ue_capability_20230414.zip
# -rw-r--r--. 1 root root 547217728 Apr 15 10:19 /var/opt/common5/mdt/20230414/mdt_20230414.zip
# -rw-r--r--. 1 root root 10291882 Apr 15 10:20 /var/opt/common5/mdt/20230414/grid_mdt_20230414.zip
# -rw-r--r--. 1 root root 31254642 Apr 15 10:21 /var/opt/common5/mdt/20230414/grid_mdt_cell_20230414.zip
# -rw-r--r--. 1 root root 77051339 Apr 15 10:26 /var/opt/common5/mdt/20230414/grid10_mdt_20230414.zip
# -rw-r--r--. 1 root root 110627384 Apr 15 10:26 /var/opt/common5/mdt/20230414/grid10_mdt_cell_20230414.zip
# -rw-r--r--. 1 root root 22035921 Apr 15 10:29 /var/opt/common5/mdt/20230414/grid_mdt_traffic_20230414.zip
# -rw-r--r--. 1 root root 71170115 Apr 15 10:29 /var/opt/common5/mdt/20230414/grid_mdt_traffic_cell_20230414.zip
# -rw-r--r--. 1 root root 126445680 Apr 15 10:36 /var/opt/common5/mdt/20230414/grid10_mdt_traffic_20230414.zip
# -rw-r--r--. 1 root root 205652729 Apr 15 10:38 /var/opt/common5/mdt/20230414/grid10_mdt_traffic_cell_20230414.zip
# -rw-r--r--. 1 root root 30419861 Apr 15 10:45 /var/opt/common5/mdt/20230414/grid_mdt_meas_20230414.zip
# -rw-r--r--. 1 root root 111802714 Apr 15 10:45 /var/opt/common5/mdt/20230414/grid_mdt_meas_cell_20230414.zip
# -rw-r--r--. 1 root root 188348368 Apr 15 10:55 /var/opt/common5/mdt/20230414/grid10_mdt_meas_20230414.zip
# -rw-r--r--. 1 root root 334246859 Apr 15 10:56 /var/opt/common5/mdt/20230414/grid10_mdt_meas_cell_20230414.zip
# -rw-r--r--. 1 root root 1074881 Apr 15 05:48 /var/opt/common5/mdt/20230415/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 25497548 Apr 15 05:49 /var/opt/common5/mdt/20230415/00/ue_traffic.zip
# -rw-r--r--. 1 root root 51457240 Apr 15 05:51 /var/opt/common5/mdt/20230415/00/ue_meas.zip
# -rw-r--r--. 1 root root 31522844 Apr 15 05:53 /var/opt/common5/mdt/20230415/00/mdt_result.zip
# -rw-r--r--. 1 root root 499711941 Apr 15 06:23 /var/opt/common5/mdt/20230415/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1715844 Apr 15 06:45 /var/opt/common5/mdt/20230415/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 35539444 Apr 15 06:46 /var/opt/common5/mdt/20230415/01/ue_traffic.zip
# -rw-r--r--. 1 root root 71724035 Apr 15 06:49 /var/opt/common5/mdt/20230415/01/ue_meas.zip
# -rw-r--r--. 1 root root 43921236 Apr 15 06:53 /var/opt/common5/mdt/20230415/01/mdt_result.zip
# -rw-r--r--. 1 root root 699180228 Apr 15 07:49 /var/opt/common5/mdt/20230415/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1722554 Apr 15 07:49 /var/opt/common5/mdt/20230415/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 33830653 Apr 15 07:53 /var/opt/common5/mdt/20230415/02/ue_traffic.zip
# -rw-r--r--. 1 root root 67909158 Apr 15 07:56 /var/opt/common5/mdt/20230415/02/ue_meas.zip
# -rw-r--r--. 1 root root 41185309 Apr 15 08:02 /var/opt/common5/mdt/20230415/02/mdt_result.zip
# -rw-r--r--. 1 root root 686461440 Apr 15 10:19 /var/opt/common5/mdt/20230415/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1387355 Apr 15 08:50 /var/opt/common5/mdt/20230415/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 29557014 Apr 15 08:51 /var/opt/common5/mdt/20230415/03/ue_traffic.zip
# -rw-r--r--. 1 root root 59583082 Apr 15 08:53 /var/opt/common5/mdt/20230415/03/ue_meas.zip
# -rw-r--r--. 1 root root 35924699 Apr 15 08:56 /var/opt/common5/mdt/20230415/03/mdt_result.zip
# ...
# -rw-r--r--. 1 root root 46701292 Jul  3 02:57 /var/opt/common5/mdt/20230702/21/mdt_result.zip
# -rw-r--r--. 1 root root 789265987 Jul  3 03:47 /var/opt/common5/mdt/20230702/21/ta_histogram.zip
# -rw-r--r--. 1 root root 1327778 Jul  3 03:48 /var/opt/common5/mdt/20230702/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 33319991 Jul  3 03:49 /var/opt/common5/mdt/20230702/22/ue_traffic.zip
# -rw-r--r--. 1 root root 67865614 Jul  3 03:51 /var/opt/common5/mdt/20230702/22/ue_meas.zip
# -rw-r--r--. 1 root root 42973502 Jul  3 03:54 /var/opt/common5/mdt/20230702/22/mdt_result.zip
# -rw-r--r--. 1 root root 753125616 Jul  3 04:38 /var/opt/common5/mdt/20230702/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1631299 Jul  3 04:48 /var/opt/common5/mdt/20230702/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 33676919 Jul  3 04:49 /var/opt/common5/mdt/20230702/23/ue_traffic.zip
# -rw-r--r--. 1 root root 67905617 Jul  3 04:51 /var/opt/common5/mdt/20230702/23/ue_meas.zip
# -rw-r--r--. 1 root root 43202218 Jul  3 04:54 /var/opt/common5/mdt/20230702/23/mdt_result.zip
# -rw-r--r--. 1 root root 789339827 Jul  3 05:40 /var/opt/common5/mdt/20230702/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4727608 Jul  3 11:13 /var/opt/common5/mdt/20230702/ue_capability_20230702.zip
# -rw-r--r--. 1 root root 33856598 Jul  3 11:27 /var/opt/common5/mdt/20230702/grid_mdt_cell_20230702.zip
# -rw-r--r--. 1 root root 55665864 Jul  3 11:35 /var/opt/common5/mdt/20230702/grid_mdt_traffic_cell_20230702.zip
# -rw-r--r--. 1 root root 87617351 Jul  3 11:48 /var/opt/common5/mdt/20230702/grid_mdt_meas_cell_20230702.zip
# -rw-r--r--. 1 root root 1762883 Jul  3 05:48 /var/opt/common5/mdt/20230703/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 30901885 Jul  3 05:50 /var/opt/common5/mdt/20230703/00/ue_traffic.zip
# -rw-r--r--. 1 root root 61710106 Jul  3 05:52 /var/opt/common5/mdt/20230703/00/ue_meas.zip
# -rw-r--r--. 1 root root 39398586 Jul  3 05:55 /var/opt/common5/mdt/20230703/00/mdt_result.zip
# -rw-r--r--. 1 root root 752728006 Jul  3 06:30 /var/opt/common5/mdt/20230703/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1751597 Jul  3 06:39 /var/opt/common5/mdt/20230703/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 25097148 Jul  3 06:42 /var/opt/common5/mdt/20230703/01/ue_traffic.zip
# -rw-r--r--. 1 root root 49539791 Jul  3 06:44 /var/opt/common5/mdt/20230703/01/ue_meas.zip
# -rw-r--r--. 1 root root 31425977 Jul  3 06:49 /var/opt/common5/mdt/20230703/01/mdt_result.zip
# -rw-r--r--. 1 root root 638012305 Jul  3 07:56 /var/opt/common5/mdt/20230703/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1714190 Jul  3 07:52 /var/opt/common5/mdt/20230703/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 21744984 Jul  3 07:55 /var/opt/common5/mdt/20230703/02/ue_traffic.zip
# -rw-r--r--. 1 root root 42517841 Jul  3 07:57 /var/opt/common5/mdt/20230703/02/ue_meas.zip
# -rw-r--r--. 1 root root 26507983 Jul  3 08:00 /var/opt/common5/mdt/20230703/02/mdt_result.zip
# -rw-r--r--. 1 root root 583767763 Jul  3 09:08 /var/opt/common5/mdt/20230703/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1418376 Jul  3 09:02 /var/opt/common5/mdt/20230703/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 17241950 Jul  3 09:05 /var/opt/common5/mdt/20230703/03/ue_traffic.zip
# -rw-r--r--. 1 root root 33418879 Jul  3 09:11 /var/opt/common5/mdt/20230703/03/ue_meas.zip
# -rw-r--r--. 1 root root 20684230 Jul  3 09:18 /var/opt/common5/mdt/20230703/03/mdt_result.zip
# -rw-r--r--. 1 root root 456944119 Jul  3 10:22 /var/opt/common5/mdt/20230703/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1158042 Jul  3 09:59 /var/opt/common5/mdt/20230703/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 14460554 Jul  3 10:02 /var/opt/common5/mdt/20230703/04/ue_traffic.zip
# -rw-r--r--. 1 root root 27950211 Jul  3 10:05 /var/opt/common5/mdt/20230703/04/ue_meas.zip
# -rw-r--r--. 1 root root 17335651 Jul  3 10:07 /var/opt/common5/mdt/20230703/04/mdt_result.zip
# -rw-r--r--. 1 root root 376246096 Jul  3 10:57 /var/opt/common5/mdt/20230703/04/ta_histogram.zip
# -rw-r--r--. 1 root root 967559 Jul  3 10:53 /var/opt/common5/mdt/20230703/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 15045102 Jul  3 10:56 /var/opt/common5/mdt/20230703/05/ue_traffic.zip
# -rw-r--r--. 1 root root 29518331 Jul  3 10:57 /var/opt/common5/mdt/20230703/05/ue_meas.zip
# -rw-r--r--. 1 root root 18853842 Jul  3 11:07 /var/opt/common5/mdt/20230703/05/mdt_result.zip
# -rw-r--r--. 1 root root 370809770 Jul  3 11:28 /var/opt/common5/mdt/20230703/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1401569 Jul  3 11:48 /var/opt/common5/mdt/20230703/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 31823889 Jul  3 11:49 /var/opt/common5/mdt/20230703/06/ue_traffic.zip
# -rw-r--r--. 1 root root 63660931 Jul  3 11:50 /var/opt/common5/mdt/20230703/06/ue_meas.zip
# -rw-r--r--. 1 root root 41503384 Jul  3 11:52 /var/opt/common5/mdt/20230703/06/mdt_result.zip
# -rw-r--r--. 1 root root 674937887 Jul  3 12:21 /var/opt/common5/mdt/20230703/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1521308 Jul  3 12:50 /var/opt/common5/mdt/20230703/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 45564178 Jul  3 12:53 /var/opt/common5/mdt/20230703/07/ue_traffic.zip
# -rw-r--r--. 1 root root 91181789 Jul  3 12:56 /var/opt/common5/mdt/20230703/07/ue_meas.zip
# -rw-r--r--. 1 root root 60625387 Jul  3 13:00 /var/opt/common5/mdt/20230703/07/mdt_result.zip
# -rw-r--r--. 1 root root 851764535 Jul  3 13:47 /var/opt/common5/mdt/20230703/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1330626 Jul  3 13:48 /var/opt/common5/mdt/20230703/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 41978910 Jul  3 13:49 /var/opt/common5/mdt/20230703/08/ue_traffic.zip
# -rw-r--r--. 1 root root 84778386 Jul  3 13:50 /var/opt/common5/mdt/20230703/08/ue_meas.zip
# -rw-r--r--. 1 root root 56033786 Jul  3 13:53 /var/opt/common5/mdt/20230703/08/mdt_result.zip
# -rw-r--r--. 1 root root 807633583 Jul  3 14:16 /var/opt/common5/mdt/20230703/08/ta_histogram.zip
# -rw-r--r--. 1 root root 1434417 Jul  3 15:51 /var/opt/common5/mdt/20230703/10/result_ue_cap.zip
# -rw-r--r--. 1 root root 46950228 Jul  3 15:53 /var/opt/common5/mdt/20230703/10/ue_traffic.zip
# -rw-r--r--. 1 root root 95410556 Jul  3 15:56 /var/opt/common5/mdt/20230703/10/ue_meas.zip
# -rw-r--r--. 1 root root 63111189 Jul  3 16:00 /var/opt/common5/mdt/20230703/10/mdt_result.zip
# -rw-r--r--. 1 root root 13532576927 Jul  3 16:42 /var/opt/common5/mdt/20230703/10/ta_histogram.csv
# -rw-r--r--. 1 root root 469688866 Jul  3 17:49 /var/opt/common5/mdt/20230703/10/ta_histogram.zip
# -rw-r--r--. 1 root root 993852 Jul  3 16:55 /var/opt/common5/mdt/20230703/11/result_ue_cap.zip
# -rw-r--r--. 1 root root 31510761 Jul  3 17:11 /var/opt/common5/mdt/20230703/11/ue_traffic.zip
# -rw-r--r--. 1 root root 1532196 Jul  4 01:49 /var/opt/common5/mdt/20230703/20/result_ue_cap.zip
# -rw-r--r--. 1 root root 49099832 Jul  4 01:50 /var/opt/common5/mdt/20230703/20/ue_traffic.zip
# -rw-r--r--. 1 root root 99814628 Jul  4 01:52 /var/opt/common5/mdt/20230703/20/ue_meas.zip
# -rw-r--r--. 1 root root 64157929 Jul  4 01:56 /var/opt/common5/mdt/20230703/20/mdt_result.zip
# -rw-r--r--. 1 root root 1034533497 Jul  4 03:55 /var/opt/common5/mdt/20230703/20/ta_histogram.zip
# -rw-r--r--. 1 root root 950410 Jul  4 02:52 /var/opt/common5/mdt/20230703/21/result_ue_cap.zip
# -rw-r--r--. 1 root root 27844610 Jul  4 02:54 /var/opt/common5/mdt/20230703/21/ue_traffic.zip
# -rw-r--r--. 1 root root 56748820 Jul  4 02:56 /var/opt/common5/mdt/20230703/21/ue_meas.zip
# -rw-r--r--. 1 root root 35853342 Jul  4 03:01 /var/opt/common5/mdt/20230703/21/mdt_result.zip
# -rw-r--r--. 1 root root 599500704 Jul  4 04:25 /var/opt/common5/mdt/20230703/21/ta_histogram.zip
# -rw-r--r--. 1 root root 680315 Jul  4 03:56 /var/opt/common5/mdt/20230703/22/result_ue_cap.zip
# -rw-r--r--. 1 root root 16716239 Jul  4 03:57 /var/opt/common5/mdt/20230703/22/ue_traffic.zip
# -rw-r--r--. 1 root root 34080392 Jul  4 03:58 /var/opt/common5/mdt/20230703/22/ue_meas.zip
# -rw-r--r--. 1 root root 21491238 Jul  4 04:00 /var/opt/common5/mdt/20230703/22/mdt_result.zip
# -rw-r--r--. 1 root root 377167622 Jul  4 04:24 /var/opt/common5/mdt/20230703/22/ta_histogram.zip
# -rw-r--r--. 1 root root 1269141 Jul  4 04:47 /var/opt/common5/mdt/20230703/23/result_ue_cap.zip
# -rw-r--r--. 1 root root 25735741 Jul  4 04:48 /var/opt/common5/mdt/20230703/23/ue_traffic.zip
# -rw-r--r--. 1 root root 51954379 Jul  4 04:50 /var/opt/common5/mdt/20230703/23/ue_meas.zip
# -rw-r--r--. 1 root root 33051807 Jul  4 04:52 /var/opt/common5/mdt/20230703/23/mdt_result.zip
# -rw-r--r--. 1 root root 606371728 Jul  4 05:21 /var/opt/common5/mdt/20230703/23/ta_histogram.zip
# -rw-r--r--. 1 root root 4627632 Jul  4 10:00 /var/opt/common5/mdt/20230703/ue_capability_20230703.zip
# -rw-r--r--. 1 root root 30857808 Jul  4 10:11 /var/opt/common5/mdt/20230703/grid_mdt_cell_20230703.zip
# -rw-r--r--. 1 root root 52770779 Jul  4 10:19 /var/opt/common5/mdt/20230703/grid_mdt_traffic_cell_20230703.zip
# -rw-r--r--. 1 root root 79957002 Jul  4 10:28 /var/opt/common5/mdt/20230703/grid_mdt_meas_cell_20230703.zip
# -rw-r--r--. 1 root root 1769713 Jul  4 05:43 /var/opt/common5/mdt/20230704/00/result_ue_cap.zip
# -rw-r--r--. 1 root root 31286210 Jul  4 05:44 /var/opt/common5/mdt/20230704/00/ue_traffic.zip
# -rw-r--r--. 1 root root 62398022 Jul  4 05:46 /var/opt/common5/mdt/20230704/00/ue_meas.zip
# -rw-r--r--. 1 root root 39964686 Jul  4 05:48 /var/opt/common5/mdt/20230704/00/mdt_result.zip
# -rw-r--r--. 1 root root 753076777 Jul  4 06:23 /var/opt/common5/mdt/20230704/00/ta_histogram.zip
# -rw-r--r--. 1 root root 1757227 Jul  4 06:32 /var/opt/common5/mdt/20230704/01/result_ue_cap.zip
# -rw-r--r--. 1 root root 25098785 Jul  4 06:35 /var/opt/common5/mdt/20230704/01/ue_traffic.zip
# -rw-r--r--. 1 root root 49496183 Jul  4 06:38 /var/opt/common5/mdt/20230704/01/ue_meas.zip
# -rw-r--r--. 1 root root 31624492 Jul  4 06:40 /var/opt/common5/mdt/20230704/01/mdt_result.zip
# -rw-r--r--. 1 root root 638443653 Jul  4 08:23 /var/opt/common5/mdt/20230704/01/ta_histogram.zip
# -rw-r--r--. 1 root root 1640269 Jul  4 07:51 /var/opt/common5/mdt/20230704/02/result_ue_cap.zip
# -rw-r--r--. 1 root root 20513800 Jul  4 07:54 /var/opt/common5/mdt/20230704/02/ue_traffic.zip
# -rw-r--r--. 1 root root 40077325 Jul  4 07:57 /var/opt/common5/mdt/20230704/02/ue_meas.zip
# -rw-r--r--. 1 root root 25133304 Jul  4 08:10 /var/opt/common5/mdt/20230704/02/mdt_result.zip
# -rw-r--r--. 1 root root 553093882 Jul  4 10:13 /var/opt/common5/mdt/20230704/02/ta_histogram.zip
# -rw-r--r--. 1 root root 1429514 Jul  4 08:50 /var/opt/common5/mdt/20230704/03/result_ue_cap.zip
# -rw-r--r--. 1 root root 16830427 Jul  4 08:52 /var/opt/common5/mdt/20230704/03/ue_traffic.zip
# -rw-r--r--. 1 root root 32588264 Jul  4 08:54 /var/opt/common5/mdt/20230704/03/ue_meas.zip
# -rw-r--r--. 1 root root 20202813 Jul  4 09:07 /var/opt/common5/mdt/20230704/03/mdt_result.zip
# -rw-r--r--. 1 root root 452775561 Jul  4 09:57 /var/opt/common5/mdt/20230704/03/ta_histogram.zip
# -rw-r--r--. 1 root root 1219760 Jul  4 09:54 /var/opt/common5/mdt/20230704/04/result_ue_cap.zip
# -rw-r--r--. 1 root root 15128182 Jul  4 09:58 /var/opt/common5/mdt/20230704/04/ue_traffic.zip
# -rw-r--r--. 1 root root 29178849 Jul  4 10:00 /var/opt/common5/mdt/20230704/04/ue_meas.zip
# -rw-r--r--. 1 root root 18264597 Jul  4 10:03 /var/opt/common5/mdt/20230704/04/mdt_result.zip
# -rw-r--r--. 1 root root 392541902 Jul  4 10:33 /var/opt/common5/mdt/20230704/04/ta_histogram.zip
# -rw-r--r--. 1 root root 1431602 Jul  4 10:50 /var/opt/common5/mdt/20230704/05/result_ue_cap.zip
# -rw-r--r--. 1 root root 22261558 Jul  4 10:52 /var/opt/common5/mdt/20230704/05/ue_traffic.zip
# -rw-r--r--. 1 root root 43573981 Jul  4 10:55 /var/opt/common5/mdt/20230704/05/ue_meas.zip
# -rw-r--r--. 1 root root 28038947 Jul  4 10:58 /var/opt/common5/mdt/20230704/05/mdt_result.zip
# -rw-r--r--. 1 root root 538410574 Jul  4 11:36 /var/opt/common5/mdt/20230704/05/ta_histogram.zip
# -rw-r--r--. 1 root root 1495199 Jul  4 11:51 /var/opt/common5/mdt/20230704/06/result_ue_cap.zip
# -rw-r--r--. 1 root root 33161021 Jul  4 11:53 /var/opt/common5/mdt/20230704/06/ue_traffic.zip
# -rw-r--r--. 1 root root 66230220 Jul  4 11:56 /var/opt/common5/mdt/20230704/06/ue_meas.zip
# -rw-r--r--. 1 root root 43337905 Jul  4 11:59 /var/opt/common5/mdt/20230704/06/mdt_result.zip
# -rw-r--r--. 1 root root 712405937 Jul  4 12:57 /var/opt/common5/mdt/20230704/06/ta_histogram.zip
# -rw-r--r--. 1 root root 1245715 Jul  4 12:52 /var/opt/common5/mdt/20230704/07/result_ue_cap.zip
# -rw-r--r--. 1 root root 35544413 Jul  4 12:54 /var/opt/common5/mdt/20230704/07/ue_traffic.zip
# -rw-r--r--. 1 root root 71061201 Jul  4 12:57 /var/opt/common5/mdt/20230704/07/ue_meas.zip
# -rw-r--r--. 1 root root 47083800 Jul  4 13:01 /var/opt/common5/mdt/20230704/07/mdt_result.zip
# -rw-r--r--. 1 root root 689639132 Jul  4 13:58 /var/opt/common5/mdt/20230704/07/ta_histogram.zip
# -rw-r--r--. 1 root root 1077445 Jul  4 13:52 /var/opt/common5/mdt/20230704/08/result_ue_cap.zip
# -rw-r--r--. 1 root root 33578974 Jul  4 13:54 /var/opt/common5/mdt/20230704/08/ue_traffic.zip
# -rw-r--r--. 1 root root 67719769 Jul  4 13:57 /var/opt/common5/mdt/20230704/08/ue_meas.zip
# -rw-r--r--. 1 root root 44977614 Jul  4 14:00 /var/opt/common5/mdt/20230704/08/mdt_result.zip
# -rw-r--r--. 1 root root 9268245609 Jul  4 14:31 /var/opt/common5/mdt/20230704/08/ta_histogram.csv
# -rw-r--r--. 1 root root 621437205 Jul  4 15:34 /var/opt/common5/mdt/20230704/08/ta_histogram.zip
# -rw-r--r--. 1 root root 983493 Jul  4 14:52 /var/opt/common5/mdt/20230704/09/result_ue_cap.zip
# -rw-r--r--. 1 root root 32319100 Jul  4 14:56 /var/opt/common5/mdt/20230704/09/ue_traffic.zip
# -rw-r--r--. 1 root root 65481178 Jul  4 14:59 /var/opt/common5/mdt/20230704/09/ue_meas.zip
# -rw-r--r--. 1 root root 6789 May  4 10:21 /var/opt/common5/mdt/20230303/filter_mdt_result.zip
# -rw-r--r--. 1 root root 10938 May  4 10:21 /var/opt/common5/mdt/20230303/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 18994 May  4 10:22 /var/opt/common5/mdt/20230303/filter_ue_meas.zip
# -rw-r--r--. 1 root root 49326031 May 12 15:02 /var/opt/common5/mdt/20230306/filter_mdt_result.zip
# -rw-r--r--. 1 root root 48858372 May 12 15:04 /var/opt/common5/mdt/20230306/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 99021326 May 12 15:05 /var/opt/common5/mdt/20230306/filter_ue_meas.zip
# -rw-r--r--. 1 root root 2906043 May 11 13:10 /var/opt/common5/mdt/20230306/ue_capability_20230306.zip
# -rw-r--r--. 1 root root 13469290 May 11 13:14 /var/opt/common5/mdt/20230306/grid_mdt_cell_20230306.zip
# -rw-r--r--. 1 root root 21136909 May 11 13:17 /var/opt/common5/mdt/20230306/grid_mdt_traffic_cell_20230306.zip
# -rw-r--r--. 1 root root 34995149 May 11 13:19 /var/opt/common5/mdt/20230306/grid_mdt_meas_cell_20230306.zip
# -rw-r--r--. 1 root root 86767 May  8 09:25 /var/opt/common5/mdt/20230308/filter_mdt_result.zip
# -rw-r--r--. 1 root root 106235 May  8 09:25 /var/opt/common5/mdt/20230308/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 219032 May  8 09:29 /var/opt/common5/mdt/20230308/filter_ue_meas.zip
# -rw-r--r--. 1 root root 24554497 May 12 15:06 /var/opt/common5/mdt/20230309/filter_mdt_result.zip
# -rw-r--r--. 1 root root 25013186 May 12 15:07 /var/opt/common5/mdt/20230309/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 50167452 May 12 15:08 /var/opt/common5/mdt/20230309/filter_ue_meas.zip
# -rw-r--r--. 1 root root 98788363 May 15 12:57 /var/opt/common5/mdt/20230311/filter_mdt_result.zip
# -rw-r--r--. 1 root root 96647390 May 15 12:58 /var/opt/common5/mdt/20230311/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 196556512 May 15 13:01 /var/opt/common5/mdt/20230311/filter_ue_meas.zip
# -rw-r--r--. 1 root root 77951 May  8 09:16 /var/opt/common5/mdt/20230312/filter_mdt_result.zip
# -rw-r--r--. 1 root root 87906 May  8 09:17 /var/opt/common5/mdt/20230312/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 173159 May  8 09:17 /var/opt/common5/mdt/20230312/filter_ue_meas.zip
# -rw-r--r--. 1 root root 26918495 May 24 11:08 /var/opt/common5/mdt/20230313/filter_mdt_result.zip
# -rw-r--r--. 1 root root 27640733 May 24 11:10 /var/opt/common5/mdt/20230313/filter_ue_traffic.zip
# -rw-r--r--. 1 root root 56333988 May 24 11:20 /var/opt/common5/mdt/20230313/filter_ue_meas.zip
# (base) [root@pmt-xl-2 ~]#

# %%
test1 = re.split(r'\s+|\n', raw)

# %%
# Create list comprehension to filter list of zip files only

# result = [file for file in test1 if file.endswith('.zip')]

# Create list comprehension to filter only mdt_result.zip only
# Option are ue_traffic or mdt_result

pattern = r'.*/(?!filter_)[^/]+/mdt_result\.zip$'
result = [path for path in test1 if re.match(pattern, path)]

# %%
# Create list comprehension to generate weekend dates in June

weekend_dates = [date.strftime("%Y%m%d") for date in (datetime.date(2023, 6, day) for day in range(1, 31)) 
                 if date.weekday() >= 5]

# Create list comprehension to generate continous dates in June (from 25 June until 30 June)
# continous_dates = re.compile(r'/var/opt/common5/mdt/202306(2[5-9]|30)/\d{2}/mdt_result\.zip')
# continous_dates = re.compile(r'/var/opt/common5/mdt/202306(0[1-8])/\d{2}/mdt_result\.zip')

# %%
# Create list comprehension to filter June Month only
# result = [path for path in result if '202306' in path]

# Create list comprehension to filter Out Some Date
# result = [path for path in result if '20230601' not in path and '20230602' not in path] 

# Create list comprehension to filter out continous dates
# result = [path for path in result if not continous_dates.search(path)]

# Create list comprehension to filter Out Weekend Date
# result = [path for path in result if path.split('/')[5] not in weekend_dates]

# Create list comprehension to filter Busy Hour only
# result = [path for path in result if '/07/' in path or '/08/' in path or '/09/' in path or '/17/' in path or '/18/' in path or '/19/' in path]

# Create list comprehension to filter Busy Hour only
# result = [path for path in result if '/11/' in path or '/12/' in path or '/13/' in path]

# result = [path for path in result if '/07/' in path or '/08/' in path or '/09/']

result.sort()

# %%
with open(r'/home/nivag/location_to_dl_8008-mdt-polygon.txt', 'w') as fp:
    fp.write('\n'.join(result))
