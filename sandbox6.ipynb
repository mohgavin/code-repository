# %%
import requests

# %%
test = requests.get('https://www.google.com')

# %%
test.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="id"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2023/googles-25th-birthday-6753651837110114.2-law.gif" itemprop="image"><meta content="Ulang Tahun Ke-25 Google" property="twitter:title"><meta content="Ulang tahun ke-25 Google #GoogleDoodle" property="twitter:description"><meta content="Ulang tahun ke-25 Google #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2023/googles-25th-birthday-6753651837110114-2xa.gif" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2023/googles-25th-birthday-6753651837110114-2xa.gif" property="og:image"><meta content="1150" property="og:image:width"><meta content="460" property="og:image:height"><meta content="https://www.google.com/logos/
# ...
