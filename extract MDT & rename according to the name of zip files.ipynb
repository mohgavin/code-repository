# %%
import os
import zipfile

for files in os.listdir('/home/nivag/2023 - Linux/ENM1-compile'):
    print(files)
    fullpath = os.path.join('/home/nivag/2023 - Linux/ENM1-compile', files)

    # Extract the zip file
    with zipfile.ZipFile(fullpath, 'r') as zip_ref:
        zip_ref.extractall('/home/nivag/2023 - Linux/Compile-Files')

    # Get the name of the zip file without the extension
    zip_name = os.path.splitext(files)[0]
    zip_name = zip_name.replace('_mdt_result', '')

    # Rename the extracted file
    extracted_file = os.path.join('/home/nivag/2023 - Linux/Compile-Files', "mdt_result.csv")
    new_file_name = os.path.join('/home/nivag/2023 - Linux/Compile-Files', f"mdt_result_{zip_name}.csv")
    os.rename(extracted_file, new_file_name)
# Out:
# 20230515_00_mdt_result.zip
# 20230518_23_mdt_result.zip
# 20230513_22_mdt_result.zip
# 20230521_13_mdt_result.zip
# 20230518_03_mdt_result.zip
# 20230524_22_mdt_result.zip
# 20230516_00_mdt_result.zip
# 20230519_09_mdt_result.zip
# 20230518_09_mdt_result.zip
# 20230516_13_mdt_result.zip
# 20230523_20_mdt_result.zip
# 20230519_02_mdt_result.zip
# 20230525_01_mdt_result.zip
# 20230517_10_mdt_result.zip
# 20230515_11_mdt_result.zip
# 20230524_11_mdt_result.zip
# 20230523_12_mdt_result.zip
# 20230524_03_mdt_result.zip
# 20230522_00_mdt_result.zip
# 20230515_04_mdt_result.zip
# 20230521_08_mdt_result.zip
# 20230515_07_mdt_result.zip
# 20230516_01_mdt_result.zip
# 20230519_14_mdt_result.zip
# 20230515_20_mdt_result.zip
# 20230514_08_mdt_result.zip
# 20230513_10_mdt_result.zip
# 20230519_05_mdt_result.zip
# 20230517_11_mdt_result.zip
# 20230513_05_mdt_result.zip
# 20230515_22_mdt_result.zip
# 20230518_00_mdt_result.zip
# 20230521_04_mdt_result.zip
# 20230513_17_mdt_result.zip
# 20230513_12_mdt_result.zip
# 20230521_02_mdt_result.zip
# 20230513_03_mdt_result.zip
# 20230522_23_mdt_result.zip
# 20230519_21_mdt_result.zip
# 20230523_03_mdt_result.zip
# 20230523_09_mdt_result.zip
# 20230516_21_mdt_result.zip
# 20230513_09_mdt_result.zip
# 20230524_08_mdt_result.zip
# 20230521_06_mdt_result.zip
# 20230521_12_mdt_result.zip
# 20230516_05_mdt_result.zip
# 20230520_01_mdt_result.zip
# 20230519_04_mdt_result.zip
# 20230525_03_mdt_result.zip
# 20230525_09_mdt_result.zip
# 20230516_11_mdt_result.zip
# 20230521_23_mdt_result.zip
# 20230524_23_mdt_result.zip
# 20230514_05_mdt_result.zip
# 20230517_02_mdt_result.zip
# 20230513_19_mdt_result.zip
# 20230514_13_mdt_result.zip
# 20230524_06_mdt_result.zip
# 20230521_05_mdt_result.zip
# 20230521_11_mdt_result.zip
# 20230517_20_mdt_result.zip
# 20230525_02_mdt_result.zip
# 20230513_18_mdt_result.zip
# 20230518_22_mdt_result.zip
# 20230515_02_mdt_result.zip
# 20230521_01_mdt_result.zip
# 20230516_10_mdt_result.zip
# 20230521_21_mdt_result.zip
# 20230517_07_mdt_result.zip
# 20230518_06_mdt_result.zip
# 20230517_23_mdt_result.zip
# 20230525_04_mdt_result.zip
# 20230515_01_mdt_result.zip
# 20230513_08_mdt_result.zip
# 20230522_01_mdt_result.zip
# 20230522_20_mdt_result.zip
# 20230520_06_mdt_result.zip
# 20230524_02_mdt_result.zip
# 20230517_08_mdt_result.zip
# 20230515_08_mdt_result.zip
# 20230517_01_mdt_result.zip
# 20230514_10_mdt_result.zip
# 20230513_21_mdt_result.zip
# 20230520_05_mdt_result.zip
# 20230525_06_mdt_result.zip
# 20230514_11_mdt_result.zip
# 20230513_07_mdt_result.zip
# 20230519_13_mdt_result.zip
# 20230515_06_mdt_result.zip
# 20230516_03_mdt_result.zip
# 20230516_14_mdt_result.zip
# 20230521_20_mdt_result.zip
# 20230519_18_mdt_result.zip
# 20230524_04_mdt_result.zip
# 20230525_07_mdt_result.zip
# 20230518_20_mdt_result.zip
# 20230514_09_mdt_result.zip
# 20230519_00_mdt_result.zip
# 20230520_07_mdt_result.zip
# 20230521_18_mdt_result.zip
# 20230519_22_mdt_result.zip
# 20230524_01_mdt_result.zip
# 20230516_15_mdt_result.zip
# 20230524_00_mdt_result.zip
# 20230519_06_mdt_result.zip
# 20230517_09_mdt_result.zip
# 20230514_21_mdt_result.zip
# 20230513_23_mdt_result.zip
# 20230523_05_mdt_result.zip
# 20230523_01_mdt_result.zip
# 20230522_03_mdt_result.zip
# 20230517_00_mdt_result.zip
# 20230525_00_mdt_result.zip
# 20230524_07_mdt_result.zip
# 20230514_06_mdt_result.zip
# 20230521_03_mdt_result.zip
# 20230513_06_mdt_result.zip
# 20230521_00_mdt_result.zip
# 20230515_10_mdt_result.zip
# 20230518_21_mdt_result.zip
# 20230521_09_mdt_result.zip
# 20230519_12_mdt_result.zip
# 20230517_03_mdt_result.zip
# 20230518_11_mdt_result.zip
# 20230514_01_mdt_result.zip
# 20230520_11_mdt_result.zip
# 20230514_20_mdt_result.zip
# 20230516_06_mdt_result.zip
# 20230523_11_mdt_result.zip
# 20230514_00_mdt_result.zip
# 20230520_02_mdt_result.zip
# 20230516_18_mdt_result.zip
# 20230516_12_mdt_result.zip
# 20230521_22_mdt_result.zip
# 20230525_10_mdt_result.zip
# 20230520_23_mdt_result.zip
# 20230515_23_mdt_result.zip
# 20230522_02_mdt_result.zip
# 20230520_22_mdt_result.zip
# 20230522_05_mdt_result.zip
# 20230513_13_mdt_result.zip
# 20230523_00_mdt_result.zip
# 20230516_19_mdt_result.zip
# 20230514_03_mdt_result.zip
# 20230517_21_mdt_result.zip
# 20230520_10_mdt_result.zip
# 20230524_21_mdt_result.zip
# 20230516_07_mdt_result.zip
# 20230515_21_mdt_result.zip
# 20230523_18_mdt_result.zip
# 20230516_23_mdt_result.zip
# 20230517_12_mdt_result.zip
# 20230518_01_mdt_result.zip
# 20230518_07_mdt_result.zip
# 20230519_03_mdt_result.zip
# 20230522_04_mdt_result.zip
# 20230524_05_mdt_result.zip
# 20230519_23_mdt_result.zip
# 20230515_05_mdt_result.zip
# 20230516_09_mdt_result.zip
# 20230518_10_mdt_result.zip
# 20230522_07_mdt_result.zip
# 20230517_22_mdt_result.zip
# 20230516_20_mdt_result.zip
# 20230523_07_mdt_result.zip
# 20230515_03_mdt_result.zip
# 20230514_18_mdt_result.zip
# 20230523_10_mdt_result.zip
# 20230523_21_mdt_result.zip
# 20230519_07_mdt_result.zip
# 20230514_23_mdt_result.zip
# 20230519_08_mdt_result.zip
# 20230513_02_mdt_result.zip
# 20230523_06_mdt_result.zip
# 20230522_09_mdt_result.zip
# 20230513_11_mdt_result.zip
# 20230520_09_mdt_result.zip
# 20230517_05_mdt_result.zip
# 20230516_02_mdt_result.zip
# 20230522_21_mdt_result.zip
# 20230516_08_mdt_result.zip
# 20230522_06_mdt_result.zip
# 20230524_10_mdt_result.zip
# 20230522_22_mdt_result.zip
# 20230525_11_mdt_result.zip
# 20230520_00_mdt_result.zip
# 20230517_04_mdt_result.zip
# 20230524_20_mdt_result.zip
# 20230520_20_mdt_result.zip
# 20230523_23_mdt_result.zip
# 20230519_20_mdt_result.zip
# 20230514_02_mdt_result.zip
# 20230523_13_mdt_result.zip
# 20230516_04_mdt_result.zip
# 20230523_02_mdt_result.zip
# 20230525_12_mdt_result.zip
# 20230513_00_mdt_result.zip
# 20230519_01_mdt_result.zip
# 20230515_09_mdt_result.zip
# 20230520_21_mdt_result.zip
# 20230518_05_mdt_result.zip
# 20230514_04_mdt_result.zip
# 20230520_04_mdt_result.zip
# 20230518_08_mdt_result.zip
# 20230522_10_mdt_result.zip
# 20230523_22_mdt_result.zip
# 20230518_02_mdt_result.zip
# 20230519_10_mdt_result.zip
# 20230518_12_mdt_result.zip
# 20230516_22_mdt_result.zip
# 20230520_03_mdt_result.zip
# 20230514_12_mdt_result.zip
# 20230514_07_mdt_result.zip
# 20230523_08_mdt_result.zip
# 20230521_10_mdt_result.zip
# 20230525_05_mdt_result.zip
# 20230517_13_mdt_result.zip
# 20230513_15_mdt_result.zip
# 20230519_11_mdt_result.zip
# 20230517_06_mdt_result.zip
# 20230513_16_mdt_result.zip
# 20230522_08_mdt_result.zip
# 20230524_09_mdt_result.zip
# 20230520_08_mdt_result.zip
# 20230513_01_mdt_result.zip
# 20230518_04_mdt_result.zip
# 20230523_04_mdt_result.zip
# 20230514_22_mdt_result.zip
# 20230513_14_mdt_result.zip
# 20230513_20_mdt_result.zip
# 20230525_08_mdt_result.zip
